# %% [markdown]
# # ⚡ Конкурентни работни процеси с Microsoft Foundry (Python)
#
# ## 📋 Напреднал урок за паралелна обработка
#
# Тази тетрадка демонстрира **конкурентни модели на работни процеси** с помощта на Microsoft Agent Framework. Ще научите как да изграждате високо производителни, паралелни работни процеси, при които множество AI агенти изпълняват едновременно, значително подобрявайки пропускателната способност и позволявайки сложни многоредови бизнес процеси.
#
# > **Бележка за миграция:** Този пример преди се позоваваше на GitHub Models. GitHub Models е остарял (с пенсиониране през юли 2026 г.), затова сега използва **Microsoft Foundry** чрез `FoundryChatClient`, който се насочва към Azure OpenAI **Responses API**.
#
# ## 🎯 Учебни цели
#
# ### 🚀 **Основи на конкурентната обработка**
# - **Паралелно изпълнение на агенти**: Стартирайте множество агенти едновременно за максимална ефективност
# - **Оркестрация на работния процес**: Координирайте конкурентни операции, като същевременно поддържате последователност на данните
# - **Оптимизация на производителността**: Постигнете значително ускорение чрез паралелна обработка
# - **Управление на ресурсите**: Ефективно използване на ресурсите на AI моделите при конкурентни операции
#
# ### 🏗️ **Напреднали модели на конкурентност**
# - **Fork-Join обработка**: Разпределяне на работата между множество агенти и сливане на резултатите
# - **Паралелизъм в конвейера**: Наслагващи се етапи на изпълнение за непрекъснато пропускане
# - **Баланс на товара**: Равномерно разпределяне на работа между наличните ресурси на агенти
# - **Синхронизационни точки**: Координиране на конкурентни агенти на критични етапи от работния процес
#
# ### 🏢 **Корпоративни конкурентни приложения**
# - **Обработка на голям обем документи**: Обработвайте множество документи едновременно
# - **Анализ на съдържание в реално време**: Конкурентен анализ на входящи потоци от данни
# - **Оптимизация на пакетна обработка**: Максимизирайте пропускателната способност за операции в голям мащаб
# - **Мултимодален анализ**: Паралелна обработка на различни типове съдържание (текст, изображения, данни)
#
# ## ⚙️ Предварителни изисквания и настройка
#
# ### 📦 **Необходими зависимости**
#
# Инсталирайте Agent Framework с възможности за конкурентни работни процеси:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Конфигурация на Microsoft Foundry**
#
# Влезте чрез Azure CLI (`az login`), за да може `AzureCliCredential` да се удостоверява, след което задайте детайлите на вашия проект в Microsoft Foundry.
#
# **Настройка на средата (.env файл):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Съображения за конкурентната обработка:**
# - **Ограничения на скоростта**: Наблюдавайте ограниченията на скоростта в Azure OpenAI за конкурентни заявки
# - **Използване на ресурси**: Обмислете използването на памет и CPU при множество конкурентни агенти
# - **Обработка на грешки**: Прилагайте стабилно възстановяване от грешки за паралелни операции
#
# ### 🏗️ **Архитектура на конкурентните работни процеси**
#
# ```mermaid
# graph TD
#     A[Започване на работния процес] --> B[Паралелно изпълнение]
#     B --> C[Агентски пул 1]
#     B --> D[Агентски пул 2]
#     B --> E[Агентски пул 3]
#     C --> F[Агрегиране на резултати]
#     D --> F
#     E --> F
#     F --> G[Краен изход]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Основни предимства:**
# - **⚡ Производителност**: Значително ускорение чрез паралелно изпълнение
# - **📈 Мащабируемост**: Обработка на увеличен обем работа без пропорционално увеличение на времето
# - **🔄 Ефективност**: По-добро използване на наличните изчислителни ресурси
# - **🎯 Пропускателна способност**: Обработвайте повече работа за същото време
#
# ## 🎨 **Модели за проектиране на конкурентни работни процеси**
#
# ### 🔍 **Конвейер за изследване и анализ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Работен процес за обработка на данни**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Конвейер за създаване на съдържание**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Многоетапна обработка**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Корпоративни ползи от производителността**
#
# ### ⚡ **Оптимизация на пропускателната способност**
# - **Паралелно изпълнение**: Множество агенти, работещи едновременно
# - **Използване на ресурси**: Максимална ефективност на наличния капацитет на AI модела
# - **Намаляване на времето**: Значително съкращаване на общото време за обработка
# - **Мащабируема архитектура**: Лесно добавяне на повече конкурентни агенти при необходимост
#
# ### 🛡️ **Надеждност и устойчивост**
# - **Устойчивост на грешки**: Неуспехите на отделни агенти не спират целия работен процес
# - **Изолиране на грешки**: Проблемите в един конкурентен клон не влияят на другите
# - **Грациозно деградиране**: Системата продължава да работи дори с намален капацитет на агенти
# - **Механизми за възстановяване**: Автоматично повторение и обработка на грешки при неуспешни операции
#
# ### 📊 **Мониторинг и наблюдаемост**
# - **Проследяване на конкурентно изпълнение**: Следете напредъка на всички паралелни операции
# - **Метрики за производителност**: Измервайте ускорението и придобивките в ефективността
# - **Анализи на ползването на ресурси**: Оптимизирайте разпределението на конкурентните агенти
# - **Идентифициране на тесни места**: Открийте и разрешете ограниченията на производителността
#
# Нека изградим високо производителни конкурентни AI работни процеси! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI преводачески услуга [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за каквито и да е недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
