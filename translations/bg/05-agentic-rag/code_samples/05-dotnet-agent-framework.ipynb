# %% [markdown]
# # 🔍 Enterprise RAG с Microsoft Foundry (.NET)
#
# ## 📋 Обучителни цели
#
# Този тетрадка показва как да изградите системи за възстановяване и допълнително генериране на информация (RAG) на корпоративно ниво, използвайки Microsoft Agent Framework в .NET с Microsoft Foundry. Ще научите как да създавате агенти, готови за продукция, които могат да търсят в документи и да предоставят точни, контекстуално осъзнати отговори с корпоративна сигурност и мащабируемост.
#
# **Възможности на Enterprise RAG, които ще изградите:**
# - 📚 **Документен интелект**: Разширена обработка на документи с Azure AI услуги
# - 🔍 **Семантично търсене**: Високопроизводително векторно търсене с корпоративни функции
# - 🛡️ **Интеграция на сигурността**: Достъп на базата на роли и модели за защита на данните
# - 🏢 **Мащабируема архитектура**: Системи RAG готови за продукция с мониторинг
#
# ## 🎯 Архитектура на Enterprise RAG
#
# ### Основни корпоративни компоненти
# - **Microsoft Foundry**: Управлявана корпоративна AI платформа със сигурност и съответствие
# - **Постоянни агенти**: Състояние на агентите с история на разговорите и управление на контекста
# - **Управление на векторно хранилище**: Индексиране и възстановяване на документи на корпоративно ниво
# - **Интеграция на идентичността**: Удостоверяване с Azure AD и контрол на достъпа базиран на роли
#
# ### Предимства на .NET за корпорации
# - **Типова безопасност**: Проверка по време на компилация за операции и структури на данни на RAG
# - **Асинхронна производителност**: Обработка и търсене на документи без блокиране
# - **Управление на паметта**: Ефективно използване на ресурси за големи колекции от документи
# - **Интеграционни модели**: Родна интеграция с Azure услуги чрез dependency injection
#
# ## 🏗️ Техническа архитектура
#
# ### Enterprise RAG Pipeline
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Основни .NET компоненти
# - **Azure.AI.Agents.Persistent**: Управление на корпоративни агенти с постоянство на състоянието
# - **Azure.Identity**: Интегрирано удостоверяване за сигурен достъп до Azure услуги
# - **Microsoft.Agents.AI.AzureAI**: Имплементация на агентска рамка оптимизирана за Azure
# - **System.Linq.Async**: Високопроизводителни асинхронни LINQ операции
#
# ## 🔧 Корпоративни функции и предимства
#
# ### Сигурност и съответствие
# - **Интеграция с Azure AD**: Управление на идентичност и удостоверяване на корпоративно ниво
# - **Достъп на базата на роли**: Прецизни права за достъп и операции с документи
# - **Защита на данните**: Криптиране в покой и при пренос за чувствителни документи
# - **Аудит логване**: Изчерпателно проследяване на дейността за изисквания за съответствие
#
# ### Производителност и мащабируемост
# - **Пул от връзки**: Ефективно управление на връзките с Azure услуги
# - **Асинхронна обработка**: Безблокиращи операции за сценарии с висок капацитет
# - **Стратегии за кеширане**: Интелигентно кеширане за често достъпвани документи
# - **Балансировка на натоварването**: Разпределена обработка за големи разгръщания
#
# ### Управление и мониторинг
# - **Проверки на здравословното състояние**: Вградени средства за мониторинг на RAG компоненти
# - **Метрики на производителността**: Подробна аналитика за качество на търсене и времена за отговор
# - **Обработка на грешки**: Изчерпателно управление на изключения с retry политики
# - **Управление на конфигурацията**: Настройки за специфични среди с валидация
#
# ## ⚙️ Предварителни изисквания и настройка
#
# **Среда за разработка:**
# - .NET 9.0 SDK или по-нова версия
# - Visual Studio 2022 или VS Code с разширение за C#
# - Абонамент за Azure с достъп до AI Foundry
#
# **Необходими NuGet пакети:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Настройка на удостоверяване в Azure:**
# ```bash
# # Инсталирайте Azure CLI и се удостоверете
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Конфигурация на средата (.env файл):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Enterprise RAG модели
#
# ### Модели за управление на документи
# - **Масово качване**: Ефективна обработка на големи колекции от документи
# - **Инкрементални актуализации**: Добавяне и модификация на документи в реално време
# - **Контрол на версиите**: Версиране и проследяване на промените в документи
# - **Управление на метаданни**: Богати атрибути и таксономия на документи
#
# ### Модели за търсене и възстановяване
# - **Хибридно търсене**: Комбиниране на семантично и ключово търсене за оптимални резултати
# - **Фасетно търсене**: Многоизмерно филтриране и категоризация
# - **Настройка на релевантността**: Персонализирани алгоритми за оценка според домейн специфични нужди
# - **Подреждане на резултатите**: Разширено класиране с интеграция на бизнес логика
#
# ### Модели за сигурност
# - **Сигурност на ниво документ**: Прецизен контрол на достъпа за всеки документ
# - **Класификация на данни**: Автоматично означаване и защита на чувствителността
# - **Аудитни пътеки**: Изчерпателно логване на всички RAG операции
# - **Защита на поверителността**: Откриване и заличаване на лични данни (PII)
#
# ## 🔒 Корпоративни функции за сигурност
#
# ### Удостоверяване и Авторизация
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Защита на данните
# - **Криптиране**: Край-към-край криптиране на документи и индекси за търсене
# - **Контроли за достъп**: Интеграция с Azure AD за потребителски и групови права
# - **Резиденция на данни**: Географски контрол на местоположението на данни за съответствие
# - **Архивиране и възстановяване**: Автоматизирани възможности за архивиране и възстановяване при бедствия
#
# ## 📈 Оптимизация на производителността
#
# ### Модели за асинхронна обработка
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управление на паметта
# - **Поточна обработка**: Работа с големи документи без проблеми с паметта
# - **Пул на ресурси**: Ефективно повторно използване на скъпи ресурси
# - **Събиране на боклук**: Оптимизирани модели за разпределение на паметта
# - **Управление на връзки**: Коректен жизнен цикъл на връзките към Azure услуги
#
# ### Стратегии за кеширане
# - **Кеширане на заявки**: Кеширане на често извършвани търсения
# - **Кеширане на документи**: Кеширане в паметта за активни документи
# - **Кеширане на индекси**: Оптимизирано кеширане на векторни индекси
# - **Кеширане на резултати**: Интелигентно кеширане на генерирани отговори
#
# ## 📊 Корпоративни случаи на използване
#
# ### Управление на знания
# - **Корпоративно уики**: Интелигентно търсене в базите знания на компанията
# - **Политики и процедури**: Автоматизирано съответствие и насоки за процедури
# - **Обучителни материали**: Интелигентна помощ за обучение и развитие
# - **Изследователски бази данни**: Системи за анализ на академични и научни документи
#
# ### Клиентска поддръжка
# - **База знания за поддръжка**: Автоматизирани отговори за клиентско обслужване
# - **Документация на продукти**: Интелигентно възстановяване на информация за продукти
# - **Ръководства за отстраняване на проблеми**: Контекстуална помощ при решаване на проблеми
# - **Системи за често задавани въпроси**: Динамично генериране на FAQ от колекции документи
#
# ### Регулаторно съответствие
# - **Анализ на правни документи**: Интелигентност за договори и правни документи
# - **Мониторинг на съответствието**: Автоматизирана проверка на регулаторни изисквания
# - **Оценка на рискове**: Анализ и докладване на рисковете на базата на документи
# - **Поддръжка на одити**: Интелигентно откриване на документи за одити
#
# ## 🚀 Продукционно разгръщане
#
# ### Мониторинг и наблюдение
# - **Application Insights**: Подробна телеметрия и мониторинг на производителността
# - **Персонализирани метрики**: Проследяване и предупреждение за бизнес-специфични KPI
# - **Разпределено трасериране**: Пълен проследяващ поток на заявки през услуги
# - **Табла за здравословно състояние**: Визуализация в реално време на здравето и производителността на системата
#
# ### Мащабируемост и надеждност
# - **Автоматично мащабиране**: Автоматично адаптиране спрямо натоварване и метрики за производителност
# - **Висока наличност**: Много регионално разгръщане с възможности за failover
# - **Тестване на натоварване**: Валидация на производителността при корпоративни натоварвания
# - **Възстановяване при бедствия**: Автоматизирани процедури за архивиране и възстановяване
#
# Готови ли сте да изградите корпоративни RAG системи, които да обработват чувствителни документи в мащаб? Нека проектираме интелигентни системи за управление на знания за корпорации! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI преводачески услуга [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за каквито и да е недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
