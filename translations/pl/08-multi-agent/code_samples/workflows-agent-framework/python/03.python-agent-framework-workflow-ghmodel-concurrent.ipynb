# %% [markdown]
# # ⚡ Współbieżne przepływy pracy agentów z Microsoft Foundry (Python)
#
# ## 📋 Zaawansowany samouczek przetwarzania równoległego
#
# Ten notatnik demonstruje **wzorce współbieżnych przepływów pracy** przy użyciu Microsoft Agent Framework. Nauczysz się, jak budować wysokowydajne, równoległe przepływy pracy, w których wiele agentów AI działa jednocześnie, znacznie poprawiając przepustowość i umożliwiając zaawansowane wielowątkowe procesy biznesowe.
#
# > **Nota dotycząca migracji:** Ten przykład wcześniej odwoływał się do GitHub Models. GitHub Models jest przestarzały (wycofanie w lipcu 2026), więc teraz korzysta z **Microsoft Foundry** przez `FoundryChatClient`, który korzysta z Azure OpenAI **Responses API**.
#
# ## 🎯 Cele nauki
#
# ### 🚀 **Podstawy przetwarzania współbieżnego**
# - **Równoczesne wykonywanie agentów**: Uruchamianie wielu agentów jednocześnie dla maksymalnej wydajności
# - **Orkiestracja przepływów pracy**: Koordynowanie współbieżnych operacji przy zachowaniu spójności danych
# - **Optymalizacja wydajności**: Osiągnięcie znacznego przyspieszenia dzięki przetwarzaniu równoległemu
# - **Zarządzanie zasobami**: Efektywne wykorzystanie zasobów modeli AI podczas współbieżnych operacji
#
# ### 🏗️ **Zaawansowane wzorce współbieżności**
# - **Przetwarzanie rozgałęzień i łączeń (Fork-Join)**: Dzielenie pracy między wielu agentów i scalanie wyników
# - **Równoległość potokowa**: Nakładające się etapy wykonania dla ciągłej przepustowości
# - **Równoważenie obciążenia**: Równomierne rozdzielanie pracy między dostępne zasoby agentów
# - **Punkty synchronizacji**: Koordynacja współbieżnych agentów na krytycznych etapach przepływu pracy
#
# ### 🏢 **Współbieżne zastosowania w przedsiębiorstwach**
# - **Przetwarzanie dużych ilości dokumentów**: Przetwarzanie wielu dokumentów jednocześnie
# - **Analiza zawartości w czasie rzeczywistym**: Współbieżna analiza napływających strumieni danych
# - **Optymalizacja przetwarzania wsadowego**: Maksymalizacja przepustowości dla operacji na dużą skalę
# - **Analiza multimodalna**: Równoległe przetwarzanie różnych rodzajów treści (tekst, obrazy, dane)
#
# ## ⚙️ Wymagania wstępne i konfiguracja
#
# ### 📦 **Wymagane zależności**
#
# Zainstaluj Agent Framework z funkcjami współbieżnych przepływów pracy:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfiguracja Microsoft Foundry**
#
# Zaloguj się za pomocą Azure CLI (`az login`), aby `AzureCliCredential` mógł uwierzytelnić, a następnie ustaw szczegóły projektu Microsoft Foundry.
#
# **Konfiguracja środowiska (plik .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Uwagi dotyczące przetwarzania współbieżnego:**
# - **Limity zapytań**: Monitoruj limity zapytań Azure OpenAI dla współbieżnych żądań
# - **Użycie zasobów**: Uwzględnij zużycie pamięci i CPU przy wielu współbieżnych agentach
# - **Obsługa błędów**: Wdroż solidne mechanizmy odzyskiwania błędów dla operacji równoległych
#
# ### 🏗️ **Architektura współbieżnego przepływu pracy**
#
# ```mermaid
# graph TD
#     A[Rozpoczęcie przepływu pracy] --> B[Wykonanie równoległe]
#     B --> C[Pulka agentów 1]
#     B --> D[Pulka agentów 2]
#     B --> E[Pulka agentów 3]
#     C --> F[Agregacja wyników]
#     D --> F
#     E --> F
#     F --> G[Końcowy wynik]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Kluczowe zalety:**
# - **⚡ Wydajność**: Znaczne przyspieszenie dzięki równoległemu wykonywaniu
# - **📈 Skalowalność**: Radzenie sobie ze zwiększonym obciążeniem bez proporcjonalnego wzrostu czasu
# - **🔄 Efektywność**: Lepsze wykorzystanie dostępnych zasobów obliczeniowych
# - **🎯 Przepustowość**: Przetwarzanie większej ilości pracy w tym samym czasie
#
# ## 🎨 **Wzorce projektowe współbieżnych przepływów pracy**
#
# ### 🔍 **Potok badań i analiz**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Przepływ przetwarzania danych**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Potok tworzenia treści**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Przetwarzanie wieloetapowe**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Korzyści wydajnościowe dla przedsiębiorstw**
#
# ### ⚡ **Optymalizacja przepustowości**
# - **Równoległe wykonywanie**: Wielu agentów działa jednocześnie
# - **Wykorzystanie zasobów**: Maksymalna efektywność dostępnej pojemności modeli AI
# - **Skrócenie czasu**: Znaczne zmniejszenie łącznego czasu przetwarzania
# - **Skalowalna architektura**: Łatwe dodawanie kolejnych współbieżnych agentów w razie potrzeby
#
# ### 🛡️ **Niezawodność i odporność**
# - **Tolerancja usterek**: Awaria pojedynczego agenta nie zatrzymuje całego przepływu pracy
# - **Izolacja błędów**: Problemy w jednej współbieżnej gałęzi nie wpływają na pozostałe
# - **Łagodna degradacja**: System kontynuuje działanie nawet przy zmniejszonej pojemności agentów
# - **Mechanizmy odzyskiwania**: Automatyczne ponawianie i obsługa błędów dla nieudanych operacji
#
# ### 📊 **Monitorowanie i obserwowalność**
# - **Śledzenie współbieżnego wykonania**: Monitorowanie postępu wszystkich operacji równoległych
# - **Metryki wydajności**: Pomiar przyspieszenia i zysków efektywności
# - **Analiza wykorzystania zasobów**: Optymalizacja przydziału współbieżnych agentów
# - **Identyfikacja wąskich gardeł**: Znajdowanie i rozwiązywanie ograniczeń wydajności
#
# Zbudujmy wysokowydajne, współbieżne przepływy pracy AI! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Zastrzeżenie**:
# Niniejszy dokument został przetłumaczony za pomocą usługi tłumaczenia AI [Co-op Translator](https://github.com/Azure/co-op-translator). Choć dążymy do dokładności, prosimy pamiętać, że automatyczne tłumaczenia mogą zawierać błędy lub niedokładności. Oryginalny dokument w jego języku źródłowym należy uznawać za autorytatywne źródło. W przypadku informacji krytycznych zalecane jest skorzystanie z profesjonalnego tłumaczenia wykonanego przez człowieka. Nie ponosimy odpowiedzialności za jakiekolwiek nieporozumienia lub błędne interpretacje wynikające z użycia tego tłumaczenia.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
