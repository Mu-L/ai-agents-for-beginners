# %% [markdown]
# # ⚡ Současné pracovní postupy agentů s Microsoft Foundry (Python)
#
# ## 📋 Pokročilý tutoriál paralelního zpracování
#
# Tento notebook demonstruje **vzory současných pracovních postupů** pomocí Microsoft Agent Framework. Naučíte se, jak vytvářet vysoce výkonné workflowy paralelního zpracování, kde více AI agentů provádí operace současně, což dramaticky zvyšuje propustnost a umožňuje sofistikované vícevláknové podnikové procesy.
#
# > **Poznámka k migraci:** Tento příklad dříve odkazoval na GitHub Models. GitHub Models je zastaralý (ukončení činnosti v červenci 2026), takže nyní používá **Microsoft Foundry** prostřednictvím `FoundryChatClient`, který cílí na Azure OpenAI **Responses API**.
#
# ## 🎯 Výukové cíle
#
# ### 🚀 **Základy současného zpracování**
# - **Paralelní spuštění agentů**: Spouštějte více agentů současně pro maximální efektivitu
# - **Orchestrace pracovních postupů**: Koordinujte současné operace při zachování konzistence dat
# - **Optimalizace výkonu**: Dosáhněte výrazného zrychlení pomocí paralelního zpracování
# - **Správa zdrojů**: Efektivně využívejte zdroje AI modelů napříč současnými operacemi
#
# ### 🏗️ **Pokročilé vzory současnosti**
# - **Fork-Join zpracování**: Rozdělte práci mezi více agentů a sloučte výsledky
# - **Pipeline paralelismus**: Překrývající se fáze vykonávání pro plynulý průchod
# - **Vyvažování zatížení**: Rovnoměrné rozdělení práce mezi dostupné agentní zdroje
# - **Synchronizační body**: Koordinujte současné agenty v klíčových fázích pracovního postupu
#
# ### 🏢 **Podnikové aplikace současnosti**
# - **Zpracování dokumentů ve velkém objemu**: Zpracovávejte více dokumentů současně
# - **Analýza obsahu v reálném čase**: Současná analýza příchozích datových toků
# - **Optimalizace zpracování hromadných úloh**: Maximalizujte propustnost pro rozsáhlé operace
# - **Více-modální analýza**: Paralelní zpracování různých typů obsahu (text, obrázky, data)
#
# ## ⚙️ Požadavky a nastavení
#
# ### 📦 **Vyžadované závislosti**
#
# Nainstalujte Agent Framework s podporou současných pracovních postupů:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfigurace Microsoft Foundry**
#
# Přihlaste se pomocí Azure CLI (`az login`), aby se mohl autentizovat `AzureCliCredential`, poté nastavte údaje projektu Microsoft Foundry.
#
# **Nastavení prostředí (soubor .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Úvahy o současném zpracování:**
# - **Limity rychlosti**: Sledujte limity rychlosti Azure OpenAI pro současné požadavky
# - **Využití zdrojů**: Zvažte využití paměti a CPU u více současných agentů
# - **Zpracování chyb**: Implementujte robustní zotavení z chyb u paralelních operací
#
# ### 🏗️ **Architektura současných pracovních postupů**
#
# ```mermaid
# graph TD
#     A[Začátek pracovního postupu] --> B[Současné spuštění]
#     B --> C[Sada agentů 1]
#     B --> D[Sada agentů 2]
#     B --> E[Sada agentů 3]
#     C --> F[Agregace výsledků]
#     D --> F
#     E --> F
#     F --> G[Konečný výstup]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Klíčové přínosy:**
# - **⚡ Výkon**: Významné zrychlení díky paralelnímu spouštění
# - **📈 Škálovatelnost**: Zvládněte zvýšené pracovní zatížení bez proporcionálního nárůstu času
# - **🔄 Efektivita**: Lepší využití dostupných výpočetních zdrojů
# - **🎯 Propustnost**: Zpracujte více práce ve stejném časovém úseku
#
# ## 🎨 **Vzorové návrhy současných pracovních postupů**
#
# ### 🔍 **Pipeline pro výzkum a analýzu**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Workflow pro zpracování dat**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline pro tvorbu obsahu**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Vícefázové zpracování**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Podnikové přínosy výkonu**
#
# ### ⚡ **Optimalizace propustnosti**
# - **Paralelní vykonávání**: Více agentů pracujících současně
# - **Využití zdrojů**: Maximální efektivita dostupné kapacity AI modelu
# - **Snížení času**: Výrazné zkrácení celkového doby zpracování
# - **Škálovatelná architektura**: Snadné přidání více současných agentů dle potřeby
#
# ### 🛡️ **Spolehlivost a odolnost**
# - **Odolnost vůči chybám**: Selhání jednotlivých agentů nezastaví celý workflow
# - **Izolace chyb**: Problémy v jedné souběžné větvi neovlivní ostatní
# - **Hladké degradace**: Systém pokračuje v provozu i se sníženou kapacitou agentů
# - **Mechanismy zotavení**: Automatické opakování a zpracování chyb u neúspěšných operací
#
# ### 📊 **Monitorování a pozorovatelnost**
# - **Sledování současného provádění**: Monitorujte průběh všech paralelních operací
# - **Výkonové metriky**: Měřte zrychlení a zisky efektivity
# - **Analýza využití zdrojů**: Optimalizujte alokaci agentů pro souběžnost
# - **Identifikace úzkých míst**: Najděte a vyřešte výkonnostní omezení
#
# Postavme vysoce výkonné současné AI workflowy! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Prohlášení o omezení odpovědnosti**:
# Tento dokument byl přeložen pomocí AI překladatelské služby [Co-op Translator](https://github.com/Azure/co-op-translator). Přestože usilujeme o co největší přesnost, mějte prosím na paměti, že automatizované překlady mohou obsahovat chyby nebo nepřesnosti. Originální dokument v jeho mateřském jazyce by měl být považován za autoritativní zdroj. Pro kritické informace se doporučuje profesionální lidský překlad. Nejsme odpovědní za jakékoli nedorozumění nebo nesprávné interpretace vzniklé použitím tohoto překladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
