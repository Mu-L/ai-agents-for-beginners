# %% [markdown]
# # ⚡ मायक्रोसॉफ्ट फाउंड्री सह समकालीन एजंट वर्कफ्लोज (Python)
#
# ## 📋 प्रगत समांतर प्रक्रिया ट्युटोरियल
#
# हा नोटबुक मायक्रोसॉफ्ट एजंट फ्रेमवर्क वापरून **समकालीन वर्कफ्लो पॅटर्न्स** दर्शवितो. येथे आपण असे वर्कफ्लोज तयार करायचे शिकाल जिथे अनेक AI एजंट्स एकाच वेळी कार्य करतात, ज्यामुळे थ्रूपुटमध्ये लक्षणीय सुधारणा होते आणि प्रगत मल्टी-थ्रेडेड व्यवसाय प्रक्रिया शक्य होतात.
#
# > **स्थानांतरण नोट:** या नमुन्याने पूर्वी GitHub मॉडेल्सचा संदर्भ दिला होता. GitHub मॉडेल्स अवसानावर आहेत (जुलै 2026 मध्ये बंद होणार), म्हणून आता ते `FoundryChatClient` द्वारे **Microsoft Foundry** वापरतात, जे Azure OpenAI च्या **Responses API** वर लक्ष केंद्रित करते.
#
# ## 🎯 शिकण्याचे उद्दिष्टे
#
# ### 🚀 **समकालीन प्रक्रिया मूलतत्त्वे**
# - **समांतर एजंट कार्यान्वयन**: जास्तीत जास्त कार्यक्षमतेसाठी अनेक एजंट एकाच वेळी चालवा
# - **वर्कफ्लो समन्वय**: डेटा सुसंगतता राखून समकालीन ऑपरेशन्स समन्वयित करा
# - **प्रदर्शन ऑप्टिमायझेशन**: समांतर प्रक्रियेने लक्षणीय वेगात वाढ करा
# - **संसाधन व्यवस्थापन**: समकालीन ऑपरेशनमधील AI मॉडेल संसाधने कार्यक्षमतेने वापरा
#
# ### 🏗️ **प्रगत समकालीन पॅटर्न्स**
# - **फोर्क-जॉइन प्रक्रिया**: अनेक एजंट्समध्ये कार्य विभाजित करा आणि निकाल एकत्र करा
# - **पाईपलाइन समांतरता**: सतत थ्रूपुटसाठी एकाचवेळी कार्यान्वयन टप्पे ओव्हरलॅप करा
# - **लोड बॅलन्सिंग**: उपलब्ध एजंट संसाधनांमध्ये कार्य समप्रमाणात वितरित करा
# - **सिन्क्रोनायझेशन पॉइंट्स**: महत्वाच्या वर्कफ्लो टप्प्यांवर समकालीन एजंट समन्वय करा
#
# ### 🏢 **एंटरप्राइझ समकालीन अनुप्रयोग**
# - **उच्च-आकाराचे दस्तऐवज प्रक्रिया**: एकाच वेळी अनेक दस्तऐवज प्रक्रिया करा
# - **रिअल-टाइम सामग्री विश्लेषण**: येणाऱ्या डेटा स्त्रोतांचे समकालीन विश्लेषण
# - **बॅच प्रक्रिया ऑप्टिमायझेशन**: मोठ्या प्रमाणावर ऑपरेशन्ससाठी थ्रूपुट वाढवा
# - **मल्टी-मोडल विश्लेषण**: वेगवेगळ्या सामग्री प्रकारांचे (माहिती, प्रतिमा, डेटा) समांतर प्रक्रिया
#
# ## ⚙️ आवश्यक गुणधर्म आणि सेटअप
#
# ### 📦 **आवश्यक अवलंबित्वे**
#
# समकालीन वर्कफ्लो क्षमता असलेले एजंट फ्रेमवर्क स्थापित करा:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **मायक्रोसॉफ्ट फाउंड्री कॉन्फिगरेशन**
#
# Azure CLI (`az login`) सोबत साइन इन करा जेणेकरून `AzureCliCredential` प्रमाणीकरण करू शकेल, नंतर आपले मायक्रोसॉफ्ट फाउंड्री प्रोजेक्ट तपशील सेट करा.
#
# **पर्यावरण सेटअप (.env फाइल):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **समकालीन प्रक्रियेसाठी विचार करावयाच्या बाबी:**
# - **रेट लिमिट्स**: समकालीन विनंत्यांसाठी Azure OpenAI च्या दरमर्यादा निरीक्षण करा
# - **संसाधन वापर**: अनेक समकालीन एजंट्ससह मेमरी आणि CPU वापर विचारात घ्या
# - **त्रुटी हाताळणी**: समांतर ऑपरेशन्ससाठी मजबूत त्रुटी पुनर्प्राप्ती कार्यान्वित करा
#
# ### 🏗️ **समकालीन वर्कफ्लो आर्किटेक्चर**
#
# ```mermaid
# graph TD
#     A[वर्कफ्लो सुरूवात] --> B[एकत्रित अंमलबजावणी]
#     B --> C[एजंट पूल 1]
#     B --> D[एजंट पूल 2]
#     B --> E[एजंट पूल 3]
#     C --> F[निकाल संकलन]
#     D --> F
#     E --> F
#     F --> G[अंतिम आऊटपुट]
#
#     H[मायक्रोसॉफ्ट फाउंड्री] --> C
#     H --> D
#     H --> E
# ```
#
# **मुख्य फायदे:**
# - **⚡ कार्यक्षमता**: समांतर कार्यान्वयनामुळे लक्षणीय गती वाढ
# - **📈 स्केलेबिलिटी**: प्रमाणानुसार वेळ वाढ न करता वाढत्या कामाचा हाताळणी
# - **🔄 कार्यक्षमतेत वाढ**: उपलब्ध संगणकीय संसाधनांचा अधिक चांगला वापर
# - **🎯 थ्रूपुट**: एकाच वेळेत अधिक कार्य प्रक्रिया करा
#
# ## 🎨 **समकालीन वर्कफ्लो डिझाइन पॅटर्न्स**
#
# ### 🔍 **संशोधन आणि विश्लेषण पाईपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रक्रिया वर्कफ्लो**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री निर्मिती पाईपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **मल्टी-स्टेज प्रक्रिया**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **एंटरप्राइझ कार्यक्षमता फायदे**
#
# ### ⚡ **थ्रूपुट ऑप्टिमायझेशन**
# - **समांतर कार्यान्वयन**: अनेक एजंट्स एकाच वेळी कार्यरत
# - **संसाधन वापर**: उपलब्ध AI मॉडेल क्षमतेचा जास्तीत जास्त कार्यक्षम वापर
# - **वेळ कपात**: एकूण प्रक्रियेसाठी लक्षणीय वेळ कपात
# - **स्केलेबल आर्किटेक्चर**: आवश्यकतेनुसार अधिक समकालीन एजंट सहज जोडा
#
# ### 🛡️ **विश्वसनीयता आणि लवचीकता**
# - **त्रुटी सहिष्णुता**: व्यक्तीगत एजंट अयशस्वी झाल्यासही वर्कफ्लो थांबत नाही
# - **त्रुटी विभाजन**: एका समकालीन शाखेतील समस्या इतरांवर परिणाम करत नाहीत
# - **सुसंवाद कमी होणे**: कमी एजंट क्षमतेमध्येही सिस्टम कार्यरत राहते
# - **पुनर्प्राप्ती यंत्रणा**: अयशस्वी ऑपरेशन्ससाठी आपोआप रीट्राय आणि त्रुटी हाताळणी
#
# ### 📊 **निरीक्षण आणि दृश्यता**
# - **समकालीन कार्यान्वयन ट्रॅकिंग**: सर्व समांतर ऑपरेशन्सची प्रगती निरीक्षण करा
# - **कार्यक्षमता मेट्रिक्स**: गती आणि कार्यक्षमतेचे मापन करा
# - **संसाधन वापर विश्लेषण**: समकालीन एजंट दर्शविण्याचे ऑप्टिमायझेशन
# - **बॉटलनेक ओळख**: कार्यक्षमता मर्यादा शोधा व सुधा करा
#
# चला उच्च कार्यक्षम समकालीन AI वर्कफ्लोज तयार करूया! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# हा दस्तऐवज AI भाषांतर सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) चा वापर करून अनुवादित केला आहे. जरी आम्ही अचूकतेसाठी प्रयत्न करतो, तरी कृपया लक्षात घ्या की स्वयंचलित भाषांतरांमध्ये त्रुटी किंवा अचूकतेची कमतरता असू शकते. मूळ दस्तऐवज त्याच्या मूळ भाषेत अधिकृत स्रोत मानला पाहिजे. महत्त्वाची माहिती असल्यास, व्यावसायिक मानवी भाषांतराची शिफारस केली जाते. या भाषांतराच्या वापरामुळे उद्भवणाऱ्या कोणत्याही गैरसमज किंवा चुकीच्या अर्थलावणीसाठी आम्ही जबाबदार नाही.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
