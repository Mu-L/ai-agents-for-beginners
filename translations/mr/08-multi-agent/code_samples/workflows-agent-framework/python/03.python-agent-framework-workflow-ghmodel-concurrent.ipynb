# %% [markdown]
# # ⚡ मायक्रोसॉफ्ट फाउंड्रीसह समांतर एजंट कार्यप्रवाह (पायथन)
#
# ## 📋 प्रगत समांतर प्रक्रिया प्रशिक्षण
#
# हा नोटबुक मायक्रोसॉफ्ट एजंट फ्रेमवर्क वापरून **समांतर कार्यप्रवाह नमुने** दाखवतो. तुम्ही शिकाल की कसे उच्च कार्यक्षमता, समांतर प्रक्रिया कार्यप्रवाह तयार करायचे जिथे अनेक AI एजंट एकाच वेळी कार्यान्वित होतात, ज्यामुळे थ्रूपुटमध्ये लक्षणीय सुधारणा होते आणि प्रगत मल्टी-थ्रेडेड बिझनेस प्रक्रिया सक्षम होतात.
#
# > **मायग्रेशन नोट:** हा नमुना पूर्वी GitHub मॉडेल्सचा संदर्भ देत होता. GitHub मॉडेल्स बंद होत आहेत (जुलै 2026 मध्ये), त्यामुळे आता तो `FoundryChatClient` द्वारे **मायक्रोसॉफ्ट फाउंड्री** वापरतो, जो Azure OpenAI च्या **Responses API** वर लक्ष केंद्रित करतो.
#
# ## 🎯 शिक्षण उद्दिष्टे
#
# ### 🚀 **समांतर प्रक्रिया मुळतत्त्वे**
# - **समांतर एजंट कार्यान्वयन**: जास्तीत जास्त कार्यक्षमता साठी अनेक एजंट्स एकाच वेळी चालवा
# - **कार्यप्रवाह समन्वय**: डेटा सुसंगतता राखत समांतर ऑपरेशन्स समन्वयित करा
# - **कार्यक्षमता ऑप्टिमायझेशन**: समांतर प्रक्रियेमुळे लक्षणीय वेग वाढवा
# - **संसाधन व्यवस्थापन**: समांतर ऑपरेशन्समध्ये AI मॉडेल संसाधने कार्यक्षमतेने वापरा
#
# ### 🏗️ **प्रगत समांतर नमुने**
# - **फोर्क-जॉइन प्रक्रिया**: काम अनेक एजंट्समध्ये विभागा आणि निकाल एकत्र करा
# - **पाइपलाइन समानांतरता**: सतत थ्रूपुटसाठी कार्यान्वयन टप्पे ओव्हरलॅप करा
# - **लोड संतुलन**: उपलब्ध एजंट संसाधनांमध्ये काम सम प्रमाणात वाटा
# - **सिंक्रोनायझेशन पॉइंट्स**: महत्त्वाच्या कार्यप्रवाह टप्प्यांवर समांतर एजंट्स समन्वयित करा
#
# ### 🏢 **एंटरप्राइझ समांतर अनुप्रयोग**
# - **उच्च-आकार दस्तऐवज प्रक्रिया**: अनेक दस्तऐवज एकाच वेळी प्रक्रिया करा
# - **रिअल-टाइम सामग्री विश्लेषण**: येणाऱ्या डेटा स्ट्रीमचे समांतर विश्लेषण करा
# - **बॅच प्रक्रिया सुधारणा**: मोठ्या प्रमाणावर ऑपरेशन्ससाठी थ्रूपुट जास्तीत जास्त करा
# - **मल्टी-मॉडल विश्लेषण**: वेगवेगळ्या सामग्री प्रकारांचे (मजकूर, प्रतिमा, डेटा) समांतर प्रक्रिया करा
#
# ## ⚙️ आवश्यक अटी व सेटअप
#
# ### 📦 **आवश्यक अवलंबित्व**
#
# समांतर कार्यप्रवाह क्षमता असलेला एजंट फ्रेमवर्क इन्स्टॉल करा:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **मायक्रोसॉफ्ट फाउंड्री कॉन्फिगरेशन**
#
# Azure CLI (`az login`) वापरून साइन इन करा कि `AzureCliCredential` प्रमाणीकरण करू शकेल, नंतर तुमचे मायक्रोसॉफ्ट फाउंड्री प्रोजेक्ट तपशील सेट करा.
#
# **पर्यावरण सेटअप (.env फाइल):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **समांतर प्रक्रिया विचारणा:**
# - **रेट लिमिट्स**: समांतर विनंत्यांसाठी Azure OpenAI च्या दर मर्यादेवर लक्ष ठेवा
# - **संसाधन वापर**: अनेक समांतर एजंट्ससोबत मेमरी व CPU वापर विचारात घ्या
# - **त्रुटी हाताळणी**: समांतर ऑपरेशन्ससाठी मजबूत त्रुटी पुनर्प्राप्ती अंमलात आणा
#
# ### 🏗️ **समांतर कार्यप्रवाह वास्तुकला**
#
# ```mermaid
# graph TD
#     A[कार्यप्रवाह सुरू] --> B[एकाच वेळी अंमलबजावणी]
#     B --> C[एजंट पूल 1]
#     B --> D[एजंट पूल 2]
#     B --> E[एजंट पूल 3]
#     C --> F[निकाल संकलन]
#     D --> F
#     E --> F
#     F --> G[अंतिम आउटपुट]
#
#     H[मायक्रोसॉफ्ट फाउंड्री] --> C
#     H --> D
#     H --> E
# ```
#
# **प्रमुख फायदे:**
# - **⚡ कार्यक्षमता**: समांतर कार्यान्वयनाद्वारे लक्षणीय वेग वाढ
# - **📈 स्केलेबिलिटी**: वेळेत प्रमाणबद्ध वाढ न करता अधिक काम हाताळा
# - **🔄 कार्यक्षमतेने वापर**: उपलब्ध संगणकीय संसाधने चांगल्या प्रकारे वापरा
# - **🎯 थ्रूपुट**: त्याच वेळी जास्त काम प्रक्रिया करा
#
# ## 🎨 **समांतर कार्यप्रवाह डिझाईन नमुने**
#
# ### 🔍 **संशोधन व विश्लेषण पाइपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रक्रिया कार्यप्रवाह**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री निर्मिती पाइपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **बहु-स्टेज प्रक्रिया**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **एंटरप्राइझ कार्यप्रदर्शन फायदे**
#
# ### ⚡ **थ्रूपुट ऑप्टिमायझेशन**
# - **समांतर कार्यान्वयन**: अनेक एजंट्स एकाच वेळी काम करत आहेत
# - **संसाधन वापर**: उपलब्ध AI मॉडेल क्षमतेचा जास्तीत जास्त कार्यक्षम वापर
# - **वेळ कपात**: एकूण प्रक्रिया वेळेत लक्षणीय घट
# - **स्केलेबल आर्किटेक्चर**: जसे गरज लागेल तसे अधिक समांतर एजंट्स सहज जोडा
#
# ### 🛡️ **विश्वसनीयता व दृढता**
# - **दोष सहनशीलता**: एका एजंटच्या अपयशामुळे संपूर्ण कार्यप्रवाह थांबत नाही
# - **त्रुटी पृथक्करण**: एका समांतर शाखेतील समस्या इतरांना प्रभावित करत नाहीत
# - **सोप्या प्रकारची ह्रास**: कमी एजंट क्षमता असूनही सिस्टम कार्यरत राहते
# - **पुनर्प्राप्ती यंत्रणा**: अयशस्वी ऑपरेशन्ससाठी स्वयंचलित पुनरावृत्ती व त्रुटी हाताळणी
#
# ### 📊 **मॉनिटरिंग व निरीक्षण**
# - **समांतर कार्यान्वयन ट्रॅकिंग**: सर्व समांतर ऑपरेशन्सची प्रगती पाहणे
# - **कार्यक्षमता मेट्रिक्स**: वेग वाढ व कार्यक्षमतेचे मापन
# - **संसाधन वापर विश्लेषण**: समांतर एजंट वाटप ऑप्टिमायझ करा
# - **बॉटलनेक ओळख**: कार्यक्षमतेच्या अडथळ्यांना शोधा व सोडा
#
# चला उच्च कार्यक्षमता समांतर AI कार्यप्रवाह तयार करूया! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# हा दस्तऐवज AI भाषांतर सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) चा वापर करून अनुवादित केला आहे. जरी आम्ही अचूकतेसाठी प्रयत्न करतो, तरी कृपया लक्षात घ्या की स्वयंचलित भाषांतरांमध्ये त्रुटी किंवा अचूकतेची कमतरता असू शकते. मूळ दस्तऐवज त्याच्या मूळ भाषेत अधिकृत स्रोत मानला पाहिजे. महत्त्वाची माहिती असल्यास, व्यावसायिक मानवी भाषांतराची शिफारस केली जाते. या भाषांतराच्या वापरामुळे उद्भवणाऱ्या कोणत्याही गैरसमज किंवा चुकीच्या अर्थलावणीसाठी आम्ही जबाबदार नाही.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
