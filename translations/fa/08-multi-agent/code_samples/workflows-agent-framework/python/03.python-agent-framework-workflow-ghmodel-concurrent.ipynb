# %% [markdown]
# # ⚡ جریان‌های کاری همزمان عامل‌ها با Microsoft Foundry (پایتون)
#
# ## 📋 آموزش پیشرفته پردازش موازی
#
# این دفترچه یادداشت الگوهای **جریان کاری همزمان** را با استفاده از چارچوب عامل مایکروسافت نشان می‌دهد. شما یاد خواهید گرفت چگونه جریان‌های کاری پردازش موازی با عملکرد بالا ایجاد کنید که در آن چندین عامل هوش مصنوعی به طور همزمان اجرا می‌شوند، که باعث بهبود چشمگیر توان عملیاتی و امکان فرایندهای پیچیده چندرشته‌ای تجاری می‌شود.
#
# > **یادداشت انتقال:** این نمونه قبلاً به مدل‌های GitHub اشاره داشت. مدل‌های GitHub منسوخ شده‌اند (بازنشسته شدن در ژوئیه ۲۰۲۶) و اکنون از طریق `FoundryChatClient` از **Microsoft Foundry** استفاده می‌کند، که هدف آن API پاسخ‌های Azure OpenAI است.
#
# ## 🎯 اهداف یادگیری
#
# ### 🚀 **مبانی پردازش همزمان**
# - **اجرای موازی عامل‌ها**: اجرای چندین عامل به طور همزمان برای حداکثر بهره‌وری
# - **هماهنگی جریان کاری**: هماهنگی عملیات همزمان در حالی که یکپارچگی داده‌ها حفظ شود
# - **بهینه‌سازی عملکرد**: دستیابی به سرعت قابل توجه از طریق پردازش موازی
# - **مدیریت منابع**: استفاده کارآمد از منابع مدل هوش مصنوعی در عملیات همزمان
#
# ### 🏗️ **الگوهای پیشرفته همزمانی**
# - **پردازش تقسیم-ادغام**: تقسیم کار بین چندین عامل و ادغام نتایج
# - **موازی‌سازی خط لوله**: اجرای مراحل همپوشانی برای توان عملیاتی پیوسته
# - **توزیع بار**: توزیع مساوی کار بین منابع عامل موجود
# - **نقاط همگام‌سازی**: هماهنگی عامل‌های همزمان در مراحل حیاتی جریان کاری
#
# ### 🏢 **برنامه‌های همزمان سازمانی**
# - **پردازش حجم بالا اسناد**: پردازش چندین سند به طور همزمان
# - **تحلیل محتوا در زمان واقعی**: تحلیل همزمان جریان‌های داده ورودی
# - **بهینه‌سازی پردازش دسته‌ای**: حداکثر کردن توان عملیاتی برای عملیات گسترده
# - **تحلیل چندرسانه‌ای**: پردازش موازی انواع مختلف محتوا (متن، تصویر، داده)
#
# ## ⚙️ پیش‌نیازها و راه‌اندازی
#
# ### 📦 **وابستگی‌های مورد نیاز**
#
# چارچوب عامل با قابلیت‌های جریان کاری همزمان را نصب کنید:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **پیکربندی Microsoft Foundry**
#
# با Azure CLI وارد شوید (`az login`) تا `AzureCliCredential` بتواند احراز هویت کند، سپس جزئیات پروژه Microsoft Foundry خود را تنظیم کنید.
#
# **راه‌اندازی محیط (.env فایل):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **ملاحظات پردازش همزمان:**
# - **محدودیت‌های نرخ**: نظارت بر محدودیت‌های نرخ Azure OpenAI برای درخواست‌های همزمان
# - **مصرف منابع**: توجه به مصرف حافظه و CPU با چندین عامل همزمان
# - **مدیریت خطا**: پیاده‌سازی بهبود بازیابی خطا برای عملیات موازی
#
# ### 🏗️ **معماری جریان کاری همزمان**
#
# ```mermaid
# graph TD
#     A[شروع گردش کار] --> B[اجرای همزمان]
#     B --> C[گروه عامل ۱]
#     B --> D[گروه عامل ۲]
#     B --> E[گروه عامل ۳]
#     C --> F[تجمیع نتایج]
#     D --> F
#     E --> F
#     F --> G[خروجی نهایی]
#
#     H[مایکروسافت فاندری] --> C
#     H --> D
#     H --> E
# ```
#
# **مزایای کلیدی:**
# - **⚡ عملکرد**: افزایش قابل توجه سرعت با اجرای موازی
# - **📈 مقیاس‌پذیری**: مدیریت حجم کاری افزایش یافته بدون افزایش متناسب زمان
# - **🔄 بهره‌وری**: استفاده بهتر از منابع محاسباتی در دسترس
# - **🎯 توان عملیاتی**: پردازش کار بیشتر در همان مقدار زمان
#
# ## 🎨 **الگوهای طراحی جریان کاری همزمان**
#
# ### 🔍 **خط لوله پژوهش و تحلیل**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **جریان کاری پردازش داده**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **خط لوله تولید محتوا**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **پردازش چندمرحله‌ای**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **مزایای عملکرد سازمانی**
#
# ### ⚡ **بهینه‌سازی توان عملیاتی**
# - **اجرای موازی**: چندین عامل به طور همزمان کار می‌کنند
# - **استفاده از منابع**: حداکثر بهره‌وری از ظرفیت مدل هوش مصنوعی موجود
# - **کاهش زمان**: کاهش قابل‌توجه در کل زمان پردازش
# - **معماری مقیاس‌پذیر**: افزودن آسان عوامل همزمان بیشتر در صورت نیاز
#
# ### 🛡️ **قابلیت اطمینان و تاب‌آوری**
# - **تحمل خطا**: خرابی‌های فردی عامل‌ها کل جریان کاری را متوقف نمی‌کند
# - **جداسازی خطا**: مشکلات در یک شاخه همزمان بر بقیه تأثیر نمی‌گذارد
# - **تضعیف نرم**: سیستم حتی با کاهش ظرفیت عامل به فعالیت خود ادامه می‌دهد
# - **مکانیسم‌های بازیابی**: تلاش دوباره خودکار و مدیریت خطا برای عملیات ناموفق
#
# ### 📊 **نظارت و پایش**
# - **ردیابی اجرای همزمان**: نظارت بر پیشرفت تمام عملیات موازی
# - **معیارهای عملکرد**: اندازه‌گیری سرعت و بهره‌وری بهبود یافته
# - **تحلیل مصرف منابع**: بهینه‌سازی تخصیص عوامل همزمان
# - **شناسایی گلوگاه‌ها**: یافتن و حل محدودیت‌های عملکرد
#
# بیایید جریان‌های کاری هوش مصنوعی همزمان با عملکرد بالا بسازیم! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **سلب مسئولیت**:
# این سند با استفاده از سرویس ترجمه هوش مصنوعی [Co-op Translator](https://github.com/Azure/co-op-translator) ترجمه شده است. در حالی که ما در تلاش برای دقت هستیم، لطفاً توجه داشته باشید که ترجمه‌های خودکار ممکن است شامل خطاها یا نادرستی‌هایی باشند. سند اصلی به زبان مادری خود باید به عنوان منبع معتبر در نظر گرفته شود. برای اطلاعات حیاتی، ترجمه حرفه‌ای انسانی توصیه می‌شود. ما در قبال هرگونه سوء تفاهم یا برداشت نادرست ناشی از استفاده از این ترجمه مسئولیتی نداریم.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
