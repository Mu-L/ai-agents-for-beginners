# %% [markdown]
# # 🔍 Επιχειρησιακό RAG με Microsoft Foundry (.NET)
#
# ## 📋 Στόχοι Μάθησης
#
# Αυτό το σημειωματάριο δείχνει πώς να κατασκευάσετε συστήματα Επιχειρησιακού Retrieval-Augmented Generation (RAG) χρησιμοποιώντας το Microsoft Agent Framework σε .NET με το Microsoft Foundry. Θα μάθετε να δημιουργείτε πράκτορες έτοιμους για παραγωγή που μπορούν να αναζητούν σε έγγραφα και να παρέχουν ακριβείς, με βάση το πλαίσιο, απαντήσεις με επιχειρησιακή ασφάλεια και κλιμάκωση.
#
# **Ικανότητες Επιχειρησιακού RAG που θα κατασκευάσετε:**
# - 📚 **Νοημοσύνη Εγγράφων**: Προηγμένη επεξεργασία εγγράφων με υπηρεσίες Azure AI
# - 🔍 **Σημασιολογική Αναζήτηση**: Υψηλής απόδοσης αναζήτηση διανυσμάτων με επιχειρησιακά χαρακτηριστικά
# - 🛡️ **Ενσωμάτωση Ασφαλείας**: Πρότυπα πρόσβασης βάσει ρόλων και προστασίας δεδομένων
# - 🏢 **Κλιμακώσιμη Αρχιτεκτονική**: Παραγωγικά συστήματα RAG με παρακολούθηση
#
# ## 🎯 Αρχιτεκτονική Επιχειρησιακού RAG
#
# ### Κύρια Επιχειρησιακά Συστατικά
# - **Microsoft Foundry**: Διαχειριζόμενη πλατφόρμα AI για επιχειρήσεις με ασφάλεια και συμμόρφωση
# - **Επίμονες Υπηρεσίες**: Πράκτορες με κατάστασης συνομιλιών και διαχείριση πλαισίου
# - **Διαχείριση Αποθήκης Διανυσμάτων**: Επιχειρησιακό δείκτη και ανάκτηση εγγράφων
# - **Ενσωμάτωση Ταυτότητας**: Έλεγχος ταυτότητας Azure AD και έλεγχος πρόσβασης βάσει ρόλων
#
# ### Οφέλη .NET για Επιχειρήσεις
# - **Τυποασφάλεια**: Επιβεβαίωση σε χρόνο μεταγλώττισης για λειτουργίες RAG και δομές δεδομένων
# - **Ασύγχρονη Απόδοση**: Μη φρασσόμενη επεξεργασία και αναζήτηση εγγράφων
# - **Διαχείριση Μνήμης**: Αποτελεσματική χρήση πόρων για μεγάλες συλλογές εγγράφων
# - **Πρότυπα Ενσωμάτωσης**: Ενσωμάτωση υπηρεσιών Azure με έγχυση εξαρτήσεων
#
# ## 🏗️ Τεχνική Αρχιτεκτονική
#
# ### Pipeline Επιχειρησιακού RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Κύρια Συστατικά .NET
# - **Azure.AI.Agents.Persistent**: Διαχείριση επιχειρησιακών πρακτόρων με διατήρηση κατάστασης
# - **Azure.Identity**: Ενσωματωμένος έλεγχος ταυτότητας για ασφαλή πρόσβαση Azure
# - **Microsoft.Agents.AI.AzureAI**: Υλοποίηση πλαισίου πράκτορα βελτιστοποιημένου για Azure
# - **System.Linq.Async**: Υψηλής απόδοσης ασύγχρονες λειτουργίες LINQ
#
# ## 🔧 Επιχειρησιακά Χαρακτηριστικά & Οφέλη
#
# ### Ασφάλεια & Συμμόρφωση
# - **Ενσωμάτωση Azure AD**: Επιχειρησιακή διαχείριση ταυτότητας και έλεγχος ταυτότητας
# - **Πρόσβαση Βάσει Ρόλων**: Λεπτομερής αδειοδότηση για πρόσβαση και λειτουργίες εγγράφων
# - **Προστασία Δεδομένων**: Κρυπτογράφηση κατά την αποθήκευση και τη μεταφορά ευαίσθητων εγγράφων
# - **Αρχείο Καταγραφής Ελέγχου**: Πλήρης παρακολούθηση δραστηριοτήτων για απαιτήσεις συμμόρφωσης
#
# ### Απόδοση & Κλιμάκωση
# - **Διαχείριση Συνδέσεων**: Αποδοτικός χειρισμός συνδέσεων υπηρεσιών Azure
# - **Ασύγχρονη Επεξεργασία**: Μη φρασσόμενες λειτουργίες για σενάρια υψηλής απόδοσης
# - **Στρατηγικές Cache**: Έξυπνη αποθήκευση για συχνά προσπελάσιμα έγγραφα
# - **Ισορροπία Φορτίου**: Κατανεμημένη επεξεργασία για μεγάλης κλίμακας εγκαταστάσεις
#
# ### Διαχείριση & Παρακολούθηση
# - **Ελέγχοι Υγείας**: Ενσωματωμένη παρακολούθηση εξαρτημάτων συστήματος RAG
# - **Μετρικές Απόδοσης**: Αναλυτικά στοιχεία για ποιότητα αναζήτησης και χρόνους απόκρισης
# - **Διαχείριση Σφαλμάτων**: Ολοκληρωμένη διαχείριση εξαιρέσεων με πολιτικές επαναπροσπάθειας
# - **Διαχείριση Ρυθμίσεων**: Περιβαλλοντικά ειδικές ρυθμίσεις με επικύρωση
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# **Περιβάλλον Ανάπτυξης:**
# - SDK .NET 9.0 ή νεότερο
# - Visual Studio 2022 ή VS Code με επέκταση C#
# - Συνδρομή Azure με πρόσβαση AI Foundry
#
# **Απαιτούμενα Πακέτα NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Ρύθμιση Αυθεντικοποίησης Azure:**
# ```bash
# # Εγκαταστήστε το Azure CLI και αυθεντικοποιηθείτε
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Ρύθμιση Περιβάλλοντος (αρχείο .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Πρότυπα Επιχειρησιακού RAG
#
# ### Πρότυπα Διαχείρισης Εγγράφων
# - **Μαζική Φόρτωση**: Αποτελεσματική επεξεργασία μεγάλων συλλογών εγγράφων
# - **Αυξομειούμενες Ενημερώσεις**: Προσθήκη και τροποποίηση εγγράφων σε πραγματικό χρόνο
# - **Έλεγχος Εκδόσεων**: Παρακολούθηση εκδόσεων εγγράφων και αλλαγών
# - **Διαχείριση Μεταδεδομένων**: Πλούσια χαρακτηριστικά και ταξονομία εγγράφων
#
# ### Πρότυπα Αναζήτησης & Ανάκτησης
# - **Υβριδική Αναζήτηση**: Συνδυασμός σημασιολογικής και βασικής αναζήτησης για βέλτιστα αποτελέσματα
# - **Πλευρική Αναζήτηση**: Πολυδιάστατη φιλτράρισμα και κατηγοριοποίηση
# - **Ρύθμιση Σχετικότητας**: Προσαρμοσμένοι αλγόριθμοι βαθμολόγησης για συγκεκριμένες ανάγκες τομέα
# - **Κατάταξη Αποτελεσμάτων**: Προχωρημένη κατάταξη με ενσωμάτωση επιχειρησιακής λογικής
#
# ### Πρότυπα Ασφαλείας
# - **Ασφάλεια Επίπεδου Εγγράφου**: Λεπτομερής έλεγχος πρόσβασης ανά έγγραφο
# - **Ταξινόμηση Δεδομένων**: Αυτόματη επισήμανση ευαισθησίας και προστασία
# - **Αρχεία Ελέγχου**: Πλήρης καταγραφή όλων των λειτουργιών RAG
# - **Προστασία Ιδιωτικότητας**: Δυνατότητες ανίχνευσης και απομάκρυνσης προσωπικών δεδομένων
#
# ## 🔒 Επιχειρησιακά Χαρακτηριστικά Ασφαλείας
#
# ### Αυθεντικοποίηση & Εξουσιοδότηση
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Προστασία Δεδομένων
# - **Κρυπτογράφηση**: Κρυπτογράφηση από άκρο σε άκρο για έγγραφα και ευρετήρια αναζήτησης
# - **Έλεγχοι Πρόσβασης**: Ενσωμάτωση με Azure AD για δικαιώματα χρηστών και ομάδων
# - **Τόπος Αποθήκευσης Δεδομένων**: Γεωγραφικός έλεγχος τοποθεσίας δεδομένων για συμμόρφωση
# - **Αντίγραφα Ασφαλείας & Ανάκτηση**: Αυτόματες δυνατότητες αντιγράφων ασφαλείας και ανάκτησης καταστροφών
#
# ## 📈 Βελτιστοποίηση Απόδοσης
#
# ### Πρότυπα Ασύγχρονης Επεξεργασίας
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Διαχείριση Μνήμης
# - **Ροή Επεξεργασίας**: Χειρισμός μεγάλων εγγράφων χωρίς προβλήματα μνήμης
# - **Κοινή Χρήση Πόρων**: Αποτελεσματική επαναχρησιμοποίηση δαπανηρών πόρων
# - **Garbage Collection**: Βελτιστοποιημένα πρότυπα κατανομής μνήμης
# - **Διαχείριση Συνδέσεων**: Ορθή διαχείριση κύκλου ζωής σύνδεσης υπηρεσιών Azure
#
# ### Στρατηγικές Cache
# - **Cache Ερωτημάτων**: Αποθήκευση συχνά εκτελούμενων αναζητήσεων
# - **Cache Εγγράφων**: Αποθήκευση στη μνήμη για "καυτά" έγγραφα
# - **Cache Ευρετηρίου**: Βελτιστοποιημένη αποθήκευση ευρετηρίου διανυσμάτων
# - **Cache Αποτελεσμάτων**: Έξυπνη αποθήκευση παραγόμενων απαντήσεων
#
# ## 📊 Επιχειρησιακές Περιπτώσεις Χρήσης
#
# ### Διαχείριση Γνώσης
# - **Εταιρικό Wiki**: Έξυπνη αναζήτηση σε βάσεις γνώσης εταιρείας
# - **Πολιτικές & Διαδικασίες**: Αυτόματος έλεγχος συμμόρφωσης και καθοδήγηση διαδικασιών
# - **Υλικά Κατάρτισης**: Έξυπνη υποστήριξη μάθησης και ανάπτυξης
# - **Βάσεις Δεδομένων Έρευνας**: Συστήματα ανάλυσης ακαδημαϊκών και ερευνητικών εργασιών
#
# ### Υποστήριξη Πελατών
# - **Βάση Γνώσης Υποστήριξης**: Αυτοματοποιημένες απαντήσεις εξυπηρέτησης πελατών
# - **Τεκμηρίωση Προϊόντων**: Έξυπνη ανάκτηση πληροφοριών προϊόντων
# - **Οδηγοί Επίλυσης Προβλημάτων**: Βοήθεια επίλυσης σε πλαίσιο πλαισίου
# - **Συστήματα FAQ**: Δυναμική δημιουργία FAQ από συλλογές εγγράφων
#
# ### Κανονιστική Συμμόρφωση
# - **Ανάλυση Νομικών Εγγράφων**: Νοημοσύνη συμβολαίων και νομικών εγγράφων
# - **Παρακολούθηση Συμμόρφωσης**: Αυτόματος έλεγχος κανονιστικής συμμόρφωσης
# - **Αξιολόγηση Κινδύνου**: Ανάλυση κινδύνου βάσει εγγράφων και αναφορές
# - **Υποστήριξη Ελέγχων**: Έξυπνη ανακάλυψη εγγράφων για ελέγχους
#
# ## 🚀 Παραγωγική Ανάπτυξη
#
# ### Παρακολούθηση & Παρατηρησιμότητα
# - **Application Insights**: Λεπτομερής τηλεμετρία και παρακολούθηση απόδοσης
# - **Προσαρμοσμένες Μετρικές**: Παρακολούθηση KPI και ειδοποιήσεις ειδικών επιχειρησιακών δεικτών
# - **Κατανεμημένη Παρακολούθηση**: Παρακολούθηση αιτημάτων end-to-end μεταξύ υπηρεσιών
# - **Πίνακες Υγείας**: Οπτικοποίηση υγείας και απόδοσης συστήματος σε πραγματικό χρόνο
#
# ### Κλιμάκωση & Αξιοπιστία
# - **Αυτομάτως Κλιμακούμενο**: Αυτόματη κλιμάκωση βάσει φορτίου και μετρικών απόδοσης
# - **Υψηλή Διαθεσιμότητα**: Πολυπεριφερειακή ανάπτυξη με δυνατότητες failover
# - **Δοκιμές Φορτίου**: Επικύρωση απόδοσης υπό επιχειρησιακό φορτίο
# - **Ανάκτηση από Καταστροφές**: Αυτόματες διαδικασίες αντιγράφων και ανάκτησης
#
# Είστε έτοιμοι να δημιουργήσετε εταιρικά συστήματα RAG ικανά να χειρίζονται ευαίσθητα έγγραφα σε μεγάλη κλίμακα; Ας σχεδιάσουμε έξυπνα συστήματα γνώσης για τις επιχειρήσεις! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Αποποίηση ευθυνών**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Ενώ επιδιώκουμε την ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
