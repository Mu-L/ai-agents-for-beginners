# %% [markdown]
# # 🔄 Βασικές Ροές Εργασίας Πρακτόρων με το Microsoft Foundry (Python)
#
# ## 📋 Εκμάθηση Ορχήστρωσης Ροών Εργασίας
#
# Αυτό το σημειωματάριο παρουσιάζει τις ισχυρές δυνατότητες του **Workflow Builder** του Microsoft Agent Framework. Μάθετε πώς να δημιουργείτε πολύπλοκες ροές εργασίας πρακτόρων πολλών βημάτων που μπορούν να χειριστούν περίπλοκες επιχειρησιακές διαδικασίες και να συντονίσουν πολλαπλές λειτουργίες AI ομαλά.
#
# > **Σημείωση μετεγκατάστασης:** Αυτό το δείγμα αναφερόταν προηγουμένως στα GitHub Models. Τα GitHub Models έχουν αποσυρθεί (θα σταματήσουν τον Ιούλιο 2026), οπότε τώρα χρησιμοποιεί το **Microsoft Foundry** μέσω του `FoundryChatClient`, που στοχεύει στο Azure OpenAI **Responses API**.
#
# ## 🎯 Στόχοι Εκμάθησης
#
# ### 🏗️ **Αρχιτεκτονική Ροής Εργασίας**
# - **Workflow Builder**: Σχεδιάστε και ορχηστρώστε πολύπλοκες διαδικασίες πολλών βημάτων
# - **Εκτέλεση με βάση τα γεγονότα**: Διαχειριστείτε γεγονότα ροών εργασίας και μεταβάσεις κατάστασης
# - **Οπτικός Σχεδιασμός Ροής Εργασίας**: Δημιουργήστε και οπτικοποιήστε δομές ροών εργασίας
# - **Ενσωμάτωση Microsoft Foundry**: Αξιοποιήστε τα μοντέλα AI μέσα σε πλαίσια ροών εργασίας
#
# ### 🔄 **Ορχήστρωση Διαδικασιών**
# - **Σειριακές Δραστηριότητες**: Συνδέστε πολλαπλές εργασίες πρακτόρων με λογική σειρά
# - **Υποθετική Λογική**: Εφαρμόστε σημεία αποφάσεων και διακλαδώσεις ροών εργασίας
# - **Διαχείριση Σφαλμάτων**: Ανθεκτική αποκατάσταση σφαλμάτων και ανθεκτικότητα ροών εργασίας
# - **Διαχείριση Κατάστασης**: Παρακολουθήστε και διαχειριστείτε την κατάσταση εκτέλεσης ροής εργασίας
#
# ### 📊 **Μοτίβα Ροών Εργασίας Επιχειρήσεων**
# - **Αυτοματοποίηση Επιχειρησιακών Διαδικασιών**: Αυτοματοποιήστε πολύπλοκες οργανωσιακές ροές εργασίας
# - **Συντονισμός Πολλαπλών Πρακτόρων**: Συντονίστε πολλούς εξειδικευμένους πράκτορες
# - **Κλιμακούμενη Εκτέλεση**: Σχεδιάστε ροές εργασίας για επιχειρησιακή κλίμακα
# - **Παρακολούθηση & Παρατηρησιμότητα**: Παρακολουθείτε την απόδοση και τα αποτελέσματα ροής εργασίας
#
# ## ⚙️ Προαπαιτούμενα & Ρύθμιση
#
# ### 📦 **Απαιτούμενες Εξαρτήσεις**
#
# Εγκαταστήστε το Agent Framework με δυνατότητες ροών εργασίας:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Διαμόρφωση Microsoft Foundry**
#
# Συνδεθείτε με το Azure CLI (`az login`) ώστε το `AzureCliCredential` να μπορεί να ταυτοποιήσει, και μετά ρυθμίστε τις λεπτομέρειες του έργου σας στο Microsoft Foundry.
#
# **Ρύθμιση Περιβάλλοντος (αρχείο .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# ### 🏢 **Περιπτώσεις Χρήσης Επιχειρήσεων**
#
# **Παραδείγματα Επιχειρησιακών Διαδικασιών:**
# - **Εισαγωγή Πελατών**: Πολυβηματικές διαδικασίες επαλήθευσης και ρύθμισης
# - **Διαχείριση Περιεχομένου**: Αυτόματη δημιουργία, αναθεώρηση και δημοσίευση περιεχομένου
# - **Επεξεργασία Δεδομένων**: Ροές ETL με μετασχηματισμό υποστηριζόμενο από AI
# - **Διασφάλιση Ποιότητας**: Αυτόματες διαδικασίες δοκιμής και επικύρωσης
#
# **Πλεονεκτήματα Ροών Εργασίας:**
# - 🎯 **Αξιοπιστία**: Αποφασιστική εκτέλεση με αποκατάσταση σφαλμάτων
# - 📈 **Κλιμακωσιμότητα**: Διαχειριστείτε αυτοματισμούς διαδικασιών υψηλού όγκου
# - 🔍 **Παρατηρησιμότητα**: Πλήρη ίχνη ελέγχου και παρακολούθηση
# - 🔧 **Διατηρησιμότητα**: Οπτικός σχεδιασμός και αρθρωτά στοιχεία
#
# ## 🎨 Μοτίβα Σχεδιασμού Ροών Εργασίας
#
# ### Βασική Δομή Ροής Εργασίας
# ```mermaid
# graph TD
#     A[Έναρξη] --> B[Εργασία Πράκτορα 1]
#     B --> C{Σημείο Απόφασης}
#     C -->|Επιτυχία| D[Εργασία Πράκτορα 2]
#     C -->|Αποτυχία| E[Διαχείριση Σφαλμάτων]
#     D --> F[Τέλος]
#     E --> F
# ```
#
# **Κύρια Συστατικά:**
# - **WorkflowBuilder**: Κύρια μηχανή ορχήστρωσης
# - **WorkflowEvent**: Διαχείριση γεγονότων και επικοινωνία
# - **WorkflowViz**: Οπτική αναπαράσταση και αποσφαλμάτωση ροής εργασίας
#
# Ας δημιουργήσουμε την πρώτη σας ευφυή ροή εργασίας! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load Microsoft Foundry project settings from .env file
load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = provider.as_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = provider.as_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Αποποίηση ευθυνών**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Ενώ επιδιώκουμε την ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
