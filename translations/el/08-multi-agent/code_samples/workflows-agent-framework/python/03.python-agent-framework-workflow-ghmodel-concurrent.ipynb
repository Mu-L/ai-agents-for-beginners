# %% [markdown]
# # ⚡ Παράλληλες Ροές Εργασίας Πρακτόρων με το Microsoft Foundry (Python)
#
# ## 📋 Προχωρημένο Σεμινάριο Παράλληλης Επεξεργασίας
#
# Αυτό το σημειωματάριο παρουσιάζει **παραδείγματα παράλληλων ροών εργασίας** χρησιμοποιώντας το Microsoft Agent Framework. Θα μάθετε πώς να δημιουργείτε ροές εργασίας υψηλής απόδοσης με παράλληλη επεξεργασία όπου πολλοί πράκτορες AI εκτελούνται ταυτόχρονα, βελτιώνοντας δραματικά τη διαμέσου και επιτρέποντας πολύπλοκες πολυνηματικές επιχειρησιακές διαδικασίες.
#
# > **Σημείωση Μεταφοράς:** Αυτό το παράδειγμα αναφερόταν προηγουμένως στα GitHub Models. Τα GitHub Models είναι παρωχημένα (θα αποσυρθούν τον Ιούλιο του 2026), οπότε πλέον χρησιμοποιούν **Microsoft Foundry** μέσω του `FoundryChatClient`, που στοχεύει στο Azure OpenAI **Responses API**.
#
# ## 🎯 Στόχοι Μάθησης
#
# ### 🚀 **Βασικές Αρχές Παράλληλης Επεξεργασίας**
# - **Παράλληλη Εκτέλεση Πρακτόρων**: Εκτέλεση πολλών πρακτόρων ταυτόχρονα για μέγιστη αποδοτικότητα
# - **Συντονισμός Ροών Εργασίας**: Συγχρονισμός παράλληλων λειτουργιών διατηρώντας τη συνοχή δεδομένων
# - **Βελτιστοποίηση Απόδοσης**: Επίτευξη σημαντικής επιτάχυνσης μέσω παράλληλης επεξεργασίας
# - **Διαχείριση Πόρων**: Αποτελεσματική χρήση πόρων μοντέλων AI κατά τις παράλληλες λειτουργίες
#
# ### 🏗️ **Προχωρημένα Μοτίβα Παράλληλης Επεξεργασίας**
# - **Fork-Join Επεξεργασία**: Διαχωρισμός εργασίας σε πολλούς πράκτορες και συγχώνευση αποτελεσμάτων
# - **Παράλληλη Ροή**: Ταυτόχρονες φάσεις εκτέλεσης για συνεχή διαμέσου
# - **Ισορροπία Φόρτου**: Ομοιόμορφη κατανομή εργασίας στους διαθέσιμους πόρους πρακτόρων
# - **Σημεία Συγχρονισμού**: Συντονισμός παράλληλων πρακτόρων σε κρίσιμα στάδια ροής εργασίας
#
# ### 🏢 **Εταιρικές Εφαρμογές Παράλληλης Επεξεργασίας**
# - **Επεξεργασία Έγγραφων Υψηλού Όγκου**: Ταυτόχρονη επεξεργασία πολλαπλών εγγράφων
# - **Ανάλυση Περιεχομένου σε Πραγματικό Χρόνο**: Παράλληλη ανάλυση ροών εισερχόμενων δεδομένων
# - **Βελτιστοποίηση Ομαδικής Επεξεργασίας**: Μέγιστη απόδοση για μεγάλης κλίμακας λειτουργίες
# - **Πολυμορφική Ανάλυση**: Παράλληλη επεξεργασία διαφορετικών τύπων περιεχομένου (κείμενο, εικόνες, δεδομένα)
#
# ## ⚙️ Απαιτήσεις & Ρύθμιση
#
# ### 📦 **Απαιτούμενες Εξαρτήσεις**
#
# Εγκαταστήστε το Agent Framework με δυνατότητες παράλληλων ροών εργασίας:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Διαμόρφωση Microsoft Foundry**
#
# Συνδεθείτε με το Azure CLI (`az login`) ώστε το `AzureCliCredential` να μπορεί να πιστοποιηθεί, και μετά ρυθμίστε τις λεπτομέρειες του έργου σας στο Microsoft Foundry.
#
# **Ρύθμιση Περιβάλλοντος (.env αρχείο):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Σκέψεις για Παράλληλη Επεξεργασία:**
# - **Όρια Ροής**: Παρακολούθηση των ορίων ρυθμού του Azure OpenAI για παράλληλα αιτήματα
# - **Χρήση Πόρων**: Λάβετε υπόψη τη μνήμη και τη χρήση CPU με πολλούς παράλληλους πράκτορες
# - **Διαχείριση Σφαλμάτων**: Υλοποίηση ανθεκτικής ανάκτησης σφαλμάτων για παράλληλες εργασίες
#
# ### 🏗️ **Αρχιτεκτονική Παράλληλης Ροής Εργασίας**
#
# ```mermaid
# graph TD
#     A[Έναρξη Ροής Εργασίας] --> B[Ταυτόχρονη Εκτέλεση]
#     B --> C[Συλλογή Πρακτόρων 1]
#     B --> D[Συλλογή Πρακτόρων 2]
#     B --> E[Συλλογή Πρακτόρων 3]
#     C --> F[Συγκέντρωση Αποτελεσμάτων]
#     D --> F
#     E --> F
#     F --> G[Τελικό Αποτέλεσμα]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Βασικά Οφέλη:**
# - **⚡ Απόδοση**: Σημαντική επιτάχυνση μέσω παράλληλης εκτέλεσης
# - **📈 Επεκτασιμότητα**: Αντιμετώπιση αυξημένου φόρτου εργασίας χωρίς ανάλογη αύξηση χρόνου
# - **🔄 Αποδοτικότητα**: Καλύτερη χρήση των διαθέσιμων υπολογιστικών πόρων
# - **🎯 Διαμέσου**: Επεξεργασία περισσότερης εργασίας στον ίδιο χρόνο
#
# ## 🎨 **Μοτίβα Σχεδιασμού Παράλληλης Ροής Εργασίας**
#
# ### 🔍 **Σωλήνας Έρευνας & Ανάλυσης**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Ροή Επεξεργασίας Δεδομένων**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Σωλήνας Δημιουργίας Περιεχομένου**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Πολυφασική Επεξεργασία**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Επιχειρησιακά Οφέλη Απόδοσης**
#
# ### ⚡ **Βελτιστοποίηση Διαμέσου**
# - **Παράλληλη Εκτέλεση**: Πολλοί πράκτορες που εργάζονται ταυτόχρονα
# - **Χρήση Πόρων**: Μέγιστη αποδοτικότητα της διαθέσιμης χωρητικότητας μοντέλου AI
# - **Σύνολο Χρόνου**: Σημαντική μείωση του συνολικού χρόνου επεξεργασίας
# - **Επεκτάσιμη Αρχιτεκτονική**: Προσθέστε εύκολα περισσότερους παράλληλους πράκτορες αν χρειαστεί
#
# ### 🛡️ **Αξιοπιστία & Ανθεκτικότητα**
# - **Ανοχή Σφαλμάτων**: Η αποτυχία μεμονωμένων πρακτόρων δεν σταματά όλη τη ροή εργασίας
# - **Απομόνωση Σφαλμάτων**: Προβλήματα σε ένα παράλληλο κλαδί δεν επηρεάζουν άλλα
# - **Ομαλή Υποβάθμιση**: Το σύστημα συνεχίζει να λειτουργεί ακόμη και με μειωμένη χωρητικότητα πρακτόρων
# - **Μηχανισμοί Ανάκτησης**: Αυτόματες επαναπειραματισμοί και διαχείριση σφαλμάτων για αποτυχημένες λειτουργίες
#
# ### 📊 **Παρακολούθηση & Παρατηρησιμότητα**
# - **Παρακολούθηση Παράλληλης Εκτέλεσης**: Παρακολουθήστε την πρόοδο όλων των παράλληλων λειτουργιών
# - **Μετρικές Απόδοσης**: Μετρήστε την επιτάχυνση και τα κέρδη αποδοτικότητας
# - **Ανάλυση Χρήσης Πόρων**: Βελτιστοποιήστε την κατανομή πρακτόρων παράλληλης επεξεργασίας
# - **Εντοπισμός Φραγμών**: Βρείτε και επιλύστε περιορισμούς απόδοσης
#
# Ας δημιουργήσουμε υψηλής απόδοσης παράλληλες ροές εργασίας AI! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Αποποίηση ευθυνών**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Ενώ επιδιώκουμε την ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
