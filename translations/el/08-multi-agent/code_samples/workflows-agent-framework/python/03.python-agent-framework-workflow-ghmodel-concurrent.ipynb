# %% [markdown]
# # ⚡ Συγχρονισμένα Ροή Εργασίας Πρακτόρων με το Microsoft Foundry (Python)
#
# ## 📋 Προχωρημένο Σεμινάριο Παράλληλης Επεξεργασίας
#
# Αυτό το σημειωματάριο παρουσιάζει **σχέδια συγχρονισμένης ροής εργασίας** χρησιμοποιώντας το Microsoft Agent Framework. Θα μάθετε πώς να κατασκευάζετε υψηλής απόδοσης, παράλληλες ροές εργασίας όπου πολλοί πράκτορες AI εκτελούνται ταυτόχρονα, βελτιώνοντας σημαντικά την απόδοση και επιτρέποντας περίπλοκες πολυνηματικές επιχειρησιακές διαδικασίες.
#
# > **Σημείωση μετανάστευσης:** Αυτό το παράδειγμα προηγουμένως αναφερόταν σε GitHub Models. Το GitHub Models καταργείται (θα αποσυρθεί τον Ιούλιο 2026), οπότε πλέον χρησιμοποιεί το **Microsoft Foundry** μέσω του `FoundryChatClient`, που στοχεύει στο Azure OpenAI **Responses API**.
#
# ## 🎯 Στόχοι Μάθησης
#
# ### 🚀 **Βασικά Στοιχεία Συγχρονισμένης Επεξεργασίας**
# - **Παράλληλη Εκτέλεση Πρακτόρων**: Εκτέλεση πολλών πρακτόρων ταυτόχρονα για μέγιστη αποδοτικότητα
# - **Ορχήστρωση Ροής Εργασίας**: Συντονισμός συγχρονισμένων εργασιών διατηρώντας τη συνοχή δεδομένων
# - **Βελτιστοποίηση Απόδοσης**: Επίτευξη σημαντικής επιτάχυνσης μέσω παράλληλης επεξεργασίας
# - **Διαχείριση Πόρων**: Αποτελεσματική χρήση πόρων μοντέλων AI σε συγχρονισμένες εργασίες
#
# ### 🏗️ **Προχωρημένα Σχέδια Συγχρονισμού**
# - **Fork-Join Επεξεργασία**: Διαχωρισμός εργασιών σε πολλούς πράκτορες και συγχώνευση αποτελεσμάτων
# - **Παράλληλη Σωληνογραμμή**: Επικάλυψη σταδίων εκτέλεσης για συνεχόμενη ροή
# - **Ισορροπία Φόρτου**: Κατανομή εργασιών ομοιόμορφα στους διαθέσιμους πόρους πρακτόρων
# - **Σημεία Συγχρονισμού**: Συντονισμός πρακτόρων σε κρίσιμα στάδια ροής εργασίας
#
# ### 🏢 **Επιχειρησιακές Εφαρμογές Συγχρονισμένης Απόδοσης**
# - **Επεξεργασία Μεγάλου Όγκου Εγγράφων**: Επεξεργασία πολλών εγγράφων ταυτόχρονα
# - **Ανάλυση Περιεχομένου σε Πραγματικό Χρόνο**: Συγχρονισμένη ανάλυση ροών δεδομένων που εισέρχονται
# - **Βελτιστοποίηση Επεξεργασίας Παρτίδων**: Μέγιστη απόδοση για μεγάλης κλίμακας εργασίες
# - **Πολυτροπική Ανάλυση**: Παράλληλη επεξεργασία διαφορετικών τύπων περιεχομένου (κείμενο, εικόνες, δεδομένα)
#
# ## ⚙️ Προαπαιτούμενα & Ρυθμίσεις
#
# ### 📦 **Απαραίτητες Εξαρτήσεις**
#
# Εγκαταστήστε το Agent Framework με δυνατότητες συγχρονισμένης ροής εργασίας:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Ρύθμιση Microsoft Foundry**
#
# Συνδεθείτε με το Azure CLI (`az login`) ώστε το `AzureCliCredential` να μπορεί να ταυτοποιήσει, έπειτα ορίστε τις λεπτομέρειες του έργου Microsoft Foundry.
#
# **Ρύθμιση Περιβάλλοντος (αρχείο .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Σκέψεις για Συγχρονισμένη Επεξεργασία:**
# - **Όρια Ρυθμού**: Παρακολουθήστε τα όρια ρυθμού Azure OpenAI για συγχρονισμένα αιτήματα
# - **Χρήση Πόρων**: Λάβετε υπόψη τη χρήση μνήμης και CPU με πολλούς συγχρονισμένους πράκτορες
# - **Διαχείριση Σφαλμάτων**: Εφαρμόστε ανθεκτική ανάκαμψη σφαλμάτων σε παράλληλες λειτουργίες
#
# ### 🏗️ **Αρχιτεκτονική Συγχρονισμένης Ροής Εργασίας**
#
# ```mermaid
# graph TD
#     A[Έναρξη Ροής Εργασίας] --> B[Ταυτόχρονη Εκτέλεση]
#     B --> C[Σύνολο Πρακτόρων 1]
#     B --> D[Σύνολο Πρακτόρων 2]
#     B --> E[Σύνολο Πρακτόρων 3]
#     C --> F[Συνάθροιση Αποτελεσμάτων]
#     D --> F
#     E --> F
#     F --> G[Τελική Έξοδος]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Βασικά Οφέλη:**
# - **⚡ Απόδοση**: Σημαντική επιτάχυνση μέσω παράλληλης εκτέλεσης
# - **📈 Κλιμάκωση**: Αντιμετώπιση αυξημένων φορτίων χωρίς αντιστοίχηση αύξησης χρόνου
# - **🔄 Αποδοτικότητα**: Καλύτερη χρήση διαθέσιμων υπολογιστικών πόρων
# - **🎯 Ρυθμός Επεξεργασίας**: Εκτέλεση περισσότερης εργασίας στον ίδιο χρόνο
#
# ## 🎨 **Σχέδια Σχεδίασης Συγχρονισμένης Ροής Εργασίας**
#
# ### 🔍 **Σωληνογραμμή Έρευνας & Ανάλυσης**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Ροή Επεξεργασίας Δεδομένων**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Σωληνογραμμή Δημιουργίας Περιεχομένου**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Πολυεπίπεδη Επεξεργασία**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Επιχειρησιακά Οφέλη Απόδοσης**
#
# ### ⚡ **Βελτιστοποίηση Ρυθμού Επεξεργασίας**
# - **Παράλληλη Εκτέλεση**: Πολλοί πράκτορες εργάζονται ταυτόχρονα
# - **Χρήση Πόρων**: Μέγιστη αποδοτικότητα της διαθέσιμης χωρητικότητας μοντέλου AI
# - **Μείωση Χρόνου**: Σημαντική μείωση στον συνολικό χρόνο επεξεργασίας
# - **Επεκτάσιμη Αρχιτεκτονική**: Εύκολη προσθήκη περισσότερων συγχρονισμένων πρακτόρων όπως απαιτείται
#
# ### 🛡️ **Αξιοπιστία & Ανθεκτικότητα**
# - **Ανοχή Σφαλμάτων**: Αποτυχίες μεμονωμένων πρακτόρων δεν σταματούν ολόκληρη τη ροή εργασίας
# - **Απομόνωση Σφαλμάτων**: Προβλήματα σε έναν κλάδο συγχρονισμένης ροής δεν επηρεάζουν άλλους
# - **Ομαλή Υποβάθμιση**: Το σύστημα συνεχίζει να λειτουργεί ακόμα και με μειωμένη ικανότητα πρακτόρων
# - **Μηχανισμοί Ανάκαμψης**: Αυτόματη επανάληψη και διαχείριση σφαλμάτων για αποτυχίες έργων
#
# ### 📊 **Παρακολούθηση & Παρατηρητικότητα**
# - **Παρακολούθηση Παράλληλης Εκτέλεσης**: Παρακολουθήστε την πρόοδο όλων των παράλληλων λειτουργιών
# - **Μετρήσεις Απόδοσης**: Μετρήστε την επιτάχυνση και τα κέρδη αποδοτικότητας
# - **Αναλύσεις Χρήσης Πόρων**: Βελτιστοποιήστε την κατανομή συγχρονισμένων πρακτόρων
# - **Εντοπισμός Φραγμών**: Βρείτε και επιλύστε περιορισμούς απόδοσης
#
# Ας δημιουργήσουμε υψηλής απόδοσης συγχρονισμένες ροές εργασίας AI! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Αποποίηση ευθυνών**:
# Αυτό το έγγραφο έχει μεταφραστεί χρησιμοποιώντας την υπηρεσία μετάφρασης με τεχνητή νοημοσύνη [Co-op Translator](https://github.com/Azure/co-op-translator). Ενώ επιδιώκουμε την ακρίβεια, παρακαλούμε να έχετε υπόψη ότι οι αυτοματοποιημένες μεταφράσεις ενδέχεται να περιέχουν λάθη ή ανακρίβειες. Το πρωτότυπο έγγραφο στη μητρική του γλώσσα πρέπει να θεωρείται η αυθεντική πηγή. Για κρίσιμες πληροφορίες, συνιστάται επαγγελματική ανθρώπινη μετάφραση. Δεν φέρουμε ευθύνη για τυχόν παρεξηγήσεις ή λανθασμένες ερμηνείες που προκύπτουν από τη χρήση αυτής της μετάφρασης.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
