# %% [markdown]
# # 🔍 Podnikový RAG s Microsoft Foundry (.NET)
#
# ## 📋 Ciele učenia
#
# Tento notebook demonštruje, ako vybudovať podnikové systémy Retrieval-Augmented Generation (RAG) pomocou Microsoft Agent Framework v .NET s Microsoft Foundry. Naučíte sa vytvárať výrobné agenty pripravené na použitie, ktoré môžu vyhľadávať v dokumentoch a poskytovať presné, kontextovo zamerané odpovede s podnikateľskou bezpečnosťou a škálovateľnosťou.
#
# **Podnikové schopnosti RAG, ktoré vytvoríte:**
# - 📚 **Dokumentová inteligencia**: Pokročilé spracovanie dokumentov so službami Azure AI
# - 🔍 **Sémantické vyhľadávanie**: Vektorové vyhľadávanie s vysokým výkonom a podnikateľskými funkciami
# - 🛡️ **Integrácia bezpečnosti**: Riadenie prístupu na základe rolí a vzory ochrany údajov
# - 🏢 **Škálovateľná architektúra**: Výrobné RAG systémy s monitorovaním
#
# ## 🎯 Podniková architektúra RAG
#
# ### Kľúčové podnikové komponenty
# - **Microsoft Foundry**: Spravovaná podniková AI platforma s bezpečnosťou a súladom
# - **Trvalí agenti**: Stavoví agenti s históriou konverzácií a správou kontextu
# - **Správa vektorového úložiska**: Podnikové indexovanie a vyhľadávanie dokumentov
# - **Integrácia identity**: Overovanie Azure AD a riadenie prístupu na základe rolí
#
# ### Výhody .NET pre podnikanie
# - **Typová bezpečnosť**: Overenie počas prekladu pre operácie RAG a dátové štruktúry
# - **Asynchrónny výkon**: Nezablokujúce spracovanie dokumentov a vyhľadávacie operácie
# - **Správa pamäte**: Efektívne využívanie zdrojov pre veľké kolekcie dokumentov
# - **Vzory integrácie**: Natívna integrácia služieb Azure s dependency injection
#
# ## 🏗️ Technická architektúra
#
# ### RAG pipeline pre podnikanie
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Hlavné .NET komponenty
# - **Azure.AI.Agents.Persistent**: Správa podnikového agenta s trvalosťou stavu
# - **Azure.Identity**: Integrované overovanie pre bezpečný prístup k službám Azure
# - **Microsoft.Agents.AI.AzureAI**: Agentový rámec optimalizovaný pre Azure
# - **System.Linq.Async**: Vysokovýkonné asynchrónne LINQ operácie
#
# ## 🔧 Podnikové funkcie a výhody
#
# ### Bezpečnosť a súlad
# - **Integrácia Azure AD**: Správa podnikovej identity a overovanie
# - **Prístup na základe rolí**: Jemnozrnná kontrola povolení pre prístup k dokumentom a operáciám
# - **Ochrana údajov**: Šifrovanie v pokoji aj počas prenosu pre citlivé dokumenty
# - **Auditné záznamy**: Komplexné sledovanie aktivít pre požiadavky na súlad
#
# ### Výkon a škálovateľnosť
# - **Správa spojení**: Efektívne riadenie pripojení ku službám Azure
# - **Asynchrónne spracovanie**: Nezablokujúce operácie pre scenáre s vysokou priepustnosťou
# - **Cachingové stratégie**: Inteligentné cachovanie často používaných dokumentov
# - **Vyrovnávanie záťaže**: Distribuované spracovanie pre rozsiahle nasadenia
#
# ### Správa a monitorovanie
# - **Kontroly zdravia**: Vstavané monitorovanie komponentov RAG systému
# - **Metriky výkonu**: Detailná analytika kvality vyhľadávania a časov odozvy
# - **Správa chýb**: Komplexná správa výnimiek s politikami opätovného pokusu
# - **Správa konfigurácie**: Nastavenia špecifické pre prostredie s validáciou
#
# ## ⚙️ Predpoklady a nastavenie
#
# **Vývojové prostredie:**
# - .NET 9.0 SDK alebo vyšší
# - Visual Studio 2022 alebo VS Code s rozšírením C#
# - Predplatné Azure s prístupom k AI Foundry
#
# **Požadované NuGet balíčky:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Nastavenie autentifikácie Azure:**
# ```bash
# # Nainštalujte Azure CLI a prihláste sa
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Konfigurácia prostredia (súbor .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Vzory podnikového RAG
#
# ### Vzory správy dokumentov
# - **Hromadné nahrávanie**: Efektívne spracovanie veľkých kolekcií dokumentov
# - **Postupné aktualizácie**: Pridávanie a úprava dokumentov v reálnom čase
# - **Verzovanie**: Verzovanie dokumentov a sledovanie zmien
# - **Správa metadát**: Bohaté atribúty dokumentov a taxonómia
#
# ### Vzory vyhľadávania a získavania
# - **Hybridné vyhľadávanie**: Kombinovanie sémantického a kľúčového vyhľadávania pre optimálne výsledky
# - **Fasetové vyhľadávanie**: Viacdimenziálne filtrovanie a kategorizácia
# - **Ladenie relevancie**: Vlastné algoritmy hodnotenia pre špecifické potreby domény
# - **Zoradenie výsledkov**: Pokročilé zoradenie s integráciou obchodnej logiky
#
# ### Bezpečnostné vzory
# - **Bezpečnosť na úrovni dokumentu**: Jemnozrnná kontrola prístupu ku každému dokumentu
# - **Klasifikácia údajov**: Automatické označovanie citlivosti a ochrana
# - **Auditné stopy**: Komplexné zaznamenávanie všetkých operácií RAG
# - **Ochrana súkromia**: Detekcia a redakcia PII
#
# ## 🔒 Podnikové bezpečnostné funkcie
#
# ### Overovanie a autorizácia
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Ochrana údajov
# - **Šifrovanie**: End-to-end šifrovanie dokumentov a vyhľadávacích indexov
# - **Kontroly prístupu**: Integrácia s Azure AD pre povolenia používateľov a skupín
# - **Umiestnenie údajov**: Geografická kontrola miesta údajov za účelom súladu
# - **Zálohovanie a obnova**: Automatizované zálohovacie a obnovovacie možnosti
#
# ## 📈 Optimalizácia výkonu
#
# ### Vzory asynchrónneho spracovania
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Správa pamäte
# - **Streamingové spracovanie**: Spracovanie veľkých dokumentov bez problémov s pamäťou
# - **Pooling zdrojov**: Efektívne opätovné používanie nákladných zdrojov
# - **Garbage Collection**: Optimalizované vzory prideľovania pamäte
# - **Správa spojení**: Správny životný cyklus pripojení ku službám Azure
#
# ### Cachingové stratégie
# - **Caching dotazov**: Cache pre často vykonávané vyhľadávania
# - **Caching dokumentov**: Cache v pamäti pre často používané dokumenty
# - **Caching indexov**: Optimalizované cachovanie vektorových indexov
# - **Caching výsledkov**: Inteligentné cachovanie generovaných odpovedí
#
# ## 📊 Podnikové prípady použitia
#
# ### Správa znalostí
# - **Firemná wiki**: Inteligentné vyhľadávanie naprieč vedomosťami firmy
# - **Politiky a postupy**: Automatizované vedenie súladu a postupov
# - **Školenia a materiály**: Inteligentná podpora vzdelávania a rozvoja
# - **Výskumné databázy**: Systémy na analýzu akademických a výskumných prác
#
# ### Zákaznícka podpora
# - **Znalostná báza podpory**: Automatizované odpovede zákazníckej podpory
# - **Produktová dokumentácia**: Inteligentné získavanie informácií o produktoch
# - **Príručky na riešenie problémov**: Kontextová pomoc pri riešení problémov
# - **FAQ systémy**: Dynamická generácia FAQ z kolekcií dokumentov
#
# ### Súlad s predpismi
# - **Analýza právnych dokumentov**: Inteligencia pre zmluvy a právne dokumenty
# - **Monitorovanie súladu**: Automatizované overovanie regulačného súladu
# - **Hodnotenie rizík**: Riziková analýza a reportovanie na základe dokumentov
# - **Podpora auditov**: Inteligentné vyhľadávanie dokumentov pre audity
#
# ## 🚀 Nasadenie do výroby
#
# ### Monitorovanie a pozorovateľnosť
# - **Application Insights**: Detailná telemetria a monitorovanie výkonu
# - **Vlastné metriky**: Sledovanie KPI špecifických pre biznis a upozornenia
# - **Distribuované trasovanie**: Celkový prehľad požiadaviek naprieč službami
# - **Dashboardy zdravia**: Vizualizácia zdravotného stavu a výkonu systému v reálnom čase
#
# ### Škálovateľnosť a spoľahlivosť
# - **Automatické škálovanie**: Automatické škálovanie na základe záťaže a metrík výkonu
# - **Vysoká dostupnosť**: Nasadenie v multi-regionoch s failover možnosťami
# - **Testovanie záťaže**: Validácia výkonu pri podnikových záťažiach
# - **Obnova po havárii**: Automatizované zálohovanie a obnovovacie postupy
#
# Pripravení vybudovať podnikové RAG systémy, ktoré zvládnu citlivé dokumenty v rozsahu? Navrhnime inteligentné znalostné systémy pre podnik! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vyhlásenie o zodpovednosti**:
# Tento dokument bol preložený pomocou AI prekladateľskej služby [Co-op Translator](https://github.com/Azure/co-op-translator). Hoci sa snažíme o presnosť, vezmite prosím na vedomie, že automatické preklady môžu obsahovať chyby alebo nepresnosti. Pôvodný dokument v jeho natívnom jazyku by mal byť považovaný za autoritatívny zdroj. Pre kritické informácie sa odporúča profesionálny ľudský preklad. Nie sme zodpovední za žiadne nedorozumenia alebo nesprávne interpretácie vyplývajúce z použitia tohto prekladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
