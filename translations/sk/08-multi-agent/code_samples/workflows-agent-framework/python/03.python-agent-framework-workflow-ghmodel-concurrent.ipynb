# %% [markdown]
# # ⚡ Súbežné workflow agentov s Microsoft Foundry (Python)
#
# ## 📋 Pokročilý návod na paralelné spracovanie
#
# Tento zošit demonštruje **súbežné vzory workflow** pomocou Microsoft Agent Framework. Naučíte sa, ako vytvárať vysoko výkonné, paralelné workflow, kde viacerí AI agenti vykonávajú úlohy súčasne, čo dramaticky zlepšuje priepustnosť a umožňuje sofistikované viacvláknové podnikové procesy.
#
# > **Poznámka o migrácii:** Tento príklad predtým používal GitHub Models. GitHub Models je zastaralý (bude ukončený v júli 2026), preto teraz využíva **Microsoft Foundry** cez `FoundryChatClient`, ktorý cieli na Azure OpenAI **Responses API**.
#
# ## 🎯 Ciele učenia
#
# ### 🚀 **Základy súbežného spracovania**
# - **Paralelné spustenie agentov**: Súbežný beh viacerých agentov pre maksímálnu efektivitu
# - **Orchestrace workflow**: Koordinácia súbežných operácií pri zachovaní konzistencie dát
# - **Optimalizácia výkonu**: Dosiahnutie výrazného zrýchlenia paralelným spracovaním
# - **Správa zdrojov**: Efektívne využívanie AI modelov pri súbežných operáciách
#
# ### 🏗️ **Pokročilé vzory súbežnosti**
# - **Fork-Join spracovanie**: Rozdelenie práce medzi viacerých agentov a zlúčenie výsledkov
# - **Pipeline paralelizmus**: Prekrývajúce sa fázy vykonávania pre kontinuitu priepustnosti
# - **Vyvažovanie záťaže**: Rovnomerné rozdelenie práce medzi dostupné agentné zdroje
# - **Synchronizačné body**: Koordinácia súbežných agentov v kritických fázach workflow
#
# ### 🏢 **Súbežné podnikové aplikácie**
# - **Spracovanie veľkého objemu dokumentov**: Súbežné spracovanie viacerých dokumentov
# - **Analýza obsahu v reálnom čase**: Súbežná analýza prichádzajúcich dátových tokov
# - **Optimalizácia dávkového spracovania**: Maximálna priepustnosť pre rozsiahle operácie
# - **Multimodálna analýza**: Paralelné spracovanie rôznych typov obsahu (text, obrázky, dáta)
#
# ## ⚙️ Predpoklady a nastavenie
#
# ### 📦 **Požadované závislosti**
#
# Nainštalujte Agent Framework so schopnosťami súbežných workflow:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfigurácia Microsoft Foundry**
#
# Prihláste sa cez Azure CLI (`az login`), aby sa `AzureCliCredential` mohol autentifikovať, potom nastavte svoje projektové údaje Microsoft Foundry.
#
# **Nastavenie prostredia (.env súbor):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Úvahy o súbežnom spracovaní:**
# - **Limit rýchlosti**: Monitorujte limity Azure OpenAI pre súbežné požiadavky
# - **Využitie zdrojov**: Zohľadnite pamäť a CPU pri viacerých súbežných agentoch
# - **Spracovanie chýb**: Implementujte robustné zotavenie z chýb pri paralelných operáciách
#
# ### 🏗️ **Architektúra súbežného workflow**
#
# ```mermaid
# graph TD
#     A[Začiatok pracovného postupu] --> B[Súbežné vykonávanie]
#     B --> C[Zásoba agentov 1]
#     B --> D[Zásoba agentov 2]
#     B --> E[Zásoba agentov 3]
#     C --> F[Zbieranie výsledkov]
#     D --> F
#     E --> F
#     F --> G[Konečný výstup]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Kľúčové výhody:**
# - **⚡ Výkon**: Výrazné zrýchlenie vďaka paralelnému vykonávaniu
# - **📈 Škálovateľnosť**: Spracovanie väčších záťaží bez pomerného nárastu času
# - **🔄 Efektivita**: Lepšie využitie dostupných výpočtových zdrojov
# - **🎯 Priepustnosť**: Spracovanie viac práce za rovnaký čas
#
# ## 🎨 **Vzory dizajnu súbežného workflow**
#
# ### 🔍 **Pipeline pre výskum a analýzu**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Workflow pre spracovanie dát**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline tvorby obsahu**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Viacfázové spracovanie**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Podnikové výhody výkonu**
#
# ### ⚡ **Optimalizácia priepustnosti**
# - **Paralelné vykonávanie**: Viacerí agenti pracujúci súčasne
# - **Využitie zdrojov**: Maksimálna efektivita kapacity dostupných AI modelov
# - **Zníženie času**: Výrazné skrátenie celkového času spracovania
# - **Škálovateľná architektúra**: Jednoduché pridanie ďalších súbežných agentov podľa potreby
#
# ### 🛡️ **Spoľahlivosť a odolnosť**
# - **Odolnosť voči chybám**: Zlyhanie jednotlivých agentov nezastaví celé workflow
# - **Izolácia chýb**: Problémy v jednej súbežnej vetve neovplyvnia ostatné
# - **Graceful degradation**: Systém pokračuje v prevádzke aj pri zníženej kapacite agentov
# - **Mechanizmy zotavenia**: Automatické opakovanie a spracovanie chýb pri zlyhaní operácií
#
# ### 📊 **Monitorovanie a pozorovateľnosť**
# - **Sledovanie súbežného vykonávania**: Monitorujte priebeh všetkých paralelných operácií
# - **Výkonové metriky**: Merajte zrýchlenie a zisky efektivity
# - **Analýza využitia zdrojov**: Optimalizujte alokáciu súbežných agentov
# - **Identifikácia úzkych miest**: Nájdite a odstránte výkonnostné obmedzenia
#
# Poďme vytvoriť vysoko výkonné súbežné AI workflow! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vyhlásenie o zodpovednosti**:
# Tento dokument bol preložený pomocou AI prekladateľskej služby [Co-op Translator](https://github.com/Azure/co-op-translator). Hoci sa snažíme o presnosť, vezmite prosím na vedomie, že automatické preklady môžu obsahovať chyby alebo nepresnosti. Pôvodný dokument v jeho natívnom jazyku by mal byť považovaný za autoritatívny zdroj. Pre kritické informácie sa odporúča profesionálny ľudský preklad. Nie sme zodpovední za žiadne nedorozumenia alebo nesprávne interpretácie vyplývajúce z použitia tohto prekladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
