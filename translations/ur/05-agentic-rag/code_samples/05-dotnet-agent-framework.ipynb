# %% [markdown]
# # 🔍 مائیکروسافٹ فاؤنڈری (.NET) کے ساتھ انٹرپرائز RAG
#
# ## 📋 تعلیمی مقاصد
#
# یہ نوٹ بک دکھاتا ہے کہ مائیکروسافٹ فاؤنڈری میں .NET کے ساتھ مائیکروسافٹ ایجنٹ فریم ورک استعمال کرتے ہوئے انٹرپرائز گریڈ رٹریول-اگمینٹڈ جنریشن (RAG) سسٹمز کیسے بنائیں۔ آپ پیداوار کے لیے تیار ایجنٹس بنانے سیکھیں گے جو دستاویزات میں تلاش کر سکتے ہیں اور انٹرپرائز سیکورٹی اور اسکیل ایبلٹی کے ساتھ درست، سیاق و سباق سے آگاہ جوابات فراہم کر سکتے ہیں۔
#
# **وہ انٹرپرائز RAG صلاحیتیں جو آپ بنائیں گے:**
# - 📚 **دستاویزات کی ذہانت**: Azure AI خدمات کے ساتھ جدید دستاویزات کی پروسیسنگ
# - 🔍 **سمانٹک سرچ**: انٹرپرائز خصوصیات کے ساتھ اعلیٰ کارکردگی والا ویکٹر سرچ
# - 🛡️ **سیکورٹی انٹیگریشن**: کردار کی بنیاد پر رسائی اور ڈیٹا تحفظ کے نمونے
# - 🏢 **اسکیل ایبل آرکیٹیکچر**: نگرانی کے ساتھ پیداوار کے لیے تیار RAG سسٹمز
#
# ## 🎯 انٹرپرائز RAG آرکیٹیکچر
#
# ### بنیادی انٹرپرائز اجزاء
# - **مائیکروسافٹ فاؤنڈری**: سیکورٹی اور تعمیل کے ساتھ منظم انٹرپرائز AI پلیٹ فارم
# - **پرسسٹنٹ ایجنٹس**: ریاستی ایجنٹس جن میں گفتگو کی تاریخ اور سیاق و سباق کا انتظام ہے
# - **ویکٹر اسٹور مینجمنٹ**: انٹرپرائز گریڈ دستاویز کی انڈیکسنگ اور بازیافت
# - **شناخت کا انضمام**: Azure AD توثیق اور کردار کی بنیاد پر رسائی کنٹرول
#
# ### .NET انٹرپرائز فوائد
# - **ٹائپ سیفٹی**: RAG آپریشنز اور ڈیٹا ڈھانچوں کے لیے کمپائل ٹائم تصدیق
# - **آسنکرونکارکردگی**: غیر منقطع دستاویزات کی پروسیسنگ اور سرچ آپریشنز
# - **میموری مینجمنٹ**: بڑے دستاویزات کے مجموعوں کے لیے موثر وسائل کا استعمال
# - **انٹیگریشن پیٹرنز**: انحصار میں انجیکشن کے ساتھ مقامی Azure سروس انضمام
#
# ## 🏗️ تکنیکی آرکیٹیکچر
#
# ### انٹرپرائز RAG پائپ لائن
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### بنیادی .NET اجزاء
# - **Azure.AI.Agents.Persistent**: ریاست کی مستقل مزاجی کے ساتھ انٹرپرائز ایجنٹ مینجمنٹ
# - **Azure.Identity**: محفوظ Azure سروس تک رسائی کے لیے مربوط توثیق
# - **Microsoft.Agents.AI.AzureAI**: Azure کے لیے بہتر بنایا ہوا ایجنٹ فریم ورک کی عملدرآمد
# - **System.Linq.Async**: اعلیٰ کارکردگی والے غیر متزامن LINQ آپریشنز
#
# ## 🔧 انٹرپرائز خصوصیات اور فوائد
#
# ### سیکورٹی اور تعمیل
# - **Azure AD انضمام**: انٹرپرائز شناخت مینجمنٹ اور توثیق
# - **کردار کی بنیاد پر رسائی**: دستاویزات کی رسائی اور آپریشنز کے لیے باریک بینی پر مبنی اجازتیں
# - **ڈیٹا پروٹیکشن**: حساس دستاویزات کے لیے آرام اور منتقلی پر انکرپشن
# - **آڈٹ لاگنگ**: تعمیل کی ضروریات کے لیے مکمل سرگرمیوں کا ریکارڈ
#
# ### کارکردگی اور اسکیل ایبلٹی
# - **کنکشن پولنگ**: موثر Azure سروس کنکشن مینجمنٹ
# - **آسنکرون پروسیسنگ**: اعلیٰ تھرو پٹ منظرناموں کے لیے غیر منقطع آپریشنز
# - **کیشنگ حکمت عملی**: بار بار استعمال ہونے والی دستاویزات کے لیے ذہین کیشنگ
# - **لوڈ بیلنسنگ**: وسیع پیمانے پر تعینات کے لیے تقسیم شدہ پروسیسنگ
#
# ### انتظام اور نگرانی
# - **ہیلتھ چیکس**: RAG سسٹم کے اجزاء کے لیے بلٹ ان نگرانی
# - **کارکردگی میٹرکس**: تلاش کے معیار اور جوابی وقتوں پر مفصل تجزیہ
# - **ایرر ہینڈلنگ**: جامع استثناء انتظام اور ریٹری پالیسیز
# - **کنفیگریشن مینجمنٹ**: ماحولیاتی مخصوص ترتیبات اور تصدیق
#
# ## ⚙️ ضروریات اور سیٹ اپ
#
# **ترقیاتی ماحول:**
# - .NET 9.0 SDK یا اس سے زیادہ
# - Visual Studio 2022 یا VS Code کے ساتھ C# ایکسٹینشن
# - AI فاؤنڈری تک رسائی کے ساتھ Azure سبسکرپشن
#
# **ضروری NuGet پیکیجز:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure توثیق سیٹ اپ:**
# ```bash
# # Azure CLI انسٹال کریں اور تصدیق کریں
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **ماحولیاتی کنفیگریشن (.env فائل):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 انٹرپرائز RAG کے نمونے
#
# ### دستاویزات کے انتظام کے نمونے
# - **بلک اپلوڈ**: بڑے دستاویزات کے مجموعوں کی موثر پروسیسنگ
# - **اضافہ شدہ تازہ کاری**: ریئل ٹائم میں دستاویزات کا اضافہ اور ترمیم
# - **ورژن کنٹرول**: دستاویزات کی ورژننگ اور تبدیلیوں کا پتہ لگانا
# - **میٹا ڈیٹا مینجمنٹ**: دستاویزات کی خصوصیات اور ٹیکسونومی کی فروانی
#
# ### تلاش اور بازیافت کے نمونے
# - **ہائبرڈ سرچ**: بہترین نتائج کے لیے سمانٹک اور کی ورڈ سرچ کا امتزاج
# - **فیسٹیڈ سرچ**: کثیر جہتی فلٹرنگ اور درجہ بندی
# - **ریلیونس ٹیوننگ**: مخصوص ڈومین ضروریات کے لیے حسب ضرورت سکورنگ الگورتھمز
# - **نتائج کی درجہ بندی**: کاروباری منطق کے انضمام کے ساتھ اعلیٰ درجے کی درجہ بندی
#
# ### سیکورٹی کے نمونے
# - **دستاویز کی سطح کی سیکورٹی**: ہر دستاویز کے لیے باریک بینی پر مبنی رسائی کنٹرول
# - **ڈیٹا درجہ بندی**: خودکار حساسیت لیبلنگ اور تحفظ
# - **آڈٹ ٹریلس**: تمام RAG آپریشنز کا جامع لاگنگ
# - **پرائیویسی پروٹیکشن**: ذاتی شناختی معلومات کی دریافت اور ریڈیکشن کی صلاحیتیں
#
# ## 🔒 انٹرپرائز سیکورٹی خصوصیات
#
# ### توثیق اور اجازت
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### ڈیٹا پروٹیکشن
# - **انکرپشن**: دستاویزات اور تلاش کے اشاریوں کے لیے اختتام سے اختتام تک انکرپشن
# - **رسائی کنٹرولز**: Azure AD کے ساتھ صارف اور گروپ کی اجازتوں کا انضمام
# - **ڈیٹا رہائش**: تعمیل کے لیے جغرافیائی ڈیٹا لوکیشن کنٹرول
# - **بیک اپ اور ریکوری**: خودکار بیک اپ اور آفت کی بحالی کی صلاحیتیں
#
# ## 📈 کارکردگی کی بہتری
#
# ### آسنکرون پروسیسنگ کے نمونے
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### میموری مینجمنٹ
# - **اسٹریمنگ پروسیسنگ**: بڑے دستاویزات کو میموری کے مسائل کے بغیر ہینڈل کریں
# - **وسائل کی پولنگ**: مہنگے وسائل کا موثر دوبارہ استعمال
# - **گاربیج کلیکشن**: میموری کی مختص کرنے کے نمونوں کو بہتر بنایا گیا
# - **کنکشن مینجمنٹ**: Azure سروس کنکشن کی مناسب لائف سائیکل
#
# ### کیشنگ حکمت عملی
# - **کوئری کیشنگ**: اکثر چلائی جانے والی تلاشوں کا کیش
# - **دستاویز کیشنگ**: گرم دستاویزات کے لیے ان میموری کیشنگ
# - **انڈیکس کیشنگ**: بہتر شدہ ویکٹر انڈیکس کیشنگ
# - **نتائج کی کیشنگ**: تیار کردہ جوابات کی ذہین کیشنگ
#
# ## 📊 انٹرپرائز استعمال کے معاملات
#
# ### علم کا انتظام
# - **کارپوریٹ وکی**: کمپنی کے علم کے بیسز میں ذہین تلاش
# - **پالیسیاں اور طریقہ کار**: خودکار تعمیل اور طریقہ کار کی رہنمائی
# - **تربیتی مواد**: ذہین تعلیم اور ترقی میں معاونت
# - **تحقیقی ڈیٹابیسز**: علمی اور تحقیقی مقالہ جات کے تجزیاتی نظام
#
# ### کسٹمر سپورٹ
# - **سپورٹ نالج بیس**: خودکار کسٹمر سروس جوابات
# - **مصنوع کی دستاویزات**: ذہین مصنوعات کی معلومات کی بازیافت
# - **مسئلہ حل کرنے کے رہنما**: سیاق و سباق پر مبنی مسئلے کا حل
# - **FAQ نظام**: دستاویزات کے مجموعوں سے متحرک FAQs کی تخلیق
#
# ### ریگولیٹری تعمیل
# - **قانونی دستاویزات کا تجزیہ**: معاہدہ اور قانونی دستاویزات کی ذہانت
# - **تعمیل کی نگرانی**: خودکار ریگولیٹری تعمیل کی جانچ
# - **خطرے کا اندازہ**: دستاویزات کی بنیاد پر خطرے کا تجزیہ اور رپورٹنگ
# - **آڈٹ سپورٹ**: آڈٹس کے لیے ذہین دستاویزات کی دریافت
#
# ## 🚀 پیداوار کی تعیناتی
#
# ### نگرانی اور مشاہدہ پذیری
# - **ایپلیکیشن انسائٹس**: مفصل ٹیلی میٹری اور کارکردگی کی نگرانی
# - **حسب ضرورت میٹرکس**: کاروباری مخصوص KPI ٹریکنگ اور الارمنگ
# - **تقسیم شدہ ٹریسنگ**: خدمات کے درمیان اختتام سے اختتام درخواست کا سراغ
# - **صحت کے ڈیش بورڈز**: نظام کی صحت اور کارکردگی کی حقیقی وقت کی بصری نمائندگی
#
# ### اسکیل ایبلٹی اور قابل اعتماد
# - **آٹو اسکیلنگ**: لوڈ اور کارکردگی میٹرکس کی بنیاد پر خودکار اسکیلنگ
# - **اعلی دستیابی**: ملٹی ریجن تعیناتی کے ساتھ فال اوور صلاحیتیں
# - **لوڈ ٹیسٹنگ**: انٹرپرائز لوڈ حالات میں کارکردگی کی تصدیق
# - **آفت کی بحالی**: خودکار بیک اپ اور ریکوری کے طریقہ کار
#
# کیا آپ تیار ہیں انٹرپرائز گریڈ RAG سسٹمز بنانے کے لیے جو حساس دستاویزات کو پیمانے پر سنبھال سکیں؟ آئیے انٹرپرائز کے لیے ذہین علم کے نظاموں کا آرکیٹیکچر بنائیں! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ڈس کلیمر**:
# یہ دستاویز AI ترجمہ سروس [Co-op Translator](https://github.com/Azure/co-op-translator) کے ذریعے ترجمہ کی گئی ہے۔ جبکہ ہم درستگی کے لیے کوشاں ہیں، براہ کرم اس بات سے آگاہ رہیں کہ خودکار ترجمے میں غلطیاں یا عدم درستیاں ہو سکتی ہیں۔ اصل دستاویز اپنے مادری زبان میں مستند ماخذ سمجھی جائے گی۔ حساس معلومات کے لیے پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ اس ترجمے کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کی ذمہ داری ہم قبول نہیں کرتے۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
