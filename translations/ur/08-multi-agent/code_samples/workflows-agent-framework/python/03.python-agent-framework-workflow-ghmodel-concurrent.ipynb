# %% [markdown]
# # ⚡ مائیکروسافٹ فاؤنڈری کے ساتھ متوازی ایجنٹ ورک فلو (پائتھون)
#
# ## 📋 جدید متوازی عمل کاری سبق
#
# یہ نوٹ بک **متوازی ورک فلو پیٹرنز** کو مائیکروسافٹ ایجنٹ فریم ورک استعمال کرتے ہوئے ظاہر کرتی ہے۔ آپ سیکھیں گے کہ کس طرح اعلی کارکردگی والے، متوازی پروسیسنگ ورک فلو تیار کیے جائیں جہاں متعدد AI ایجنٹ بیک وقت عمل کرتے ہیں، جس سے تھروپٹ میں نمایاں بہتری آتی ہے اور پیچیدہ ملٹی تھریڈڈ کاروباری عمل ممکن ہوتے ہیں۔
#
# > **منتقلی کا نوٹ:** یہ نمونہ پہلے GitHub ماڈلز کا حوالہ دیتا تھا۔ GitHub ماڈلز غیر فعال ہو رہا ہے (جولائی 2026 کو ریٹائر ہو رہا ہے)، لہٰذا اب یہ **مائیکروسافٹ فاؤنڈری** کو `FoundryChatClient` کے ذریعے استعمال کرتا ہے، جو Azure OpenAI **Responses API** کو ہدف بناتا ہے۔
#
# ## 🎯 سیکھنے کے مقاصد
#
# ### 🚀 **متوازی عمل کاری کی بنیادی باتیں**
# - **متوازی ایجنٹ عمل کاری**: زیادہ سے زیادہ کارکردگی کے لیے متعدد ایجنٹس کو بیک وقت چلائیں
# - **ورک فلو آرتھسٹریشن**: متوازی عملیات کی ہم آہنگی کرتے ہوئے ڈیٹا کی مطابقت برقرار رکھیں
# - **کارکردگی کی بہتری**: متوازی پروسیسنگ کے ذریعے نمایاں تیز رفتاری حاصل کریں
# - **وسائل کا انتظام**: متوازی عملیات میں AI ماڈل کے وسائل کا مؤثر استعمال کریں
#
# ### 🏗️ **جدید متوازی پیٹرنز**
# - **فورک-جوائن پروسیسنگ**: کام کو متعدد ایجنٹس میں تقسیم کریں اور نتائج ضم کریں
# - **پائپ لائن متوازی عمل کاری**: متواتر پروسیسنگ کے لیے عمل کے مراحل کو متوازی چلائیں
# - **لوڈ بیلنسنگ**: دستیاب ایجنٹ وسائل میں کام برابر تقسیم کریں
# - **ہم آہنگی کے نکات**: اہم ورک فلو مراحل پر متوازی ایجنٹس کی ہم آہنگی کریں
#
# ### 🏢 **ادارتی متوازی ایپلیکیشنز**
# - **اعلی مقدار دستاویز پروسیسنگ**: متعدد دستاویزات بیک وقت پروسیس کریں
# - **ریئل ٹائم مواد کی تجزیہ**: آنے والے ڈیٹا اسٹریمز کا متوازی تجزیہ کریں
# - **بیچ پروسیسنگ کی بہتری**: بڑی سطح کے عمل کے لیے تھروپٹ زیادہ سے زیادہ کریں
# - **ملٹی موڈال تجزیہ**: مختلف قسم کے مواد (متن، تصاویر، ڈیٹا) کا متوازی پروسیسنگ کریں
#
# ## ⚙️ بنیادی تقاضے اور سیٹ اپ
#
# ### 📦 **ضروری انحصار**
#
# ایجنٹ فریم ورک انسٹال کریں جو متوازی ورک فلو صلاحیت رکھتا ہو:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **مائیکروسافٹ فاؤنڈری کنفیگریشن**
#
# Azure CLI (`az login`) کے ساتھ سائن ان کریں تاکہ `AzureCliCredential` تصدیق کر سکے، پھر اپنے مائیکروسافٹ فاؤنڈری پروجیکٹ کی تفصیلات سیٹ کریں۔
#
# **ماحول کی ترتیب (.env فائل):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **متوازی پروسیسنگ کے گ،واندز:**
# - **ریٹ لیمٹس**: متوازی درخواستوں کے لیے Azure OpenAI کی ریٹ لیمٹس کا مشاہدہ کریں
# - **وسائل کا استعمال**: متعدد متوازی ایجنٹس کے حافظہ اور CPU استعمال کو مدنظر رکھیں
# - **خرابی کا انتظام**: متوازی عملیات کے لیے مضبوط خرابی بازیابی نافذ کریں
#
# ### 🏗️ **متوازی ورک فلو کی ساخت**
#
# ```mermaid
# graph TD
#     A[ورک فلو شروع] --> B[متوازی عملدرآمد]
#     B --> C[ایجنٹ پول 1]
#     B --> D[ایجنٹ پول 2]
#     B --> E[ایجنٹ پول 3]
#     C --> F[نتیجہ تجمیع]
#     D --> F
#     E --> F
#     F --> G[حتمی آؤٹ پٹ]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **اہم فوائد:**
# - **⚡ کارکردگی**: متوازی عمل کاری کے ذریعے نمایاں تیز رفتاری
# - **📈 توسیع پذیری**: بغیر وقت میں تناسبی اضافہ کے بڑھتے ہوئے کام سنبھالیں
# - **🔄 مؤثریت**: دستیاب کمپیوٹیشنل وسائل کا بہتر استعمال
# - **🎯 تھروپٹ**: ایک ہی وقت میں زیادہ کام پروسیس کریں
#
# ## 🎨 **متوازی ورک فلو ڈیزائن پیٹرنز**
#
# ### 🔍 **تحقیقی و تجزیاتی پائپ لائن**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ڈیٹا پروسیسنگ ورک فلو**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **مواد تخلیق کی پائپ لائن**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **کئی مراحل کی پروسیسنگ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ادارتی کارکردگی کے فوائد**
#
# ### ⚡ **تھروپٹ کی بہتری**
# - **متوازی عمل کاری**: متعدد ایجنٹس بیک وقت کام کر رہے ہیں
# - **وسائل کا استعمال**: دستیاب AI ماڈل کی صلاحیت کی زیادہ سے زیادہ مؤثریت
# - **وقت کی کمی**: کل عمل کاری کے وقت میں نمایاں کمی
# - **توسیع پذیر ساخت**: ضرورت کے مطابق متوازی ایجنٹس آسانی سے بڑھائیں
#
# ### 🛡️ **اعتماد اور استحکام**
# - **فالٹ ٹولیرنس**: انفرادی ایجنٹ کی ناکامیاں پورے ورک فلو کو روکتی نہیں ہیں
# - **خرابی کی علیحدگی**: ایک متوازی شاخ کے مسائل دوسروں کو متاثر نہیں کرتے
# - **شائستہ کمی**: کم ایجنٹ صلاحیت کے باوجود نظام چلتا رہتا ہے
# - **بازیابی کے طریقے**: ناکام آپریشنز کے لیے خودکار دوبارہ کوشش اور خرابی کا انتظام
#
# ### 📊 **مانیٹرنگ اور مشاہدہ**
# - **متوازی عمل کی نگرانی**: تمام متوازی عملیات کی پیش رفت کو مانیٹر کریں
# - **کارکردگی کے میٹرکس**: تیز رفتاری اور مؤثریت میں اضافہ ماپیں
# - **وسائل کے استعمال کا تجزیہ**: متوازی ایجنٹس کی تخصیص کو بہتر بنائیں
# - **رکاوٹ کی شناخت**: کارکردگی کی حدود کو تلاش اور حل کریں
#
# آئیے اعلی کارکردگی والے متوازی AI ورک فلو بنائیں! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ڈس کلیمر**:
# یہ دستاویز AI ترجمہ سروس [Co-op Translator](https://github.com/Azure/co-op-translator) کے ذریعے ترجمہ کی گئی ہے۔ جبکہ ہم درستگی کے لیے کوشاں ہیں، براہ کرم اس بات سے آگاہ رہیں کہ خودکار ترجمے میں غلطیاں یا عدم درستیاں ہو سکتی ہیں۔ اصل دستاویز اپنے مادری زبان میں مستند ماخذ سمجھی جائے گی۔ حساس معلومات کے لیے پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ اس ترجمے کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کی ذمہ داری ہم قبول نہیں کرتے۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
