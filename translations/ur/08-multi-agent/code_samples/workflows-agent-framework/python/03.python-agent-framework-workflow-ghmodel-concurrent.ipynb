# %% [markdown]
# # ⚡ مائیکروسافٹ فاؤنڈری کے ساتھ متوازی ایجنٹ ورک فلو (پائتھون)
#
# ## 📋 اعلی سطح کا متوازی پراسیسنگ سبق
#
# یہ نوٹ بک مائیکروسافٹ ایجنٹ فریم ورک کا استعمال کرتے ہوئے **ہم وقت ساز ورک فلو پیٹرنز** کو ظاہر کرتی ہے۔ آپ سیکھیں گے کہ کس طرح اعلیٰ کارکردگی والے، متوازی پراسیسنگ ورک فلو تیار کریں جہاں متعدد AI ایجنٹ بیک وقت کام کرتے ہیں، جس سے تھروپٹ میں بے حد اضافہ ہوتا ہے اور پیچیدہ ملٹی تھریڈڈ کاروباری عمل ممکن ہوتے ہیں۔
#
# > **منتقلی کا نوٹس:** اس نمونے میں پہلے GitHub Models کا حوالہ دیا گیا تھا۔ GitHub Models کو ختم کیا جا رہا ہے (جولائی 2026 سے ریٹائرمنٹ کے لیے)، لہٰذا اب یہ Azure OpenAI **Responses API** کو ہدف بنانے والے `FoundryChatClient` کے ذریعے **Microsoft Foundry** استعمال کرتا ہے۔
#
# ## 🎯 سیکھنے کے مقاصد
#
# ### 🚀 **ہم وقت ساز پراسیسنگ کے اصول**
# - **متوازی ایجنٹ عمل درآمد**: زیادہ سے زیادہ کارکردگی کے لیے متعدد ایجنٹس کو بیک وقت چلائیں
# - **ورک فلو ترتیب**: ہم وقت ساز عمل کو مربوط کریں اور ڈیٹا کی مطابقت برقرار رکھیں
# - **کارکردگی کی بہتری**: متوازی پراسیسنگ کے ذریعے نمایاں رفتار میں اضافہ حاصل کریں
# - **وسائل کا انتظام**: ہم وقت ساز عمل میں AI ماڈل کے وسائل کا موثر استعمال
#
# ### 🏗️ **اعلی درجے کے ہم وقت ساز پیٹرن**
# - **فورک-جوائن پراسیسنگ**: کام کو متعدد ایجنٹس میں تقسیم کریں اور نتائج کو ضم کریں
# - **پائپ لائن متوازی عمل**: لگاتار تھروپٹ کے لیے عملدرآمد کے مراحل میں اوورلیپنگ
# - **لوڈ بیلنسنگ**: دستیاب ایجنٹ وسائل کے درمیان مساوی تقسیم
# - **ہم وقت سازی کے نقاط**: اہم ورک فلو مراحل پر ہم وقت ساز ایجنٹس کا تعاون
#
# ### 🏢 **انٹرپرائز میں ہم وقت ساز ایپلیکیشنز**
# - **بڑی مقدار میں دستاویزات کی پراسیسنگ**: متعدد دستاویزات کو بیک وقت پراسیس کریں
# - **حقیقی وقت مواد کا تجزیہ**: آنے والے ڈیٹا اسٹریمز کا ہم وقت تجزیہ
# - **بیچ پراسیسنگ کی بہتری**: بڑے پیمانے پر آپریشنز کے لیے زیادہ سے زیادہ تھروپٹ
# - **کثیر وضعی تجزیہ**: مختلف قسم کے مواد (متن، تصاویر، ڈیٹا) کی متوازی پراسیسنگ
#
# ## ⚙️ ضروریات اور ترتیب
#
# ### 📦 **ضروری انحصار**
#
# متوازی ورک فلو کی صلاحیتوں کے ساتھ ایجنٹ فریم ورک انسٹال کریں:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **مائیکروسافٹ فاؤنڈری کی ترتیب**
#
# Azure CLI (`az login`) کے ذریعے سائن ان کریں تاکہ `AzureCliCredential` تصدیق کر سکے، پھر اپنے Microsoft Foundry پراجیکٹ کی تفصیلات سیٹ کریں۔
#
# **ماحول کی ترتیب (.env فائل):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **ہم وقت ساز پراسیسنگ کے خیالات:**
# - **ریٹ لمٹس**: Azure OpenAI کی سات وقت درخواستوں کی حدوں کی نگرانی کریں
# - **وسائل کا استعمال**: متعدد ہم وقت ایجنٹس کے ساتھ میموری اور CPU کا خیال رکھیں
# - **غلطی سے نمٹنا**: متوازی آپریشنز کے لیے مضبوط غلطی کی بازیابی نافذ کریں
#
# ### 🏗️ **ہم وقت ساز ورک فلو کی فن تعمیر**
#
# ```mermaid
# graph TD
#     A[ورک فلو شروع] --> B[متوازی عملدرآمد]
#     B --> C[ایجنٹ پول 1]
#     B --> D[ایجنٹ پول 2]
#     B --> E[ایجنٹ پول 3]
#     C --> F[نتائج کا مجموعہ]
#     D --> F
#     E --> F
#     F --> G[حتمی آؤٹ پٹ]
#
#     H[مائیکروسافٹ فاؤنڈری] --> C
#     H --> D
#     H --> E
# ```
#
# **اہم فوائد:**
# - **⚡ کارکردگی**: متوازی عملدرآمد کے ذریعے نمایاں رفتار میں اضافہ
# - **📈 توسیع پذیری**: بڑھتے ہوئے کاموں کو بغیر وقت میں اضافے کے سنبھالیں
# - **🔄 کفایتی**: دستیاب کمپیوٹیشنل وسائل کا بہتر استعمال
# - **🎯 تھروپٹ**: ایک ہی وقت میں مزید کام انجام دیں
#
# ## 🎨 **ہم وقت ساز ورک فلو ڈیزائن پیٹرنز**
#
# ### 🔍 **تحقیقی و تجزیاتی پائپ لائن**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ڈیٹا پراسیسنگ ورک فلو**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **مواد کی تخلیقی پائپ لائن**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **کئی مرحلوں والی پراسیسنگ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **انٹرپرائز کی کارکردگی کے فائدے**
#
# ### ⚡ **تھروپٹ کی بہتری**
# - **متوازی عمل**: متعدد ایجنٹس بیک وقت کام کر رہے ہیں
# - **وسائل کا استعمال**: دستیاب AI ماڈل صلاحیت کی زیادہ سے زیادہ کارکردگی
# - **وقت میں کمی**: کل پروسیسنگ کے وقت میں نمایاں کمی
# - **توسیعی فن تعمیر**: ضرورت کے مطابق مزید ہم وقت ایجنٹس آسانی سے شامل کریں
#
# ### 🛡️ **قابل اعتبار اور مضبوطی**
# - **خرابی برداشت**: فرد ایجنٹ کی ناکامیاں مکمل ورک فلو کو نہیں روکتیں
# - **غلطی کی جداکاری**: ایک متوازی شاخ میں مسائل دیگر پر اثر انداز نہیں ہوتے
# - **نرمی سے کمی**: ایجنٹ کی کم صلاحیت کے باوجود نظام کام جاری رکھتا ہے
# - **بازیابی کے طریقے**: ناکام آپریشنز کے لیے خودکار دوبارہ کوشش اور غلطی کا انتظام
#
# ### 📊 **نگرانی اور مشاہدہ**
# - **ہم وقت عمل کی ٹریکنگ**: تمام متوازی آپریشنز کی پیش رفت کی نگرانی
# - **کارکردگی میٹرکس**: رفتار میں اضافہ اور کفایت شعاری کے فائدے ناپیں
# - **وسائل کے استعمال کا تجزیہ**: متوازی ایجنٹ تقسیم کو بہتر بنائیں
# - **رکاوٹ کی نشاندہی**: کارکردگی کی پابندیوں کو تلاش کریں اور حل کریں
#
# آئیں اعلیٰ کارکردگی والے ہم وقت ساز AI ورک فلو تیار کریں! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ڈس کلیمر**:
# یہ دستاویز AI ترجمہ سروس [Co-op Translator](https://github.com/Azure/co-op-translator) کے ذریعے ترجمہ کی گئی ہے۔ جبکہ ہم درستگی کے لیے کوشاں ہیں، براہ کرم اس بات سے آگاہ رہیں کہ خودکار ترجمے میں غلطیاں یا عدم درستیاں ہو سکتی ہیں۔ اصل دستاویز اپنے مادری زبان میں مستند ماخذ سمجھی جائے گی۔ حساس معلومات کے لیے پیشہ ور انسانی ترجمہ کی سفارش کی جاتی ہے۔ اس ترجمے کے استعمال سے پیدا ہونے والی کسی بھی غلط فہمی یا غلط تشریح کی ذمہ داری ہم قبول نہیں کرتے۔
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
