# %% [markdown]
# # ⚡ Aliran Kerja Ejen Serentak dengan Microsoft Foundry (Python)
#
# ## 📋 Tutorial Pemprosesan Selari Lanjutan
#
# Notebook ini menunjukkan **corak aliran kerja serentak** menggunakan Rangka Kerja Ejen Microsoft. Anda akan belajar bagaimana membina aliran kerja pemprosesan selari berprestasi tinggi di mana beberapa ejen AI melaksanakan serentak, secara dramatik meningkatkan hasil dan membolehkan proses perniagaan berbilang utas yang canggih.
#
# > **Nota migrasi:** Contoh ini sebelum ini merujuk Model GitHub. Model GitHub telah dimansuhkan (bersara Julai 2026), jadi kini ia menggunakan **Microsoft Foundry** melalui `FoundryChatClient`, yang menyasarkan Azure OpenAI **Responses API**.
#
# ## 🎯 Objektif Pembelajaran
#
# ### 🚀 **Asas Pemprosesan Serentak**
# - **Pelaksanaan Ejen Selari**: Jalankan pelbagai ejen secara serentak untuk kecekapan maksimum
# - **Orkestrasi Aliran Kerja**: Menyelaras operasi serentak sambil mengekalkan konsistensi data
# - **Pengoptimuman Prestasi**: Mencapai peningkatan ketara melalui pemprosesan selari
# - **Pengurusan Sumber**: Menggunakan sumber model AI dengan cekap merentas operasi serentak
#
# ### 🏗️ **Corak Keserentakan Lanjutan**
# - **Pemprosesan Fork-Join**: Membahagikan kerja merentas pelbagai ejen dan menggabungkan hasil
# - **Selari Saluran Paip**: Tahap pelaksanaan bertindih untuk hasil berterusan
# - **Pengimbangan Beban**: Mengagihkan kerja secara sama rata merentas sumber ejen yang tersedia
# - **Titik Penyegerakan**: Menyelaras ejen serentak di peringkat aliran kerja kritikal
#
# ### 🏢 **Aplikasi Serentak Perusahaan**
# - **Pemprosesan Dokumen Berkelajuan Tinggi**: Memproses pelbagai dokumen secara serentak
# - **Analisis Kandungan Masa Nyata**: Analisis serentak aliran data masuk
# - **Pengoptimuman Pemprosesan Kumpulan**: Memaksimumkan hasil untuk operasi skala besar
# - **Analisis Pelbagai Mod**: Pemprosesan selari jenis kandungan berbeza (teks, imej, data)
#
# ## ⚙️ Prasyarat & Persediaan
#
# ### 📦 **Kebergantungan Diperlukan**
#
# Pasang Rangka Kerja Ejen dengan keupayaan aliran kerja serentak:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfigurasi Microsoft Foundry**
#
# Log masuk dengan Azure CLI (`az login`) supaya `AzureCliCredential` boleh mengesahkan, kemudian tetapkan butiran projek Microsoft Foundry anda.
#
# **Persediaan Persekitaran (fail .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Pertimbangan Pemprosesan Serentak:**
# - **Had Kadar**: Pantau had kadar Azure OpenAI untuk permintaan serentak
# - **Penggunaan Sumber**: Pertimbangkan penggunaan memori dan CPU dengan beberapa ejen serentak
# - **Pengendalian Ralat**: Laksanakan pemulihan ralat yang kukuh untuk operasi selari
#
# ### 🏗️ **Seni Bina Aliran Kerja Serentak**
#
# ```mermaid
# graph TD
#     A[Permulaan Aliran Kerja] --> B[Pelaksanaan Serentak]
#     B --> C[Kumpulan Ejen 1]
#     B --> D[Kumpulan Ejen 2]
#     B --> E[Kumpulan Ejen 3]
#     C --> F[Penggabungan Keputusan]
#     D --> F
#     E --> F
#     F --> G[Output Akhir]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Manfaat Utama:**
# - **⚡ Prestasi**: Peningkatan kelajuan ketara melalui pelaksanaan selari
# - **📈 Skala**: Mengendalikan beban kerja yang meningkat tanpa peningkatan masa secara berkadar
# - **🔄 Kecekapan**: Penggunaan sumber pengkomputeran yang lebih baik
# - **🎯 Hasil**: Memproses lebih banyak kerja dalam tempoh masa yang sama
#
# ## 🎨 **Corak Reka Bentuk Aliran Kerja Serentak**
#
# ### 🔍 **Saluran Paip Penyelidikan & Analisis**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Aliran Kerja Pemprosesan Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Saluran Paip Penciptaan Kandungan**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Pemprosesan Berbilang Tahap**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Manfaat Prestasi Perusahaan**
#
# ### ⚡ **Pengoptimuman Hasil**
# - **Pelaksanaan Selari**: Pelbagai ejen berkerja serentak
# - **Penggunaan Sumber**: Kecekapan maksimum kapasiti model AI yang tersedia
# - **Pengurangan Masa**: Pengurangan ketara dalam jumlah masa pemprosesan
# - **Seni Bina Berskala**: Mudah menambah lebih banyak ejen serentak mengikut keperluan
#
# ### 🛡️ **Kebolehpercayaan & Ketahanan**
# - **Tahan Kerosakan**: Kegagalan ejen individu tidak menghentikan keseluruhan aliran kerja
# - **Pengasingan Ralat**: Masalah dalam satu cabang serentak tidak mempengaruhi yang lain
# - **Pengurangan Secara Anggun**: Sistem terus beroperasi walaupun dengan kapasiti ejen yang dikurangkan
# - **Mekanisme Pemulihan**: Percubaan semula automatik dan pengendalian ralat untuk operasi yang gagal
#
# ### 📊 **Pemantauan & Kebolehlihatan**
# - **Penjejakan Pelaksanaan Serentak**: Pantau kemajuan semua operasi selari
# - **Metrix Prestasi**: Ukur peningkatan kelajuan dan kecekapan
# - **Analitik Penggunaan Sumber**: Optimumkan peruntukan ejen serentak
# - **Pengenalpastian Kesesakan**: Cari dan selesaikan kekangan prestasi
#
# Mari bina aliran kerja AI serentak berprestasi tinggi! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Penafian**:
# Dokumen ini telah diterjemahkan menggunakan perkhidmatan terjemahan AI [Co-op Translator](https://github.com/Azure/co-op-translator). Walaupun kami berusaha untuk ketepatan, sila ambil maklum bahawa terjemahan automatik mungkin mengandungi kesilapan atau ketidaktepatan. Dokumen asal dalam bahasa asalnya harus dianggap sebagai sumber yang sahih. Untuk maklumat penting, terjemahan oleh manusia profesional adalah disyorkan. Kami tidak bertanggungjawab terhadap sebarang salah faham atau salah tafsir yang timbul daripada penggunaan terjemahan ini.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
