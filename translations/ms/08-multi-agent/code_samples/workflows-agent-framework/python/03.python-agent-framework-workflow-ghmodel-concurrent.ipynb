# %% [markdown]
# # ⚡ Aliran Kerja Ejen Serentak dengan Microsoft Foundry (Python)
#
# ## 📋 Tutorial Pemprosesan Selari Lanjutan
#
# Notebook ini memperagakan **corak aliran kerja serentak** menggunakan Rangka Kerja Ejen Microsoft. Anda akan belajar cara membina aliran kerja pemprosesan selari berprestasi tinggi di mana beberapa ejen AI melaksanakan serentak, meningkatkan throughput secara dramatik dan membolehkan proses perniagaan berbilang benang yang canggih.
#
# > **Nota migrasi:** Contoh ini sebelum ini merujuk Model GitHub. Model GitHub sudah tidak digunakan (bersara Julai 2026), jadi ia kini menggunakan **Microsoft Foundry** melalui `FoundryChatClient`, yang mensasarkan **API Respons** Azure OpenAI.
#
# ## 🎯 Objektif Pembelajaran
#
# ### 🚀 **Asas Pemprosesan Serentak**
# - **Pelaksanaan Ejen Selari**: Jalankan beberapa ejen serentak untuk kecekapan maksimum
# - **Orkestrasi Aliran Kerja**: Menyelaras operasi serentak sambil mengekalkan konsistensi data
# - **Pengoptimuman Prestasi**: Capai pecutan ketara melalui pemprosesan selari
# - **Pengurusan Sumber**: Gunakan sumber model AI secara cekap dalam operasi serentak
#
# ### 🏗️ **Corak Serentak Lanjutan**
# - **Pemprosesan Fork-Join**: Bahagikan kerja kepada beberapa ejen dan gabungkan hasilnya
# - **Selari Laluan Paip**: Peringkat pelaksanaan bertindih untuk throughput berterusan
# - **Penyeimbangan Beban**: Bagi kerja secara sama rata antara sumber ejen yang tersedia
# - **Titik Penyelarasan**: Menyelaras ejen serentak pada peringkat penting aliran kerja
#
# ### 🏢 **Aplikasi Serentak Perusahaan**
# - **Pemprosesan Dokumen Berkelantangan Tinggi**: Proses pelbagai dokumen serentak
# - **Analisis Kandungan Masa Nyata**: Analisis serentak aliran data masuk
# - **Pengoptimuman Pemprosesan Kumpulan**: Maksimumkan throughput untuk operasi skala besar
# - **Analisis Pelbagai Mod**: Pemprosesan selari jenis kandungan berbeza (teks, imej, data)
#
# ## ⚙️ Pra-syarat & Persediaan
#
# ### 📦 **Kebergantungan Diperlukan**
#
# Pasang Rangka Kerja Ejen dengan keupayaan aliran kerja serentak:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfigurasi Microsoft Foundry**
#
# Log masuk dengan Azure CLI (`az login`) supaya `AzureCliCredential` boleh mengesahkan, kemudian tetapkan butiran projek Microsoft Foundry anda.
#
# **Persediaan Persekitaran (fail .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Pertimbangan Pemprosesan Serentak:**
# - **Had Kadar**: Pantau had kadar Azure OpenAI untuk permintaan serentak
# - **Penggunaan Sumber**: Pertimbangkan penggunaan memori dan CPU dengan beberapa ejen serentak
# - **Pengendalian Ralat**: Laksanakan pemulihan ralat yang kukuh untuk operasi selari
#
# ### 🏗️ **Senibina Aliran Kerja Serentak**
#
# ```mermaid
# graph TD
#     A[Permulaan Aliran Kerja] --> B[Pelaksanaan Serentak]
#     B --> C[Kolam Ejen 1]
#     B --> D[Kolam Ejen 2]
#     B --> E[Kolam Ejen 3]
#     C --> F[Penggabungan Keputusan]
#     D --> F
#     E --> F
#     F --> G[Output Akhir]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Manfaat Utama:**
# - **⚡ Prestasi**: Pecutan ketara melalui pelaksanaan selari
# - **📈 Skalabiliti**: Urus beban kerja yang meningkat tanpa peningkatan masa yang sebanding
# - **🔄 Kecekapan**: Penggunaan yang lebih baik sumber pengkomputeran yang tersedia
# - **🎯 Throughput**: Proses lebih banyak kerja dalam masa yang sama
#
# ## 🎨 **Corak Reka Bentuk Aliran Kerja Serentak**
#
# ### 🔍 **Laluan Paip Penyelidikan & Analisis**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Aliran Kerja Pemprosesan Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Laluan Paip Penciptaan Kandungan**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Pemprosesan Berbilang Peringkat**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Manfaat Prestasi Perusahaan**
#
# ### ⚡ **Pengoptimuman Throughput**
# - **Pelaksanaan Selari**: Beberapa ejen bekerja serentak
# - **Penggunaan Sumber**: Kecekapan maksimum kapasiti model AI yang tersedia
# - **Pengurangan Masa**: Pengurangan ketara dalam masa pemprosesan keseluruhan
# - **Senibina Skalabel**: Mudah tambah lebih banyak ejen serentak mengikut keperluan
#
# ### 🛡️ **Kebolehpercayaan & Ketahanan**
# - **Toleransi Kerosakan**: Kegagalan ejen individu tidak menghentikan keseluruhan aliran kerja
# - **Pengasingan Ralat**: Masalah dalam cabang serentak tidak menjejaskan yang lain
# - **Degradasi Anggun**: Sistem terus beroperasi walaupun dengan kapasiti ejen yang dikurangkan
# - **Mekanisme Pemulihan**: Cuba semula automatik dan pengendalian ralat untuk operasi yang gagal
#
# ### 📊 **Pemantauan & Keterlihatan**
# - **Penjejakan Pelaksanaan Serentak**: Pantau kemajuan semua operasi selari
# - **Metik Prestasi**: Ukur pecutan dan peningkatan kecekapan
# - **Analitik Penggunaan Sumber**: Optimumkan peruntukan ejen serentak
# - **Pengenalpastian Halangan Prestasi**: Kenal pasti dan selesaikan kekangan prestasi
#
# Mari bina aliran kerja AI serentak berprestasi tinggi! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Penafian**:
# Dokumen ini telah diterjemahkan menggunakan perkhidmatan terjemahan AI [Co-op Translator](https://github.com/Azure/co-op-translator). Walaupun kami berusaha untuk ketepatan, sila ambil maklum bahawa terjemahan automatik mungkin mengandungi kesilapan atau ketidaktepatan. Dokumen asal dalam bahasa asalnya harus dianggap sebagai sumber yang sahih. Untuk maklumat penting, terjemahan oleh manusia profesional adalah disyorkan. Kami tidak bertanggungjawab terhadap sebarang salah faham atau salah tafsir yang timbul daripada penggunaan terjemahan ini.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
