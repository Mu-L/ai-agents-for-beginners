# %% [markdown]
# # ⚡ ಮೈಕ್ರೋಸಾಫ್ಟ್ ಫೌಂಡ್ರಿ (Python) ಸಹಿತ ಸಮಕಾಲೀನ ಏಜೆಂಟ್ ವರ್ಕ್‌ಫ್ಲೋಗಳು
#
# ## 📋 ಅತೀಂದ್ರಿಯ ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ಟ್ಯುಟೋರಿಯಲ್
#
# ಈ ನೋಟಬುಕ್ ಮೈಕ್ರೋಸಾಫ್ಟ್ ಏಜೆಂಟ್ ಫ್ರೇಮ್‌ವರ್ಕ್ ಬಳಸಿ **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಮಾದರಿಗಳನ್ನು** ತೋರಿಸುತ್ತದೆ. ಬಹು ಏಐ ಏಜೆಂಟ್‌ಗಳು ಸಮಕಾಲೀನವಾಗಿ ಕಾರ್ಯಗತಗೊಳ್ಳುವ ಮೂಲಕ ಉನ್ನತ ಪ್ರದರ್ಶನ, ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ನೀವು ಹೇಗೆ ನಿರ್ಮಿಸಬೇಕು ಎಂದು ತಿಳಿಯಿರಿ, ಇದು ಥ್ರುಪೂಟ್ ಅನ್ನುdráಮಾtic ally ಸುಧಾರಿಸುತ್ತದೆ ಮತ್ತು ಸೂಕ್ಷ್ಮ ಬಹು-ಥ್ರೆಡ್ ವ್ಯಾಪಾರ ಪ್ರಕ್ರಿಯೆಗಳನ್ನು ಸಾದ್ಯಮಾಡುತ್ತದೆ.
#
# > **ಸ್ಥಳಾಂತರಿಕೆ ಟಿಪ್ಪಣಿ:** ಈ ಉದಾಹರಣೆ ಮೊದಲು GitHub Models ಅನ್ನು ಉಲ್ಲೇಖಿಸಿದೆ. GitHub Models ನು ಟೇರಿ (`ಮಧ್ಯ 2026ರ ಜುಲೈ` ನಿವೃತ್ತಿ), ಆದ್ದರಿಂದ ಈಗ ಇದು `FoundryChatClient` ಮೂಲಕ **Microsoft Foundry** ಅನ್ನು ಬಳಸುತ್ತದೆ, ಇದು Azure OpenAI **Responses API** ಅನ್ನು ಗುರಿಯಾಗಿಸಿದೆ.
#
# ## 🎯 ಕಲಿಕೆಯ ಉದ್ದೇಶಗಳು
#
# ### 🚀 **ಸಮಕಾಲೀನ ಪ್ರಕ್ರಿಯೆಯ ಮೂಲಭೂತಗಳು**
# - **ಸಮಾಂತರ ಏಜೆಂಟ್ ಕಾರ್ಯ ನಿರ್ವಹಣೆ**: ಸ್ಥೂಲ ಕಾರ್ಯಕ್ಷಮತೆಯಿಗಾಗಿ ಬಹು ಏಜೆಂಟ್‌ಗಳನ್ನು ಸಮಕಾಲೀನವಾಗಿ ಕಾರ್ಯಗತಗೊಳಿಸಿ
# - **ವರ್ಕ್‌ಫ್ಲೋ ಸಂಯೋಜನೆ**: ಡೇಟಾ ಸಪ್ತಕತೆಯನ್ನು ಕಾಯ್ದು ಹಿಡಿದು ಸಮಕಾಲೀನ ಕಾರ್ಯಗಳನ್ನು ಸಂಯೋಜಿಸಿ
# - **ದಕ್ಷತೆ ಸುಧಾರಣೆ**: ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆಯಿಂದ ಮಹತ್ವದ ವೇಗವನ್ನೇ ಸಾಧಿಸಿ
# - **ಸಂಪನ್ಮೂಲ ನಿರ್ವಹಣೆ**: ಸಮಕಾಲೀನ ಕಾರ್ಯಗಳಲ್ಲಿ ಏಐ ಮಾದರಿ ಸಂಪನ್ಮೂಲಗಳನ್ನು ಪರಿಣಾಮಕಾರಿಯಾಗಿ ಬಳಸಿ
#
# ### 🏗️ **ಅತೀಂದ್ರಿಯ ಸಮಕಾಲೀನ ಮಾದರಿಗಳು**
# - **Fork-Join ಪ್ರಕ್ರಿಯೆ**: ಹಲವಾರು ಏಜೆಂಟ್‌ಗಳ ನಡುವೆ ಕೆಲಸ ಹಂಚಿ ಫಲಿತಾಂಶಗಳನ್ನು ಮಿಶ್ರಣಮಾಡಿ
# - **ಪೈಪ್‌ಲೈನ್ ಸಮಾಂತರತೆ**: ನಿರಂತರ ಥ್ರುಪೂಟ್ ಗಾಗಿ ಕಾರ್ಯಗತಗೊಳಿಸುವ ಹಂತಗಳನ್ನು ಒಟ್ಟಿಗೆ ನಡೆಸಿಕೊಳ್ಳಿ
# - **ಲೋಡ್ ಬ್ಯಾಲನ್ಸಿಂಗ್**: ಲಭ್ಯವಿರುವ ಏಜೆಂಟ್ ಸಂಪನ್ಮೂಲಗಳ ಮೇಲೆ ಸಮನಾಗಿ ಕೆಲಸ ಹಂಚಿಕೆ
# - **ಸಿಂಕ್ರೊನೈಜೇಶನ್ ಪಾಯಿಂಟ್‌ಗಳು**: ಪ್ರಮುಖ ವರ್ಕ್‌ಫ್ಲೋ ಹಂತಗಳಲ್ಲಿ ಸಮಕಾಲೀನ ಏಜೆಂಟ್‌ಗಳನ್ನು ಸಂಯೋಜಿಸಿ
#
# ### 🏢 **ಸಂಸ್ಥಾತ್ಮಕ ಸಮಕಾಲೀನ ಅನ್ವಯಿಕೆಗಳು**
# - **ಹೆಚ್ಚು ಪ್ರಮಾಣದ ಡಾಕ್ಯುಮೆಂಟ್ ಪ್ರಕ್ರಿಯೆ**: ಹಲವಾರು ಡಾಕ್ಯುಮೆಂಟ್‌ಗಳನ್ನು ಸಮಕಾಲೀನವಾಗಿ ಪ್ರಕ್ರಿಯಿಸಿ
# - **ರಿಯಲ್-ಟೈಮ್ ವಿಷಯ ವಿಶ್ಲೇಷಣೆ**: ಬರುವ ಡೇಟಾ ಸರಪಳಿಗಳ ಸಮಕಾಲೀನ ವಿಶ್ಲೇಷಣೆ
# - **ಬ್ಯಾಚ್ ಪ್ರಕ್ರಿಯೆ ಸುಧಾರಣೆ**: ದೊಡ್ಡ ಮಟ್ಟದ ಕಾರ್ಯಾಚರಣೆಗೆ ಗರಿಷ್ಠ ಥ್ರುಪೂಟ್
# - **ಬಹು-ಮೋಡಲ್ ವಿಶ್ಲೇಷಣೆ**: ವಿಭಿನ್ನ ವಿಷಯ ಪ್ರಕಾರಗಳ (ಪಠ್ಯ, ಚಿತ್ರಗಳು, ಡೇಟಾ) ಸಮಾಂತರ ಪ್ರಕ್ರಿಯೆ
#
# ## ⚙️ ಪೂರ್ವಾಪೇಕ್ಷೆಗಳು & ಸೆಟಪ್
#
# ### 📦 **आವಶ್ಯಕ ಅವಲಂಬನೆಗಳು**
#
# ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ಸಾಮರ್ಥ್ಯಗಳೊಂದಿಗೆ ಏಜೆಂಟ್ ಫ್ರೇಮ್‌ವರ್ಕ್ ಅನ್ನು ಸ್ಥಾಪಿಸಿ:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **ಮೈಕ್ರೋಸಾಫ್ಟ್ ಫೌಂಡ್ರಿ ಸಂರಚನೆ**
#
# `az login` ಮೂಲಕ Azure CLI ನಲ್ಲಿ ಸೈನ್ ಇನ್ ಆಗಿ, ನಂತರ ನಿಮ್ಮ Microsoft Foundry ಪ್ರಾಜೆಕ್ಟ್ ವಿವರಗಳನ್ನು ಹೊಂದಿಸಿ.
#
# **ಪರಿಸರ ಸೆಟಪ್ (.env ಫೈಲ್):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **ಸಮಕಾಲೀನ ಪ್ರಕ್ರಿಯೆಯ ಗಮನಿಕೆಗಳು:**
# - **ರೇಟು ಸೀಮಿತಿಗಳು**: ಸಮಕಾಲೀನ ವಿನಂತಿಗಳಿಗಾಗಿ Azure OpenAI ರೇಟು ಮಿತಿಗಳನ್ನು ಗಮನಿಸಿ
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ**: ಬಹು ಸಮಕಾಲೀನ ಏಜೆಂಟ್‌ಗಳೊಂದಿಗೆ ಮೆಮೊರಿ ಮತ್ತು CPU ಬಳಕೆಯನ್ನು ಪರಿಗಣಿಸಿ
# - **ದೋಷ ನಿರ್ವಹಣೆ**: ಸಮಾಂತರ ಕಾರ್ಯಗಳಿಗೆ ಪ್ರಬಲ ದೋಷ ಮರುಸ್ಥಾಪನೆಯನ್ನು ಜಾರಿಗೊಳಿಸಿ
#
# ### 🏗️ **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ವಾಸ್ತವಶಾಸ್ತ್ರ**
#
# ```mermaid
# graph TD
#     A[ಕಾರ್‍यಪ್ರವಾಹ ಆರಂಭ] --> B[ಸಹಕಾಲಿಕ ನಿರ್ವಹಣೆ]
#     B --> C[ಏಜೆಂಟ್ ಪೂಲ್ 1]
#     B --> D[ಏಜೆಂಟ್ ಪೂಲ್ 2]
#     B --> E[ಏಜೆಂಟ್ ಪೂಲ್ 3]
#     C --> F[ಫಲಿತಾಂಶ ಸಂಗ್ರಹಣೆ]
#     D --> F
#     E --> F
#     F --> G[ಅಂತಿಮ ನಿರ್ಗಮನೆಯು]
#
#     H[ಮೈಕ್ರೋಸಾಫ್ಟ್ ಫೌಂಡ್ರೀ] --> C
#     H --> D
#     H --> E
# ```
#
# **ಪ್ರಮುಖ ಲಾಭಗಳು:**
# - **⚡ ಪ್ರದರ್ಶನ**: ಸಮಾಂತರ ಕಾರ್ಯಗತಗೊಳಿಸುವಿಕೆಯಿಂದ ಪ್ರಮುಖ ವೇಗವರ್ಧನೆ
# - **📈 ವಿಸ್ತರಣೆ ಸಾಮರ್ಥ್ಯ**: ಗರಿಷ್ಠ ಕೆಲಸದ ಭಾರವನ್ನು ಹೆಚ್ಚುವರಿ ಸಮಯವಿಲ್ಲದೆ ನಿರ್ವಹಿಸಿ
# - **🔄 ದಕ್ಷತೆ**: ಲಭ್ಯವಿರುವ ಗಣನಾತ್ಮಕ ಸಂಪನ್ಮೂಲಗಳ ಉತ್ತಮ ಉಪಯೋಗ
# - **🎯 ಥ್ರುಪೂಟ್**: ಅದೇ ಸಮಯದಲ್ಲಿ ಹೆಚ್ಚು ಕೆಲಸವನ್ನು ಪ್ರಕ್ರಿಯಿಸಿ
#
# ## 🎨 **ಸಮಕಾಲೀನ ವರ್ಕ್‌ಫ್ಲೋ ವಿನ್ಯಾಸ ಮಾದರಿಗಳು**
#
# ### 🔍 ** ಸಂಶೋಧನೆ & ವಿಶ್ಲೇಷಣೆ ಪೈಪ್‌ಲೈನ್**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ಡೇಟಾ ಪ್ರಕ್ರಿಯೆ ವರ್ಕ್‌ಫ್ಲೋ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ವಿಷಯ ಸೃಜನ ಪೈಪ್‌ಲೈನ್**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ಬಹು-ಹಂತ ಪ್ರಕ್ರಿಯೆ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ಸಂಸ್ಥಾತ್ಮಕ ಪ್ರದರ್ಶನ ಲಾಭಗಳು**
#
# ### ⚡ **ಥ್ರುಪೂಟ್ ಸಧಾರಣೆ**
# - **ಸಮಕಾಲೀನ ಕಾರ್ಯನಿರ್ವಹಣೆ**: ಹಲವು ಏಜೆಂಟ್‌ಗಳು ಸಮಕಾಲೀನವಾಗಿ ಕಾರ್ಯನಿರ್ವಹಿಸುತ್ತಾರೆ
# - **ಸಂಪನ್ಮೂಲ ಉಪಯೋಗ**: ಲಭ್ಯವಿರುವ ಏಐ ಮಾದರಿ ಸಾಮರ್ಥ್ಯದ ಗರಿಷ್ಠ ದಕ್ಷತೆ
# - **ಸಮಯ ಕಡಿಮೆ ಮಾಡುವುದು**: ಒಟ್ಟು ಪ್ರಕ್ರಿಯೆ ಸಮಯದಲ್ಲಿ ಪ್ರಮುಖ ಇಳಿಕೆ
# - **ವಿಸ್ತರಣೆ ಯೋಗ್ಯ ವಾಸ್ತವಶಾಸ್ತ್ರ**: ಅಗತ್ಯವಿದ್ದರೆ ಹೆಚ್ಚು ಸಮಕಾಲೀನ ಏಜೆಂಟ್‌ಗಳನ್ನು ಸುಲಭವಾಗಿ ಸೇರಿಸಬಹುದು
#
# ### 🛡️ **ನಂಬಿಕೆ ಮತ್ತು ಸ್ಥಿತಿಸ್ಥಾಪಕತೆ**
# - **ದೋಷ ಸಹಿಷ್ಣುತೆ**: ವೈಯಕ್ತಿಕ ಏಜೆಂಟ್ ವೈಫಲ್ಯಗಳು ಸಮಸ್ತ ವರ್ಕ್‌ಫ್ಲೋವನ್ನು ನಿಲ್ಲಿಸುವುದಿಲ್ಲ
# - **ದೋಷ ಬೇರುವಿಕೆ**: ಒಂದೇ ಸಮಕಾಲೀನ ಶಾಖೆಯಲ್ಲಿ ಸಮಸ್ಯೆಗಳು ಇತರರಿಗೆ ಪರಿಣಾಮ ಬೀರವುದು ಇಲ್ಲ
# - **ಸೌಮ್ಯ ಕುಸಿತ**: ಕಡಿಮೆಯಾದ ಏಜೆಂಟ್ ಸಾಮರ್ಥ್ಯ ಹೊಂದಿದ್ದರೂ ವ್ಯವಸ್ಥೆ ಕಾರ್ಯತತ್ಪರತೆಯನ್ನು ಮುಂದುವರೆಸುತ್ತದೆ
# - **ಪುನರುತ್ಪಾದನೆ ವಿಧಾನಗಳು**: ವಿಫಲವಾದ ಕಾರ್ಯಗಳಿಗಾಗಿ ಸ್ವಯಂಚಾಲಿತ ಪುನರಾರಂಭ ಮತ್ತು ದೋಷ ನಿರ್ವಹಣೆ
#
# ### 📊 **ನಿಗಾವಳಿ & ನಿರೀಕ್ಷಣಾ ಸಾಮರ್ಥ್ಯ**
# - **ಸಮಕಾಲೀನ ಕಾರ್ಯನಿರ್ವಹಣಾ ಅನುಸರಣೆ**: ಎಲ್ಲಾ ಸಮಾಂತರ ಕಾರ್ಯಗಳ ಪ್ರಗತಿಯನ್ನು ನಿಗದಿಗೊಳಿಸಿ
# - **ದಕ್ಷತೆ ಮಾಪನಗಳು**: ವೇಗ ಮತ್ತು ದಕ್ಷತೆಯ ಲಾಭಗಳನ್ನು ಅಳೆಯಿರಿ
# - **ಸಂಪನ್ಮೂಲ ಬಳಕೆ ವಿಶ್ಲೇಷಣೆ**: ಸಮಕಾಲೀನ ಏಜೆಂಟ್ ಹಂಚಿಕೆಯನ್ನು ಗರಿಷ್ಠಗೊಳಿಸಿ
# - **ಬಾಟಲ್ ನೇಕ್ ಗುರುತುಮಾಡಿಕೊಳ್ಳುವುದು**: ಪ್ರದರ್ಶನ ನಿರ್ಬಂಧಗಳನ್ನು ಕಂಡು ಪರಿಹರಿಸಿ
#
# ಹೌದು, ಉನ್ನತ ಪ್ರದರ್ಶನದ ಸಮಕಾಲೀನ ಏಐ ವರ್ಕ್‌ಫ್ಲೋಗಳನ್ನು ನಿರ್ಮಿಸೋಣ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ಅಸ್ವೀಕಾರ**:
# ಈ ದಸ್ತಾವೇಜು AI ಅನುವಾದ ಸೇವೆ [Co-op Translator](https://github.com/Azure/co-op-translator) ಬಳಸಿ ಅನುವಾದಿಸಲಾಗಿದೆ. ನಾವು ನಿಖರತೆಯನ್ನು ಸಾಧಿಸಲು ಪ್ರಯತ್ನಿಸುತ್ತಿದ್ದರೂ, ದಯವಿಟ್ಟು ಗಮನಿಸಿ, ಸ್ವಯಂಚಾಲಿತ ಅನುವಾದಗಳಲ್ಲಿ ದೋಷಗಳು ಅಥವಾ ಅಸಡ್ಡೆಗಳು ಇರಬಹುದು. ಮೂಲ ಭಾಷೆಯಲ್ಲಿರುವ ಮೂಲ ದಸ್ತಾವೇಜು ಪ್ರಾಮಾಣಿಕ ಮೂಲವೆಂದು ಪರಿಗಣಿಸಬೇಕು. ಪ್ರಮುಖ ಮಾಹಿತಿಗಾಗಿ, ವೃತ್ತಿಪರ ಮಾನವ ಅನುವಾದವನ್ನು ಶಿಫಾರಸು ಮಾಡಲಾಗುತ್ತದೆ. ಈ ಅನುವಾದವನ್ನು ಬಳಸುವ ಮೂಲಕ ಉಂಟಾಗುವ ಯಾವುದೇ ತಪ್ಪು ಅರ್ಥಗಳ ಅಥವಾ ತಪ್ಪು ವ್ಯಾಖ್ಯಾನಗಳ ಬಗ್ಗೆ ನಾವು ಹೊಣೆಗಾರರಲ್ಲ.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
