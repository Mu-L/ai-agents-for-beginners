# %% [markdown]
# # 🔄 Põhilised agente töövood Microsoft Foundryga (Python)
#
# ## 📋 Töövoo orkestreerimise juhend
#
# See märkmik tutvustab Microsoft Agent Frameworki võimsaid **Workflow Builder** funktsioone. Õpi looma keerukaid, mitmeastmelisi agendi töövooge, mis suudavad sujuvalt käsitseda keerukaid äriprotsesse ja koordineerida mitut tehisintellekti operatsiooni.
#
# > **Migration note:** See näide viitas varem GitHub Modelsile. GitHub Models on aegunud (väljareti juuli 2026), seetõttu kasutatakse nüüd **Microsoft Foundry't** `FoundryChatClient` kaudu, mis kasutab Azure OpenAI **Responses API-d**.
#
# ## 🎯 Õpieesmärgid
#
# ### 🏗️ **Töövoo arhitektuur**
# - **Workflow Builder**: Keerukate mitmeastmeliste protsesside disain ja orkestreerimine
# - **Sündmuspõhine täitmine**: Töövoo sündmuste ja olekumuudatuste käsitlemine
# - **Visuaalne töövoo kujundus**: Töövoo struktuuride loomine ja visualiseerimine
# - **Microsoft Foundry integreerimine**: AI mudelite kasutamine töövoo kontekstis
#
# ### 🔄 **Protsessi orkestreerimine**
# - **Järjestikused toimingud**: Mitme agendi ülesande loogiline ühendamine
# - **Tingimuslik loogika**: Otsustuspunktide ja harude lisamine töövoogudele
# - **Veakäsitlemine**: Tugev veast taastumine ja töövoo vastupidavus
# - **Olekute haldus**: Töövoo täitmise oleku jälgimine ja haldamine
#
# ### 📊 **Ettevõtte töövoo mustrid**
# - **Äriprotsesside automatiseerimine**: Keerukate organisatsiooniliste töövoogude automatiseerimine
# - **Mitme agendi koordineerimine**: Mitme spetsialiseeritud agendi koordineerimine
# - **Skaleeritav täitmine**: Töövoogude disain ettevõtte tasemel operatsioonide jaoks
# - **Jälgimine ja nähtavus**: Töövoo jõudluse ja tulemuste jälgimine
#
# ## ⚙️ Eeldused ja seadistamine
#
# ### 📦 **Nõutavad sõltuvused**
#
# Paigalda Agent Framework töövoo võimekustega:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry seadistus**
#
# Logi sisse Azure CLI abil (`az login`), et `AzureCliCredential` saaks autentida, seejärel määra oma Microsoft Foundry projekti andmed.
#
# **Keskkonna seadistus (.env fail):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# ### 🏢 **Ettevõtte kasutusjuhtumid**
#
# **Äriprotsesside näited:**
# - **Kliendi registreerimine**: Mitmeastmeline kontroll ja seadistamisprotsess
# - **Sisu torujuhe**: Automatiseeritud sisu loomine, ülevaatus ja avaldamine
# - **Andmetöötlus**: ETL töövood AI jõustatud transformatsiooniga
# - **Kvaliteedikontroll**: Automatiseeritud testimise ja valideerimise protsessid
#
# **Töövoo eelised:**
# - 🎯 **Usaldusväärsus**: Deterministlik täitmine veast taastumisega
# - 📈 **Skaleeritavus**: Suurte mahtude protsesside automatiseerimine
# - 🔍 **Nähtavus**: Täielikud auditijäljed ja jälgimine
# - 🔧 **Hooldatavus**: Visuaalne disain ja moodulkomponendid
#
# ## 🎨 Töövoo disainimustrid
#
# ### Põhiline töövoo struktuur
# ```mermaid
# graph TD
#     A[Algus] --> B[Agendi ülesanne 1]
#     B --> C{Otsustuspunkt}
#     C -->|Edu| D[Agendi ülesanne 2]
#     C -->|Ebaõnnestumine| E[Veahaldur]
#     D --> F[Lõpp]
#     E --> F
# ```
#
# **Põhikompendid:**
# - **WorkflowBuilder**: Peamine orkestreerimismootor
# - **WorkflowEvent**: Sündmuste töötlemine ja kommunikatsioon
# - **WorkflowViz**: Töövoo visuaalne esitlus ja silumine
#
# Loome sinu esimese nutika töövoo! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load Microsoft Foundry project settings from .env file
load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = provider.as_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = provider.as_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
