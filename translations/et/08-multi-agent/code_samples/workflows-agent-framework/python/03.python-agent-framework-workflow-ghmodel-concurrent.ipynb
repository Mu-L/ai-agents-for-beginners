# %% [markdown]
# # ⚡ Päriselt paralleelsed agendi töövood Microsoft Foundryga (Python)
#
# ## 📋 Täiustatud paralleelse töötlemise õppetund
#
# See märkmik demonstreerib **päriselt paralleelseid töövoo mustreid** Microsoft Agendi raamistikuga. Õpid, kuidas luua kõrge jõudlusega paralleelse töötlemise töövooge, kus mitu tehisintellekti agenti töötavad samaaegselt, parandades oluliselt läbilaskevõimet ja võimaldades keerukaid mitme lõimelisi äriprotsesse.
#
# > **Migreerimise märkus:** See näidis viitas varem GitHub Modelsile. GitHub Models on hüljatud (ametlikult lõpetatakse juulis 2026), seega kasutatakse nüüd **Microsoft Foundry’t** läbi `FoundryChatClient`i, mis sihib Azure OpenAI **Responses API-t**.
#
# ## 🎯 Õpieesmärgid
#
# ### 🚀 **Paralleelprotsesside põhitõed**
# - **Paralleelne agendi täitmine**: Käivita mitu agenti samaaegselt maksimaalse efektiivsuse saavutamiseks
# - **Töövoo orkestreerimine**: Koordineeri samaaegseid toiminguid, säilitades andmete järjepidevuse
# - **Jõudluse optimeerimine**: Saavuta märkimisväärne kiirendus paralleeltöötluse kaudu
# - **Ressursside haldamine**: Kasuta AI mudelite ressursse tõhusalt paralleelsete toimingute puhul
#
# ### 🏗️ **Täpsemad samaaegsuse mustrid**
# - **Fork-Join töötlemine**: Jaga töö mitme agendi vahel ja ühenda tulemused
# - **Torustiku paralleelsus**: Täitmisetappide kattumine pideva läbilaske tagamiseks
# - **Koormuse tasakaalustamine**: Jaga töö võrdselt saadaolevate agendiressursside vahel
# - **Sünkroniseerimispunktid**: Koordineeri samaaegseid agente töövoo kriitilistes etappides
#
# ### 🏢 **Ettevõtte samaaegselt toimivad rakendused**
# - **Suurmahuline dokumenditöötlus**: Töötle mitut dokumenti samaaegselt
# - **Reaalajaline sisuanalüüs**: Sisendandmevoogude samaaegne analüüs
# - **Partii töötlemise optimeerimine**: Maksimeeri läbilase suurte mahutega operatsioonide puhul
# - **Mitmemodaalne analüüs**: Paralleelne erinevat tüüpi sisu (tekst, pildid, andmed) töötlemine
#
# ## ⚙️ Eeldused ja seadistamine
#
# ### 📦 **Nõutavad sõltuvused**
#
# Paigalda Agendi raamistik koos paralleelsete töövoogude võimalusega:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry konfiguratsioon**
#
# Logi sisse Azure CLI-ga (`az login`), et `AzureCliCredential` saaks autentida, seejärel määra Microsoft Foundry projekti detailid.
#
# **Keskkonna seadistamine (.env fail):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Paralleeltöötluse kaalutlused:**
# - **Kiiruspiirangud**: Jälgi Azure OpenAI kiiruspiiranguid samaaegsete päringute jaoks
# - **Ressursside kasutus**: Arvesta mälu ja CPU kasutusega mitme samaaegse agendi puhul
# - **Veakäsitlus**: Rakenda vastupidav viga taasteprotsess paralleelsete operatsioonide korral
#
# ### 🏗️ **Paralleelsete töövoogude arhitektuur**
#
# ```mermaid
# graph TD
#     A[Töövoo algus] --> B[Sünkroonne täitmine]
#     B --> C[Agendi grupp 1]
#     B --> D[Agendi grupp 2]
#     B --> E[Agendi grupp 3]
#     C --> F[Tulemuste kogumine]
#     D --> F
#     E --> F
#     F --> G[Lõplik väljund]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Peamised eelised:**
# - **⚡ Jõudlus**: Märkimisväärne kiirus juurde paralleelse täitmise kaudu
# - **📈 Skaalautuvus**: Suudad hallata suuremaid töökoormusi ilma proportsionaalse ajakasvuta
# - **🔄 Efektiivsus**: Paremini ära kasutatud olemasolevad arvutusressursid
# - **🎯 Läbilaskevõime**: Töötle rohkem tööd samas ajavahemikus
#
# ## 🎨 **Paralleelsete töövoogude disainimustrid**
#
# ### 🔍 **Uurimis- ja analüüsitorustik**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Andmetöötluse töövoog**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisu loomise torustik**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Mitmeetapiline töötlemine**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Ettevõtte jõudluse eelised**
#
# ### ⚡ **Läbilaskevõime optimeerimine**
# - **Paralleelne täitmine**: Mitmed agentid töötavad samaaegselt
# - **Ressursside kasutamine**: Maksimaalne olemasoleva AI mudeli võimsuse kasutus
# - **Ajavähendus**: Märkimisväärne protsesside koguaegade lühenemine
# - **Skaalautuv arhitektuur**: Vajadusel lisa hõlpsasti rohkem samaaegseid agente
#
# ### 🛡️ **Usaldusväärsus ja vastupidavus**
# - **Richitaluvus**: Üksiku agendi tõrked ei peata kogu töövoogu
# - **Vigade isoleerimine**: Probleemid ühes samaaegses harus ei mõjuta teisi
# - **Jalakäija degradatsioon**: Süsteem jätkab tööd isegi vähendatud agendi võimsusega
# - **Taastemehhanismid**: Automaatne taaskäivitamine ja vigade käsitlus ebaõnnestunud toimingutel
#
# ### 📊 **Jälgimine ja vaatlus**
# - **Paralleeltäitmise jälgimine**: Jälgi kõigi paralleelsete toimingute edenemist
# - **Jõudlusmõõdikud**: Mõõda kiirendust ja efektiivsuse kasvu
# - **Ressursside kasutuse analüüs**: Optimeeri paralleelsete agentide jaotust
# - **Põhjuste leidmine**: Leia ja lahenda jõudluspiirangud
#
# Loome kõrge jõudlusega paralleelseid AI töövooge! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
