# %% [markdown]
# # ⚡ Koostööagentide töövood Microsoft Foundryga (Python)
#
# ## 📋 Täiustatud paralleeltöötluse juhend
#
# See märkmik demonstreerib **koostöövoo mustreid** Microsoft Agent Frameworki kasutades. Õpid, kuidas luua kõrge jõudlusega paralleeltöötluse töövooge, kus mitu AI-agenti töötavad samaaegselt, parandades oluliselt läbilaskevõimet ja võimaldades keerukaid mitme niidiga äriprotsesse.
#
# > **Migratsioonimärkus:** See näidis viitas varem GitHubi mudelitele. GitHubi mudelid on aegunud (ametlikult katkestatakse juulis 2026), seega kasutatakse nüüd **Microsoft Foundryd** `FoundryChatClient` kaudu, mis kasutab Azure OpenAI **Responses API-t**.
#
# ## 🎯 Õpieesmärgid
#
# ### 🚀 **Koostöötluse põhialused**
# - **Agentide paralleelne käitamine**: Käivita mitu agenti samaaegselt maksimaalse efektiivsuse saavutamiseks
# - **Töövoo korraldamine**: Koordineeri samaaegseid operatsioone andmete korrektsuse säilitamiseks
# - **Jõudluse optimeerimine**: Saavuta märkimisväärne kiiruse kasv paralleeltöötluse abil
# - **Ressursside haldamine**: Kasuta AI mudelite ressursse tõhusalt samaaegsete toimingute jaoks
#
# ### 🏗️ **Täiustatud koostöö mustrid**
# - **Fork-Join töötlemine**: Jaota töö mitme agendi vahel ja ühenda tulemused
# - **Torujoone paralleelsus**: Katkestamata läbilaskevõime saavutamiseks kattuvad tööetapid
# - **Koormuse tasakaalustamine**: Jaga töö ühtlaselt kõigi agentide ressursi hulgas
# - **Sünkroonimispunktid**: Koordineeri agentide samaaegsust kriitilistes töövoo etappides
#
# ### 🏢 **Ettevõtte koostöötlusrakendused**
# - **Suurte dokumentide töötlemine**: Töötle mitut dokumenti samaaegselt
# - **Reaalajas sisuanalüüs**: Sissetulevate andmevoogude samaaegne analüüs
# - **Partii töötlemise optimeerimine**: Maksimeeri läbilaskevõime suurte operatsioonide raames
# - **Mitme modaalne analüüs**: Paralleeltöötlus erinevate sisutüüpide (tekst, pildid, andmed) jaoks
#
# ## ⚙️ Eeldused ja seadistus
#
# ### 📦 **Nõutavad sõltuvused**
#
# Installi Agent Framework koos koostöövoogude võimalustega:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry konfiguratsioon**
#
# Logi Azure CLI-ga sisse (`az login`), et `AzureCliCredential` saaks autentida, seejärel määra oma Microsoft Foundry projekti üksikasjad.
#
# **Keskkonna seadistus (.env fail):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Koostöötluse kaalutlused:**
# - **Piirnormid**: Jälgi Azure OpenAI piirnorme samaaegsete päringute jaoks
# - **Ressursside kasutus**: Arvesta mälukasutuse ja CPU koormusega mitme samaaegse agendi puhul
# - **Vigade käsitlemine**: Rakenda usaldusväärset vigade taastamist paralleelsete operatsioonide puhul
#
# ### 🏗️ **Koostöövoo arhitektuur**
#
# ```mermaid
# graph TD
#     A[Töövoo algus] --> B[Kaasaja täitmine]
#     B --> C[Agendi bassein 1]
#     B --> D[Agendi bassein 2]
#     B --> E[Agendi bassein 3]
#     C --> F[Tulemuste kogumine]
#     D --> F
#     E --> F
#     F --> G[Lõplik väljund]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Peamised eelised:**
# - **⚡ Jõudlus**: Märkimisväärne kiiruse kasv paralleelse käitamisega
# - **📈 Laiendatavus**: Suudab käsitleda suuremaid koormusi ilma aega proportsionaalselt suurendamata
# - **🔄 Tõhusus**: Paremini kasutatud olemasolevad arvutusressursid
# - **🎯 Läbilaskevõime**: Töötle rohkem tööd sama ajaga
#
# ## 🎨 **Koostöövoo disainimustrid**
#
# ### 🔍 **Uuringu ja analüüsi torujuhe**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Andmetöötluse töövoog**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisu loomise torujuhe**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Mitmeetapiline töötlemine**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Ettevõtte jõudluse eelised**
#
# ### ⚡ **Läbilaskevõime optimeerimine**
# - **Paralleelne käitamine**: Mitmed agendid töötavad samaaegselt
# - **Ressursside kasutus**: Maksimaalne efektiivsus olemasolevast AI mudeli mahust
# - **Aja vähendamine**: Märkimisväärne kogu töötlemisaja lühendamine
# - **Laiendatav arhitektuur**: Vajadusel lisa lihtsalt rohkem samaaegseid agente
#
# ### 🛡️ **Usaldusväärsus ja vastupidavus**
# - **Riketaluvus**: Individuaalsed agendi vead ei peata kogu töövoogu
# - **Vigade isolatsioon**: Probleemid ühes samaeas haru ei mõjuta teisi
# - **Sujuv degradeerumine**: Süsteem jätkab tööd ka vähendatud agendi mahuga
# - **Taastemehhanismid**: Automaatne uuesti proovimine ja vigade käsitlemine ebaõnnestunud operatsioonide puhul
#
# ### 📊 **Jälgimine ja jälgitavus**
# - **Koostöötluse edenemise jälgimine**: Jälgi kõigi paralleelsete operatsioonide kulgu
# - **Jõudlusmõõdikud**: Mõõda kiirendus ja efektiivsuse kasvu
# - **Ressursside kasutuse analüüs**: Optimeeri samaaegsete agentide jaotust
# - **Pudelikehtede tuvastamine**: Leia ja lahenda jõudluspiiranguid
#
# Loome kõrge jõudlusega samaaegseid AI töövooge! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
