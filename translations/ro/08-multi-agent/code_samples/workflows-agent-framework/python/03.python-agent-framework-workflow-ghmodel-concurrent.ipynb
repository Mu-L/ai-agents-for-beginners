# %% [markdown]
# # ⚡ Fluxuri de Lucru Concurrente ale Agenților cu Microsoft Foundry (Python)
#
# ## 📋 Tutorial Avansat de Procesare Paralelă
#
# Acest caiet demonstrează **modele de fluxuri de lucru concurente** utilizând Microsoft Agent Framework. Veți învăța cum să construiți fluxuri de lucru de procesare paralelă și de înaltă performanță, în care mai mulți agenți AI execută simultan, îmbunătățind dramatic debitul și permițând procese de afaceri sofisticate multi-thread.
#
# > **Notă de migrare:** Acest exemplu a făcut anterior referire la Modele GitHub. Modele GitHub este învechit (în retragere în iulie 2026), așa că acum folosește **Microsoft Foundry** prin `FoundryChatClient`, care vizează API-ul Azure OpenAI **Responses API**.
#
# ## 🎯 Obiective de Învățare
#
# ### 🚀 **Fundamentele Procesării Concurrente**
# - **Execuția Paralelă a Agenților**: Rulați mai mulți agenți simultan pentru eficiență maximă
# - **Orchestrarea Fluxurilor de Lucru**: Coordonați operațiunile concurente menținând consistența datelor
# - **Optimizarea Performanței**: Obțineți o creștere semnificativă a vitezei prin procesarea paralelă
# - **Gestionarea Resurselor**: Utilizați eficient resursele modelelor AI în operațiuni concurente
#
# ### 🏗️ **Modele Avansate de Concurență**
# - **Procesare Fork-Join**: Împărțiți munca între mai mulți agenți și reuniți rezultatele
# - **Paralelism prin Pipeline**: Suprapunerea etapelor de execuție pentru debit continuu
# - **Echilibrarea Sarcinii**: Distribuiți munca uniform între resursele agenților disponibili
# - **Puncte de Sincronizare**: Coordonați agenții concurenți în etape critice ale fluxului de lucru
#
# ### 🏢 **Aplicații Enterprise Concurente**
# - **Procesarea Documentelor la Volum Mare**: Procesați simultan mai multe documente
# - **Analiză de Conținut în Timp Real**: Analiză concurentă a fluxurilor de date primite
# - **Optimizarea Procesării pe Loturi**: Maximizează debitul pentru operațiuni la scară largă
# - **Analiză Multi-Modală**: Procesare paralelă a diferitelor tipuri de conținut (text, imagini, date)
#
# ## ⚙️ Cerințe și Configurare
#
# ### 📦 **Dependențe Necesare**
#
# Instalați Agent Framework cu capacități de fluxuri de lucru concurente:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Configurarea Microsoft Foundry**
#
# Autentificați-vă cu Azure CLI (`az login`) pentru ca `AzureCliCredential` să poată autentifica, apoi setați detaliile proiectului Microsoft Foundry.
#
# **Configurarea Mediului (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Considerații privind Procesarea Concurentă:**
# - **Limitele de Rată**: Monitorizați limitele de rată Azure OpenAI pentru cererile concurente
# - **Utilizarea Resurselor**: Luați în considerare consumul de memorie și CPU cu mai mulți agenți concurenți
# - **Gestionarea Erorilor**: Implementați recuperarea robustă a erorilor pentru operațiunile paralele
#
# ### 🏗️ **Arhitectura Fluxurilor de Lucru Concurrente**
#
# ```mermaid
# graph TD
#     A[Începerea fluxului de lucru] --> B[Execuție concurentă]
#     B --> C[Grup de agenți 1]
#     B --> D[Grup de agenți 2]
#     B --> E[Grup de agenți 3]
#     C --> F[Agregarea rezultatelor]
#     D --> F
#     E --> F
#     F --> G[Rezultatul final]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Beneficii Cheie:**
# - **⚡ Performanță**: Accelerare semnificativă prin execuție paralelă
# - **📈 Scalabilitate**: Gestionați sarcini crescute fără creștere proporțională a timpului
# - **🔄 Eficiență**: Utilizare mai bună a resurselor computaționale disponibile
# - **🎯 Debit**: Procesează mai multă muncă în același interval de timp
#
# ## 🎨 **Modele de Proiectare pentru Fluxuri de Lucru Concurrente**
#
# ### 🔍 **Pipeline de Cercetare & Analiză**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Flux de Procesare a Datelor**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline de Creare de Conținut**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Procesare Multi-Etape**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Beneficii de Performanță Enterprise**
#
# ### ⚡ **Optimizarea Debitului**
# - **Execuție Paralelă**: Mai mulți agenți lucrând simultan
# - **Utilizarea Resurselor**: Eficiență maximă a capacității AI disponibile
# - **Reducerea Timpului**: Scădere semnificativă a timpului total de procesare
# - **Arhitectură Scalabilă**: Adăugați ușor mai mulți agenți concurenți după necesitate
#
# ### 🛡️ **Fiabilitate & Reziliență**
# - **Toleranță la Defecțiuni**: Defecțiunile agenților individuali nu opresc întregul flux de lucru
# - **Izolarea Erorilor**: Problemele într-un ramură concurentă nu afectează celelalte
# - **Degradare Grațioasă**: Sistemul continuă să funcționeze chiar și cu capacitate redusă a agenților
# - **Mecanisme de Recuperare**: Reîncercare automată și gestionare a erorilor pentru operațiuni eșuate
#
# ### 📊 **Monitorizare & Observabilitate**
# - **Urmărirea Execuției Concurrente**: Monitorizați progresul tuturor operațiunilor paralele
# - **Metrici de Performanță**: Măsurați accelerarea și câștigurile de eficiență
# - **Analiză a Utilizării Resurselor**: Optimizați alocarea agenților concurenți
# - **Identificarea Blocajelor**: Detectați și rezolvați constrângerile de performanță
#
# Hai să construim fluxuri de lucru AI concurente de înaltă performanță! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Declinare a responsabilității**:
# Acest document a fost tradus folosind serviciul de traducere AI [Co-op Translator](https://github.com/Azure/co-op-translator). În timp ce ne străduim pentru acuratețe, vă rugăm să rețineți că traducerile automate pot conține erori sau inexactități. Documentul original în limba sa nativă trebuie considerat sursa autorizată. Pentru informații critice, se recomandă traducerea profesională realizată de un om. Nu ne asumăm responsabilitatea pentru eventualele neînțelegeri sau interpretări greșite care decurg din utilizarea acestei traduceri.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
