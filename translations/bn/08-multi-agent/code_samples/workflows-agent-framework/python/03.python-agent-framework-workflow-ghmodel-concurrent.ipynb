# %% [markdown]
# # ⚡ মাইক্রোসফ্ট ফাউন্ড্রির সাথে সমান্তরাল এজেন্ট ওয়ার্কফ্লো (পাইথন)
#
# ## 📋 উন্নত সমান্তরাল প্রক্রিয়াকরণ টিউটোরিয়াল
#
# এই নোটবুকটি মাইক্রোসফ্ট এজেন্ট ফ্রেমওয়ার্ক ব্যবহার করে **সমান্তরাল ওয়ার্কফ্লো প্যাটার্ন** প্রদর্শন করে। আপনি শিখবেন কীভাবে উচ্চ-দক্ষতা সম্পন্ন, সমান্তরাল প্রক্রিয়াকরণ ওয়ার্কফ্লো তৈরি করতে হয় যেখানে একাধিক AI এজেন্ট একই সময়ে কাজ করে, যেটি বাইপাস বৃদ্ধি করে এবং জটিল মাল্টিথ্রেডেড ব্যবসায়িক প্রক্রিয়াগুলো সক্ষম করে।
#
# > **স্থানান্তর নোট:** এই নমুনা আগে GitHub Models নির্দেশ করত। GitHub Models অব্যবহৃত (জুলাই ২০২৬ তে অবসর গ্রহণ করতেছে), তাই এখন এটি **Microsoft Foundry** ব্যবহার করে `FoundryChatClient` এর মাধ্যমে, যা Azure OpenAI **Responses API** এর লক্ষ্যবস্তু।
#
# ## 🎯 শেখার উদ্দেশ্য
#
# ### 🚀 **সমান্তরাল প্রক্রিয়াকরণের মৌলিক বিষয়**
# - **সমান্তরাল এজেন্ট কার্যকরী**: সর্বাধিক দক্ষতার জন্য একাধিক এজেন্ট একই সময়ে চালানো
# - **ওয়ার্কফ্লো সিস্টেম সমন্বয়**: তথ্য সংহতি বজায় রেখে সহকর্মী অপারেশন সমন্বয় করা
# - **ক্ষমতা বৃদ্ধি**: সমান্তরাল প্রক্রিয়াকরণের মাধ্যমে উল্লেখযোগ্য গতি বৃদ্ধি অর্জন
# - **সম্পদ ব্যবস্থাপনা**: একাধিক সমান্তরাল অপারেশনে AI মডেল সম্পদ কার্যকরভাবে ব্যবহার করা
#
# ### 🏗️ **উন্নত সমান্তরাল প্যাটার্ন**
# - **Fork-Join প্রক্রিয়াকরণ**: একাধিক এজেন্টের মধ্যে কাজ ভাগ করে ফলাফল একত্রিত করা
# - **পাইপলাইন সমান্তরালতা**: ধারাবাহিক প্রবাহের জন্য ওভারল্যাপিং এক্সিকিউশন স্টেজ
# - **লোড ব্যালান্সিং**: উপলব্ধ এজেন্ট সম্পদসমূহের মধ্যে কাজ সমানভাবে বিতরণ
# - **সিঙ্ক্রোনাইজেশন পয়েন্ট**: সমালোচনামূলক ওয়ার্কফ্লো ধাপগুলোতে সমান্তরাল এজেন্ট সমন্বয়
#
# ### 🏢 **উদ্যোগসমূহের সমান্তরাল অ্যাপ্লিকেশন**
# - **উচ্চ-মাত্রার ডকুমেন্ট প্রক্রিয়াকরণ**: একাধিক ডকুমেন্ট একই সময়ে প্রক্রিয়াজাত করা
# - **রিয়েল-টাইম কন্টেন্ট বিশ্লেষণ**: আগত ডেটা স্ট্রীমের সমান্তরাল বিশ্লেষণ
# - **ব্যাচ প্রক্রিয়াকরণ অপটিমাইজেশন**: বড় পরিসরের অপারেশনের জন্য সর্বোচ্চ পারফরম্যান্স
# - **বহুমুখী বিশ্লেষণ**: বিভিন্ন কন্টেন্ট টাইপ (টেক্সট, ছবি, ডেটা) এর সমান্তরাল প্রক্রিয়াকরণ
#
# ## ⚙️ প্রয়োজনীয়তাসমূহ ও সেটআপ
#
# ### 📦 **অবশ্যকীয় নির্ভরশীলতাসমূহ**
#
# সমান্তরাল ওয়ার্কফ্লো ক্ষমতাসম্পন্ন এজেন্ট ফ্রেমওয়ার্ক ইনস্টল করুন:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry কনফিগারেশন**
#
# Azure CLI (`az login`) দিয়ে সাইন ইন করুন যাতে `AzureCliCredential` প্রমাণীকরণ করতে পারে, তারপর আপনার Microsoft Foundry প্রকল্প বিবরণ সেট করুন।
#
# **এনভায়রনমেন্ট সেটআপ (.env ফাইল):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **সমান্তরাল প্রক্রিয়াকরণের বিবেচ্য বিষয়:**
# - **রেট লিমিটস**: সমান্তরাল অনুরোধের জন্য Azure OpenAI রেট সীমা পর্যবেক্ষণ করুন
# - **সম্পদ ব্যবহার**: একাধিক সমান্তরাল এজেন্টের সাথে মেমরি এবং সিপিইউ ব্যবহার বিবেচনা করুন
# - **ত্রুটি পরিচালনা**: সমান্তরাল অপারেশনের জন্য দৃঢ় ত্রুটি পুনরুদ্ধার বাস্তবায়ন করুন
#
# ### 🏗️ **সমান্তরাল ওয়ার্কফ্লো স্থাপত্য**
#
# ```mermaid
# graph TD
#     A[কর্মপ্রবাহ শুরু] --> B[একযোগে কার্যকরী]
#     B --> C[এজেন্ট পুল ১]
#     B --> D[এজেন্ট পুল ২]
#     B --> E[এজেন্ট পুল ৩]
#     C --> F[ফলাফল সমবায়ন]
#     D --> F
#     E --> F
#     F --> G[চূড়ান্ত আউটপুট]
#
#     H[মাইক্রোসফট ফাউন্ড্রি] --> C
#     H --> D
#     H --> E
# ```
#
# **মূল সুবিধাসমূহ:**
# - **⚡ পারফরম্যান্স**: সমান্তরাল কার্যকারিতার মাধ্যমে উল্লেখযোগ্য গতি বৃদ্ধি
# - **📈 স্কেলেবিলিটি**: প্রয়োজনীয়তা বাড়লেও সময়ের অপ্রচলিত বৃদ্ধির পক্ষে হ্যান্ডেল করা
# - **🔄 দক্ষতা**: উপলব্ধ কম্পিউটেশনাল সম্পদের উন্নত ব্যবহার
# - **🎯 থ্রুপুট**: একই সময়ে আরও কাজ প্রক্রিয়াজাত করা
#
# ## 🎨 **সমান্তরাল ওয়ার্কফ্লো ডিজাইন প্যাটার্ন**
#
# ### 🔍 **গবেষণা ও বিশ্লেষণ পাইপলাইন**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ডেটা প্রক্রিয়াকরণ ওয়ার্কফ্লো**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **কন্টেন্ট সৃষ্টির পাইপলাইন**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **বহু-স্তর প্রক্রিয়াকরণ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **উদ্যোগের পারফরম্যান্স উপকারিতা**
#
# ### ⚡ **থ্রুপুট অপ্টিমাইজেশন**
# - **সমান্তরাল কার্যকরী**: একাধিক এজেন্ট একই সময়ে কাজ করছে
# - **সম্পদ ব্যবহার**: উপলব্ধ AI মডেল ক্ষমতার সর্বোচ্চ দক্ষতা
# - **সময় কমানো**: মোট প্রক্রিয়াকরণের সময় উল্লেখযোগ্যভাবে হ্রাস
# - **স্কেলেবেল স্থাপত্য**: প্রয়োজন অনুসারে আরও সমান্তরাল এজেন্ট যোগ করা সহজ
#
# ### 🛡️ **বিশ্বাসযোগ্যতা ও স্থিতিস্থাপকতা**
# - **ফল্ট টলারেন্স**: ব্যক্তিগত এজেন্ট ব্যর্থতা পুরো ওয়ার্কফ্লো বন্ধ করে না
# - **ত্রুটি বিচ্ছিন্নতা**: এক সমান্তরাল শাখার সমস্যা অন্যগুলিকে প্রভাবিত করে না
# - **সুশীল অবনতি**: এজেন্ট ক্ষমতা কমলেও সিস্টেম চলমান থাকে
# - **পুনরুদ্ধার ব্যবস্থা**: ব্যর্থ অপারেশনের জন্য স্বয়ংক্রিয় পুনরায় চেষ্টা এবং ত্রুটি পরিচালনা
#
# ### 📊 **পর্যবেক্ষণ ও পর্যবেক্ষণযোগ্যতা**
# - **সমান্তরাল কার্যকরী ট্র্যাকিং**: সমস্ত সমান্তরাল অপারেশনের অগ্রগতি পর্যবেক্ষণ করুন
# - **পারফরম্যান্স মেট্রিক্স**: গতি বৃদ্ধি এবং দক্ষতা লাভ পরিমাপ করুন
# - **সম্পদ ব্যবহার বিশ্লেষণ**: সমান্তরাল এজেন্ট বরাদ্দ পরিকল্পনা উন্নত করুন
# - **বটলনেক সনাক্তকরণ**: পারফরম্যান্স সীমাবদ্ধতা চিহ্নিত ও সমাধান করুন
#
# চলুন উচ্চ-দক্ষ সমান্তরাল AI ওয়ার্কফ্লো নির্মাণ করি! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **অস্বীকৃতি**:
# এই নথিটি AI অনুবাদ পরিষেবা [Co-op Translator](https://github.com/Azure/co-op-translator) ব্যবহার করে অনূদিত হয়েছে। যদিও আমরা শুদ্ধতার জন্য চেষ্টা করি, অনুগ্রহ করে মনে রাখবেন যে স্বয়ংক্রিয় অনুবাদে ত্রুটি বা অসঙ্গতি থাকতে পারে। মূল নথিটি তার স্বভাষায় কর্তৃত্বপূর্ণ উৎস হিসেবে বিবেচিত হওয়া উচিত। গুরুত্বপূর্ণ তথ্যের জন্য পেশাদার মানব অনুবাদ সুপারিশ করা হয়। এই অনুবাদের ব্যবহারে প্রয়োজনীয় ভুল বোঝাবুঝি বা ভুল ব্যাখ্যার জন্য আমরা দায়বদ্ধ নই।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
