# %% [markdown]
# # ⚡ মাইক্রোসফ্ট ফাউন্ড্রি (পাইথন) দিয়ে সমান্তরাল এজেন্ট ওয়ার্কফ্লো
#
# ## 📋 অগ্রগতি স্তরের সমান্তরাল প্রক্রিয়াকরণ টিউটোরিয়াল
#
# এই নোটবুকটি মাইক্রোসফ্ট এজেন্ট ফ্রেমওয়ার্ক ব্যবহার করে **সমান্তরাল ওয়ার্কফ্লো প্যাটার্নগুলি** প্রদর্শন করে। আপনি কীভাবে একাধিক এআই এজেন্ট একসাথে কাজ করে উচ্চ-প্রদর্শন ক্ষমতা সম্পন্ন, সমান্তরাল প্রক্রিয়াকরণ ওয়ার্কফ্লো তৈরি করতে পারেন তা শিখবেন, যা থ্রুপুট উন্নত করে এবং জটিল মাল্টি-থ্রেডেড ব্যবসায়িক প্রক্রিয়াগুলিকে সক্ষম করে।
#
# > **মাইগ্রেশন নোট:** এই স্যাম্পলটি পূর্বে GitHub Models রেফার করত। GitHub Models স্থগিত হচ্ছে (জুলাই ২০২৬ এ বন্ধ হওয়া), তাই এখন এটি `FoundryChatClient` এর মাধ্যমে **Microsoft Foundry** ব্যবহার করে, যা Azure OpenAI **Responses API** লক্ষ্য করে।
#
# ## 🎯 শেখার উদ্দেশ্য
#
# ### 🚀 **সমান্তরাল প্রক্রিয়াকরণের মৌলিক বিষয়**
# - **সমান্তরাল এজেন্ট এক্সিকিউশন**: সর্বোচ্চ দক্ষতার জন্য একাধিক এজেন্ট একসাথে চালান
# - **ওয়ার্কফ্লো সমন্বয়**: ডেটার একসূত্রতা বজায় রেখে সমান্তরাল অপারেশন সমন্বয় করুন
# - **পারফরম্যান্স অপ্টিমাইজেশন**: সমান্তরাল প্রক্রিয়াকরণের মাধ্যমে উল্লেখযোগ্য গতি বৃদ্ধি অর্জন করুন
# - **সরাসরি ব্যবস্থাপনা**: পারস্পরিক অপারেশনগুলির মধ্যে এআই মডেলের সম্পদ দক্ষ ব্যবহারে সচেতন থাকুন
#
# ### 🏗️ **উন্নত সমান্তরাল প্যাটার্নগুলি**
# - **ফর্ক-জয়েন প্রক্রিয়াকরণ**: একাধিক এজেন্টের মধ্যে কাজ ভাগ করুন এবং ফলাফল মিশ্রিত করুন
# - **পাইপলাইন সমান্তরালতা**: ধারাবাহিক থ্রুপুটের জন্য নির্বাহ পর্যায় একত্রিতকরণ
# - **লোড ব্যালান্সিং**: উপলব্ধ এজেন্ট সম্পদের মধ্যে কাজ সমানভাবে বিতরণ করুন
# - **সিঙ্ক্রোনাইজেশন পয়েন্ট**: সমান্তরাল এজেন্টদের সমন্বয় নিশ্চিত করুন গুরুত্বপূর্ণ ওয়ার্কফ্লো ধাপে
#
# ### 🏢 **এন্টারপ্রাইজ সমান্তরাল অ্যাপ্লিকেশন**
# - **উচ্চ-পরিমাণ ডকুমেন্ট প্রক্রিয়াকরণ**: একাধিক ডকুমেন্ট একসাথে প্রক্রিয়া করুন
# - **রিয়েল-টাইম কনটেন্ট বিশ্লেষণ**: ইনকামিং ডেটা স্ট্রিমের সমান্তরাল বিশ্লেষণ
# - **ব্যাচ প্রক্রিয়াকরণ অপ্টিমাইজেশন**: বড় স্কেলের অপারেশনের জন্য সর্বোচ্চ থ্রুপুট নিশ্চিত করা
# - **মাল্টি-মোডাল বিশ্লেষণ**: বিভিন্ন ধরনের কনটেন্ট (টেক্সট, ছবি, ডেটা) সমান্তরাল প্রক্রিয়াকরণ
#
# ## ⚙️ প্রয়োজনীয়তা ও সেটআপ
#
# ### 📦 **প্রয়োজনীয় ডিপেন্ডেন্সিস**
#
# সমান্তরাল ওয়ার্কফ্লো সক্ষমতা সহ এজেন্ট ফ্রেমওয়ার্ক ইনস্টল করুন:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry কনফিগারেশন**
#
# Azure CLI (`az login`) দিয়ে সাইন ইন করুন যাতে `AzureCliCredential` প্রমাণীকরণ করতে পারে, তারপর আপনার Microsoft Foundry প্রকল্পের বিবরণ সেট করুন।
#
# **পরিবেশ সেটআপ (.env ফাইল):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **সমান্তরাল প্রক্রিয়াকরণ বিবেচনা:**
# - **রেট লিমিটস**: সমান্তরাল অনুরোধের জন্য Azure OpenAI রেট লিমিট মনিটর করুন
# - **সম্পদ ব্যবহার**: একাধিক সমান্তরাল এজেন্টের জন্য মেমরি ও CPU ব্যবহারের দিক বিবেচনা করুন
# - **ত্রুটি ব্যবস্থাপনা**: সমান্তরাল অপারেশনগুলির জন্য শক্তিশালী ত্রুটি পুনরুদ্ধার বাস্তবায়ন করুন
#
# ### 🏗️ **সমান্তরাল ওয়ার্কফ্লো আর্কিটেকচার**
#
# ```mermaid
# graph TD
#     A[কর্মপ্রবাহ শুরু] --> B[সমান্তরাল কার্যক্রম]
#     B --> C[এজেন্ট পুল ১]
#     B --> D[এজেন্ট পুল ২]
#     B --> E[এজেন্ট পুল ৩]
#     C --> F[ফলাফল সংকলন]
#     D --> F
#     E --> F
#     F --> G[চূড়ান্ত আউটপুট]
#
#     H[মাইক্রোসফট ফাউন্ড্রি] --> C
#     H --> D
#     H --> E
# ```
#
# **প্রধান সুবিধাসমূহ:**
# - **⚡ পারফরম্যান্স**: সমান্তরাল এক্সিকিউশনের মাধ্যমে উল্লেখযোগ্য গতি বৃদ্ধি
# - **📈 স্কেলেবিলিটি**: বাড়তি কাজের চাপ মোকাবেলা করতে সমান্তরালতা বৃদ্ধি করা যায়
# - **🔄 দক্ষতা**: উপলব্ধ কম্পিউটেশনাল রিসোর্সের উন্নত ব্যবহার
# - **🎯 থ্রুপুট**: একই সময়ে বেশি কাজ প্রক্রিয়া করুন
#
# ## 🎨 **সমান্তরাল ওয়ার্কফ্লো ডিজাইন প্যাটার্ন**
#
# ### 🔍 **গবেষণা ও বিশ্লেষণ পাইপলাইন**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ডেটা প্রক্রিয়াকরণ ওয়ার্কফ্লো**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **কনটেন্ট ক্রিয়েশন পাইপলাইন**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **বহু-পর্যায় প্রক্রিয়াকরণ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **এন্টারপ্রাইজ পারফরম্যান্স সুবিধাসমূহ**
#
# ### ⚡ **থ্রুপুট অপ্টিমাইজেশন**
# - **সমান্তরাল এক্সিকিউশন**: একাধিক এজেন্ট একই সময়ে কাজ করছে
# - **সম্পদ ব্যবহার**: উপলব্ধ AI মডেল ক্ষমতার সর্বোচ্চ দক্ষতা
# - **সময় হ্রাস**: মোট প্রক্রিয়াকরণের সময় উল্লেখযোগ্য হ্রাস
# - **স্কেলেবল আর্কিটেকচার**: প্রয়োজন অনুযায়ী আরও সমান্তরাল এজেন্ট যোগ করা সহজ
#
# ### 🛡️ **নির্ভরযোগ্যতা ও স্থিতিশীলতা**
# - **ফল্ট টলারেন্স**: ব্যক্তিগত এজেন্ট ব্যর্থতা পুরো ওয়ার্কফ্লো থামায় না
# - **ত্রুটি বিচ্ছিন্নকরণ**: এক সমান্তরাল ব্রাঞ্চে সমস্যা অন্যদের প্রভাবিত করে না
# - **গ্রেসফুল ডিগ্রেডেশন**: কম এজেন্ট ক্ষমতা থাকলেও সিস্টেম চালু থাকে
# - **পুনরুদ্ধার প্রক্রিয়া**: ব্যর্থ অপারেশনের স্বয়ংক্রিয় পুনরায় চেষ্টা ও ত্রুটি পরিচালনা
#
# ### 📊 **মনিটরিং ও অবজারভারিলিটি**
# - **সমান্তরাল এক্সিকিউশন ট্র্যাকিং**: সব সমান্তরাল অপারেশনের অগ্রগতি নজরে রাখুন
# - **পারফরম্যান্স মেট্রিক্স**: গতি বৃদ্ধি এবং দক্ষতার পরিমাপ
# - **সম্পদ ব্যবহার বিশ্লেষণ**: সমান্তরাল এজেন্ট বরাদ্দ উন্নত করুন
# - **বটলনেক সনাক্তকরণ**: পারফরম্যান্স সীমাবদ্ধতা খুঁজে বের করুন এবং সমাধান করুন
#
# আসুন, উচ্চ-দক্ষ সমান্তরাল এআই ওয়ার্কফ্লো তৈরি করি! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **অস্বীকৃতি**:
# এই নথিটি AI অনুবাদ পরিষেবা [Co-op Translator](https://github.com/Azure/co-op-translator) ব্যবহার করে অনূদিত হয়েছে। যদিও আমরা শুদ্ধতার জন্য চেষ্টা করি, অনুগ্রহ করে মনে রাখবেন যে স্বয়ংক্রিয় অনুবাদে ত্রুটি বা অসঙ্গতি থাকতে পারে। মূল নথিটি তার স্বভাষায় কর্তৃত্বপূর্ণ উৎস হিসেবে বিবেচিত হওয়া উচিত। গুরুত্বপূর্ণ তথ্যের জন্য পেশাদার মানব অনুবাদ সুপারিশ করা হয়। এই অনুবাদের ব্যবহারে প্রয়োজনীয় ভুল বোঝাবুঝি বা ভুল ব্যাখ্যার জন্য আমরা দায়বদ্ধ নই।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
