# %% [markdown]
# # ਮਾਇਕ੍ਰੋਸੌਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ — ਆਜ਼ੂਰ ਓਪਨਏਆਈ (Responses API)
#
# ਇਸ ਕੋਡ ਸੈਂਪਲ ਵਿੱਚ, ਤੁਸੀਂ **ਮਾਇਕ੍ਰੋਸੌਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ (MAF)** ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਇੱਕ ਸਾਦਾ ਏਜੰਟ ਬਣਾਵੋਗੇ ਜੋ ਕਿ **ਆਜ਼ੂਰ ਓਪਨਏਆਈ** ਦੁਆਰਾ ਸਮਰਥਿਤ ਹੈ ਅਤੇ **Responses API** ਵਰਤਦਾ ਹੈ।
#
# > **ਮਾਈਗ੍ਰੇਸ਼ਨ ਨੋਟ:** ਇਹ ਸੈਂਪਲ ਪਹਿਲਾਂ Semantic Kernel ਨੁੰGitHub ਮਾਡਲਾਂ ਨਾਲ ਵਰਤਦਾ ਸੀ। ਇਸ ਨੂੰ ਮਾਇਕ੍ਰੋਸੌਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ ਵਿੱਚ ਮਾਈਗ੍ਰੇਟ ਕਰ ਦਿੱਤਾ ਗਿਆ ਹੈ, ਅਤੇ GitHub ਮਾਡਲਾਂ (ਜੋ ਮਿਆਦ ختمੀ, ਜੁਲਾਈ 2026 ਨੂੰ ਰਿਟਾਇਰ ਹੋ ਰਹੇ ਹਨ) ਦੀ ਥਾਂ ਆਜ਼ੂਰ ਓਪਨਏਆਈ ਨਾਲ ਬਦਲੀ ਕਰ ਦਿੱਤੀ ਗਈ ਹੈ, ਜੋ ਕਿ Responses API ਨੂੰ ਸਪੋਰਟ ਕਰਦਾ ਹੈ। MAF ਵਿੱਚ `OpenAIChatClient` ਆਜ਼ੂਰ ਓਪਨਏਆਈ ਦੇ ਸਥਿਰ `/openai/v1/` ਐਂਡਪੌਇੰਟ ਨੂੰ ਨਿਸ਼ਾਨਾ ਬਣਾਉਂਦਾ ਹੈ ਅਤੇ ਡਿਫ਼ੌਲਟ ਤੋਂ Responses API ਬਰਤਦਾ ਹੈ।
#
# ਇਸ ਸੈਂਪਲ ਦਾ ਮਕਸਦ ਇਹ ਦਿਖਾਉਣਾ ਹੈ ਕਿ ਵੱਖ-ਵੱਖ ਏਜੰਟ ਪੈਟਰਨ ਲਾਗੂ ਕਰਨ ਵੇਲੇ ਅੱਗੇ ਜਾ ਕੇ ਹੋਰ ਕੋਡ ਸੈਂਪਲਾਂ ਵਿੱਚ ਕਿਹੜੇ ਕਦਮ ਲਏ ਜਾਣਗੇ।

# %%
# %pip install agent-framework agent-framework-openai azure-identity -q

# %% [markdown]
# ## ਜ਼ਰੂਰੀ ਪਾਇਥਨ ਪੈਕੇਜਾਂ ਨੂੰ ਆਯਾਤ ਕਰੋ

# %%
import os
import random

from dotenv import load_dotenv
from IPython.display import display, HTML

from agent_framework import tool
from agent_framework.openai import OpenAIChatClient
from azure.identity import AzureCliCredential

# %% [markdown]
# ## ਇੱਕ ਟੂਲ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਨਾ
#
# ਮਾਈਕ੍ਰੋਸੌਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ ਵਿੱਚ, ਇੱਕ **ਟੂਲ** ਸਾਧਾਰਣ ਪਾਇਥਨ ਫੰਕਸ਼ਨ ਹੁੰਦਾ ਹੈ ਜਿਸਨੂੰ `@tool` ਨਾਲ ਸਜਾਇਆ ਜਾਂਦਾ ਹੈ ਜਿਸਨੂੰ ਏਜੰਟ ਕਾਲ ਕਰ ਸਕਦਾ ਹੈ। ਹੇਠਾਂ ਅਸੀਂ ਇੱਕ ਐਸਾ ਟੂਲ ਪਰਿਭਾਸ਼ਿਤ ਕਰਦੇ ਹਾਂ ਜੋ ਇੱਕ ਬੇਤਰਤੀਬ ਛੁੱਟੀਆਂ ਦਾ ਮੰਜ਼ਿਲ ਵਾਪਸ ਕਰਦਾ ਹੈ ਅਤੇ ਪਿਛਲੇ ਮੰਜ਼ਿਲ ਨੂੰ ਦੁਹਰਾਉਂਣ ਤੋਂ ਬਚਦਾ ਹੈ।

# %%
# A list of vacation destinations the tool can choose from.
_DESTINATIONS = [
    "Barcelona, Spain",
    "Paris, France",
    "Berlin, Germany",
    "Tokyo, Japan",
    "Sydney, Australia",
    "New York, USA",
    "Cairo, Egypt",
    "Cape Town, South Africa",
    "Rio de Janeiro, Brazil",
    "Bali, Indonesia",
]

# Track the last destination so repeated calls avoid immediate repeats.
_last_destination: str | None = None


@tool(approval_mode="never_require")
def get_random_destination() -> str:
    """Provides a random vacation destination."""
    global _last_destination
    available = _DESTINATIONS.copy()
    if _last_destination and len(available) > 1:
        available.remove(_last_destination)
    destination = random.choice(available)
    _last_destination = destination
    return destination

# %%
load_dotenv()

endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
deployment = os.environ["AZURE_OPENAI_DEPLOYMENT"]

# OpenAIChatClient targets Azure OpenAI's v1 endpoint and uses the Responses API.
# Sign in with `az login` first so AzureCliCredential can authenticate.
chat_client = OpenAIChatClient(
    model=deployment,
    azure_endpoint=endpoint,
    credential=AzureCliCredential(),
)

# %% [markdown]
# ## ਏਜੰਟ ਬਣਾਉਣਾ
#
# ਇੱਥੇ, ਅਸੀਂ `TravelAgent` ਨਾਮਕ ਏਜੰਟ ਬਣਾਉਂਦੇ ਹਾਂ।
#
# ਇਸ ਉਦਾਹਰਨ ਵਿੱਚ, ਅਸੀਂ ਬਹੁਤ ਹੀ ਬੁਨਿਆਦੀ ਹੁਕਮ ਵਰਤਦੇ ਹਾਂ। ਇਹ ਹੁਕਮ ਬਦਲ ਕੇ ਦੇਖੋ ਕਿ ਏਜੰਟ ਦੇ ਵਿਹਾਰ ਵਿੱਚ ਕਿਵੇਂ ਬਦਲਾਅ ਆਉਂਦੇ ਹਨ।

# %%
agent = chat_client.as_agent(
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
    tools=[get_random_destination],
)

# %% [markdown]
# ## ਏਜੰਟ ਚਲਾਉਣਾ
#
# ਹੁਣ ਅਸੀਂ ਏਜੰਟ ਚਲਾ ਸਕਦੇ ਹਾਂ। ਅਸੀਂ ਇੱਕ `AgentSession` ਬਣਾਉਂਦੇ ਹਾਂ ਤਾਂ ਕਿ ਏਜੰਟ ਗੱਲਬਾਤ ਨੂੰ ਮੋੜ ਦਰ ਮੋੜ ਯਾਦ ਰੱਖ ਸਕੇ, ਫਿਰ ਦੋ `user_inputs` ਭੇਜਦੇ ਹਾਂ। ਪਹਿਲਾ ਇੱਕ ਯਾਤਰਾ ਲਈ ਪੁੱਛਦਾ ਹੈ; ਦੂਜਾ ਕਹਿੰਦਾ ਹੈ ਕਿ ਉਪਭੋਗਤਾ ਨੂੰ ਸੁਝਾਅ ਪਸੰਦ ਨਹੀਂ ਆਇਆ ਅਤੇ ਹੋਰ ਮੰਗਦਾ ਹੈ — ਏਜੰਟ ਸੈਸ਼ਨ ਇਤਿਹਾਸ ਨਾਲ ਨਾਲ `get_random_destination` ਟੂਲ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਜਵਾਬ ਦਿੰਦਾ ਹੈ।
#
# ਤੁਸੀਂ ਇਹ संदेश ਤਬਦੀਲ ਕਰ ਸਕਦੇ ਹੋ ਤਾਂ ਜੋ ਦੇਖ ਸਕੋ ਕਿ ਏਜੰਟ ਕਿਸ ਤਰ੍ਹਾਂ ਵੱਖਰੇ ਤਰੀਕੇ ਨਾਲ ਪ੍ਰਤੀਕ੍ਰਿਆ ਕਰਦਾ ਹੈ। ਜਵਾਬ **ਟੋਕਨ-ਬਾਇ-ਟੋਕਨ** ਸਟਰੀਮ ਕੀਤੇ ਜਾਂਦੇ ਹਨ।

# %%
user_inputs = [
    "Plan me a day trip.",
    "I don't like that destination. Plan me another vacation.",
]


async def main():
    # A session keeps conversation history across turns.
    session = agent.create_session()

    for user_input in user_inputs:
        html_output = (
            f"<div style='margin-bottom:10px'>"
            f"<div style='font-weight:bold'>User:</div>"
            f"<div style='margin-left:20px'>{user_input}</div></div>"
        )

        full_response: list[str] = []
        # Stream the agent's response token-by-token. The agent will call the
        # get_random_destination tool automatically when it needs a destination.
        async for chunk in agent.run(user_input, session=session, stream=True):
            full_response.append(str(chunk))

        html_output += (
            "<div style='margin-bottom:20px'>"
            f"<div style='font-weight:bold'>TravelAgent:</div>"
            f"<div style='margin-left:20px; white-space:pre-wrap'>{''.join(full_response)}</div></div><hr>"
        )

        display(HTML(html_output))


await main()

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
