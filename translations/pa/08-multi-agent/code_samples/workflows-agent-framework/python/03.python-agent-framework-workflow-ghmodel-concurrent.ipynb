# %% [markdown]
# # ⚡ ਮਾਈਕ੍ਰੋਸੌਫਟ ਫਾਊਂਡਰੀ ਨਾਲ ਸਾਥੀ ਏਜੰਟ ਵਰਕਫਲੋਜ਼ (ਪਾਇਥਨ)
#
# ## 📋 ਉੱਨਤ ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ ਟਿਊਟੋਰਿਯਲ
#
# ਇਹ ਨੋਟਬੁੱਕ ਮਾਈਕ੍ਰੋਸੌਫਟ ਏਜੰਟ ਫ੍ਰੇਮਵਰਕ ਦੀ ਵਰਤੋਂ ਕਰਕੇ **ਸਾਥੀ ਵਰਕਫਲੋ ਪੈਟਰਨ** ਦਰਸਾਉਂਦਾ ਹੈ। ਤੁਸੀਂ ਸਿੱਖੋਗੇ ਕਿ ਕਿਸ ਤਰ੍ਹਾਂ ਉੱਚ ਪ੍ਰਦਰਸ਼ਨ ਵਾਲੇ, ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ ਵਰਕਫਲੋਜ਼ ਬਣਾਏ ਜਾਣ ਜੋ ਕਈ ਏਆਈ ਏਜੰਟ ਇੱਕ ਸਮੇਂ ਚਲਾਉਂਦੇ ਹਨ, ਜਿਸ ਨਾਲ ਥਰੂਪੁੱਟ ਵਿੱਚ ਬਹੁਤ ਸੁਧਾਰ ਹੁੰਦਾ ਹੈ ਅਤੇ ਸੁਖੀ ਮਹਾਰਥ ਵਾਲੀਆਂ ਮਲਟੀ-ਥ੍ਰੈਡ ਕੀਤਾ ਗਿਆ ਕਾਰੋਬਾਰੀ ਪ੍ਰਕਿਰਿਆਵਾਂ ਯੋਗ ਬਣਦੇ ਹਨ।
#
# > **ਮਾਈਗ੍ਰੇਸ਼ਨ ਨੋਟ:** ਇਸ ਸੈਂਪਲ ਨੇ ਪਹਿਲਾਂ GitHub ਮਾਡਲ ਸੂਚਿਤ ਕੀਤੇ ਸਨ। GitHub ਮਾਡਲ ਹਟਾਏ ਜਾ ਰਹੇ ਹਨ (ਜੁਲਾਈ 2026 ਵਿਚ ਸੇਵਾ समाप्त), ਇਸ ਲਈ ਹੁਣ ਇਹ **Microsoft Foundry** ਨੂੰ `FoundryChatClient` ਰਾਹੀਂ ਵਰਤਦਾ ਹੈ, ਜੋ Azure OpenAI **Responses API** ਨੂੰ ਟਾਰਗੇਟ ਕਰਦਾ ਹੈ।
#
# ## 🎯 ਸਿਖਣ ਦੇ ਲੱਖੇ
#
# ### 🚀 **ਸਾਥੀ ਪ੍ਰੋਸੈਸਿੰਗ ਦੇ ਮੁਢਲੇ ਤੱਤ**
# - **ਪੈਰਾਲਲ ਏਜੰਟ ਕਿਰਿਆਨਵਯਨ**: ਵੱਧ ਤੋਂ ਵੱਧ ਕੁਸ਼ਲਤਾ ਲਈ ਕਈ ਏਜੰਟਾਂ ਨੂੰ ਇੱਕਸਮੇਂ ਚਲਾਉਣਾ
# - **ਵਰਕਫਲੋ ਸੰਯੋਜਨ**: ਡਾਟਾ ਅਡੋਲਤਾ ਜਾਰੀ ਰੱਖਦਿਆਂ ਸਾਥੀ ਆਪਰੇਸ਼ਨਾਂ ਦਾ ਕੋਆਰਡਿਨੇਸ਼ਨ
# - **ਪਰਫਾਰਮੈਂਸ ਸੁਧਾਰ**: ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ ਨਾਲ ਮਹੱਤਵਪੂਰਣ ਤੇਜ਼ੀ ਹਾਸਲ ਕਰਨਾ
# - **ਸਰੋਤ ਪ੍ਰਬੰਧਨ**: ਸਾਥੀ ਕਾਰਜਾਂ ਵਿੱਚ ਏਆਈ ਮਾਡਲ ਸਰੋਤਾਂ ਦੀ ਕੁਸ਼ਲ ਵਰਤੋਂ
#
# ### 🏗️ **ਉੱਨਤ ਸਾਥੀ ਪੈਟਰਨ**
# - **ਫੋਰਕ-ਜੋਇਨ ਪ੍ਰੋਸੈਸਿੰਗ**: ਕਈ ਏਜੰਟਾਂ ਵਿੱਚ ਕੰਮ ਵੰਡਣਾ ਅਤੇ ਨਤੀਜੇ ਜੋੜਨਾ
# - **ਪਾਈਪਲਾਈਨ ਪੈਰਾਲਲਿਜ਼ਮ**: ਲਗਾਤਾਰ ਥਰੂਪੁੱਟ ਲਈ ਇਕ ਦੂਜੇ ਨਾਲ ਓਵਰਲੈਪਿੰਗ ਕਿਰਿਆਵਾਂ
# - **ਲੋਡ ਬੈਲੈਂਸਿੰਗ**: ਉਪਲੱਬਧ ਏਜੰਟ ਸਰੋਤਾਂ ਵਿੱਚ ਕੰਮ ਨੂੰ ਨਿਆਂਸੰਗਤ ਤੌਰ 'ਤੇ ਵੰਡਣਾ
# - **ਸਿੰਕ੍ਰੋਨਾਈਜ਼ੇਸ਼ਨ ਬਿੰਦੂ**: ਮਹਤਵਪੂਰਣ ਵਰਕਫਲੋ ਚਰਣਾਂ 'ਚ ਸਾਥੀ ਏਜੰਟਾਂ ਦਾ ਕੋਆਰਡਿਨੇਸ਼ਨ
#
# ### 🏢 **ਕਾਰੋਬਾਰੀ ਸਾਥੀ ਐਪਲੀਕੇਸ਼ਨਾਂ**
# - **ਵੱਡੇ ਮਾਤਰਾ ਵਿੱਚ ਦਸਤਾਵੇਜ਼ ਪ੍ਰੋਸੈਸਿੰਗ**: ਕਈ ਦਸਤਾਵੇਜ਼ਾਂ ਨੂੰ ਇੱਕਸਮੇਂ ਪ੍ਰੋਸੈਸ ਕਰਨਾ
# - **ਰੀਅਲ-ਟਾਈਮ ਸਮੱਗਰੀ ਵਿਸ਼ਲੇਸ਼ਣ**: ਆ ਰਹੇ ਡੇਟਾ ਸਟ੍ਰੀਮਾਂ ਦੀ ਸਾਥੀ ਵਿਸ਼ਲੇਸ਼ਣ
# - **ਬੈਚ ਪ੍ਰੋਸੈਸਿੰਗ ਸੁਧਾਰ**: ਵੱਡੇ ਪੱਧਰ ਦੀ ਕਾਰਗੁਜ਼ਾਰੀ ਲਈ ਵੱਧ ਤੋਂ ਵੱਧ ਥਰੂਪੁੱਟ
# - **ਮਲਟੀ-ਮੋਡਲ ਵਿਸ਼ਲੇਸ਼ਣ**: ਵੱਖ-ਵੱਖ ਸਮੱਗਰੀ ਕਿਸਮਾਂ (ਟੈਕਸਟ, ਤਸਵੀਰਾਂ, ਡੇਟਾ) ਦੀ ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ
#
# ## ⚙️ ਜ਼ਰੂਰੀ ਤਿਆਰੀ ਅਤੇ ਸੈਟਅੱਪ
#
# ### 📦 **ਲਾਜ਼ਮੀ ਡਿਪੈਂਡੈਂਸੀਜ਼**
#
# ਸਾਥੀ ਵਰਕਫਲੋ ਸਮਰੱਥਾ ਵਾਲਾ ਏਜੰਟ ਫ੍ਰੇਮਵਰਕ ਇੰਸਟਾਲ ਕਰੋ:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ਸੈਟਿੰਗ**
#
# Azure CLI (`az login`) ਨਾਲ ਸਾਈਨ ਇਨ ਕਰੋ ਤਾਂ ਜੋ `AzureCliCredential` ਪ੍ਰਮਾਣਿਕਤਾ ਕਰ ਸਕੇ, ਫਿਰ ਆਪਣੇ Microsoft Foundry ਪ੍ਰਾਜੈਕਟ ਵੇਰਵੇ ਸੈੱਟ ਕਰੋ।
#
# **ਐਨਵਾਇਰਨਮੈਂਟ ਸੈਟਅੱਪ (.env ਫਾਈਲ):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **ਸਾਥੀ ਪ੍ਰੋਸੈਸਿੰਗ ਵਿਚ ਧਿਆਨ ਦੇਣ ਵਾਲੀਆਂ ਗੱਲਾਂ:**
# - **ਰੇਟ ਲਿਮਿਟਸ**: ਸਾਥੀ ਬੇਨਤੀਆਂ ਲਈ Azure OpenAI ਰੇਟ ਲਿਮਿਟਸ ਦੀ ਨਿਗਰਾਨੀ
# - **ਸਰੋਤ ਦੀ ਵਰਤੋਂ**: ਕਈ ਸਾਥੀ ਏਜੰਟਾਂ ਨਾਲ ਯਾਦਾ ਅਤੇ CPU ਦੀ ਵਰਤੋਂ ਵਿਚ ਧਿਆਨ
# - **ਗਲਤੀ ਸਾਂਭਣੀ**: ਪੈਰਾਲਲ ਕਾਰਜ ਲਈ ਮਜ਼ਬੂਤ ਗਲਤੀ ਬਹਾਲੀ ਲਾਗੂ ਕਰੋ
#
# ### 🏗️ **ਸਾਥੀ ਵਰਕਫਲੋ ਆਰਕੀਟੈਕਚਰ**
#
# ```mermaid
# graph TD
#     A[ਵਰਕਫਲੋ ਸ਼ੁਰੂਆਤ] --> B[ਸਾਂਝੇ ਤੌਰ 'ਤੇ ਚਲਾਉਣਾ]
#     B --> C[ਏਜੰਟ ਪੂਲ 1]
#     B --> D[ਏਜੰਟ ਪੂਲ 2]
#     B --> E[ਏਜੰਟ ਪੂਲ 3]
#     C --> F[ਨਤੀਜਾ ਇਕੱਠਾ ਕਰਨਾ]
#     D --> F
#     E --> F
#     F --> G[ਅੰਤਿਮ ਨਿਕਾਸ]
#
#     H[ਮਾਈਕ੍ਰੋਸੌਫਟ ਫਾਊਂਡਰੀ] --> C
#     H --> D
#     H --> E
# ```
#
# **ਮੁੱਖ ਫਾਇਦੇ:**
# - **⚡ ਪ੍ਰਦਰਸ਼ਨ**: ਪੈਰਾਲਲ ਕਿਰਿਆਵਾਈ ਨਾਲ ਪ੍ਰਮੁੱਖ ਤੇਜ਼ੀ
# - **📈 ਵਿਸ਼ਾਲਤਾ**: ਵੱਧ ਕਰੇਲੋਡ ਬਿਨਾਂ ਸਮੇਂ ਵਿੱਚ ਅਨੁਪਾਤੀ ਵਾਧਾ ਹੋਣ ਦੇ
# - **🔄 ਕੁਸ਼ਲਤਾ**: ਉਪਲੱਬਧ ਗਣਤੰਤਰ ਸਰੋਤਾਂ ਦੀ ਬਿਹਤਰ ਵਰਤੋਂ
# - **🎯 ਥਰੂਪੁੱਟ**: ਇੱਕੋ ਸਮੇਂ ਵਿੱਚ ਹੋਰ ਕੰਮ ਪ੍ਰੋਸੈਸ ਕਰੋ
#
# ## 🎨 **ਸਾਥੀ ਵਰਕਫਲੋ ਡਿਜ਼ਾਈਨ ਪੈਟਰਨ**
#
# ### 🔍 **ਖੋਜ ਅਤੇ ਵਿਸ਼ਲੇਸ਼ਣ ਪਾਈਪਲਾਈਨ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ਡੇਟਾ ਪ੍ਰੋਸੈਸਿੰਗ ਵਰਕਫਲੋ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ਸਮੱਗਰੀ ਬਣਾਉਣ ਪਾਈਪਲਾਈਨ**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ਮਲਟੀ-ਸਟੇਜ ਪ੍ਰੋਸੈਸਿੰਗ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ਕਾਰੋਬਾਰੀ ਪ੍ਰਦਰਸ਼ਨ ਦੇ ਫਾਇਦੇ**
#
# ### ⚡ **ਥਰੂਪੁੱਟ ਸੁਧਾਰ**
# - **ਪੈਰਾਲਲ ਕਿਰਿਆਵਾਈ**: ਕਈ ਏਜੰਟ ਇੱਕ ਸਮੇਂ ਕੰਮ ਕਰ ਰਹੇ ਹਨ
# - **ਸਰੋਤ ਵਰਤੋਂ**: ਉਪਲੱਬਧ AI ਮਾਡਲ ਸਮਰੱਥਾ ਦੀ ਜ਼ਿਆਦਾ ਤੋਂ ਜ਼ਿਆਦਾ ਕੁਸ਼ਲ ਵਰਤੋਂ
# - **ਸਮੇਂ ਵਿੱਚ ਕਮੀ**: ਕੁੱਲ ਪ੍ਰੋਸੈਸਿੰਗ ਸਮੇਂ ਵਿੱਚ ਮਹੱਤਵਪੂਰਣ ਘਟਾਓ
# - **ਵਧਦੇ ਆਰਕੀਟੈਕਚਰ**: ਜਰੂਰਤ ਅਨੁਸਾਰ ਸਾਥੀ ਏਜੰਟਾਂ ਨੂੰ ਆਸਾਨੀ ਨਾਲ ਵਧਾਓ
#
# ### 🛡️ **ਭਰੋਸਾ ਯੋਗਤਾ ਅਤੇ ਸਹਿਣਸ਼ੀਲਤਾ**
# - **ਫੌਲਟ ਟੋਲਰੈਂਸ**: ਕਿਸੇ ਇੱਕ ਏਜੰਟ ਦੀ ਗਲਤੀ ਪੂਰੇ ਵਰਕਫਲੋ ਨੂੰ ਰੋਕਦੀ ਨਹੀਂ
# - **ਗਲਤੀ ਆਇਸੋਲੇਸ਼ਨ**: ਇੱਕ ਸਾਥੀ ਸਾਖਾ ਵਿੱਚ ਸਮੱਸਿਆ ਹੋਣ ਉੱਤੇ ਹੋਰਾਂ ਉੱਤੇ ਅਸਰ ਨਹੀਂ ਹੁੰਦਾ
# - **ਸੁੰਦਰ ਹ੍ਰਾਸ**: ਘਟੇ ਹੋਏ ਏਜੰਟ ਸਮਰੱਥਾ ਨਾਲ ਵੀ ਪ੍ਰਣਾਲੀ ਚੱਲਦੀ ਰਹਿੰਦੀ ਹੈ
# - **ਬਹਾਲੀ ਮਕੈਨਿਜ਼ਮ**: ਅਸਫਲ ਕਾਰਜਾਂ ਲਈ ਸੁਚਾਰੂ ਮੁੜ ਕੋਸ਼ਿਸ਼ ਅਤੇ ਗਲਤੀ ਸੰਭਾਲਣਾ
#
# ### 📊 **ਨਿਗਰਾਨੀ ਅਤੇ ਦਰਸ਼ਨ**
# - **ਸਾਥੀ ਕਿਰਿਆਵਾਈ ਟਰੈਕਿੰਗ**: ਸਾਰੇ ਪੈਰਾਲਲ ਕਾਰਜਾਂ ਦੀ ਪ੍ਰਗਤੀ ਦੀ ਨਿਗਰਾਨੀ ਕਰੋ
# - **ਪਰਫਾਰਮੈਂਸ ਮੈਟਰਿਕਸ**: ਤੇਜ਼ੀ ਅਤੇ ਕੁਸ਼ਲਤਾ ਲਾਭਾਂ ਨੂੰ ਮਾਪੋ
# - **ਸਰੋਤ ਵਰਤੋਂ ਵਿਸ਼ਲੇਸ਼ਣ**: ਸਾਥੀ ਏਜੰਟਾਂ ਦਾ ਵੰਡ ਸੁਧਾਰੋ
# - **ਬੌਟਲਨੇਕ ਪਛਾਣ**: ਪ੍ਰਦਰਸ਼ਨ ਦੀਆਂ ਰੁਕਾਵਟਾਂ ਲੱਭੋ ਅਤੇ ਹੱਲ ਕਰੋ
#
# ਆਓ ਉੱਚ ਪ੍ਰਦਰਸ਼ਨ ਵਾਲੇ ਸਾਥੀ ਏਆਈ ਵਰਕਫਲੋਜ਼ ਬਣਾਈਏ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
