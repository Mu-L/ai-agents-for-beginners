# %% [markdown]
# # ⚡ ਮਾਇਕ੍ਰੋਸੌਫਟ ਫਾਊਂਡਰੀ (Python) ਨਾਲ ਸਮਕਾਲੀ ਏਜੰਟ ਵਰਕਫਲੋਜ਼
#
# ## 📋 ਅਡਵਾਂਸਡ ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ ਟਿਊਟੋਰિયલ
#
# ਇਹ ਨੋਟਬੁੱਕ ਮਾਇਕ੍ਰੋਸੌਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ ਦੀ ਵਰਤੋਂ ਕਰਦਿਆਂ **ਸਮਕਾਲੀ ਵਰਕਫਲੋ ਪੈਟਰਨ** ਦਿਖਾਉਂਦੀ ਹੈ। ਤੁਸੀਂ ਅਜਿਹਾ ਕਿਵੇਂ ਬਣਾਉਣਾ ਸਿੱਖੋਗੇ ਜਿੱਥੇ ਬਹੁਤ ਸਾਰੇ ਏਆਈ ਏਜੰਟ ਇੱਕ ਨਾਲ ਚੱਲਦੇ ਹਨ, ਜਿਸ ਨਾਲ ਕੰਮ ਦੀ ਦਰ ਵਧਦੀ ਹੈ ਅਤੇ ਸੁਧਰੇ ਹੋਏ ਬਹੁ-ਥ੍ਰੇਡਿਡ ਵਪਾਰਕ ਪ੍ਰਕਿਰਿਆਵਾਂ ਨੂੰ ਯੋਗ ਕਰਦਾ ਹੈ।
#
# > **ਮਾਈਗ੍ਰੇਸ਼ਨ ਨੋਟ:** ਇਸ ਨਮੂਨੇ ਨੇ ਪਹਿਲਾਂ GitHub ਮਾਡਲ ਸੂਚਿਤ ਕੀਤੇ ਸਨ। GitHub ਮਾਡਲ (ਜੋ ਕਿ ਜੁਲਾਈ 2026 ਤੱਕ ਅਟਕਾ ਦਿੱਤੇ ਜਾ ਰਹੇ ਹਨ) ਦੇਅੰਤर्गत ਹੁਣ ਇਹ `FoundryChatClient` ਰਾਹੀਂ **Microsoft Foundry** ਨੂੰ ਵਰਤਦਾ ਹੈ, ਜੋ Azure OpenAI **Responses API** ਨੂੰ ਨਿਸ਼ਾਨਾ ਬਨਾਉਂਦਾ ਹੈ।
#
# ## 🎯 ਸਿੱਖਣ ਦੇ ਉਦੇਸ਼
#
# ### 🚀 **ਸਮਕਾਲੀ ਪ੍ਰੋਸੈਸਿੰਗ ਦੀਆਂ ਮੂਲ ਭਾਸ਼ਾਵਾਂ**
# - **ਪੈਰਾਲਲ ਏਜੰਟ ਚਲਾਉਣਾ**: ਜ਼ਿਆਦਾ ਕੁਸ਼ਲਤਾ ਲਈ ਕਈ ਏਜੰਟਾਂ ਨੂੰ ਇੱਕ ਨਾਲ ਚਲਾਓ
# - **ਵਰਕਫਲੋ ਸਹਿ-ਸੰਚਾਲਨ**: ਡੇਟਾ ਸਥਿਰਤਾ ਬਰਕਰਾਰ ਰੱਖਦਿਆਂ ਸਮਕਾਲੀ ਕਾਰਵਾਈਆਂ ਨੂੰ ਸਮਨਵਿਤ ਕਰੋ
# - **ਕੁਸ਼ਲਤਾ ਬਿਹਤਰੀ**: ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ ਰਾਹੀਂ ਮਹੱਤਵਪੂਰਨ ਤੇਜ਼ੀ ਹਾਸਲ ਕਰੋ
# - **ਸੰਸਾਧਨ ਪਰਬੰਧਨ**: ਸਮਕਾਲੀ ਕਾਰਵਾਈਆਂ ਵਿੱਚ ਏਆਈ ਮਾਡਲ ਸੰਸਾਧਨਾਂ ਦੀ ਸਫਲ ਵਰਤੋਂ ਕਰੋ
#
# ### 🏗️ **ਅਡਵਾਂਸਡ ਸਮਕਾਲੀ ਪੈਟਰਨ**
# - **ਫੋਰਕ-ਜੋਇਨ ਪ੍ਰੋਸੈਸਿੰਗ**: ਕਈ ਏਜੰਟਾਂ ਵਿੱਚ ਕੰਮ ਵੰਡੋ ਅਤੇ ਨਤੀਜਿਆਂ ਨੂੰ ਇਕੱਠਾ ਕਰੋ
# - **ਪਾਈਪਲਾਈਨ ਪੈਰਾਲਲਿਜ਼ਮ**: ਲਗਾਤਾਰ ਪ੍ਰਦਰਸ਼ਨ ਲਈ ਚਰਨਾਂ ਦਾ ਓਵਰਲੈਪਿੰਗ ਐਗਜ਼ਿਕਿਊਸ਼ਨ
# - **ਲੋਡ ਬੈਲੈਂਸਿੰਗ**: ਉਪਲਬਧ ਏਜੰਟ ਸੰਸਾਧਨਾਂ 'ਤੇ ਕੰਮ ਦੀ ਬਰਾਬਰੀ ਵੰਡ
# - **ਸਮਨਵਯੀ ਬਿੰਦੂ**: ਅਹੰਕਾਰ ਬਿੰਦੂਆਂ 'ਤੇ ਸਮਕਾਲੀ ਏਜੰਟਾਂ ਦਾ ਸਹਿਯੋਗ
#
# ### 🏢 **ਉਦਯੋਗਿਕ ਸਮਕਾਲੀ ਐਪਲੀਕੇਸ਼ਨ**
# - **ਉੱਚ-ਪ੍ਰਮਾਣ ਡਾਕੂਮੈਂਟ ਪ੍ਰੋਸੈਸਿੰਗ**: ਕਈ ਡਾਕੂਮੈਂਟਾਂ ਨੂੰ ਇਕੱਠੇ ਪ੍ਰੋਸੈਸ ਕਰੋ
# - **ਅਸਲੀ ਸਮੇਂ ਸਮੱਗਰੀ ਵਿਸ਼ਲੇਸ਼ਣ**: ਆਉਂਦੇ ਡੇਟਾ ਸਟ੍ਰੀਮਾਂ ਦਾ ਸਮਕਾਲੀ ਵਿਸ਼ਲੇਸ਼ਣ
# - **ਥੋਕ ਪ੍ਰਕਿਰਿਆਵਾਂ ਦੀ ਬਿਹਤਰੀ**: ਵੱਡੇ ਪੈਮਾਨੇ ਵਾਲੀਆਂ ਕਾਰਵਾਈਆਂ ਲਈ ਪ੍ਰਦਰਸ਼ਨ ਵਧਾਓ
# - **ਮੁਲਟੀ-ਮੋਡਲ ਵਿਸ਼ਲੇਸ਼ਣ**: ਵੱਖ-ਵੱਖ ਸਮੱਗਰੀ ਕਿਸਮਾਂ (ਟੈਕਸਟ, ਚਿੱਤਰ, ਡੇਟਾ) ਦੀ ਪੈਰਾਲਲ ਪ੍ਰੋਸੈਸਿੰਗ
#
# ## ⚙️ ਲੋੜਾਂ ਅਤੇ ਸੈਟਅੱਪ
#
# ### 📦 **ਜ਼ਰੂਰੀ ਨਿਰਭਰਤਾਵਾਂ**
#
# ਏਜੰਟ ਫਰੇਮਵਰਕ ਜੋ ਸਮਕਾਲੀ ਵਰਕਫਲੋਜ਼ ਸਮਰਥਨ ਕਰਦਾ ਹੈ ਨੂੰ ਇੰਸਟਾਲ ਕਰੋ:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ਸੰਰਚਨਾ**
#
# Azure CLI (`az login`) ਨਾਲ ਸਾਈਨ ਇਨ ਕਰੋ ਤਾਂ ਜੋ `AzureCliCredential` ਪ੍ਰਮਾਣਿਕ ਕਰਨ ਦੇ ਯੋਗ ਹੋਵੇ, ਫਿਰ ਆਪਣਾ Microsoft Foundry ਪਰੋਜੈਕਟ ਵੇਰਵੇ ਸੈੱਟ ਕਰੋ।
#
# **ਵਾਤਾਵਰਣ ਸੈਟਅੱਪ (.env ਫਾਈਲ):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **ਸਮਕਾਲੀ ਪ੍ਰੋਸੈਸਿੰਗ ਸਾਬਧਾਨੀਆਂ:**
# - **ਰੇਟ ਸੀਮਾਵਾਂ**: ਸਮਕਾਲੀ ਬੇਨਤੀਆਂ ਲਈ Azure OpenAI ਰੇਟ ਸੀਮਾਵਾਂ ਦੀ ਨਿਗਰਾਨੀ ਕਰੋ
# - **ਸੰਸਾਧਨ ਵਰਤੋਂ**: ਕਈ ਸਮਕਾਲੀ ਏਜੰਟਾਂ ਨਾਲ ਮੈਮੋਰੀ ਅਤੇ CPU ਵਰਤੋਂ 'ਤੇ ਧਿਆਨ ਦਿਓ
# - **ਗਲਤੀ ਸੰਭਾਲਣਾ**: ਪੈਰਾਲਲ ਓਪਰੇਸ਼ਨਾਂ ਲਈ ਮਜ਼ਬੂਤ ਗਲਤੀ ਵਾਪਸੀ ਪ੍ਰਣਾਲੀ ਲਾਗੂ ਕਰੋ
#
# ### 🏗️ **ਸਮਕਾਲੀ ਵਰਕਫਲੋ ਆਰਕੀਟੈਕਚਰ**
#
# ```mermaid
# graph TD
#     A[ਵਰਕਫ਼ਲੋ ਸ਼ੁਰੂ] --> B[ਸਮਕਾਲੀ ਕਾਰਜਨਵਾਈ]
#     B --> C[ਏਜੰਟ ਪੂਲ 1]
#     B --> D[ਏਜੰਟ ਪੂਲ 2]
#     B --> E[ਏਜੰਟ ਪੂਲ 3]
#     C --> F[ਨਤੀਜੇ ਦਾ ਸੰਗ੍ਰਹਿ]
#     D --> F
#     E --> F
#     F --> G[ਅੰਤਿਮ ਨਤੀਜਾ]
#
#     H[ਮਾਈਕ੍ਰੋਸੌਫਟ ਫਾਊਂਡਰੀ] --> C
#     H --> D
#     H --> E
# ```
#
# **ਮੁੱਖ ਲਾਭ:**
# - **⚡ ਕੁਸ਼ਲਤਾ**: ਪੈਰਾਲਲ ਐਗਜ਼ਿਕਿਊਸ਼ਨ ਰਾਹੀਂ ਮਹੱਤਵਪੂਰਨ ਤੇਜ਼ੀ
# - **📈 ਸਕੇਲਬਿਲਟੀ**: ਵਧੇਰੇ ਕੰਮਾਂ ਨੂੰ ਸਾਂਭਣ ਦੀ ਸਮਰੱਥਾ ਬਿਨਾਂ ਟਾਈਮ ਲਾਗਤ ਵਧਾਏ
# - **🔄 ਕੁਸ਼ਲ ਵਰਤੋਂ**: ਉਪਲਬਧ ਕੰਪਿਊਟੇਸ਼ਨਲ ਸੰਸਾਧਨਾਂ ਦੀ ਬਿਹਤਰ ਵਰਤੋਂ
# - **🎯 ਪ੍ਰਦਰਸ਼ਨ**: ਇੱਕੋ ਸਮੇਂ ਵਿੱਚ ਵਧੇਰੇ ਕੰਮ ਪ੍ਰਕਿਰਿਆ ਵਿੱਚ ਲਿਆਓ
#
# ## 🎨 **ਸਮਕਾਲੀ ਵਰਕਫਲੋ ਡਿਜ਼ਾਈਨ ਪੈਟਰਨ**
#
# ### 🔍 **ਿਗਵਾਈ & ਵਿਸ਼ਲੇਸ਼ਣ ਪਾਈਪਲਾਈਨ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ਡਾਟਾ ਪ੍ਰੋਸੈਸਿੰਗ ਵਰਕਫਲੋ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ਸਮੱਗਰੀ ਰਚਨਾ ਪਾਈਪਲਾਈਨ**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ਮੁਲਟੀ-ਚਰਨ ਪ੍ਰੋਸੈਸਿੰਗ**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ਉਦਯੋਗਿਕ ਕੁਸ਼ਲਤਾ ਲਾਭ**
#
# ### ⚡ **ਪ੍ਰਦਰਸ਼ਨ ਬਿਹਤਰੀ**
# - **ਪੈਰਾਲਲ ਐਗਜ਼ਿਕਿਊਸ਼ਨ**: ਕਈ ਏਜੰਟ ਇਕੱਠੇ ਕੰਮ ਕਰ ਰਹੇ ਹਨ
# - **ਸੰਸਾਧਨ ਵਰਤੋਂ**: ਉਪਲਬਧ ਏਆਈ ਮਾਡਲ ਸਮਰੱਥਾ ਦੀ ਵੱਧ ਤੋਂ ਵੱਧ ਕੁਸ਼ਲਤਾ
# - **ਟਾਈਮ ਕਟੌਤੀ**: ਕੁੱਲ ਪ੍ਰੋਸੈਸਿੰਗ ਸਮੇਂ ਵਿੱਚ ਗੰਭੀਰ کمی
# - **ਸਕੇਲਬਲ ਆਰਕੀਟੈਕਚਰ**: ਜਰੂਰਤ ਪੈਂਦੇ ਹੀ ਹੋਰ ਸਮਕਾਲੀ ਏਜੰਟ ਸੌਂਪੋ
#
# ### 🛡️ **ਭਰੋਸਾ ਅਤੇ ਸਹਿਣਸ਼ੀਲਤਾ**
# - **ਫਾਲਟ ਸੋਖਣਾ**: ਇੱਕ-ਇੱਕ ਏਜੰਟ ਦੇ ਫੇਲ੍ਹ ਹੋਣ ਨਾਲ ਸਾਰੀ ਵਰਕਫਲੋ ਨਹੀਂ ਰੁਕਦੀ
# - **ਗਲਤੀ ਨਿਰੋਲਤਾ**: ਇੱਕ ਸਮਕਾਲੀ ਸ਼ਾਖਾ ਵਿੱਚ ਸਮੱਸਿਆਵਾਂ ਦੂਜੀਆਂ ਨੂੰ ਪ੍ਰਭਾਵਿਤ ਨਹੀਂ ਕਰਦੀਆਂ
# - **ਕ੍ਰਮਬੱਧ ਕਮਜ਼ੋਰੀ**: ਘੱਟੇ ਹੋਏ ਏਜੰਟ ਸਮਰੱਥਾ ਦੇ ਬਾਵਜੂਦ ਪ੍ਰਣਾਲੀ ਕੰਮ ਕਰਦੀ ਰਹਿੰਦੀ ਹੈ
# - **ਵਾਪਸੀ ਮਕੈਨਿਜ਼ਮ**: ਨਾਕਾਮ ਓਪਰੇਸ਼ਨਾਂ ਲਈ ਆਟੋਮੈਟਿਕ ਮੁੜ ਕੋਸ਼ਿਸ਼ ਅਤੇ ਗਲਤੀ ਸੰਭਾਲ
#
# ### 📊 **ਮਾਨੀਟਰਿੰਗ ਅਤੇ ਨਜ਼ਰਦਾਰੀ**
# - **ਸਮਕਾਲੀ ਐਗਜ਼ਿਕਿਊਸ਼ਨ ਟ੍ਰੈਕਿੰਗ**: ਸਾਰੇ ਪੈਰਾਲਲ ਓਪਰੇਸ਼ਨਾਂ ਦੀ ਪ੍ਰਗਤੀ ਮਾਨੋਟਰ ਕਰੋ
# - **ਕੁਸ਼ਲਤਾ ਮਾਪਦੰਡ**: ਤੇਜ਼ੀ ਅਤੇ ਕੁਸ਼ਲਤਾ ਮੁਲਾਂਕਣ
# - **ਸੰਸਾਧਨ ਵਰਤੋਂ ਵਿਸ਼ਲੇਸ਼ਣ**: ਸਮਕਾਲੀ ਏਜੰਟ ਵੰਡ ਨੂੰ ਬਿਹਤਰ ਕਰੋ
# - **ਬੋਤਲਨੈਕ ਪਛਾਣ**: ਕੁਸ਼ਲਤਾ ਰੁਕਾਵਟਾਂ ਲੱਭੋ ਅਤੇ ਸुलਝਾਓ
#
# ਆਓ ਉੱਚ ਕੁਸ਼ਲਤਾ ਵਾਲੇ ਸਮਕਾਲੀ ਏਆਈ ਵਰਕਫਲੋ ਬਣਾ ਲਈਏ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
