# %% [markdown]
# # 🔍 ਮਾਈਕ੍ਰੋਸਾਫਟ ਫਾਊਂਡਰੀ (.NET) ਨਾਲ ਇੰਟਰਪ੍ਰਾਈਜ਼ RAG
#
# ## 📋 ਸਿੱਖਣ ਦੇ ਉਦੇਸ਼
#
# ਇਹ ਨੋਟਬੁੱਕ ਦਿਖਾਉਂਦਾ ਹੈ ਕਿ ਮਾਈਕ੍ਰੋਸਾਫਟ ਫਾਊਂਡਰੀ ਵਿੱਚ .NET ਨਾਲ ਮਾਈਕ੍ਰੋਸਾਫਟ ਏਜੰਟ ਫਰੇਮਵਰਕ ਨੂੰ ਵਰਤ ਕੇ ਇੰਟਰਪ੍ਰਾਈਜ਼-ਗਰੇਡ Retrieval-Augmented Generation (RAG) ਸਿਸਟਮ ਕਿਵੇਂ ਬਣਾਏ ਜਾਣ। ਤੁਸੀਂ ਉਤਪਾਦ-ਤਿਆਰ ਏਜੰਟ ਬਣਾਉਣ ਸਿੱਖੋਗੇ ਜੋ ਦਸਤਾਵੇਜ਼ਾਂ ਵਿੱਚ ਖੋਜ ਸਕਦੇ ਹਨ ਅਤੇ ਇੰਟਰਪ੍ਰਾਈਜ਼ ਸੁਰੱਖਿਆ ਅਤੇ ਸਕੇਲਬਿਲਟੀ ਨਾਲ ਸਹੀ, ਪ੍ਰਸੰਗ-ਜਾਣੂ ਜਵਾਬ ਦਿੰਦੇ ਹਨ।
#
# **ਤੁਸੀਂ ਬਣਾਉਣ ਵਾਲੀਆਂ ਇੰਟਰਪ੍ਰਾਈਜ਼ RAG ਸਮਰੱਥਾਵਾਂ:**
# - 📚 **ਦਸਤਾਵੇਜ਼ ਬੁੱਧੀਮਤਾ**: ਏਜ਼ਿਊਰ AI ਸੇਵਾਵਾਂ ਨਾਲ ਉन्नਤ ਦਸਤਾਵੇਜ਼ ਪ੍ਰੋਸੈਸਿੰਗ
# - 🔍 **ਸੈਮਾਂਟਿਕ ਖੋਜ**: ਇੰਟਰਪ੍ਰਾਈਜ਼ ਵਿਸ਼ੇਸ਼ਤਾਵਾਂ ਨਾਲ ਉੱਚ-ਪ੍ਰਦਰਸ਼ਨ ਵੈਕਟਰ ਖੋਜ
# - 🛡️ **ਸੁਰੱਖਿਆ ਏਕਤਾ**: ਭੂਮਿਕਾ-ਆਧਾਰਿਤ ਪਹੁੰਚ ਅਤੇ ਡੇਟਾ ਸੁਰੱਖਿਆ ਨਮੂਨੇ
# - 🏢 **ਸਕੇਲ ਕਰਨ ਯੋਗ ਆਰਕੀਟੈਕਚਰ**: ਨਿਗਰਾਨੀ ਨਾਲ ਉਤਪਾਦ-ਤਿਆਰ RAG ਸਿਸਟਮ
#
# ## 🎯 ਇੰਟਰਪ੍ਰਾਈਜ਼ RAG ਆਰਕੀਟੈਕਚਰ
#
# ### ਮੁੱਖ ਇੰਟਰਪ੍ਰਾਈਜ਼ ਭਾਗ
# - **ਮਾਈਕ੍ਰੋਸਾਫਟ ਫਾਊਂਡਰੀ**: ਸੁਰੱਖਿਆ ਅਤੇ ਅਨੁਕੂਲਤਾ ਨਾਲ ਪਰਬੰਧਤ ਇੰਟਰਪ੍ਰਾਈਜ਼ AI ਪਲੇਟਫਾਰਮ
# - **ਪ੍ਰਸਥਿਤੀ ਵਾਲੇ ਏਜੰਟ**: ਗੱਲਬਾਤ ਇਤਿਹਾਸ ਅਤੇ ਪ੍ਰਸੰਗ ਪ੍ਰਬੰਧਨ ਨਾਲ Stateful ਏਜੰਟ
# - **ਵੈਕਟਰ ਸਟੋਰ ਪ੍ਰਬੰਧਨ**: ਇੰਟਰਪ੍ਰਾਈਜ਼-ਗਰੇਡ ਦਸਤਾਵੇਜ਼ ਇੰਡੈਕਸਿੰਗ ਅਤੇ ਪ੍ਰਾਪਤੀ
# - **ਪਛਾਣ ਏਕਤਾ**: ਏਜ਼ਿਊਰ AD ਪ੍ਰਮਾਣਿਕਤਾ ਅਤੇ ਭੂਮਿਕਾ-ਆਧਾਰਿਤ ਪਹੁੰਚ ਨਿਯੰਤਰਣ
#
# ### .NET ਇੰਟਰਪ੍ਰਾਈਜ਼ ਲਾਭ
# - **ਟਾਈਪ ਸੇਫਟੀ**: RAG ਆਪਰੇਸ਼ਨਾਂ ਅਤੇ ਡੇਟਾ ਸਰਚਨਾਵਾਂ ਲਈ ਕੰਪਾਇਲ-ਟਾਈਮ ਜਾਂਚ
# - **Async ਪ੍ਰਦਰਸ਼ਨ**: ਗੈਰ-ਅਟਕਣ ਵਾਲੇ ਦਸਤਾਵੇਜ਼ ਪ੍ਰੋਸੈਸਿੰਗ ਅਤੇ ਖੋਜ ਆਪਰੇਸ਼ਨ
# - **ਮੇਮੋਰੀ ਪ੍ਰਬੰਧਨ**: ਵੱਡੇ ਦਸਤਾਵੇਜ਼ ਸੰਗ੍ਰਹਿਤ ਦੀ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਵਰਤੋਂ
# - **ਇੰਟੈਗ੍ਰੇਸ਼ਨ ਨਮੂਨੇ**: ਨੈਟਿਵ ਏਜ਼ਿਊਰ ਸੇਵਾ ਇੰਟੈਗ੍ਰੇਸ਼ਨ ਨਾਲ ਡਿਪੈਂਡਸੀ ਇੰਜੈਕਸ਼ਨ
#
# ## 🏗️ ਤਕਨੀਕੀ ਆਰਕੀਟੈਕਚਰ
#
# ### ਇੰਟਰਪ੍ਰਾਈਜ਼ RAG ਪਾਈਪਲਾਈਨ
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### ਮੁੱਖ .NET ਭਾਗ
# - **Azure.AI.Agents.Persistent**: ਸਥਿਤੀ ਸਥਿਰਤਾ ਨਾਲ ਇੰਟਰਪ੍ਰਾਈਜ਼ ਏਜੰਟ ਪ੍ਰਬੰਧਨ
# - **Azure.Identity**: ਸੁਰੱਖਿਅਤ ਏਜ਼ਿਊਰ ਸੇਵਾ ਪਹੁੰਚ ਲਈ ਏਕਤ੍ਰਿਤ ਪ੍ਰਮਾਣਿਕਤਾ
# - **Microsoft.Agents.AI.AzureAI**: ਏਜ਼ਿਊਰ-ਅਨੁਕੂਲਿਤ ਏਜੰਟ ਫਰੇਮਵਰਕ ਲਾਗੂ ਕਰਨ
# - **System.Linq.Async**: ਉੱਚ-ਪ੍ਰਦਰਸ਼ਨ ਅਸਿੰਕ੍ਰਨਸ LINQ ਆਪਰੇਸ਼ਨ
#
# ## 🔧 ਇੰਟਰਪ੍ਰਾਈਜ਼ ਵਿਸ਼ੇਸ਼ਤਾਵਾਂ ਅਤੇ ਲਾਭ
#
# ### ਸੁਰੱਖਿਆ ਅਤੇ ਅਨੁਕੂਲਤਾ
# - **ਏਜ਼ਿਊਰ AD ਏਕਤਾ**: ਇੰਟਰਪ੍ਰਾਈਜ਼ ਪਛਾਣ ਪ੍ਰਬੰਧਨ ਅਤੇ ਪ੍ਰਮਾਣਿਕਤਾ
# - **ਭੂਮਿਕਾ-ਆਧਾਰਿਤ ਪਹੁੰਚ**: ਦਸਤਾਵੇਜ਼ ਪਹੁੰਚ ਅਤੇ ਆਪਰੇਸ਼ਨਾਂ ਲਈ ਸੁਖਮ ਪੱਤਰਕਾਰੀਆਂ
# - **ਡੇਟਾ ਸੁਰੱਖਿਆ**: ਸੰਵੇਦਨਸ਼ੀਲ ਦਸਤਾਵੇਜ਼ਾਂ ਲਈ ਰੈਸਟ ਅਤੇ ਟ੍ਰਾਂਜ਼ਿਟ ਵਿੱਚ ਇੰਕ੍ਰਿਪਸ਼ਨ
# - **ਆਡਿਟ ਲਾਗਿੰਗ**: ਅਨੁਕੂਲਤਾ ਦੀਆਂ ਲੋੜਾਂ ਲਈ ਵਿਸਤਾਰਿਤ ਕਾਰਜ ਟ੍ਰੈਕਿੰਗ
#
# ### ਪ੍ਰਦਰਸ਼ਨ ਅਤੇ ਸਕੇਲਬਿਲਟੀ
# - **ਕਨੈਕਸ਼ਨ ਪੁਲਿੰਗ**: ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਏਜ਼ਿਊਰ ਸੇਵਾ ਕਨੈਕਸ਼ਨ ਪ੍ਰਬੰਧਨ
# - **Async ਪ੍ਰੋਸੈਸਿੰਗ**: ਉੱਚ-ਥਰੂਪੁੱਟ ਪਰਿਸਥਿਤੀਆਂ ਲਈ ਗੈਰ-ਅਟਕਣ ਵਾਲੇ ਆਪਰੇਸ਼ਨ
# - **ਕੈਸ਼ਿੰਗ ਰਣਨੀਤੀਆਂ**: ਬਾਰ-ਬਾਰ ਐਕਸੈੱਸ ਕੀਤੇ ਦਸਤਾਵੇਜ਼ਾਂ ਲਈ ਬੁੱਧਿਮਾਨ ਕੈਸ਼ਿੰਗ
# - **ਲੋਡ ਬੈਲੈਂਸਿੰਗ**: ਵੱਡੇ ਪੱਧਰ ਦੇ ਤਾਇਨਾਤੀਆਂ ਲਈ ਵੰਡਿਆ ਪ੍ਰੋਸੈਸਿੰਗ
#
# ### ਪ੍ਰਬੰਧਨ ਅਤੇ ਨਿਗਰਾਨੀ
# - **ਹੈਲਥ ਚੈੱਕਸ**: RAG ਸਿਸਟਮ ਭਾਗਾਂ ਲਈ ਅੰਦਰੂਨੀ ਨਿਗਰਾਨੀ
# - **ਪ੍ਰਦਰਸ਼ਨ ਮੈਟਰਿਕਸ**: ਖੋਜ ਗੁਣਵੱਤਾ ਅਤੇ ਜਵਾਬ ਸਮਿਆਂ 'ਤੇ ਵਿਸਤਾਰਿਤ ਵਿਸ਼ਲੇਸ਼ਣ
# - **ਗਲਤੀ ਹੱਲ**: ਦੁਬਾਰਾ ਕੋਸ਼ਿਸ਼ ਨੀਤੀਆਂ ਨਾਲ ਵਿਸਤਾਰਿਤ ਐਕਸਪਸ਼ਨ ਪ੍ਰਬੰਧਨ
# - **ਸੰਰਚਨਾ ਪ੍ਰਬੰਧਨ**: ਵਾਤਾਵਰਣ-ਵਿਸ਼ੇਸ਼ ਸੈਟਿੰਗਜ਼ ਨਾਲ ਪ੍ਰਮਾਣੀਕਰਨ
#
# ## ⚙️ ਪੂਰਵਸ਼ਰਤਾਂ ਅਤੇ ਸੈਟਅਪ
#
# **ਵਿਕਾਸ ਵਾਤਾਵਰਨ:**
# - .NET 9.0 SDK ਜਾਂ ਉੱਚਾ
# - ਵਿਜ਼ੂਅਲ ਸਟੂਡੀਓ 2022 ਜਾਂ C# ਐਕਸਟੈਂਸ਼ਨ ਨਾਲ VS ਕੋਡ
# - ਏਜ਼ਿਊਰ ਸਬਸਕ੍ਰਿਪਸ਼ਨ ਨਾਲ AI Foundry ਪ੍ਰਾਪਤੀ
#
# **ਲੋੜੀਂਦੇ NuGet ਪੈਕੇਜ:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **ਏਜ਼ਿਊਰ ਪ੍ਰਮਾਣਿਕਤਾ ਸੈਟਅਪ:**
# ```bash
# # ਅਜ਼ੂਰ CLI ਇੰਸਟਾਲ ਕਰੋ ਅਤੇ ਪ੍ਰਮਾਣਿਤ ਕਰੋ
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **ਵਾਤਾਵਰਣ ਸੰਰਚਨਾ (.env ਫਾਇਲ):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 ਇੰਟਰਪ੍ਰਾਈਜ਼ RAG ਨਮੂਨੇ
#
# ### ਦਸਤਾਵੇਜ਼ ਪ੍ਰਬੰਧਨ ਨਮੂਨੇ
# - **ਥੋਕ ਅੱਪਲੋਡ**: ਵੱਡੇ ਦਸਤਾਵੇਜ਼ ਸੰਗ੍ਰਹਿ ਦੀ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਪ੍ਰੋਸੈਸਿੰਗ
# - **ਦੀਰਘਕਾਲੀ ਅੱਪਡੇਟਸ**: ਰੀਅਲ-ਟਾਈਮ ਦਸਤਾਵੇਜ਼ ਸ਼ਾਮਲਕਰਨ ਅਤੇ ਸੋਧ
# - **ਵਰਜ਼ਨ ਨਿਯੰਤਰਣ**: ਦਸਤਾਵੇਜ਼ ਵਰਜ਼ਨਿੰਗ ਅਤੇ ਬਦਲਾਅ ਟ੍ਰੈਕਿੰਗ
# - **ਮੀਟਾਡੇਟਾ ਪ੍ਰਬੰਧਨ**: ਰਿਚ ਦਸਤਾਵੇਜ਼ ਗੁਣ ਅਤੇ ਵਰਗੀਕਰਨ
#
# ### ਖੋਜ ਅਤੇ ਪ੍ਰਾਪਤੀ ਨਮੂਨੇ
# - **ਹਾਈਬ੍ਰਿਡ ਖੋਜ**: ਸਰਵੋਤਮ ਨਤੀਜੇ ਲਈ ਸੈਮਾਂਟਿਕ ਅਤੇ ਕੁੰਜੀਸ਼ਬਦ ਖੋਜ ਦਾ ਮਿਲਾਪ
# - **ਫੈਸਿਟ ਖੋਜ**: ਬਹੁ-ਪਾਸੇ ਫਿਲਟਰਿੰਗ ਅਤੇ ਵਰਗੀਕਰਨ
# - **ਪਹੁੰਚ ਸਮਰੱਥਾ ਟਿੂੰਗਿੰਗ**: ਖੇਤਰ ਖਾਸ ਜ਼ਰੂਰਤਾਂ ਲਈ ਕਸਟਮ ਸਕੋਰਿੰਗ ਅਲਗੋਰਿਦਮ
# - **ਨਤੀਜਾ ਰੈਂਕਿੰਗ**: ਕਾਰੋਬਾਰੀ ਲਾਜ਼ਮ ਨਾਲ ਉੱਨਤ ਰੈਂਕਿੰਗ
#
# ### ਸੁਰੱਖਿਆ ਨਮੂਨੇ
# - **ਦਸਤਾਵੇਜ਼ ਸਤਰ ਸੁਰੱਖਿਆ**: ਹਰ ਦਸਤਾਵੇਜ਼ ਲਈ ਸੁਖਮ ਪਹੁੰਚ ਨਿਯੰਤਰਣ
# - **ਡੇਟਾ ਵਰਗੀਕਰਨ**: ਸਵੈਚਾਲਿਤ ਸੰਵੇਦਨਸ਼ੀਲਤਾ ਲੇਬਲਿੰਗ ਅਤੇ ਸੁਰੱਖਿਆ
# - **ਆਡਿਟ ਟਰੇਲਜ਼**: ਸਾਰੇ RAG ਆਪਰੇਸ਼ਨਾਂ ਦੀ ਵਿਸਤਾਰਿਤ ਲਾਗਿੰਗ
# - **ਗੋਪਨੀਯਤਾ ਸੁਰੱਖਿਆ**: ਪੀ.ਆਈ.ਆਈ ਪਹਚਾਣ ਤੇ ਸੰਸ਼ੋਧਨ ਸਮਰੱਥਾਵਾਂ
#
# ## 🔒 ਇੰਟਰਪ੍ਰਾਈਜ਼ ਸੁਰੱਖਿਆ ਵਿਸ਼ੇਸ਼ਤਾਵਾਂ
#
# ### ਪ੍ਰਮਾਣਿਕਤਾ ਅਤੇ ਪਰਵਾਨਗੀ
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### ਡੇਟਾ ਸੁਰੱਖਿਆ
# - **ਇੰਕ੍ਰਿਪਸ਼ਨ**: ਦਸਤਾਵੇਜ਼ਾਂ ਅਤੇ ਖੋਜ ਇੰਡੈਕਸਾਂ ਲਈ ਅੰਤ-ਤੱਕ ਇੰਕ੍ਰਿਪਸ਼ਨ
# - **ਪਹੁੰਚ ਨਿਯੰਤਰਣ**: ਉਪਭੋਗਤਾ ਅਤੇ ਸਮੂਹ ਅਧਿਕਾਰਾਂ ਲਈ ਏਜ਼ਿਊਰ AD ਨਾਲ ਏਕਤਾ
# - **ਡੇਟਾ ਨਿਵਾਸ**: ਅਨੁਕੂਲਤਾ ਲਈ ਭੂਗੋਲਿਕ ਡੇਟਾ ਸਥਾਨ ਨਿਯੰਤਰਣ
# - **ਬੈਕਅੱਪ ਅਤੇ ਬਹਾਲੀ**: ਸਵੈਚਾਲਿਤ ਬੈਕਅੱਪ ਅਤੇ ਆਪਦਾ ਬਹਾਲੀ ਸਮਰੱਥਾਵਾਂ
#
# ## 📈 ਪ੍ਰਦਰਸ਼ਨ ਅਪਟੀਮਾਈਜੇਸ਼ਨ
#
# ### Async ਪ੍ਰੋਸੈਸਿੰਗ ਨਮੂਨੇ
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### ਮੇਮੋਰੀ ਪ੍ਰਬੰਧਨ
# - **ਸਟਰੀਮਿੰਗ ਪ੍ਰੋਸੈਸਿੰਗ**: ਵੱਡੇ ਦਸਤਾਵੇਜ਼ਾਂ ਨੂੰ ਮੇਮੋਰੀ ਸਮੱਸਿਆਵਾਂ ਤੋਂ ਬਿਨਾਂ ਸੰਭਾਲੋ
# - **ਸੰਸਾਧਨ ਪੁਲਿੰਗ**: ਮਹਿੰਗੇ ਸੰਸਾਧਨਾਂ ਦੀ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਦੁਬਾਰਾ ਵਰਤੋਂ
# - **ਗਾਰਬੇਜ ਕਲੈਕਸ਼ਨ**: ਅਪਟੀਮਾਈਜ਼ਡ ਮੇਮੋਰੀ ਵੰਡ ਨਮੂਨੇ
# - **ਕਨੈਕਸ਼ਨ ਪ੍ਰਬੰਧਨ**: ਠੀਕ ਏਜ਼ਿਊਰ ਸੇਵਾ ਕਨੈਕਸ਼ਨ ਜੀਵਨ ਚੱਕਰ
#
# ### ਕੈਸ਼ਿੰਗ ਰਣਨੀਤੀਆਂ
# - **ਪ੍ਰਸ਼ਨ ਕੈਸ਼ਿੰਗ**: ਅਕਸਰ ਕੀਤੀ ਜਾਂਦੀ ਖੋਜਾਂ ਲਈ ਕੈਸ਼
# - **ਦਸਤਾਵੇਜ਼ ਕੈਸ਼ਿੰਗ**: ਗਰਮ ਦਸਤਾਵੇਜ਼ਾਂ ਲਈ ਇਨ-ਮੇਮੋਰੀ ਕੈਸ਼ਿੰਗ
# - **ਇੰਡੈਕਸ ਕੈਸ਼ਿੰਗ**: ਅਪਟੀਮਾਈਜ਼ਡ ਵੈਕਟਰ ਇੰਡੈਕਸ ਕੈਸ਼ਿੰਗ
# - **ਨਤੀਜਾ ਕੈਸ਼ਿੰਗ**: ਬਣਾਈ ਗਈਆਂ ਜਵਾਬਾਂ ਲਈ ਬੁੱਧਿਮਾਨ ਕੈਸ਼ਿੰਗ
#
# ## 📊 ਇੰਟਰਪ੍ਰਾਈਜ਼ ਉਪਯੋਗ ਕੇਸ
#
# ### ਗਿਆਨ ਪ੍ਰਬੰਧਨ
# - **ਨਿਗਮ ਵਿੱਕੀ**: ਕੰਪਨੀ ਦੇ ਗਿਆਨ ਅਧਾਰਾਂ ਵਿੱਚ ਬੁੱਧਿਮਾਨ ਖੋਜ
# - **ਨੀਤੀ ਅਤੇ ਪ੍ਰਕਿਰਿਆਵਾਂ**: ਸਵੈਚਾਲਿਤ ਅਨੁਕੂਲਤਾ ਅਤੇ ਪ੍ਰਕਿਰਿਆ ਸਹਾਇਤਾ
# - **ਟ੍ਰੇਨਿੰਗ ਸਾਮਗਰੀ**: ਬੁੱਧਿਮਾਨ ਸਿੱਖਣ ਅਤੇ ਵਿਕਾਸ ਸਹਾਇਤਾ
# - **ਅਨੁਸੰਧਾਨ ਡੇਟਾਬੇਸ**: ਅਕਾਦਮਿਕ ਅਤੇ ਅਨੁਸੰਧਾਨ ਪੇਪਰ ਵਿਸ਼ਲੇਸ਼ਣ ਸਿਸਟਮ
#
# ### ਗਾਹਕ ਸਹਾਇਤਾ
# - **ਸਹਾਇਤਾ ਗਿਆਨ ਅਧਾਰ**: ਸਵੈਚਾਲਿਤ ਗਾਹਕ ਸੇਵਾ ਜਵਾਬ
# - **ਉਤਪਾਦ ਦਸਤਾਵੇਜ਼ੀਕਰਨ**: ਬੁੱਧਿਮਾਨ ਉਤਪਾਦ ਜਾਣਕਾਰੀ ਪ੍ਰਾਪਤੀ
# - **ਟ੍ਰਬਲਸ਼ੂਟਿੰਗ ਗਾਈਡਸ**: ਪ੍ਰਸੰਗਿਕ ਸਮੱਸਿਆ-ਹੱਲ ਸਹਾਇਤਾ
# - **FAQ ਸਿਸਟਮ**: ਦਸਤਾਵੇਜ਼ ਸੰਗ੍ਰਹਿ ਤੋਂ ਗਤੀਸ਼ੀਲ FAQ ਤਿਆਰ ਕਰਨਾ
#
# ### ਨਿਯਮਕ ਅਨੁਕੂਲਤਾ
# - **ਕਾਨੂੰਨੀ ਦਸਤਾਵੇਜ਼ ਵਿਸ਼ਲੇਸ਼ਣ**: ਠੇਕਾ ਅਤੇ ਕਾਨੂੰਨੀ ਦਸਤਾਵੇਜ਼ ਬੁੱਧੀਮਤਾ
# - **ਅਨੁਕੂਲਤਾ ਨਿਗਰਾਨੀ**: ਸਵੈਚਾਲਿਤ ਨਿਯਮਕ ਅਨੁਕੂਲਤਾ ਜਾਂਚ
# - **ਖਤਰਾ ਮੁਲਾਂਕਣ**: ਦਸਤਾਵੇਜ਼ ਆਧਾਰਿਤ ਖਤਰਾ ਵਿਸ਼ਲੇਸ਼ਣ ਅਤੇ ਰਿਪੋਰਟਿੰਗ
# - **ਆਡਿਟ ਸਹਾਇਤਾ**: ਆਡਿਟ ਲਈ ਬੁੱਧਿਮਾਨ ਦਸਤਾਵੇਜ਼ ਖੋਜ
#
# ## 🚀 ਉਤਪਾਦਨ ਤਾਇਨਾਤੀ
#
# ### ਨਿਗਰਾਨੀ ਅਤੇ ਦ੍ਰਿਸ਼ਟੀਕੋਣਯੋਗਤਾ
# - **ਐਪਲੀਕੇਸ਼ਨ ਇਨਸਾਈਟਸ**: ਵਿਸਥਾਰਿਤ ਟੈਲੀਮੇਟਰੀ ਅਤੇ ਪ੍ਰਦਰਸ਼ਨ ਨਿਗਰਾਨੀ
# - **ਕਸਟਮ ਮੈਟਰਿਕਸ**: ਕਾਰੋਬਾਰੀ ਵਿਸ਼ੇਸ਼ KPI ਟ੍ਰੈਕਿੰਗ ਅਤੇ ਅਲਾਰਮਿੰਗ
# - **ਵੰਡਿਆ ਹੋਇਆ ਟਰੇਸਿੰਗ**: ਸੇਵਾਵਾਂ ਦੇ ਵਿੱਚ ਅੰਤ-ਤੱਕ ਬੇਨਤੀ ਟ੍ਰੈਕਿੰਗ
# - **ਹੈਲਥ ਡੈਸ਼ਬੋਰਡਸ**: ਵਾਸਤਵਿਕ ਸਮੇਂ ਸਿਸਟਮ ਹੈਲਥ ਅਤੇ ਪ੍ਰਦਰਸ਼ਨ ਦੇ ਦ੍ਰਿਸ਼
#
# ### ਸਕੇਲਬਿਲਟੀ ਅਤੇ ਭਰੋਸੇਯੋਗਤਾ
# - **ਆਟੋ-ਸਕੇਲਿੰਗ**: ਲੋਡ ਅਤੇ ਪ੍ਰਦਰਸ਼ਨ ਮੈਟਰਿਕਸ ਦੇ ਆਧਾਰ ਤੇ ਆਪਣੇ ਆਪ ਸਕੇਲਿੰਗ
# - **ਉੱਚ ਉਪਲੱਬਧਤਾ**: ਫੇਲਓਵਰ ਸਮਰੱਥਾਵਾਂ ਨਾਲ ਬਹੁ-ਖੇਤਰ ਤਾਇਨਾਤੀ
# - **ਲੋਡ ਟੈਸਟਿੰਗ**: ਇੰਟਰਪ੍ਰਾਈਜ਼ ਲੋਡ ਹਾਲਾਤਾਂ ਤਹਿਤ ਪ੍ਰਦਰਸ਼ਨ ਵਾਲੀਡੇਸ਼ਨ
# - **ਆਪਦਾ ਬਹਾਲੀ**: ਸਵੈਚਾਲਿਤ ਬੈਕਅੱਪ ਅਤੇ ਬਹਾਲੀ ਪ੍ਰਕਿਰਿਆਵਾਂ
#
# ਕੀ ਤੁਸੀਂ ਸਦਨਾਊ ਦਸਤਾਵੇਜ਼ ਵੱਡੇ ਪੱਧਰ 'ਤੇ ਸੰਭਾਲ ਸਕਣ ਵਾਲੇ ਇੰਟਰਪ੍ਰਾਈਜ਼-ਗਰੇਡ RAG ਸਿਸਟਮ ਬਣਾਉਣ ਲਈ ਤਿਆਰ ਹੋ? ਆਓ ਇੰਟਰਪ੍ਰਾਈਜ਼ ਲਈ ਬੁੱਧਿਮਾਨ ਗਿਆਨ ਸਿਸਟਮਾਂ ਦਾ ਆਰਕੀਟੈਕਚਰ ਬਣਾਈਏ! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
