# %% [markdown]
# # ⚡ Konkurentiniai agentų darbo procesai su Microsoft Foundry (Python)
#
# ## 📋 Pažangus lygiagretus apdorojimo vadovas
#
# Šiame užraše demonstruojami **konkurentinių darbo procesų šablonai** naudojant Microsoft Agent Framework. Sužinosite, kaip kurti didelio našumo, lygiagretus darbo procesus, kuriuose keli AI agentai veikia vienu metu, dramatiškai pagerindami pralaidumą ir leidžiantys įgyvendinti sudėtingus daugiagijų verslo procesus.
#
# > **Migracijos pastaba:** Šis pavyzdys anksčiau naudojo GitHub Models. GitHub Models yra pasenęs (nutraukiamas 2026 m. liepą), todėl dabar naudojama **Microsoft Foundry** per `FoundryChatClient`, kuris naudoja Azure OpenAI **Responses API**.
#
# ## 🎯 Mokymosi tikslai
#
# ### 🚀 **Konkurentinio apdorojimo pagrindai**
# - **Lygiagretus agentų vykdymas**: vienu metu paleiskite kelis agentus maksimaliam efektyvumui
# - **Darbo proceso koordinavimas**: suderinkite konkurentines operacijas išlaikant duomenų nuoseklumą
# - **Našumo optimizavimas**: pasiekite reikšmingą spartėjimą per lygiagretų apdorojimą
# - **Išteklių valdymas**: efektyviai naudokite AI modelių išteklius kelioms konkurentinėms operacijoms
#
# ### 🏗️ **Pažangūs konkurencijos šablonai**
# - **Fork-Join apdorojimas**: paskirstykite darbą keliems agentams ir sujunkite rezultatus
# - **Pipelines lygiagretumas**: vykdymo uždavinių persidengimas nenutrūkstamam pralaidumui
# - **Krovio balansavimas**: tolygus darbo paskirstymas tarp turimų agentų išteklių
# - **Sinchronizacijos taškai**: suderinkite konkurentinius agentus kritinėse darbo proceso stadijose
#
# ### 🏢 **Įmonių konkurentinės programos**
# - **Daug dokumentų apdorojimas**: vienu metu apdorokite kelis dokumentus
# - **Realaus laiko turinio analizė**: konkurentinis gaunamų duomenų srautų analizavimas
# - **Partijų apdorojimo optimizavimas**: maksimalus pralaidumas didelio masto operacijoms
# - **Daugiaplatformė analizė**: lygiagretus skirtingų turinio tipų (teksto, vaizdų, duomenų) apdorojimas
#
# ## ⚙️ Pradiniai reikalavimai ir diegimas
#
# ### 📦 **Reikalingos priklausomybės**
#
# Įdiekite Agent Framework su konkurentinių darbo procesų galimybėmis:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry konfigūracija**
#
# Prisijunkite su Azure CLI (`az login`), kad `AzureCliCredential` galėtų autentifikuoti, tada nustatykite savo Microsoft Foundry projekto duomenis.
#
# **Aplinkos nustatymas (.env failas):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Konkurentinio apdorojimo aspektai:**
# - **Greitaveikos apribojimai**: stebėkite Azure OpenAI užklausų dažnio apribojimus
# - **Išteklių naudojimas**: atsižvelkite į atminties ir CPU naudojimą keliems agentams
# - **Klaidų valdymas**: įgyvendinkite tvirtą klaidų atkūrimą lygiagrečioms operacijoms
#
# ### 🏗️ **Konkurentinių darbo procesų architektūra**
#
# ```mermaid
# graph TD
#     A[Darbo eiga Pradžia] --> B[Lygiagretus Vykdymas]
#     B --> C[Agentų Grupė 1]
#     B --> D[Agentų Grupė 2]
#     B --> E[Agentų Grupė 3]
#     C --> F[Rezultatų Apibendrinimas]
#     D --> F
#     E --> F
#     F --> G[Galutinis Rezultatas]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Pagrindinės naudos:**
# - **⚡ Našumas**: reikšmingas spartėjimas per lygiagretų vykdymą
# - **📈 Masto keitimas**: įveikite augančius darbo krūvius neprailgindami laiko
# - **🔄 Efektyvumas**: geresnis turimų skaičiavimo išteklių panaudojimas
# - **🎯 Pralaidumas**: apdorokite daugiau darbo per tą pačią laiką
#
# ## 🎨 **Konkurentinių darbo procesų dizaino šablonai**
#
# ### 🔍 **Tyrimų ir analizės pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Duomenų apdorojimo darbo procesas**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Turinio kūrimo pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Daugiapakopis apdorojimas**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Įmonių našumo privalumai**
#
# ### ⚡ **Pralaidumo optimizavimas**
# - **Lygiagretus vykdymas**: keli agentai veikia vienu metu
# - **Išteklių panaudojimas**: maksimalus turimos AI modelio talpos efektyvumas
# - **Laiko sutrumpinimas**: reikšmingas bendro apdorojimo laiko sumažėjimas
# - **Mastelio keitimo architektūra**: lengvai pridėkite daugiau konkurentinių agentų pagal poreikį
#
# ### 🛡️ **Patikimumas ir atsparumas**
# - **Gedimų tolerancija**: atskirų agentų gedimai nesustabdo viso darbo proceso
# - **Klaidų izoliacija**: problemos viename konkurentiniame sraute nepaveikia kitų
# - **Graži degradacija**: sistema veikia net sumažėjus agentų pajėgumui
# - **Atkūrimo mechanizmai**: automatinis bandymas iš naujo ir klaidų valdymas nepavykusioms operacijoms
#
# ### 📊 **Stebėsena ir stebimumas**
# - **Konkurentinio vykdymo stebėjimas**: sekite visų lygiagrečių operacijų eigą
# - **Našumo metrika**: matuokite spartėjimą ir efektyvumo prieaugį
# - **Išteklių naudojimo analizė**: optimizuokite agentų paskirstymą konkurencinėse užduotyse
# - **Sąstovių identifikavimas**: raskite ir pašalinkite našumo apribojimus
#
# Sukurkime didelio našumo konkurentinius AI darbo procesus! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
