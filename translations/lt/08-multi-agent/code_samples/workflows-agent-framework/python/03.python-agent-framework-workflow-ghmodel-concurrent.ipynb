# %% [markdown]
# # ⚡ Konkuruojančios agentų darbo eigos su Microsoft Foundry (Python)
#
# ## 📋 Išplėstinis lygiagretusis apdorojimo vadovas
#
# Šiame užrašų knygelėje demonstruojami **konkuruojančių darbo eigos modeliai** naudojant Microsoft Agent Framework. Išmoksite kurti našias, lygiagrečiai veikiančias darbo eigas, kur kelios DI agentų veikos vykdomos vienu metu, žymiai pagerinant pralaidumą ir leidžiant sudėtingus daugiasriegius verslo procesus.
#
# > **Migracijos pastaba:** Šis pavyzdys anksčiau naudojo GitHub Models. GitHub Models yra atšaukiamas (nutraukiamas 2026 m. liepos mėn.), todėl dabar naudojama **Microsoft Foundry** per `FoundryChatClient`, skirtą Azure OpenAI **Responses API**.
#
# ## 🎯 Mokymosi tikslai
#
# ### 🚀 **Konkuruojančio apdorojimo pagrindai**
# - **Lygiagretus agentų vykdymas**: Vykdykite kelis agentus vienu metu maksimaliam efektyvumui
# - **Darbo eigos koordinavimas**: Sinchronizuokite konkuruojančias operacijas užtikrinant duomenų nuoseklumą
# - **Našumo optimizavimas**: Pasiekti žymų pagreitį naudojant lygiagretų apdorojimą
# - **Išteklių valdymas**: Efektyviai naudoti DI modelių išteklius konkuruojančiose operacijose
#
# ### 🏗️ **Išplėstiniai konkuruojančių modeliai**
# - **Fork-Join apdorojimas**: Darbo paskirstymas keliems agentams ir rezultatų sujungimas
# - **Vamzdyno lygiagretumas**: Lygiagretūs vykdymo etapai nuolatiniam pralaidumui
# - **Krovos paskirstymas**: Darbo tolygus paskirstymas turimiems agentų ištekliams
# - **Sinchronizacijos taškai**: Koordinuoti konkuruojančius agentus kritiniais darbo eigos etapais
#
# ### 🏢 **Įmonių lygmens konkuruojančios programos**
# - **Didelės apimties dokumentų apdorojimas**: Vienu metu apdoroti kelis dokumentus
# - **Realaus laiko turinio analizė**: Konkuruojanti atvykstančių duomenų srautų analizė
# - **Partijų apdorojimo optimizavimas**: Maksimalus pralaidumas didelio masto operacijoms
# - **Daugiakanalė analizė**: Lygiagretus skirtingų turinio tipų (tekstų, paveikslėlių, duomenų) apdorojimas
#
# ## ⚙️ Reikalavimai ir nustatymai
#
# ### 📦 **Reikalingos priklausomybės**
#
# Įdiekite Agent Framework su konkuruojančių darbo eigų galimybėmis:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry konfigūracija**
#
# Prisijunkite per Azure CLI (`az login`), kad `AzureCliCredential` galėtų autentifikuoti, tada nustatykite savo Microsoft Foundry projekto duomenis.
#
# **Aplinkos nustatymas (.env failas):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Konkuruojančio apdorojimo ypatybės:**
# - **Ribos**: Stebėkite Azure OpenAI ribas konkuruojančioms užklausoms
# - **Išteklių naudojimas**: Atsižvelkite į atminties ir CPU naudojimą su keliomis vienu metu veikiančiomis agentėmis
# - **Klaidų valdymas**: Įdiekite patikimą klaidų atkūrimą lygiagrečioms operacijoms
#
# ### 🏗️ **Konkuruojančios darbo eigos architektūra**
#
# ```mermaid
# graph TD
#     A[Darbo srauto pradžia] --> B[Lygiagretus vykdymas]
#     B --> C[Agentų grupė 1]
#     B --> D[Agentų grupė 2]
#     B --> E[Agentų grupė 3]
#     C --> F[Rezultatų surinkimas]
#     D --> F
#     E --> F
#     F --> G[Galutinis rezultatas]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Pagrindinės naudos:**
# - **⚡ Našumas**: Žymus pagreitinimas naudojant lygiagretų vykdymą
# - **📈 Mastelio keitimas**: Apdorokite didesnes apkrovas neprailgindami laiko proporcingai
# - **🔄 Efektyvumas**: Geresnis turimų skaičiavimo išteklių panaudojimas
# - **🎯 Pralaidumas**: Apdorokite daugiau darbo per tą patį laiką
#
# ## 🎨 **Konkuruojančių darbo eigų dizaino modeliai**
#
# ### 🔍 **Tyrimų ir analizės vamzdynas**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Duomenų apdorojimo darbo eiga**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Turinio kūrimo vamzdynas**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Daugiaetapis apdorojimas**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Įmonių našumo privalumai**
#
# ### ⚡ **Pralaidumo optimizavimas**
# - **Lygiagretus vykdymas**: Keli agentai veikia vienu metu
# - **Išteklių panaudojimas**: Maksimalus turimų DI modelių pajėgumų efektyvumas
# - **Laiko sutrumpinimas**: Žymus bendro apdorojimo laiko sumažėjimas
# - **Mastelio keičiamumas**: Lengvai pridėti daugiau konkuruojančių agentų prireikus
#
# ### 🛡️ **Patikimumas ir atsparumas**
# - **Atsparumas gedimams**: Atskirų agentų gedimai nesustabdo visos darbo eigos
# - **Klaidų izoliacija**: Problemų viename konkuruojančiame šake neveikia kitos
# - **Sklandi degradacija**: Sistema veikia net sumažinus agentų pajėgumą
# - **Atkūrimo mechanizmai**: Automatinis bandymas iš naujo ir klaidų valdymas nepavykus operacijoms
#
# ### 📊 **Stebėsena ir pastebimumas**
# - **Konkuruojančių vykdymų stebėjimas**: Stebėkite visų lygiagrečių operacijų pažangą
# - **Našumo metrikos**: Matavimai pagreičiui ir efektyvumo prieaugiams
# - **Išteklių naudojimo analizė**: Optimizuokite konkuruojančių agentų paskirstymą
# - **Sąstingio nustatymas**: Raskite ir pašalinkite našumo ribojimus
#
# Kurkime našias konkuruojančias DI darbo eigas! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
