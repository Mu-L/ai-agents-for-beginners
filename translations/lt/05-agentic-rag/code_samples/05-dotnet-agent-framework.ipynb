# %% [markdown]
# # 🔍 Įmonių RAG su Microsoft Foundry (.NET)
#
# ## 📋 Mokymosi tikslai
#
# Ši užrašų knygelė demonstruoja, kaip sukurti įmonių klasės Retrieval-Augmented Generation (RAG) sistemas, naudojant Microsoft Agent Framework .NET su Microsoft Foundry. Išmoksite kurti paruoštus naudoti agentus, kurie gali ieškoti dokumentuose ir pateikti tikslius, kontekstualiai pagrįstus atsakymus su įmonių saugumu ir mastelį.
#
# **Įmonių RAG galimybės, kurias sukursite:**
# - 📚 **Dokumentų intelektas**: Pažangus dokumentų apdorojimas su Azure AI paslaugomis
# - 🔍 **Semantinė paieška**: Aukšto našumo vektorinė paieška su įmonių funkcijomis
# - 🛡️ **Saugumo integracija**: Pritaikyta vaidmenimis pagrįsta prieiga ir duomenų apsauga
# - 🏢 **Mastelio architektūra**: Paruoštos gamybai RAG sistemos su stebėjimu
#
# ## 🎯 Įmonių RAG architektūra
#
# ### Pagrindinės įmonių sudedamosios dalys
# - **Microsoft Foundry**: Valdoma įmonių AI platforma su saugumu ir atitiktimi
# - **Pastovūs agentai**: Būseną saugantys agentai su pokalbių istorija ir konteksto valdymu
# - **Vektorinės saugyklos valdymas**: Įmonių klasės dokumentų indeksavimas ir atgavimas
# - **Tapatybės integracija**: Azure AD autentifikacija ir vaidmenimis pagrįsta prieigos kontrolė
#
# ### .NET naudą įmonėms
# - **Tipų saugumas**: Kompiliavimo metu atliekamas RAG operacijų ir duomenų struktūrų tikrinimas
# - **Asinchroninis našumas**: Blokavimą išvengiantis dokumentų apdorojimas ir paieškos operacijos
# - **Atminties valdymas**: Efektyvus išteklių naudojimas didelėms dokumentų kolekcijoms
# - **Integracijos patternai**: Gimtasis Azure paslaugų integravimas su priklausomybių injekcija
#
# ## 🏗️ Techninė architektūra
#
# ### Įmonių RAG vamzdynas
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Pagrindinės .NET sudedamosios dalys
# - **Azure.AI.Agents.Persistent**: Įmonių agentų valdymas su būsenos išsaugojimu
# - **Azure.Identity**: Integruota autentifikacija saugiam Azure paslaugų prieigai
# - **Microsoft.Agents.AI.AzureAI**: Azure optimizuotas agentų sistemos įgyvendinimas
# - **System.Linq.Async**: Aukšto našumo asinchroninės LINQ operacijos
#
# ## 🔧 Įmonių funkcijos ir privalumai
#
# ### Saugumas ir atitiktis
# - **Azure AD integracija**: Įmonių tapatybės valdymas ir autentifikacija
# - **Vaidmenimis pagrįsta prieiga**: Smulkiai pritaikytos teisės prieigai prie dokumentų ir operacijų
# - **Duomenų apsauga**: Užšifravimas ramybės metu ir perdavimo metu jautriems dokumentams
# - **Auditavimo žurnalas**: Išsamus veiklų sekimas atitikties reikalavimams
#
# ### Našumas ir mastelis
# - **Ryšių kaupimas**: Efektyvus Azure paslaugų jungčių valdymas
# - **Asinchroninis apdorojimas**: Blokavimo išvengianti didelio pralaidumo apdorojimo logika
# - **Talpinimo strategijos**: Protingas dažnai naudojamų dokumentų talpinimas
# - **Krovinio paskirstymas**: Išskirstytas apdorojimas didelio masto diegimams
#
# ### Valdymas ir stebėsena
# - **Sveikatos patikrinimai**: Įmontuota RAG sistemos komponentų stebėsena
# - **Našumo metrikos**: Išsamios paieškos kokybės ir atsakymų laikų analizės
# - **Klaidų valdymas**: Visapusiškas išimčių valdymas su pakartojimo taisyklėmis
# - **Konfigūracijos valdymas**: Aplinkai pritaikyti nustatymai su tikrinimu
#
# ## ⚙️ Reikalavimai ir paruošimas
#
# **Plėtros aplinka:**
# - .NET 9.0 SDK arba naujesnė versija
# - Visual Studio 2022 arba VS Code su C# plėtiniu
# - Azure prenumerata su AI Foundry prieiga
#
# **Būtinos NuGet paketuos:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure autentifikacijos nustatymas:**
# ```bash
# # Įdiekite Azure CLI ir autentifikuokitės
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Aplinkos konfigūracija (.env failas):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Įmonių RAG šablonai
#
# ### Dokumentų valdymo šablonai
# - **Masinis įkėlimas**: Efektyvus didelių dokumentų kolekcijų apdorojimas
# - **Inkrementiniai atnaujinimai**: Realaus laiko dokumentų pridėjimas ir keitimas
# - **Versijų valdymas**: Dokumentų versijavimas ir pakeitimų sekimas
# - **Metaduomenų valdymas**: Išsamios dokumentų charakteristikos ir taksonomija
#
# ### Paieškos ir atgavimų šablonai
# - **Hibridinė paieška**: Semantinės ir raktinių žodžių paieškos derinimas optimaliems rezultatams
# - **Fasuota paieška**: Daugiamačio filtravimo ir kategorizavimo sistema
# - **Reikšmingumo derinimas**: Individualūs vertinimo algoritmai domenui pritaikytiems poreikiams
# - **Rezultatų reitingavimas**: Pažangus reitingavimas su verslo logikos integracija
#
# ### Saugumo šablonai
# - **Dokumentų lygmens saugumas**: Smulkiai pritaikyta prieigos kontrolė kiekvienam dokumentui
# - **Duomenų klasifikavimas**: Automatinis jautrumo ženklinimas ir apsauga
# - **Auditavimo įrašai**: Visapusiškas visų RAG operacijų registravimas
# - **Privatumo apsauga**: Asmens duomenų atpažinimo ir užmaskavimo galimybės
#
# ## 🔒 Įmonių saugumo funkcijos
#
# ### Autentifikacija ir autorizacija
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Duomenų apsauga
# - **Užšifravimas**: Galutinis užšifravimas dokumentams ir paieškos indeksams
# - **Prieigos kontrolė**: Integracija su Azure AD naudotojų ir grupių teisėms
# - **Duomenų lokalizacija**: Geografinės duomenų vietos valdymas atitikties poreikiams
# - **Atsarginė kopija ir atkūrimas**: Automatizuotos atsarginių kopijų ir katastrofų atstatymo galimybės
#
# ## 📈 Našumo optimizavimas
#
# ### Asinchroninio apdorojimo šablonai
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Atminties valdymas
# - **Srautinė apdorojimas**: Didelių dokumentų apdorojimas be atminties problemų
# - **Išteklų kaupimas**: Efektyvus brangių išteklių pakartotinis naudojimas
# - **Atminties valymo mechanizmai**: Optimizuotos atminties skyrimo strategijos
# - **Ryšių valdymas**: Tinkamas Azure paslaugų ryšių gyvavimo ciklo valdymas
#
# ### Talpinimo strategijos
# - **Užklausų talpinimas**: Dažnai atliekamų paieškų talpinimas
# - **Dokumentų talpinimas**: Atminties talpinimas aktyviems dokumentams
# - **Indeksų talpinimas**: Optimizuotas vektorinių indeksų talpinimas
# - **Rezultatų talpinimas**: Protingas sugeneruotų atsakymų talpinimas
#
# ## 📊 Įmonių naudojimo atvejai
#
# ### Žinių valdymas
# - **Įmonių žinių bazė**: Išmanioji paieška įmonės žinių bazėse
# - **Politikos ir procedūros**: Automatizuotas atitikties ir procedūrų vadovas
# - **Mokymo medžiaga**: Išmani pagalba mokymuisi ir tobulėjimui
# - **Tyrimų duomenų bazės**: Akademinių ir mokslinių darbų analizės sistemos
#
# ### Klientų aptarnavimas
# - **Pagalbos žinių bazė**: Automatizuoti klientų aptarnavimo atsakymai
# - **Produkto dokumentacija**: Išmanus produkto informacijos atgavimas
# - **Trikčių šalinimo gidai**: Kontekstinė pagalba problemų sprendimui
# - **DUK sistemos**: Dinamiškas DUK generavimas iš dokumentų rinkinių
#
# ### Reguliacinė atitiktis
# - **Teisinių dokumentų analizė**: Sutarčių ir teisinių dokumentų intelektas
# - **Atitikties stebėsena**: Automatizuotas reguliacinės atitikties tikrinimas
# - **Rizikos vertinimas**: Dokumentais pagrįsta rizikos analizė ir ataskaitos
# - **Audito pagalba**: Išmanus dokumentų paieška auditams
#
# ## 🚀 Gamybinis diegimas
#
# ### Stebėsena ir stebimumas
# - **Application Insights**: Detali telemetrija ir našumo stebėjimas
# - **Individualios metrikos**: Verslo KPI sekimas ir perspėjimai
# - **Išsklaidytas stebėjimas**: Visapusiškas užklausų sekimas per visas paslaugas
# - **Sveikatos kontrolės skydai**: Sistemos būklės ir veikimo laiko vizualizacija realiuoju laiku
#
# ### Mastelio keitimas ir patikimumas
# - **Automatinis mastelio keitimas**: Automatinis skalavimas pagal apkrovą ir našumo rodiklius
# - **Aukštas prieinamumas**: Daugregioninis diegimas su gedimų perkėlimu
# - **Krovinio testavimas**: Našumo patvirtinimas įmonės apkrovos sąlygomis
# - **Avarijų atkūrimas**: Automatizuotos atsarginės kopijos ir atkūrimo procedūros
#
# Pasiruošę kurti įmonių klasės RAG sistemas, kurios tvarkytų jautrius dokumentus dideliu mastu? Sukurkime išmanias žinių sistemas įmonei! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
