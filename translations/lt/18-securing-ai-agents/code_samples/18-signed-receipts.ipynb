# %% [markdown]
# # 18 pamoka: AI agentų apsauga naudojant kriptografinius kvitus
#
# ## Praktinis užsiėmimas
#
# Šiame užsiėmime išmoksite keturis pratimus:
#
# 1. **Pasirašykite pirmąjį kvitą** agento įrankio kvietimui ir patikrinkite jį.
# 2. **Pakeiskite kvitą** ir stebėkite, kaip patikra nepavyksta.
# 3. **Sukurkite trijų kvitų grandinę** ir patvirtinkite grandinės vientisumą.
# 4. **Apvyniokite Microsoft Agent Framework įrankio kvietimą** taip, kad kiekvienas veiksmas generuotų kvitą.
#
# Visos kriptografinės funkcijos yra importuojamos iš gerai prižiūrimų bibliotekų (`pynacl` Ed25519, `jcs` RFC 8785 kanoniniam JSON, `hashlib` iš Python standartinės bibliotekos SHA-256). Pats kvito logikos kodas yra paprastas Python, kurį galite skaityti ir keisti.
#
# Paleiskite langelius pagal tvarką. Kiekviena dalis yra trumpa ir savarankiška.

# %% [markdown]
# ## Diegimas
#
# Įdiekite dvi priklausomybes. Abi turi atvirus licencijavimo sąlygų leidimus (Apache-2.0 / MIT).

# %%
# !pip install -q pynacl jcs

# %%
import json
import hashlib
import base64
from datetime import datetime, timezone

from nacl import signing
from nacl.exceptions import BadSignatureError
from jcs import canonicalize

# %% [markdown]
# ## Pagalbinės priemonės
#
# Šie du pagalbiniai įrankiai tvarko base64url kodavimą (be papildymo) ir SHA-256 maišos skaičiavimą iš įvairių objektų. Jie leidžia likusiai užrašų knygutei susitelkti ties pačios kvito logikos įgyvendinimu.

# %%
def b64url_nopad(data: bytes) -> str:
    """Base64url-encode bytes without padding (RFC 4648 Section 5)."""
    return base64.urlsafe_b64encode(data).decode("ascii").rstrip("=")

def b64url_decode(s: str) -> bytes:
    """Decode a base64url string that may be missing padding."""
    padding = "=" * ((4 - len(s) % 4) % 4)
    return base64.urlsafe_b64decode(s + padding)

def sha256_canonical(obj) -> str:
    """
    SHA-256 hash of a Python object, computed over its JCS-canonical JSON form.
    Returns a 'sha256:' prefixed hex digest so callers can identify the algorithm.
    """
    canonical = canonicalize(obj)
    digest = hashlib.sha256(canonical).hexdigest()
    return f"sha256:{digest}"

# %% [markdown]
# ## 1 skyrius: Pasirašykite savo pirmąjį kvitą
#
# Įsivaizduokite, kad mūsų **Contoso Travel** agentas ką tik surado skrydžius iš Sidnėjaus į Los Andželą klientui. Norime įrašyti šį įrankio kvietimą kaip pasirašytą kvitą, kad būsimasis auditorius galėtų tai patikrinti nepasikliaudamas mumis.
#
# ### 1.1 veiksmas: Sukurkite pasirašymo raktą
#
# Gamyboje agente pasirašymo raktas būtų saugomas aparatinės įrangos saugumo modulyje (HSM), Azure Key Vault arba panašioje apsaugotoje saugykloje. Šiai pamokai mes sugeneruojame naują raktą atmintyje.

# %%
signing_key = signing.SigningKey.generate()
verify_key = signing_key.verify_key

public_key_b64 = b64url_nopad(bytes(verify_key))
print(f"Public key (Ed25519, 32 bytes): {public_key_b64}")

# %% [markdown]
# ### 1.2 žingsnis: Sudaryti kvito užklausą
#
# Užklausoje yra viskas, ką kvitas turi patvirtinti: kas veikė, kokį įrankį naudojo, su kokiais argumentais, kas grįžo, pagal kokią politiką ir kada. Argumentus ir rezultatą maišome, o ne įterpiame tiesiogiai, kad kvitas neišsiduotų jautrios informacijos.

# %%
tool_args = {
    "origin": "SYD",
    "destination": "LAX",
    "departure_date": "2026-06-15",
    "passengers": 2,
}

tool_result = [
    {"flight": "QF11", "price": 1850, "stops": 0},
    {"flight": "UA864", "price": 1620, "stops": 1},
    {"flight": "DL11", "price": 1740, "stops": 0},
]

payload = {
    "type": "agent.tool_call.v1",
    "agent_id": "contoso-travel-bot",
    "tool_name": "lookup_flights",
    "tool_args_hash": sha256_canonical(tool_args),
    "result_hash": sha256_canonical(tool_result),
    "policy_id": "contoso-travel-policy-v3",
    "timestamp": datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ"),
    "sequence": 0,
    "previous_receipt_hash": None,
}

print(json.dumps(payload, indent=2))

# %% [markdown]
# ### 1.3 žingsnis: Pasirašykite ir surinkite kvitą
#
# Trys žingsniai:
#
# 1. Kanonizuokite naudingąją apkrovą naudodami JCS, kad dvi įgyvendinimo versijos, gaminančios tą patį loginį kvitą, generuotų baitus, kurie būtų bitų identiški.
# 2. Hesuokite kanonizuotus baitus su SHA-256.
# 3. Pasirašykite hašą su Ed25519 privačiu raktu.
#
# Parašas tada pridedamas prie originalios naudingosios apkrovos, kad būtų sukurtas galutinis kvitas.

# %%
def sign_receipt(payload: dict, signing_key: signing.SigningKey, verify_key) -> dict:
    """
    Sign a receipt payload. Returns the receipt with attached signature and public key.
    The 'signature' and 'public_key' fields are NOT part of the canonical signed bytes.
    """
    canonical = canonicalize(payload)
    message_hash = hashlib.sha256(canonical).digest()
    signature_bytes = signing_key.sign(message_hash).signature
    return {
        **payload,
        "signature": {
            "alg": "EdDSA",
            "sig": b64url_nopad(signature_bytes),
            "public_key": b64url_nopad(bytes(verify_key)),
        },
    }

receipt = sign_receipt(payload, signing_key, verify_key)
print(json.dumps(receipt, indent=2))

# %% [markdown]
# ### 1.4 veiksmas: Patikrinti kvitą
#
# Patikra vykdoma atvirkščiai. Išimame parašą, perskaičiuojame kanoninį maišos kodą ir tikriname parašą pagal viešąjį rakto kvito faile.
#
# Auditorius, atliekantis šią patikrą, mums nebereikia nieko, išskyrus pats kvitas. Nereikia kviesti jokių paslaugų, klausyti rakto katalogo ar pasikliauti pasitikėjimu.

# %%
def verify_receipt(receipt: dict) -> bool:
    """
    Verify a receipt's Ed25519 signature.
    Returns True if valid, False otherwise.
    """
    sig_obj = receipt.get("signature")
    if not sig_obj or sig_obj.get("alg") != "EdDSA":
        return False

    # Reconstruct the payload that was actually signed (everything except signature).
    payload = {k: v for k, v in receipt.items() if k != "signature"}

    canonical = canonicalize(payload)
    message_hash = hashlib.sha256(canonical).digest()

    try:
        verify_key = signing.VerifyKey(b64url_decode(sig_obj["public_key"]))
        verify_key.verify(message_hash, b64url_decode(sig_obj["sig"]))
        return True
    except BadSignatureError:
        return False
    except Exception as exc:
        print(f"Verification error: {exc}")
        return False

is_valid = verify_receipt(receipt)
print(f"Receipt is valid: {is_valid}")

# %% [markdown]
# Turėtumėte matyti `Receipt is valid: True`. Agentas sukūrė savo pirmąjį kriptografiškai pasirašytą audito įrašą.

# %% [markdown]
# ## 2 skyrius: Manipuliuoti kvitu
#
# Visas kvitų tikslas yra kad jie būtų nuo manipuliacijų apsaugoti. Įrodykime tai.
#
# Mes pakeisime tik vieną kvito simbolį ir stebėsime patikrinimo nesėkmę.

# %%
import copy

tampered = copy.deepcopy(receipt)

# Modify the policy_id field (this is what an attacker might do to claim
# the action was governed by a more permissive policy than was actually used).
original_policy = tampered["policy_id"]
tampered["policy_id"] = "contoso-travel-policy-PERMISSIVE"

print(f"Original policy_id:  {original_policy}")
print(f"Tampered policy_id:  {tampered['policy_id']}")
print()
print(f"Tampered receipt valid? {verify_receipt(tampered)}")

# %% [markdown]
# ### Kas ką tik nutiko?
#
# Kai pakeitėme `policy_id`, pasikeitė kanoninės baitų reikšmės. Tų baitų SHA-256 maišos reikšmė pasikeitė. Parašas (kuris buvo padarytas ant originalios maišos) nebeatitinka naujos maišos. Patikrinimas teisingai grąžina `False`.
#
# Nėra jokio būdo pakeisti bet kurį kvito lauką ir tuo pačiu metu patvirtinti jo teisingumą, jei tik užpuolikas neturi privačiojo rakto. Kol privatusis raktas laikomas raktų saugykloje, o viešasis raktas yra paskelbtas, klastojimo paslėpti neįmanoma.
#
# Išbandykite patys: pakeiskite `tool_name` arba `agent_id` arba `timestamp` viršuje esančioje ląstelėje ir paleiskite iš naujo. Kiekvienas pakeitimas sukuria negaliojantį kvitą.

# %% [markdown]
# ## 3 skirsnis: Susiekite kvitus grandine
#
# Vienas kvitas saugo vieną veiksmą. Dauguma agentų atlieka daug veiksmų. Kad visa seka būtų apsaugota nuo klastojimų, mes susiejame kiekvieną kvitą su ankstesniu, įtraukdami ankstesnio kvito maišos reikšmę į naujo kvito turinį.
#
# ```text
# Receipt 0  -->  Receipt 1  -->  Receipt 2
#                   |                 |
#                   +-- previous_receipt_hash field --+
# ```
#
# Jei kas nors pašalina arba pakeičia kvitų tvarką, grandinė nutrūksta būtent tame taške. Vėlesnio kvito patikrinimas nepavyksta, nes jo `previous_receipt_hash` nebeatitinka tikros jo pirmtako maišos reikšmės.

# %%
def receipt_hash(receipt: dict) -> str:
    """
    Compute the chain hash of a complete receipt (including signature).
    This becomes the previous_receipt_hash of the next receipt in the chain.
    """
    canonical = canonicalize(receipt)
    digest = hashlib.sha256(canonical).hexdigest()
    return f"sha256:{digest}"

def make_receipt(
    tool_name: str,
    tool_args: dict,
    tool_result,
    sequence: int,
    previous_receipt_hash,
    signing_key,
    verify_key,
    agent_id: str = "contoso-travel-bot",
    policy_id: str = "contoso-travel-policy-v3",
) -> dict:
    """Convenience: build, sign, and return a receipt for one tool call."""
    payload = {
        "type": "agent.tool_call.v1",
        "agent_id": agent_id,
        "tool_name": tool_name,
        "tool_args_hash": sha256_canonical(tool_args),
        "result_hash": sha256_canonical(tool_result),
        "policy_id": policy_id,
        "timestamp": datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ"),
        "sequence": sequence,
        "previous_receipt_hash": previous_receipt_hash,
    }
    return sign_receipt(payload, signing_key, verify_key)

# %%
# Build a chain of three receipts: search, hold, book.
r0 = make_receipt(
    tool_name="lookup_flights",
    tool_args={"origin": "SYD", "destination": "LAX", "date": "2026-06-15"},
    tool_result=[{"flight": "QF11", "price": 1850}],
    sequence=0,
    previous_receipt_hash=None,
    signing_key=signing_key,
    verify_key=verify_key,
)

r1 = make_receipt(
    tool_name="hold_seat",
    tool_args={"flight": "QF11", "seat": "14A", "hold_minutes": 30},
    tool_result={"hold_id": "H8472", "expires_at": "2026-06-15T15:00:00Z"},
    sequence=1,
    previous_receipt_hash=receipt_hash(r0),
    signing_key=signing_key,
    verify_key=verify_key,
)

r2 = make_receipt(
    tool_name="confirm_booking",
    tool_args={"hold_id": "H8472", "payment_token": "tok_redacted"},
    tool_result={"booking_ref": "CT-09182", "status": "confirmed"},
    sequence=2,
    previous_receipt_hash=receipt_hash(r1),
    signing_key=signing_key,
    verify_key=verify_key,
)

chain = [r0, r1, r2]
for i, r in enumerate(chain):
    print(f"Receipt {i}: tool={r['tool_name']}, prev={r['previous_receipt_hash']}")

# %%
def verify_chain(chain: list) -> list[dict]:
    """
    Verify a sequence of receipts:
      1. Each receipt's signature must verify.
      2. Each receipt (except the genesis) must reference the previous receipt's hash.
      3. Sequence numbers must match each receipt's zero-based position in the chain.
    Returns a list of per-receipt result dicts.
    """
    results = []
    for i, receipt in enumerate(chain):
        sig_ok = verify_receipt(receipt)

        if i == 0:
            chain_ok = receipt["previous_receipt_hash"] is None
        else:
            expected = receipt_hash(chain[i - 1])
            chain_ok = receipt["previous_receipt_hash"] == expected

        seq_ok = receipt["sequence"] == i

        results.append({
            "index": i,
            "tool": receipt["tool_name"],
            "signature_valid": sig_ok,
            "chain_link_valid": chain_ok,
            "sequence_valid": seq_ok,
            "overall_valid": sig_ok and chain_ok and seq_ok,
        })
    return results

for r in verify_chain(chain):
    status = "VALID" if r["overall_valid"] else "INVALID"
    print(f"Receipt {r['index']} ({r['tool']:>18}): {status}")

# %% [markdown]
# Dabar nutraukite grandinę pakeisdami vidurinį kvitą ir vėl patikrinkite. Pakeistas kvitas nepraeina savo parašo patikrinimo, O KITO kvito patikrinimas dėl grandinės ryšio nepraeina (nes jo `previous_receipt_hash` nebeatitinka pakeisto vidurinio kvito maišos).

# %%
# Tamper with the middle receipt: change the hold duration to something
# more permissive than was actually authorized.
tampered_chain = [copy.deepcopy(r) for r in chain]
tampered_chain[1]["tool_args_hash"] = sha256_canonical(
    {"flight": "QF11", "seat": "14A", "hold_minutes": 9999}
)

for r in verify_chain(tampered_chain):
    status = "VALID" if r["overall_valid"] else "INVALID"
    why = ""
    if not r["overall_valid"]:
        reasons = []
        if not r["signature_valid"]:
            reasons.append("signature")
        if not r["chain_link_valid"]:
            reasons.append("chain link")
        if not r["sequence_valid"]:
            reasons.append("sequence")
        why = " (failed: " + ", ".join(reasons) + ")"
    print(f"Receipt {r['index']} ({r['tool']:>18}): {status}{why}")

# %% [markdown]
# Gauta 0 vis dar patikrina (ji nebuvo pakeista ir neturi ankstesnio, nuo kurio priklausytų). Gauta 1 nepraeina savo parašo patikrinimo, nes mes pakeitėme `tool_args_hash`. Gauta 2 nepraeina savo grandinės ryšio patikrinimo, nes jos `previous_receipt_hash` buvo apskaičiuotas remiantis originalia (dabar pakeista) gauta 1.
#
# Net jei užpuolikas persirašytų pakeistą gautą 1 (ką jis negali padaryti be privataus rakto), grandinės ryšio neatitikimas gautoje 2 vis tiek atskleistų klastojimą. Norėdamas paslėpti pakeitimą, užpuolikas turėtų persirašyti kiekvieną gautą nuo pakeitimo taško, o tai reikalauja privataus rakto turėjimo.

# %% [markdown]
# ## Skirsnis 4: Aplink agentų įrankio kvietimą apvyniokite kvito pasirašymą
#
# Tikroje diegimo aplinkoje nenorite, kad kiekvienas agento autorius prisimintų kvieti `make_receipt`. Norite, kad kvito pasirašymas vyktų automatiškai kiekvienam įrankio iškvietimui.
#
# Čia pateikiamas paprasčiausias modelis: apvyniojimo klasė, kuri priima bet kokią iškviečiamą įrankio funkciją ir grąžina kvitą išduodančią jos versiją. Tai pritaikoma bet kokiai agentų sistemai, įskaitant Microsoft Agent Framework (`agent_framework.foundry`).
#
# Jei neturite įdiegtos Microsoft Foundry projekto, žemiau pateiktas vietinis imitavimas vis tiek demonstruoja šį modelį.

# %%
class ReceiptedTool:
    """
    Wraps a tool function so every invocation produces a signed receipt.
    Receipts are appended to a chain held by this object.

    Accepts both positional and keyword arguments. The receipt's
    tool_args field records args (as a list) and kwargs (as a dict)
    so the canonical hash binds to whichever the caller supplied.
    """

    def __init__(self, name: str, fn, signing_key, verify_key, agent_id: str, policy_id: str):
        self.name = name
        self.fn = fn
        self.signing_key = signing_key
        self.verify_key = verify_key
        self.agent_id = agent_id
        self.policy_id = policy_id
        self.receipts: list = []

    def __call__(self, *args, **kwargs):
        result = self.fn(*args, **kwargs)
        previous_hash = receipt_hash(self.receipts[-1]) if self.receipts else None
        receipt = make_receipt(
            tool_name=self.name,
            tool_args={"args": list(args), "kwargs": kwargs},
            tool_result=result,
            sequence=len(self.receipts),
            previous_receipt_hash=previous_hash,
            signing_key=self.signing_key,
            verify_key=self.verify_key,
            agent_id=self.agent_id,
            policy_id=self.policy_id,
        )
        self.receipts.append(receipt)
        return result

# %%
# Example tool: a mock flight lookup. In a real Microsoft Agent Framework deployment,
# this would be a function passed to FoundryChatClient as a tool.
def mock_lookup_flights(origin: str, destination: str, departure_date: str) -> list:
    return [
        {"flight": "QF11", "price": 1850, "stops": 0},
        {"flight": "UA864", "price": 1620, "stops": 1},
    ]

# Wrap it with receipt signing.
receipted_lookup = ReceiptedTool(
    name="lookup_flights",
    fn=mock_lookup_flights,
    signing_key=signing_key,
    verify_key=verify_key,
    agent_id="contoso-travel-bot",
    policy_id="contoso-travel-policy-v3",
)

# Use the wrapped tool exactly like the original.
results_a = receipted_lookup(origin="SYD", destination="LAX", departure_date="2026-06-15")
results_b = receipted_lookup(origin="SYD", destination="NRT", departure_date="2026-07-02")
results_c = receipted_lookup(origin="MEL", destination="SIN", departure_date="2026-08-10")

print(f"Tool was called {len(receipted_lookup.receipts)} times.")
print(f"Each call produced a signed receipt linked to the previous one.")
print()

for r in verify_chain(receipted_lookup.receipts):
    status = "VALID" if r["overall_valid"] else "INVALID"
    print(f"Receipt {r['index']} ({r['tool']}): {status}")

# %% [markdown]
# ### Integracija su Microsoft Agent Framework
#
# Aukščiau pateiktas `ReceiptedTool` apvyniojimas yra nepriklausomas nuo platformos. Norėdami jį naudoti agentui, sukurtam naudojant Microsoft Agent Framework, užregistruokite apvyniotą funkciją kaip įrankį. Štai schema (jūs pakeistumėte imituojamą elementą tikru Microsoft Foundry įrankio registravimu):
#
# ```python
# # Pseudokodas, rodantis integracijos formą.
# # importuoti os
# # iš agent_framework.foundry importuoti FoundryChatClient
# # iš azure.identity importuoti AzureCliCredential
# #
# # teikėjas = FoundryChatClient(
# #     project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
# #     model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
# #     credential=AzureCliCredential(),
# # )
# # agentas = teikėjas.as_agent(
# #     instrukcijos="Jūs esate Contoso Travel agentas ...",
# #     įrankiai=[receipted_lookup],   # supakuotas įrankis, ne žaliava funkcija
# # )
# # atsakymas = agentas.run("Raskite skrydžius iš Sidnėjaus į Los Andželą birželį.")
# #
# # # Po vykdymo kiekvienas įrankio kvietimas, kurį atliko agentas, turi pasirašytą kvitą:
# # audit_chain = receipted_lookup.receipts
# ```
#
# Agentūros sistema neturi žinoti nieko apie kvitus. Kvito pasirašymas yra apvyniotas aplink įrankį, o ne įmontuotas į sistemą. Taip pridėsite kilmės informaciją prie esamo agento kodo be jo perrašymo.

# %% [markdown]
# ## Apžvalga ir iššūkis
#
# Jūs:
#
# - Sugeneravote Ed25519 raktų porą.
# - Sukūrėte ir pasirašėte kvitą agento įrankio kvietimui.
# - Patikrinote kvitą neprisijungus naudodami tik viešąjį raktą.
# - Pakeitėte kvitą ir pastebėjote patvirtinimo gedimą.
# - Sukūrėte trejų kvitų grandinės seką su maišos grandine.
# - Pakeitėte grandinės vidurį ir pastebėjote tiek parašo, tiek grandinės ryšio gedimą.
# - Apsupote įrankio funkciją automatinio kvito pasirašymo mechanizmu.
#
# **Iššūkis.** Išplėskite kvito schemą `request_id` lauku (UUID, skirtas paskirstytam sekimui). Atnaujinkite `make_receipt`, kad jį įtrauktų, ir patikrinkite, ar kvitai vis dar tikrinami nuo pradžios iki galo. Tada pakeiskite lauką po pasirašymo ir patikrinkite, kad patvirtinimas nepavyktų. Tai privers jus įsisavinti, kaip kiekvienas kanoninės koduotės baitas prisideda prie parašo.
#
# **Svarbi riba.** Kvitai įrodo tris dalykus ir tik tris: priskyrimą (šis raktas pasirašė šį turinį), vientisumą (turinys nebuvo pakeistas nuo pasirašymo) ir tvarką (šis kvitas sekė po kito kvito). Jie NEĮRODO, kad agento veiksmas buvo teisingas, kad `policy_id` nurodyta politika iš tikrųjų buvo įvertinta, ar kad agentas laikėsi visų taisyklių. Kvitai yra pagrindas. Valdymas yra sistema, kurią statote ant šio pagrindo.
#
# Perskaitykite pamokos README dar kartą turėdami omenyje šią ribą. Dažniausia komandos klaida dėl kvitų yra manyti, kad „turime kvitus“ reiškia „mus valdoma“. Ne. Kvitai padaro agento elgesį audituojamą. Jie nepadaro jo teisingu.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
