# %% [markdown]
# # ⚡ माइक्रोसॉफ्ट फाउंड्री के साथ समवर्ती एजेंट वर्कफ़्लोज़ (Python)
#
# ## 📋 उन्नत समानांतर प्रसंस्करण ट्यूटोरियल
#
# यह नोटबुक माइक्रोसॉफ्ट एजेंट फ्रेमवर्क का उपयोग करते हुए **समवर्ती वर्कफ़्लो पैटर्न** प्रदर्शित करता है। आप सीखेंगे कि कैसे उच्च-प्रदर्शन, समानांतर प्रसंस्करण वर्कफ़्लोज़ बनाएँ जहाँ कई AI एजेंट एक साथ निष्पादित होते हैं, जिससे थ्रूपुट में नाटकीय सुधार होता है और परिष्कृत मल्टी-थ्रेडेड व्यावसायिक प्रक्रियाओं को सक्षम किया जाता है।
#
# > **माइग्रेशन नोट:** इस उदाहरण में पहले GitHub Models का संदर्भ था। GitHub Models अब अप्रचलित हैं (जुलाई 2026 में समाप्त हो रहे हैं), इसलिए अब यह `FoundryChatClient` के माध्यम से **Microsoft Foundry** का उपयोग करता है, जो Azure OpenAI **Responses API** को लक्षित करता है।
#
# ## 🎯 सीखने के उद्देश्य
#
# ### 🚀 **समवर्ती प्रसंस्करण के मूल सिद्धांत**
# - **समानांतर एजेंट निष्पादन**: अधिकतम दक्षता के लिए कई एजेंटों को एक साथ चलाएं
# - **वर्कफ़्लो समन्वयन**: डेटा संगति बनाए रखते हुए समवर्ती संचालन का समन्वय करें
# - **प्रदर्शन अनुकूलन**: समानांतर प्रसंस्करण के माध्यम से महत्वपूर्ण गति प्राप्त करें
# - **संसाधन प्रबंधन**: समवर्ती संचालन के दौरान AI मॉडल संसाधनों का कुशल उपयोग करें
#
# ### 🏗️ **उन्नत समवर्ती पैटर्न**
# - **फोर्क-जॉइन प्रसंस्करण**: कार्य को कई एजेंटों में विभाजित करें और परिणामों को मिलाएं
# - **पाइपलाइन समानांतरता**: निरंतर थ्रूपुट के लिए निष्पादन चरणों को ओवरलैप करें
# - **लोड बैलेंसिंग**: उपलब्ध एजेंट संसाधनों में कार्य समान रूप से वितरित करें
# - **सिंक रैपिंट पॉइंट्स**: महत्वपूर्ण वर्कफ़्लो चरणों पर समवर्ती एजेंटों का समन्वय करें
#
# ### 🏢 **उद्यम समवर्ती अनुप्रयोग**
# - **उच्च-आयतन दस्तावेज़ प्रसंस्करण**: कई दस्तावेज़ों को एक साथ संसाधित करें
# - **रीयल-टाइम कंटेंट विश्लेषण**: आने वाले डेटा स्ट्रीम का समवर्ती विश्लेषण
# - **बैच प्रसंस्करण अनुकूलन**: बड़े पैमाने पर संचालन के लिए थ्रूपुट अधिकतम करें
# - **मल्टी-मोडल विश्लेषण**: विभिन्न सामग्री प्रकारों (टेक्स्ट, छवियां, डेटा) का समानांतर प्रसंस्करण
#
# ## ⚙️ आवश्यकताएं और सेटअप
#
# ### 📦 **आवश्यक निर्भरता**
#
# समवर्ती वर्कफ़्लो क्षमताओं के साथ एजेंट फ्रेमवर्क इंस्टॉल करें:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry कॉन्फ़िगरेशन**
#
# Azure CLI (`az login`) के साथ साइन इन करें ताकि `AzureCliCredential` प्रमाणीकृत कर सके, फिर अपने Microsoft Foundry प्रोजेक्ट विवरण सेट करें।
#
# **पर्यावरण सेटअप (.env फ़ाइल):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **समवर्ती प्रसंस्करण विचार:**
# - **रेट लिमिट्स**: समवर्ती अनुरोधों के लिए Azure OpenAI रेट लिमिट्स मॉनिटर करें
# - **संसाधन उपयोग**: कई समवर्ती एजेंटों के साथ मेमोरी और CPU उपयोग पर विचार करें
# - **त्रुटि हैंडलिंग**: समानांतर संचालन के लिए मजबूत त्रुटि पुनर्प्राप्ति लागू करें
#
# ### 🏗️ **समवर्ती वर्कफ़्लो आर्किटेक्चर**
#
# ```mermaid
# graph TD
#     A[वर्कफ़्लो प्रारंभ] --> B[एक साथ निष्पादन]
#     B --> C[एजेंट पूल 1]
#     B --> D[एजेंट पूल 2]
#     B --> E[एजेंट पूल 3]
#     C --> F[परिणाम संग्रहण]
#     D --> F
#     E --> F
#     F --> G[अंतिम आउटपुट]
#
#     H[माइक्रोसॉफ्ट फाउंड्री] --> C
#     H --> D
#     H --> E
# ```
#
# **प्रमुख लाभ:**
# - **⚡ प्रदर्शन**: समानांतर निष्पादन के माध्यम से महत्वपूर्ण गति वृद्धि
# - **📈 स्केलेबिलिटी**: बढ़े हुए वर्कलोड को बिना समानुपाती समय वृद्धि के संभालें
# - **🔄 दक्षता**: उपलब्ध कम्प्यूटेशनल संसाधनों का बेहतर उपयोग
# - **🎯 थ्रूपुट**: समान समय में अधिक कार्य संसाधित करें
#
# ## 🎨 **समवर्ती वर्कफ़्लो डिज़ाइन पैटर्न**
#
# ### 🔍 **अनुसंधान और विश्लेषण पाइपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रसंस्करण वर्कफ़्लो**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री निर्माण पाइपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **मल्टी-चरण प्रसंस्करण**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **उद्यम प्रदर्शन लाभ**
#
# ### ⚡ **थ्रूपुट अनुकूलन**
# - **समानांतर निष्पादन**: कई एजेंट एक साथ काम करते हैं
# - **संसाधन उपयोग**: उपलब्ध AI मॉडल क्षमता की अधिकतम दक्षता
# - **समय में कमी**: कुल प्रसंस्करण समय में महत्वपूर्ण कमी
# - **स्केलेबल आर्किटेक्चर**: आवश्यकता अनुसार अधिक समवर्ती एजेंट आसानी से जोड़ें
#
# ### 🛡️ **विश्वसनीयता और लचीलापन**
# - **फॉल्ट टॉलरेंस**: व्यक्तिगत एजेंट त्रुटियाँ पूरे वर्कफ़्लो को नहीं रोकतीं
# - **त्रुटि पृथक्करण**: एक समवर्ती शाखा में समस्याएँ अन्य को प्रभावित नहीं करतीं
# - **सौम्य पतन**: एजेंट क्षमता कम होने पर भी सिस्टम संचालित रहता है
# - **पुनर्प्राप्ति तंत्र**: असफल ऑपरेशनों के लिए स्वत: पुनः प्रयास और त्रुटि प्रबंधन
#
# ### 📊 **निगरानी और अवलोकन**
# - **समवर्ती निष्पादन ट्रैकिंग**: सभी समानांतर संचालन की प्रगति मॉनिटर करें
# - **प्रदर्शन मीट्रिक्स**: गति और दक्षता लाभ मापें
# - **संसाधन उपयोग विश्लेषण**: समवर्ती एजेंट आवंटन को अनुकूलित करें
# - **बॉटलनेक्स की पहचान**: प्रदर्शन बाधाओं को खोजें और हल करें
#
# चलिए उच्च प्रदर्शन वाले समवर्ती AI वर्कफ़्लोज़ बनाते हैं! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# इस दस्तावेज़ का अनुवाद AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) का उपयोग करके किया गया है। जबकि हम सटीकता के लिए प्रयास करते हैं, कृपया ध्यान दें कि स्वचालित अनुवादों में त्रुटियाँ या अशुद्धियाँ हो सकती हैं। मूल दस्तावेज़ अपनी मूल भाषा में ही प्रामाणिक स्रोत माना जाना चाहिए। महत्वपूर्ण जानकारी के लिए, पेशेवर मानव अनुवाद की सिफारिश की जाती है। इस अनुवाद के उपयोग से उत्पन्न किसी भी गलतफहमी या गलत व्याख्या के लिए हम उत्तरदायी नहीं हैं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
