# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) के साथ एंटरप्राइज़ RAG
#
# ## 📋 सीखने के उद्देश्य
#
# यह नोटबुक दिखाता है कि Microsoft Foundry के साथ .NET में Microsoft Agent Framework का उपयोग करके एंटरप्राइज़-ग्रेड Retrieval-Augmented Generation (RAG) सिस्टम कैसे बनाएँ। आप ऐसे प्रोडक्शन-रेडी एजेंट बनाने सीखेंगे जो दस्तावेज़ों के माध्यम से खोज कर सकें और एंटरप्राइज़ सुरक्षा और स्केलेबिलिटी के साथ सटीक, संदर्भ-संबंधित उत्तर प्रदान कर सकें।
#
# **आप जो एंटरप्राइज़ RAG क्षमताएँ बनाएंगे:**
# - 📚 **दस्तावेज़ बुद्धिमत्ता**: Azure AI सेवाओं के साथ उन्नत दस्तावेज़ प्रसंस्करण
# - 🔍 **सामांतिक खोज**: एंटरप्राइज़ विशेषताओं के साथ उच्च प्रदर्शन वेक्टर खोज
# - 🛡️ **सुरक्षा एकीकरण**: भूमिका-आधारित पहुंच और डेटा संरक्षण पैटर्न
# - 🏢 **स्केलेबल आर्किटेक्चर**: निगरानी के साथ प्रोडक्शन-रेडी RAG सिस्टम
#
# ## 🎯 एंटरप्राइज़ RAG वास्तुकला
#
# ### मुख्य एंटरप्राइज़ घटक
# - **Microsoft Foundry**: सुरक्षा और अनुपालन के साथ प्रबंधित एंटरप्राइज़ AI मंच
# - **स्थायी एजेंट**: संवाद इतिहास और संदर्भ प्रबंधन के साथ Stateful एजेंट
# - **वेक्टर स्टोर प्रबंधन**: एंटरप्राइज़-ग्रेड दस्तावेज़ अनुक्रमण और पुनःप्राप्ति
# - **पहचान एकीकरण**: Azure AD प्रमाणीकरण और भूमिका-आधारित पहुंच नियंत्रण
#
# ### .NET एंटरप्राइज़ लाभ
# - **टाइप सुरक्षा**: RAG संचालन और डेटा संरचनाओं के लिए कंपाइल-टाइम सत्यापन
# - **असिंक प्रदर्शन**: गैर-ब्लॉकिंग दस्तावेज़ प्रसंस्करण और खोज संचालन
# - **मेमोरी प्रबंधन**: बड़े दस्तावेज़ संग्रह के लिए कुशल संसाधन उपयोग
# - **इंटीग्रेशन पैटर्न्स**: निर्भरता इंजेक्शन के साथ मूल Azure सेवा एकीकरण
#
# ## 🏗️ तकनीकी वास्तुकला
#
# ### एंटरप्राइज़ RAG पाइपलाइन
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### मुख्य .NET घटक
# - **Azure.AI.Agents.Persistent**: स्थिति धारण के साथ एंटरप्राइज़ एजेंट प्रबंधन
# - **Azure.Identity**: सुरक्षित Azure सेवा पहुंच के लिए एकीकृत प्रमाणीकरण
# - **Microsoft.Agents.AI.AzureAI**: Azure-उन्मुख एजेंट फ्रेमवर्क कार्यान्वयन
# - **System.Linq.Async**: उच्च प्रदर्शन असिंक्रोनस LINQ संचालन
#
# ## 🔧 एंटरप्राइज़ फीचर्स और लाभ
#
# ### सुरक्षा और अनुपालन
# - **Azure AD एकीकरण**: एंटरप्राइज़ पहचान प्रबंधन और प्रमाणीकरण
# - **भूमिका-आधारित पहुंच**: दस्तावेज़ पहुंच और संचालन के लिए सूक्ष्म अनुमतियाँ
# - **डेटा सुरक्षा**: संवेदनशील दस्तावेज़ों के लिए विश्राम और प्रवाह में एन्क्रिप्शन
# - **ऑडिट लॉगिंग**: अनुपालन आवश्यकताओं के लिए व्यापक गतिविधि ट्रैकिंग
#
# ### प्रदर्शन और स्केलेबिलिटी
# - **कनेक्शन पूलिंग**: कुशल Azure सेवा कनेक्शन प्रबंधन
# - **असिंक प्रोसेसिंग**: उच्च थ्रूपुट परिदृश्यों के लिए गैर-ब्लॉकिंग संचालन
# - **कैशिंग रणनीतियाँ**: अक्सर एक्सेस किए जाने वाले दस्तावेज़ों के लिए बुद्धिमान कैशिंग
# - **लोड बैलेंसिंग**: बड़े पैमाने पर डिप्लॉयमेंट के लिए वितरित प्रसंस्करण
#
# ### प्रबंधन और निगरानी
# - **हेल्थ चेक**: RAG सिस्टम घटकों के लिए बिल्ट-इन निगरानी
# - **प्रदर्शन मेट्रिक्स**: खोज गुणवत्ता और प्रतिक्रिया समय पर विस्तृत विश्लेषण
# - **त्रुटि प्रबंधन**: पुनः प्रयास नीतियों के साथ व्यापक अपवाद प्रबंधन
# - **कॉन्फ़िगरेशन प्रबंधन**: पर्यावरण-विशिष्ट सेटिंग्स के साथ मान्यता
#
# ## ⚙️ पूर्वापेक्षाएँ और सेटअप
#
# **विकास वातावरण:**
# - .NET 9.0 SDK या उच्चतर
# - Visual Studio 2022 या VS Code में C# एक्सटेंशन के साथ
# - AI Foundry एक्सेस के साथ Azure सदस्यता
#
# **आवश्यक NuGet पैकेज:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure प्रमाणीकरण सेटअप:**
# ```bash
# # Azure CLI स्थापित करें और प्रमाणित करें
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **पर्यावरण विन्यास (.env फ़ाइल):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 एंटरप्राइज़ RAG पैटर्न
#
# ### दस्तावेज़ प्रबंधन पैटर्न
# - **थोक अपलोड**: बड़े दस्तावेज़ संग्रह की कुशल प्रसंस्करण
# - **क्रमिक अपडेट**: वास्तविक समय में दस्तावेज़ जोड़ना और संशोधन
# - **संस्करण नियंत्रण**: दस्तावेज़ संस्करण और परिवर्तन ट्रैकिंग
# - **मेटाडेटा प्रबंधन**: समृद्ध दस्तावेज़ गुण और वर्गीकरण
#
# ### खोज और पुनःप्राप्ति पैटर्न
# - **हाइब्रिड खोज**: आदर्श परिणामों के लिए सामांतिक और कीवर्ड खोज का संयोजन
# - **फैसिटेड खोज**: बहु-आयामी फ़िल्टरिंग और वर्गीकरण
# - **प्रासंगिकता ट्यूनिंग**: डोमेन-विशिष्ट आवश्यकताओं के लिए कस्टम स्कोरिंग एल्गोरिदम
# - **परिणाम रैंकिंग**: व्यावसायिक लॉजिक एकीकरण के साथ उन्नत रैंकिंग
#
# ### सुरक्षा पैटर्न
# - **दस्तावेज़-स्तरीय सुरक्षा**: प्रति दस्तावेज़ सूक्ष्म पहुंच नियंत्रण
# - **डेटा वर्गीकरण**: स्वचालित संवेदनशीलता लेबलिंग और संरक्षण
# - **ऑडिट ट्रेल्स**: सभी RAG संचालन का व्यापक लॉगिंग
# - **गोपनीयता संरक्षण**: PII पहचान और संपादन क्षमताएँ
#
# ## 🔒 एंटरप्राइज़ सुरक्षा विशेषताएँ
#
# ### प्रमाणीकरण और प्राधिकरण
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### डेटा सुरक्षा
# - **एन्क्रिप्शन**: दस्तावेज़ों और खोज सूचकांकों के लिए अंत-से-अंत एन्क्रिप्शन
# - **पहुँच नियंत्रण**: उपयोगकर्ता और समूह अनुमतियों के लिए Azure AD के साथ एकीकरण
# - **डेटा निवास**: अनुपालन के लिए भौगोलिक डेटा स्थान नियंत्रण
# - **बैकअप और पुनर्प्राप्ति**: स्वचालित बैकअप और आपदा पुनर्प्राप्ति क्षमताएँ
#
# ## 📈 प्रदर्शन अनुकूलन
#
# ### असिंक प्रोसेसिंग पैटर्न्स
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### मेमोरी प्रबंधन
# - **स्ट्रीमिंग प्रोसेसिंग**: बिना मेमोरी समस्याओं के बड़े दस्तावेज़ संभालना
# - **संसाधन पूलिंग**: महंगे संसाधनों का कुशल पुनः उपयोग
# - **कचरा संग्रहण**: अनुकूलित मेमोरी आवंटन पैटर्न
# - **कनेक्शन प्रबंधन**: उचित Azure सेवा कनेक्शन जीवनचक्र
#
# ### कैशिंग रणनीतियाँ
# - **क्वेरी कैशिंग**: बार-बार निष्पादित खोजों का कैशिंग
# - **दस्तावेज़ कैशिंग**: महत्वपूर्ण दस्तावेज़ों के लिए मेमोरी में कैशिंग
# - **सूचकांक कैशिंग**: अनुकूलित वेक्टर सूचकांक कैशिंग
# - **परिणाम कैशिंग**: उत्पन्न उत्तरों की बुद्धिमान कैशिंग
#
# ## 📊 एंटरप्राइज़ उपयोग मामले
#
# ### ज्ञान प्रबंधन
# - **कॉर्पोरेट विकि**: कंपनी ज्ञान आधारों में बुद्धिमान खोज
# - **नीति और प्रक्रियाएं**: स्वचालित अनुपालन और प्रक्रिया मार्गदर्शन
# - **प्रशिक्षण सामग्री**: बुद्धिमान सीखने और विकास सहायता
# - **अनुसंधान डेटाबेस**: अकादमिक और शोध पत्र विश्लेषण प्रणाली
#
# ### ग्राहक सहायता
# - **सपोर्ट ज्ञान आधार**: स्वचालित ग्राहक सेवा प्रतिक्रियाएं
# - **उत्पाद दस्तावेज़ीकरण**: बुद्धिमान उत्पाद सूचना पुनःप्राप्ति
# - **समस्या निवारण गाइड**: संदर्भ-आधारित समस्या हल सहायता
# - **FAQ सिस्टम**: दस्तावेज़ संग्रहों से गतिशील FAQ निर्माण
#
# ### नियामक अनुपालन
# - **कानूनी दस्तावेज़ विश्लेषण**: अनुबंध और कानूनी दस्तावेज़ बुद्धिमत्ता
# - **अनुपालन निगरानी**: स्वचालित नियामक अनुपालन जांच
# - **जोखिम मूल्यांकन**: दस्तावेज़ आधारित जोखिम विश्लेषण और रिपोर्टिंग
# - **ऑडिट समर्थन**: ऑडिट के लिए बुद्धिमान दस्तावेज़ खोज
#
# ## 🚀 उत्पादन परिनियोजन
#
# ### निगरानी और अवलोकन
# - **एप्लिकेशन इनसाइट्स**: विस्तृत टेलीमेट्री और प्रदर्शन निगरानी
# - **कस्टम मेट्रिक्स**: व्यापार-विशिष्ट KPI ट्रैकिंग और अलर्टिंग
# - **वितरित ट्रेसिंग**: सेवाओं के पार अंत-से-अंत अनुरोध ट्रैकिंग
# - **हेल्थ डैशबोर्ड**: वास्तविक समय सिस्टम स्वास्थ्य और प्रदर्शन दृश्यावलोकन
#
# ### स्केलेबिलिटी और विश्वसनीयता
# - **ऑटो-स्केलिंग**: लोड और प्रदर्शन मेट्रिक्स के आधार पर स्वचालित स्केलिंग
# - **उच्च उपलब्धता**: फेलओवर क्षमताओं के साथ बहु-क्षेत्रीय तैनाती
# - **लोड परीक्षण**: एंटरप्राइज़ लोड स्थितियों के तहत प्रदर्शन सत्यापन
# - **आपदा पुनर्प्राप्ति**: स्वचालित बैकअप और पुनर्प्राप्ति प्रक्रियाएं
#
# क्या आप संवेदनशील दस्तावेज़ों को बड़े पैमाने पर संभाल सकने वाले एंटरप्राइज़-ग्रेड RAG सिस्टम बनाने के लिए तैयार हैं? आइए एंटरप्राइज़ के लिए बुद्धिमान ज्ञान सिस्टम डिजाइन करें! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# इस दस्तावेज़ का अनुवाद AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) का उपयोग करके किया गया है। जबकि हम सटीकता के लिए प्रयास करते हैं, कृपया ध्यान दें कि स्वचालित अनुवादों में त्रुटियाँ या अशुद्धियाँ हो सकती हैं। मूल दस्तावेज़ अपनी मूल भाषा में ही प्रामाणिक स्रोत माना जाना चाहिए। महत्वपूर्ण जानकारी के लिए, पेशेवर मानव अनुवाद की सिफारिश की जाती है। इस अनुवाद के उपयोग से उत्पन्न किसी भी गलतफहमी या गलत व्याख्या के लिए हम उत्तरदायी नहीं हैं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
