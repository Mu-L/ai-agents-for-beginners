# %% [markdown]
# # 🔍 Enterprise RAG na Microsoft Foundry (.NET)
#
# ## 📋 Malengo ya Kujifunza
#
# Daftari hili linaonyesha jinsi ya kujenga mifumo ya Uzalishaji-Augmented Generation (RAG) ya kiwango cha biashara kwa kutumia Microsoft Agent Framework katika .NET na Microsoft Foundry. Utafunzi kuunda mawakala tayari kwa uzalishaji ambao wanaweza kutafuta katika nyaraka na kutoa majibu sahihi, yanaozingatia muktadha na usalama pamoja na ukubwa wa biashara.
#
# **Uwezo wa Enterprise RAG Utakaoujenga:**
# - 📚 **Uelewa wa Nyaraka**: Usindikaji wa hali ya juu wa nyaraka kwa huduma za Azure AI
# - 🔍 **Utafutaji wa Kimaana**: Utafutaji wa vector wenye utendaji wa juu na vipengele vya biashara
# - 🛡️ **Uingizaji wa Usalama**: Upatikanaji wa msingi wa nafasi na mifumo ya ulinzi wa data
# - 🏢 **Miundo Inayoweza Kuongeza Vipimo**: Mifumo ya RAG tayari kwa uzalishaji yenye ufuatiliaji
#
# ## 🎯 Mipango ya Enterprise RAG
#
# ### Vipengele Vikuu vya Biashara
# - **Microsoft Foundry**: Jukwaa la AI la biashara lililoendeshwa na usalama na utimilifu
# - **Mawakala Dumu**: Mawakala wenye hali na historia ya mazungumzo na usimamizi wa muktadha
# - **Usimamizi wa Hifadhi ya Vector**: Uainishaji na upatikaji wa nyaraka wa kiwango cha biashara
# - **Uingizaji wa Utambulisho**: Uthibitishaji wa Azure AD na udhibiti wa upatikanaji wa msingi wa nafasi
#
# ### Faida za .NET za Biashara
# - **Usalama wa Aina**: Uthibitishaji wa wakati wa kuundwa kwa operesheni za RAG na muundo wa data
# - **Utendaji wa Async**: Usindikaji wa nyaraka na operesheni za utafutaji zisizozuia
# - **Usimamizi wa Kumbukumbu**: Matumizi bora ya rasilimali kwa makusanyo makubwa ya nyaraka
# - **Mifumo ya Uingizaji**: Uingizaji wa huduma ya Azure asilia kwa sindano ya utegemezi
#
# ## 🏗️ Miundo ya Kiufundi
#
# ### Mlolongo wa Enterprise RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Vipengele Vikuu vya .NET
# - **Azure.AI.Agents.Persistent**: Usimamizi wa mawakala wa biashara wenye kuhifadhi hali
# - **Azure.Identity**: Uthibitishaji uliounganishwa kwa upatikanaji salama wa huduma za Azure
# - **Microsoft.Agents.AI.AzureAI**: Utekelezaji wa mfumo wa mawakala ulioboreshwa kwa Azure
# - **System.Linq.Async**: Operesheni za LINQ zisizo na mshono zenye utendaji wa juu
#
# ## 🔧 Vipengele na Faida za Biashara
#
# ### Usalama na Utimilifu
# - **Uingizaji wa Azure AD**: Usimamizi wa utambulisho wa biashara na uthibitishaji
# - **Upatikanaji wa Msingi wa Nia**: Ruhusa zilizopangwa kwa ufikiaji wa nyaraka na operesheni
# - **Ulinzi wa Data**: Ufungaji fiche wakati wa kuhifadhi na usafirishaji kwa nyaraka nyeti
# - **Kurekodi Ukaguzi**: Ufuatiliaji wa shughuli kwa mahitaji ya utimilifu
#
# ### Utendaji na Ukubwa
# - **Kuunganisha Pools**: Usimamizi bora wa muunganisho wa huduma za Azure
# - **Usindikaji wa Async**: Operesheni zisizozuia kwa hali za upitishaji habari wa juu
# - **Mikakati ya Caching**: Uhifadhi wa akili kwa nyaraka zinazoonekana mara kwa mara
# - **Usawa wa Mzigo**: Usindikaji uliogawanywa kwa utekelezaji wa kiwango kikubwa
#
# ### Usimamizi na Ufuatiliaji
# - **Ukaguzi wa Afya**: Ufuatiliaji uliojengwa kwa vipengele vya mifumo ya RAG
# - **Vipimo vya Utendaji**: Takwimu za kina juu ya ubora wa utafutaji na nyakati za majibu
# - **Usimamizi wa Makosa**: Usimamizi wa kina wa makosa kwa sera za jaribu tena
# - **Usimamizi wa Mipangilio**: Mipangilio maalum ya mazingira yenye uthibitishaji
#
# ## ⚙️ Mahitaji na Usanidi
#
# **Mazingira ya Maendeleo:**
# - SDK ya .NET 9.0 au zaidi
# - Visual Studio 2022 au VS Code na kiendelezi cha C#
# - Ushiriki wa Azure wenye upatikanaji wa AI Foundry
#
# **Pakia za Lazima za NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Usanidi wa Uthibitishaji wa Azure:**
# ```bash
# # Sakinisha Azure CLI na uthibitisho
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Usanidi wa Mazingira (faili .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Mifumo ya Enterprise RAG
#
# ### Mifumo ya Usimamizi wa Nyaraka
# - **Upakiaji wa Kifurushi**: Usindikaji bora wa makusanyo makubwa ya nyaraka
# - **Marekebisho ya Kuongezeka**: Ongeza na ubadilishe nyaraka kwa wakati halisi
# - **Udhibiti wa Toleo**: Ufuatiliaji wa mabadiliko na toleo la nyaraka
# - **Usimamizi wa Metadata**: Sifa tajiri za nyaraka na utaratibu wa orodha
#
# ### Mifumo ya Utafutaji na Urejeshaji
# - **Utafutaji Mchanganyiko**: Kuunganisha utafutaji wa maana na maneno muhimu kwa matokeo bora
# - **Utafutaji wa Kipengele Mbalimbali**: Kuchuja na kupanga kwa vipimo vingi
# - **Urekebishaji wa Uhusiano**: Algorithmi maalum za alama kwa mahitaji ya kikoa
# - **Kupangilia Matokeo**: Upangishaji wa hali ya juu na uingizaji wa mantiki ya biashara
#
# ### Mifumo ya Usalama
# - **Usalama wa Kiwango cha Nyaraka**: Udhibiti wa upatikanaji wa kina kwa kila nyaraka
# - **Uainishaji wa Data**: Uwekaji lebo wa kiotomatiki wa unyeti na ulinzi
# - **Mafuatano ya Ukaguzi**: Kurekodi kwa kina kwa operesheni zote za RAG
# - **Ulinzi wa Faragha**: Uhitaji wa kugundua na kuficha PII
#
# ## 🔒 Vipengele vya Usalama vya Biashara
#
# ### Uthibitishaji na Uidhinishaji
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Ulinzi wa Data
# - **Ufungaji Fiche**: Ufungaji fiche kamili kwa nyaraka na vihifadhi vya utafutaji
# - **Udhibiti wa Upatikanaji**: Uingizaji na Azure AD kwa zvandarua na ruhusa za kikundi
# - **Makazi ya Data**: Udhibiti wa eneo la data kwa utimilifu
# - **Nakili na Uokozi**: Nakili za moja kwa moja na uwezo wa kupona maafa
#
# ## 📈 Urekebishaji wa Utendaji
#
# ### Mifumo ya Usindikaji wa Async
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Usimamizi wa Kumbukumbu
# - **Usindikaji wa Uenezaji**: Shughulikia nyaraka kubwa bila matatizo ya kumbukumbu
# - **Kuunganisha Rasilimali**: Tumia tena rasilimali ghali kwa ufanisi
# - **Ukusanyaji wa Takataka**: Mifumo bora ya ugawaji kumbukumbu
# - **Usimamizi wa Muunganisho**: Mzunguko sahihi wa muunganisho wa huduma za Azure
#
# ### Mikakati ya Caching
# - **Caching ya Maswali**: Hifadhi wa utafutaji unaofanywa mara kwa mara
# - **Caching ya Nyaraka**: Uhifadhi wa nyaraka ndani ya kumbukumbu
# - **Caching ya Index**: Uboreshaji wa kuhifadhi faharisi za vector
# - **Caching ya Matokeo**: Uhifadhi wa akili wa majibu yaliyotengenezwa
#
# ## 📊 Matumizi ya Enterprise
#
# ### Usimamizi wa Maarifa
# - **Wiki ya Kampuni**: Utafutaji wa akili katika misingi ya maarifa ya kampuni
# - **Sera na Taratibu**: Ufuatiliaji wa utimilifu na mwongozo wa taratibu uliotoa kiotomatiki
# - **Vifaa vya Mafunzo**: Msaada wa kujifunza na maendeleo wa akili
# - **Maktaba za Utafiti**: Mifumo ya uchambuzi wa karatasi za utafiti na kitaaluma
#
# ### Usaidizi wa Wateja
# - **Msingi wa Maarifa wa Msaada**: Majibu ya huduma kwa wateja yaliyoratibiwa kiotomatiki
# - **Nyaraka za Bidhaa**: Upataji wa habari mahususi za bidhaa kwa akili
# - **Mwongozo wa Utatuzi wa Matatizo**: Msaada wa kutatua matatizo kwa muktadha
# - **Mifumo ya Maswali ya Mara kwa Mara (FAQ)**: Uundaji wa maswali na majibu kwa nyaraka
#
# ### Utimilifu wa Kanuni
# - **Uchambuzi wa Nyaraka za Kisheria**: Uelewa wa mikataba na nyaraka za kisheria
# - **Ufuatiliaji wa Utimilifu**: Ukaguzi wa utimilifu wa kanuni kwa njia ya kiotomatiki
# - **Tathmini ya Hatari**: Uchambuzi na utoaji ripoti wa hatari kwa nyaraka
# - **Msaada wa Ukaguzi**: Ugunduzi wa nyaraka kwa ukaguzi kwa akili
#
# ## 🚀 Utekelezaji wa Uzalishaji
#
# ### Ufuatiliaji na Uwezo wa Kuonekana
# - **Application Insights**: Ufuatiliaji wa kina wa utambuzi na utendaji
# - **Vipimo Maalum**: Ufuatiliaji wa KPI maalum za biashara na tahadhari
# - **Ufuatiliaji wa Maombi Yaliyogawanywa**: Ufuatiliaji wa maombi kutoka mwanzo hadi mwisho katika huduma
# - **Dashibodi za Afya**: Onyesho la afya na utendaji wa mfumo kwa wakati halisi
#
# ### Ukubwa na Uaminifu
# - **Kuongeza Kwa Kiotomatiki**: Kiwango cha kuongeza kwa otomatiki kulingana na mzigo na vipimo vya utendaji
# - **Upatikanaji wa Juu**: Utekelezaji wa maeneo mengi na uwezo wa kubadili
# - **Upimaji wa Mzigo**: Uthibitisho wa utendaji chini ya hali za mzigo wa biashara
# - **Uokoaji wa Maafa**: Taratibu za nakili na uokoaji wa moja kwa moja
#
# Tayari kujenga mifumo ya kiwango cha biashara ya RAG inayoweza kushughulikia nyaraka nyeti kwa wingi? Twende tukaunde mifumo ya maarifa ya akili kwa biashara! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
