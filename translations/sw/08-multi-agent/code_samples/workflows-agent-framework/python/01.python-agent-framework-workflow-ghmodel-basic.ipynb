# %% [markdown]
# # 🔄 Mtaratibu wa Mwendeshaji wa Msingi na Microsoft Foundry (Python)
#
# ## 📋 Mafunzo ya Uratibu wa Mtaratibu
#
# Daftari hili linaanzisha uwezo mkubwa wa **Workflow Builder** wa Mfumo wa Wakala wa Microsoft. Jifunze jinsi ya kuunda mchakato wa wakala wa hatua nyingi, wa kisasa unaoweza kushughulikia michakato tata ya biashara na kuratibu shughuli nyingi za AI kwa urahisi.
#
# > **Kumbuka Kuhamia:** Sampuli hii ilitumia mfano wa GitHub awali. Mfano wa GitHub umekwisha kutumika (utaachwa mwezi Julai 2026), sasa inatumia **Microsoft Foundry** kupitia `FoundryChatClient`, ambayo inalenga Azure OpenAI **Responses API**.
#
# ## 🎯 Malengo ya Kujifunza
#
# ### 🏗️ **Mimambo ya Mwandiko wa Mtaratibu**
# - **Workflow Builder**: Tengeneza na ratibu michakato ngumu yenye hatua nyingi
# - **Uendeshaji Unaotegemea Matukio**: Shughulikia matukio ya mtaratibu na mabadiliko ya hali
# - **Ubunifu wa Mtaratibu Unaoonekana**: Tengeneza na angalia muundo wa mtaratibu
# - **Uunganisho na Microsoft Foundry**: Tumia mifano ya AI katika muktadha wa mtaratibu
#
# ### 🔄 **Uratibu wa Mchakato**
# - **Shughuli Mfululizo**: Lenga majukumu mengi ya wakala kwa mpangilio wa mantiki
# - **Mantiki ya Masharti**: Tekeleza pointi za maamuzi na miteremko ya mtaratibu
# - **Shughulikia Hitilafu**: Urejeshaji wa hitilafu wenye nguvu na uimara wa mtaratibu
# - **Usimamizi wa Hali**: Fuata na usimamishe hali ya utekelezaji wa mtaratibu
#
# ### 📊 **Mifano ya Mtaratibu wa Biashara**
# - **Automatiki ya Mchakato wa Biashara**: Automatic mizigo ya kazi tata za shirika
# - **Uratibu wa Wakala Wengi**: Ratibu mawakala maalum wengi
# - **Utekelezaji Unaoweza Kupanuka**: Tengeneza mitaratibu ya shughuli za kiwango cha shirika
# - **Ufuatiliaji & Uwezo wa Kuangalia**: Fuata utendaji wa mtaratibu na matokeo yake
#
# ## ⚙️ Mahitaji ya Awali & Usanidi
#
# ### 📦 **Vitegemezi Inavyohitajika**
#
# Sakinisha Mfumo wa Wakala unaoendeshwa na uwezo wa mtaratibu:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Usanidi wa Microsoft Foundry**
#
# Ingia na Azure CLI (`az login`) ili `AzureCliCredential` ibadilishane taarifa za kuingia, kisha weka maelezo ya mradi wako wa Microsoft Foundry.
#
# **Mazingira ya Usanidi (Faili la .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# ### 🏢 **Matukio ya Matumizi ya Shirika**
#
# **Mifano ya Mchakato wa Biashara:**
# - **Kuingiza Wateja**: Mchakato wa uthibitisho na usanidi wa hatua nyingi
# - **Mtiririko wa Maudhui**: Uundaji wa maudhui moja kwa moja, ukaguzi, na kuchapisha
# - **Usindikaji wa Data**: Mifumo ya ETL yenye mabadiliko yanayotumia AI
# - **Uhakiki wa Ubora**: Mtihani wa moja kwa moja na michakato ya uthibitisho
#
# **Manufaa ya Mtaratibu:**
# - 🎯 **Uaminifu**: Utekelezaji ulio thabiti na urejeshaji wa makosa
# - 📈 **Kupanuka**: Shughulikia automatishea za kazi nyingi kwa wingi
# - 🔍 **Kuangalia**: Rekodi kamili za ukaguzi na ufuatiliaji
# - 🔧 **Uendelevu**: Ubunifu unaoonekana na vipengele vya moduli
#
# ## 🎨 Mifano ya Ubunifu wa Mtaratibu
#
# ### Muundo wa Msingi wa Mtaratibu
# ```mermaid
# graph TD
#     A[Anza] --> B[Kazi ya Wakala 1]
#     B --> C{Sehemu ya Uamuzi}
#     C -->|Mafanikio| D[Kazi ya Wakala 2]
#     C -->|Kushindwa| E[Mshughulikiaji wa Makosa]
#     D --> F[Mwisho]
#     E --> F
# ```
#
# **Vipengele Vikuu:**
# - **WorkflowBuilder**: Injini kuu ya uratibu
# - **WorkflowEvent**: Shughulikia matukio na mawasiliano
# - **WorkflowViz**: Uwakilishi wa mtaratibu unaoonekana na urekebishaji dosari
#
# Tujenge mtaratibu wako wa kwanza mwenye akili! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load Microsoft Foundry project settings from .env file
load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = provider.as_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = provider.as_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
