# %% [markdown]
# # ⚡ Mifumo ya Kazi ya Mawakala Wengi kwa Microsoft Foundry (Python)
#
# ## 📋 Mafunzo ya Usindikaji Sambamba wa Juu
#
# Daftari hili linaonyesha **mifumo ya mtiririko wa kazi ya wakati mmoja** kwa kutumia Mfumo wa Mawakala wa Microsoft. Utajifunza jinsi ya kujenga mifumo ya kazi yenye utendaji wa hali ya juu, usindikaji sambamba ambapo mawakala wengi wa AI hufanya kazi kwa pamoja, kuongezeka kwa kasi kwa kiasi kikubwa na kuwezesha michakato tata ya biashara yenye nyuzi nyingi.
#
# > **Kumbuka kuhusu uhamisho:** Mfano huu awali ulirejelea Modeli za GitHub. Modeli za GitHub zimepitwa na wakati (zitafutwa Julai 2026), hivyo sasa inatumia **Microsoft Foundry** kupitia `FoundryChatClient`, ambayo inalenga kwenye Azure OpenAI **API za Majibu**.
#
# ## 🎯 Malengo ya Kujifunza
#
# ### 🚀 **Misingi ya Usindikaji Sambamba**
# - **Uendeshaji wa Mawakala Wengi kwa Wakati Mmoja**: Endesha mawakala wengi kwa wakati mmoja kwa ufanisi wa juu
# - **Uratibu wa Mtiririko wa Kazi**: Ratibu operesheni zinazofanyika kwa wakati mmoja huku ukidumisha muafaka wa data
# - **Uboreshaji wa Utendaji**: Pata kasi kubwa kwa usindikaji sambamba
# - **Usimamizi wa Rasilimali**: Tumia rasilimali za mfano wa AI kwa ufanisi katika operesheni zinazofanyika kwa wakati mmoja
#
# ### 🏗️ **Mifumo ya Juu ya Usindikaji Sambamba**
# - **Usindikaji wa Fork-Join**: Gawanya kazi kati ya mawakala wengi na ungana matokeo
# - **Usindikaji Sambamba wa Mlolongo**: Sehemu za utekelezaji zinazoviringiana kwa mtiririko endelevu
# - **Ugawaji Mizigo**: Sambaza kazi kwa usawa kwa rasilimali za mawakala zilizopo
# - **Mambo ya Ulinganifu**: Ratibu mawakala wa wakati mmoja katika hatua muhimu za mtiririko wa kazi
#
# ### 🏢 **Programu za Biashara za Operesheni Sambamba**
# - **Usindikaji wa Nyaraka za Wingi**: Fanya kazi na nyaraka nyingi kwa wakati mmoja
# - **Uchambuzi wa Maudhui wa Muda Halisi**: Uchambuzi wa mfululizo wa data zinazopokelewa kwa wakati mmoja
# - **Uboreshaji wa Usindikaji wa Kikundi**: Ongeza ufanisi kwa operesheni za wingi
# - **Uchambuzi wa Aina Mbalimbali**: Usindikaji sambamba wa aina tofauti za maudhui (maandishi, picha, data)
#
# ## ⚙️ Masharti na Usanidi
#
# ### 📦 **Kutegemea Kunahitajika**
#
# Sakinisha Mfumo wa Mawakala wenye uwezo wa mitiririko ya kazi ya wakati mmoja:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Usanidi wa Microsoft Foundry**
#
# Ingia kwa kutumia Azure CLI (`az login`) ili `AzureCliCredential` iweze kuthibitisha, kisha weka maelezo ya mradi wako wa Microsoft Foundry.
#
# **Usanidi wa Mazingira (faili .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Mambo ya Kuuza Akilini katika Usindikaji Sambamba:**
# - **Mipaka ya Kiwango**: Fuatilia mipaka ya Azure OpenAI kwa maombi ya wakati mmoja
# - **Matumizi ya Rasilimali**: Chunguza matumizi ya kumbukumbu na CPU kwa mawakala wengi wa wakati mmoja
# - **Kushughulikia Makosa**: Tekeleza urejeshaji thabiti wa makosa kwa operesheni sambamba
#
# ### 🏗️ **Miundo ya Mtiririko wa Kazi ya Wakati Mmoja**
#
# ```mermaid
# graph TD
#     A[Mwanzo wa Mtiririko wa Kazi] --> B[Utekelezaji Sambamba]
#     B --> C[Ziwa la Wakala 1]
#     B --> D[Ziwa la Wakala 2]
#     B --> E[Ziwa la Wakala 3]
#     C --> F[Ukusanyaji wa Matokeo]
#     D --> F
#     E --> F
#     F --> G[Matokeo ya Mwisho]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Manufaa Muhimu:**
# - **⚡ Utendaji**: Kuongeza kasi kubwa kupitia utekelezaji sambamba
# - **📈 Kupanuka**: Shughulikia mzigo mwingi bila kuongeza muda kwa uwiano
# - **🔄 Ufanisi**: Matumizi bora ya rasilimali ya kompyuta iliyopo
# - **🎯 Uwezo wa Kutoka Kazi**: Fanya kazi nyingi katika muda mmoja
#
# ## 🎨 **Miundo ya Ubunifu ya Mtiririko wa Kazi wa Wakati Mmoja**
#
# ### 🔍 **Mlolongo wa Utafiti na Uchambuzi**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Mtiririko wa Usindikaji Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Mlolongo wa Uundaji Maudhui**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Usindikaji wa Hatua Nyingi**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Manufaa ya Utendaji kwa Biashara**
#
# ### ⚡ **Uboreshaji wa Kipimo cha Kutoka Kazi**
# - **Utekelezaji Sambamba**: Mawakala wengi wakifanya kazi kwa wakati mmoja
# - **Matumizi ya Rasilimali**: Ufanisi wa juu wa uwezo wa mfano wa AI uliopo
# - **Kupunguza Muda**: Kupungua kwa muda wa jumla wa usindikaji
# - **Muundo Unaoweza Kupanuka**: Ongeza mawakala zaidi wa wakati mmoja kirahisi inapohitajika
#
# ### 🛡️ **Uaminifu & Ustahimilivu**
# - **Uvumilivu wa Makosa**: Kushindwa kwa wakala mmoja hakuzuii mtiririko mzima wa kazi
# - **Kutenganisha Makosa**: Matatizo kwenye tawi moja la mchakato wa wakati mmoja hayathiri mengine
# - **Kupungua kwa Hali Nzuri**: Mfumo unaendelea kufanya kazi hata kwa uwezo mdogo wa wakala
# - **Mbinu za Kupona**: Jaribio la kiotomatiki na kushughulikia makosa kwa operesheni zilizoshindwa
#
# ### 📊 **Ufuatiliaji & Uwezekano wa Kuangalia**
# - **Ufuatiliaji wa Utekelezaji Sambamba**: Fuatilia maendeleo ya operesheni zote sambamba
# - **Vipimo vya Utendaji**: Pima kasi na faida za ufanisi
# - **Uchambuzi wa Matumizi ya Rasilimali**: Boresha mgawanyo wa mawakala wa wakati mmoja
# - **Utambuzi wa Vizingiti**: Tafuta na tatua vizuizi vya utendaji
#
# Tujenge mifumo ya kazi ya AI yenye utendaji wa juu ya wakati mmoja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
