# %% [markdown]
# # ⚡ Miradi ya Kazi ya Mawakala Wengi kwa Wakati Mmoja na Microsoft Foundry (Python)
#
# ## 📋 Mafunzo ya Usindikaji Sambamba wa Juu
#
# Kitabu hiki cha kumbukumbu kinaonyesha **mifumo ya mtiririko wa kazi wa wakati mmoja** ukitumia Microsoft Agent Framework. Utajifunza jinsi ya kujenga mitiririko ya kazi yenye utendaji mkubwa, usindikaji sambamba ambapo mawakala kadhaa wa AI hufanya kazi kwa wakati mmoja, kuboresha kwa kiasi kikubwa uzalishaji na kuwezesha michakato ya biashara yenye mwelekeo wa kutumia nyuzi nyingi.
#
# > **Kumbuka kuhusu uhamishaji:** Sampuli hii hapo awali ilirejelea Models za GitHub. Models za GitHub zimeachwa (zitafutwa Julai 2026), hivyo sasa inatumia **Microsoft Foundry** kupitia `FoundryChatClient`, inayolenga Azure OpenAI **Responses API**.
#
# ## 🎯 Malengo ya Kujifunza
#
# ### 🚀 **Misingi ya Usindikaji Sambamba**
# - **Utekelezaji wa Mawakala Wengi kwa Wakati Mmoja**: Endesha mawakala wengi kwa wakati mmoja kwa ufanisi mkubwa
# - **Uratibu wa Mtiririko wa Kazi**: Ratibu operesheni sambamba huku ukidumisha muafaka wa data
# - **Kuboresha Utendaji**: Fikia mwendo wa kasi mkubwa kupitia usindikaji sambamba
# - **Usimamizi wa Rasilimali**: Tumia rasilimali za modeli za AI kwa ufanisi katika operesheni sambamba
#
# ### 🏗️ **Mifumo ya Juu ya Muingiliano wa Operesheni**
# - **Usindikaji wa Fork-Join**: Gawanya kazi kwa mawakala wengi na kuunganisha matokeo
# - **Usindikaji wa Mlolongo Sambamba**: Awamu za utekelezaji zinazoelekea kwa kuendelea kwa uzalishaji
# - **Ugawaji mzuri wa Mizigo**: Sambaza kazi kwa usawa kwa rasilimali za mawakala zinazopatikana
# - **Miwendo ya Msimamizi**: Ratibu mawakala sambamba katika hatua muhimu za mtiririko wa kazi
#
# ### 🏢 **Programu za Biashara za Wakati Mmoja**
# - **Usindikaji wa Nyaraka Zaidi ya Moja kwa Wakati Mmoja**: Fanyia kazi nyaraka nyingi kwa wakati mmoja
# - **Uchambuzi wa Maudhui kwa Wakati Halisi**: Uchambuzi sambamba wa mitiririko ya data inayoingia
# - **Kuboresha Usindikaji wa Batch**: Kuwezesha uzalishaji mkubwa kwa operesheni kubwa
# - **Uchambuzi wa Multi-Modal**: Usindikaji sambamba wa aina tofauti za maudhui (maandishi, picha, data)
#
# ## ⚙️ Mahitaji ya Awali & Usanidi
#
# ### 📦 **Mategemeo Yanayohitajika**
#
# Sakinisha Agent Framework yenye uwezo wa mtiririko wa kazi wa wakati mmoja:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Usanidi wa Microsoft Foundry**
#
# Ingia kwa kutumia Azure CLI (`az login`) ili `AzureCliCredential` iweze kuthibitisha, kisha weka maelezo ya mradi wako wa Microsoft Foundry.
#
# **Usanidi wa Mazingira (faili .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Mambo ya Kuzingatia katika Usindikaji Sambamba:**
# - **Mipaka ya Kiwango**: Fuata viwango vya kuomba vya Azure OpenAI kwa maombi sambamba
# - **Matumizi ya Rasilimali**: Zingatia matumizi ya kumbukumbu na CPU na mawakala wengi sambamba
# - **Udhibiti wa Makosa**: Tekeleza urekebishaji imara wa makosa kwa operesheni sambamba
#
# ### 🏗️ **Msingi wa Miundo ya Mtiririko wa Kazi wa Sambamba**
#
# ```mermaid
# graph TD
#     A[Kuanzisha Mtiririko wa Kazi] --> B[Utekelezaji Sambamba]
#     B --> C[Kundi la Mawakala 1]
#     B --> D[Kundi la Mawakala 2]
#     B --> E[Kundi la Mawakala 3]
#     C --> F[Kukusanya Matokeo]
#     D --> F
#     E --> F
#     F --> G[Matokeo Ya Mwisho]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Faida Muhimu:**
# - **⚡ Utendaji**: Kuongeza mwendo kwa utekelezaji sambamba
# - **📈 Ustahimilivu**: Shughulikia mzigo mkubwa bila kuongeza muda sawa
# - **🔄 Ufanisi**: Tumia rasilimali za kompyuta zilizopatikana kwa ufanisi zaidi
# - **🎯 Uzalishaji wa Kazi**: Fanyia kazi nyingi kwa wakati mmoja
#
# ## 🎨 **Mifano ya Ubunifu wa Mtiririko wa Kazi wa Sambamba**
#
# ### 🔍 **Mtiririko wa Utafiti & Uchambuzi**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Mtiririko wa Usindikaji Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Mtiririko wa Uundaji wa Maudhui**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Usindikaji wa Awamu Nyingi**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Faida za Utendaji wa Biashara**
#
# ### ⚡ **Kuboresha Uzalishaji**
# - **Utekelezaji Sambamba**: Mawakala wengi wakifanya kazi kwa wakati mmoja
# - **Matumizi ya Rasilimali**: Ufanisi mkubwa wa uwezo wa modeli za AI zilizopo
# - **Kupunguza Muda**: Kupungua kwa kiasi kikubwa kwa muda wa usindikaji kwa jumla
# - **Muundo Unaoweza Kupanuliwa**: Ongeza mawakala wengine wa wakati mmoja kulingana na mahitaji
#
# ### 🛡️ **Uaminifu & Ustahimilivu**
# - **Uvumilivu wa Hitilafu**: Kushindwa kwa wakala mmoja hakusimamishi mtiririko mzima wa kazi
# - **Kutengwa kwa Makosa**: Matatizo katika tawi moja la wakati mmoja hayaathiri mengine
# - **Kupungua Polepole kwa Utendaji**: Mfumo unaendelea kufanya kazi hata kama uwezo wa wakala umepunguzwa
# - **Mbinu za Kupona**: Jaribio la kiotomatiki na udhibiti wa makosa kwa operesheni zilizoshindwa
#
# ### 📊 **Ufuatiliaji & Uwezo wa Kuonekana**
# - **Ufuatiliaji wa Utekelezaji Sambamba**: Fuata maendeleo ya operesheni zote sambamba
# - **Vipimo vya Utendaji**: Pima mwendo wa kasi na faida za ufanisi
# - **Uchanganuzi wa Matumizi ya Rasilimali**: Boresha mgawanyo wa mawakala sambamba
# - **Utambuzi wa Vizingiti**: Tafuta na tatua vizuizi vya utendaji
#
# Hebu tujenge mitiririko ya kazi ya AI yenye utendaji mkubwa kwa wakati mmoja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
