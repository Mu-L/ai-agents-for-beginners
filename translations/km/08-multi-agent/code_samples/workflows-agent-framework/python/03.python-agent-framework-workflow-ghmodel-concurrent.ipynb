# %% [markdown]
# # ⚡ កម្មវិធីភ្នាក់ងារច្រើនជាមួយ Microsoft Foundry (Python)
#
# ## 📋 មេរៀនកម្រិតខ្ពស់នៃការកំណត់ដំណើរការដំណាក់កាលជាពហុ
#
# កំណត់ត្រានេះបង្ហាញពី **គំរូដំណើរការច្រើនជាមួយគ្នា** ដោយប្រើ Microsoft Agent Framework។ អ្នកនឹងរៀនរបៀបបង្កើតដំណើរការកែច្នៃលើស្តង់ដារក្នុងពេលតែមួយ ដែលភ្នាក់ងារ AI ច្រើនអាចប្រតិបត្តិការជាប្រព្រឹត្តនៅជាក់លាក់ កើនឡើងតម្លាភាពនៃការបំពេញការងារ និងអនុញ្ញាតឱ្យមានដំណើរការអាជីវកម្មពហុច្រកសូម្បីតែមួយបានយ៉ាងស្មុគស្មាញ។
#
# > **កំណត់ចំណាំការផ្លាស់ប្តូរ:** ឧទាហរណ៍នេះយោងទៅកាន់គំរូ GitHub មុនមក។ គំរូ GitHub ត្រូវបានបិទ (នឹងផុតកំណត់នៅខែកក្កដា ២០២៦) ដូចនេះឥឡូវនេះ វាប្រើប្រាស់ **Microsoft Foundry** តាមរយៈ `FoundryChatClient` ដែលមានគោលបំណងទៅកាន់ Azure OpenAI **Responses API**។
#
# ## 🎯 គោលដៅការសិក្សា
#
# ### 🚀 **មូលដ្ឋាននៃការកំណត់ដំណើរការជាមួយគ្នា**
# - **ការប្រតិបត្តិភ្នាក់ងារច្រើនក្នុងពេលតែមួយ**៖ ដំណើរការភ្នាក់ងារច្រើនក្នុងពេលតែមួយដើម្បីមានប្រសិទ្ធិភាពអតិបរមា
# - **ការសម្របសម្រួលដំណើរការ**៖ សម្របចំណុចប្រតិបត្តិការច្រើនក្នុងពេលតែមួយទាំងដែលរក្សាទុកភាពស្របគ្នានៃទិន្នន័យ
# - **បង្រួមកម្រិតប្រសិទ្ធភាពដំណើរការ**៖ សម្រាច់ល្បឿនយ៉ាងសំខាន់តាមរយៈការកំណត់ដំណើរការជាពហុ
# - **ការគ្រប់គ្រងធនធាន**៖ ប្រើប្រាស់ធនធានម៉ូដែល AI មានប្រសិទ្ធភាពនៅក្នុងនៃការប្រតិបត្តិការជាមួយគ្នា
#
# ### 🏗️ **គំរូដំណើរការជាមួយគ្នាចំរូងខ្ពស់**
# - **ការបំបែក-បញ្ចូល**៖ បំបែកការងារចែកចាយទៅភ្នាក់ងារជាច្រើនហើយបញ្ចូលលទ្ធផលវិញ
# - **បណ្តាញដំណើរការជារៀងរាល់**៖ ដំណើរការជាស្របគ្នាពេញលេញនៅថ្នាក់បន្ទាប់ៗ សម្រាប់ការផ្ទុកទិន្នន័យជាបន្ត
# - **ការបំបែកការងារជាតុល្យភាព**៖ ចែកចាយការងារយ៉ាងសមស្របទៅលើធនធានភ្នាក់ងារដែលមាន
# - **ចំណុចសម្របសម្រួល**៖ សម្របសម្រួលភ្នាក់ងារច្រើននៅដំណាក់កាលសំខាន់នៃដំណើរការ
#
# ### 🏢 **កម្មវិធីអាជីវកម្មជាមួយការប្រតិបត្តិជាមួយគ្នា**
# - **ដំណើរការឯកសារផ្ទុកបរិមាណខ្ពស់**៖ ដំណើរការឯកសារច្រើនក្នុងពេលតែមួយ
# - **វិភាគមាតិកាពេលវេលាពិត**៖ វិភាគទិន្នន័យចូលក្នុងដោយប្រតិបត្តិជាមួយគ្នា
# - **បង្រួមប្រសិទ្ធភាពក្រុមដំណើរការ**៖ បង្កើនទិន្នផលសម្រាប់ប្រតិបត្តិការលើកម្រិតធំហ
# - **វិភាគពហុម៉ូដ្យុល**៖ កំណត់ដំណើរការជាមួយគ្នារបស់មាតិកាប្រភេទផ្សេងៗ (អត្ថបទ រូបភាព ទិន្នន័យ)
#
# ## ⚙️ លក្ខណៈទាមទារ និងការតំឡើង
#
# ### 📦 **ការពាក់ព័ន្ធដែលត្រូវការ**
#
# តំឡើង Agent Framework ជាមួយសមត្ថភាពដំណើរការជាមួយគ្នា:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **ការកំណត់ Microsoft Foundry**
#
# ចូលប្រើដោយ Azure CLI (`az login`) ដើម្បីឱ្យ `AzureCliCredential` អាចផ្ទៀងផ្ទាត់បុគ្គលិកភាពបាន បន្ទាប់មកកំណត់ព័ត៌មានលម្អិតគម្រោង Microsoft Foundry របស់អ្នក។
#
# **ការតំឡើងបរិយាកាស (.env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **ការពិចារណាពេលប្រតិបត្តិជាមួយគ្នា:**
# - **កំណត់អត្រា**៖ តាមដានអត្រា Azure OpenAI សម្រាប់សំណើរសុំជាមួយគ្នា
# - **ការប្រើប្រាស់ធនធាន**៖ ពិចារណាអំពីកំណត់អង្គចងចាំនិង CPU នៅពេលប្រតិបត្តិភ្នាក់ងារជាច្រើន
# - **ការដោះស្រាយកំហុស**៖ អនុវត្តវិធីសាស្ត្រជួយស្តារឡើងវិញនៅពេលកើតកំហុសក្នុងដំណើរការជាពហុ
#
# ### 🏗️ **រចនាសម្ព័ន្ធដំណើរការជាមួយគ្នា**
#
# ```mermaid
# graph TD
#     A[ចាប់ផ្តើមដំណើរការ] --> B[ការប្រតិបត្តិដោយស្របពេល]
#     B --> C[បញ្ជីភ្នាក់ងារលេខ 1]
#     B --> D[បញ្ជីភ្នាក់ងារលេខ 2]
#     B --> E[បញ្ជីភ្នាក់ងារលេខ 3]
#     C --> F[ការប្រមួលលទ្ធផល]
#     D --> F
#     E --> F
#     F --> G[លទ្ធផលចុងក្រោយ]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **អត្ថប្រយោជន៍សំខាន់ៗ:**
# - **⚡ ប្រសិទ្ធភាព**៖ ល្បឿនកើនឡើងយ៉ាងខ្លាំងតាមរយៈការប្រតិបត្តិជាមួយគ្នា
# - **📈 អាចត្រូវបានកែសម្រួល**៖ ដោះស្រាយការងារជាច្រើនដោយមិនប៉ះពាល់ដល់ពេលវេលា
# - **🔄 ប្រសិទ្ធភាព**៖ ប្រើប្រាស់ធនធានកុំព្យូទ័រដែលមានបានប្រសើរឡើង
# - **🎯 ការផលិតផល**៖ ដំណើរការការងារបន្ថែមក្នុងពេលវេលាដដែលគ្នា
#
# ## 🎨 **គំរូរចនាដំណើរការជាមួយគ្នា**
#
# ### 🔍 **បណ្តាញស្រាវជ្រាវ និងវិភាគ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ដំណើរការកំណត់ទិន្នន័យ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **បណ្តាញបង្កើតមាតិកា**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ដំណើរការជាចំណុចជាច្រើន**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **អត្ថប្រយោជន៍ប្រសិទ្ធភាពសម្រាប់សហគ្រាស**
#
# ### ⚡ **បង្រួមកម្រិតចំនួនលទ្ធផល**
# - **ការប្រតិបត្តិជាមួយគ្នា**៖ ភ្នាក់ងារច្រើនកំពុងធ្វើការដំណើរការជាមួយគ្នា
# - **ការប្រើប្រាស់ធនធាន**៖ ប្រសិទ្ធភាពអតិបរមានៃសមត្ថភាពម៉ូដែល AI ដែលមាន
# - **បន្ថយពេលវេលា**៖ បន្ថយពេលប្រតិបត្តិការចូលរួមយ៉ាងខ្លាំង
# - **រចនាសម្ព័ន្ធអាចពង្រីកបាន**៖ ជាច្រើនអាចបន្ថែមភ្នាក់ងារជាច្រើននៅពេលត្រូវការ
#
# ### 🛡️ **ភាពទុកចិត្ត និងភាពធន់ទ្រាំ**
# - **ភាពធន់នឹងកំហុស**៖ ភ្នាក់ងារចាប់ផ្តើមបរាជ័យមួយមិនបង្ហាញឱ្យដំណើរការទាំងមូលឈប់បាត់
# - **ការផ្តាច់កំហុស**៖ បញ្ហាកើតនៅក្នុងសាខាមួយមិនប៉ះពាល់ដល់សាខាផ្សេងទេ
# - **ការបន្ថយយ៉ាងអំណោយផល**៖ ប្រព័ន្ធបន្តដំណើរការរហូតទោះបីបានបន្ថយសមត្ថភាពភ្នាក់ងារសោះ
# - **មេកានិចស្តារឡើងវិញ**៖ ធ្វើម៉ូតស្វ័យប្រវត្តិនិងដោះស្រាយកំហុសសម្រាប់ការប្រតិបត្តិការបរាជ័យ
#
# ### 📊 **ការតាមដាន និងការមើលឃើញ**
# - **តាមដានការប្រតិបត្តិជាមួយគ្នា**៖ ត្រួតពិនិត្យដំណើរការរបស់ប្រតិបត្តិការជាពហុ
# - **ម៉ាត្រិចប្រសិទ្ធភាព**៖ វាស់វែងល្បឿននិងការកើនឡើងនៃប្រសិទ្ធភាព
# - **វិភាគការប្រើប្រាស់ធនធាន**៖ បង្កើនប្រសិទ្ធភាពក្នុងការចែកចាយភ្នាក់ងារជាមួយគ្នា
# - **កំណត់កន្លែងបំរុង**៖ រកឃើញនិងដោះស្រាយការរឹតត្បិតប្រសិទ្ធភាព
#
# យើងចាប់ផ្តើមបង្កើតដំណើរការជាមួយ AI ប្រសិទ្ធភាពខ្ពស់បន្តរបៀបគ្នា! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
