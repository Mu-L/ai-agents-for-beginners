# %% [markdown]
# # ⚡ Microsoft Foundry உடன் ஒரே நேரம் பல முகவர்களின் வேலை ஓட்டங்கள் (Python)
#
# ## 📋 முன்னேற்றப்பட்ட 병렬 செயலாக்கம் கற்றல்
#
# இந்த நோட்புக் Microsoft முகவர் கட்டமைப்பை பயன்படுத்தி **ஒரே நேரம் பல வேலை ஓட்டக் கட்டமைப்புகளை** விளக்குகிறது. பல AI முகவர்கள் ஒத்துக் கொண்டு கூடிய வேகத்தில் செயல்படும் உயர் செயல்பாட்டுடனான 병렬 செயலாக்க வேலை ஓட்டங்களை எப்படி கட்டுப்படுத்துவது என்பதை நீங்கள் கற்றுக்கொள்வீர்கள், இது செயல்திறனை பெரிதும் மேம்படுத்தி, நுணுக்கமான பல-தரை வணிக செயல்முறைகளை சாத்தியமாக்குகிறது.
#
# > **இடமாற்ற குறிப்பு:** இந்த மாதிரி முன்பு GitHub மாதிரிகள் குறிக்கப் பெற்றது. GitHub மாதிரிகள் மோசடி செய்யப்பட்டுள்ளது (ஜூலை 2026 இல் முடிவடைகிறது), ஆகையால் இப்போது இது `FoundryChatClient` மூலம் **Microsoft Foundry** ஐப் பயன்படுத்துகிறது, இது Azure OpenAI **Responses API** ஐ குறிக்கிறது.
#
# ## 🎯 கற்றல் இலக்குகள்
#
# ### 🚀 **ஒரே நேரம் பல செயலாக்க அடிப்படைகள்**
# - **병렬 முகவர் செயல்பாடு**: அதிகபட்ச செயல்திறனைப் பெற பல முகவர்களை ஒரே நேரத்தில் இயக்கவும்
# - **வேலை ஓட்ட ஒழுங்கமைப்பு**: தரவு ஒருங்கிணைப்பை பேணிக்கொண்டு ஒரே நேரம் பல செயல்களை ஒருங்கிணைக்கவும்
# - **செயல்திறன் மேம்பாடு**: 병렬 செயலாக்க மூலமாக მნიშვნელოვான வேகத்தை அடையவும்
# - **வள மேலாண்மை**: ஒரே நேர செயல்பாட்டில் AI மாதிரி வளங்களை திறம்பட பயன்படுத்தவும்
#
# ### 🏗️ **மேம்பட்ட 병렬 கட்டமைப்புகள்**
# - **Fork-Join செயலாக்கம்**: பல முகவர்களுக்குள் பணி பிரித்து முடிவுகளை இணைக்கவும்
# - **பைப்லைன் 병렬ம்**: தொடர்ச்சியான செயல்திறனைக்காக நிறைய செயற்பாடுகளை ஒட்டிக்கொள்ளவும்
# - **சுமை சமநிலை**: கிடைக்கும் முகவர் வளங்களுக்குள் பணிகளை சமமாக பகிரவும்
# - **இணைதல் புள்ளிகள்**: முக்கிய வேலை ஓட்டு கட்டங்களில்ஒரே நேரத்தில் பல முகவர்களை ஒருங்கிணைக்கவும்
#
# ### 🏢 **தொழில்முறை 병렬 பயன்பாடுகள்**
# - **உயர் அளவிலான ஆவண செயலாக்கம்**: பல ஆவணங்களை ஒரே நேரத்தில் செயலாக்கவும்
# - **உடனடி உள்ளடக்க বিশ্লேசனை**: வருவாய் தரவுத் தொடர்களின் ஒரே நேரம் பல பகுப்பாய்வு
# - **தொகுப்பு செயலாக்க மேம்பாடு**: பெரிய அளவிலான செயல்களுக்கு அதிக செயல்திறன்
# - **பல-முறை பகுப்பாய்வு**: வெவ்வேறு உள்ளடக்க வகைகளின் 병렬 செயலாக்கம் (உரை, படங்கள், தரவு)
#
# ## ⚙️ தேவையானவை & அமைப்பு
#
# ### 📦 **தேவைப்படும் சார்பு நூலகங்கள்**
#
# ஒரே நேரம் பல வேலை ஓட்டக் கட்டமைப்பு திறன்களுடன் முகவர் கட்டமைப்பை நிறுவவும்:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry கட்டமைப்பு**
#
# அசுர கிளி (Azure CLI) மூலம் உள்நுழைக (`az login`), அப்புறம் `AzureCliCredential` மூலம் அங்கீகாரம் செய்யவும், பின்னர் Microsoft Foundry திட்ட விவரங்களை அமைக்கவும்.
#
# **சுற்றுச் சூழல் அமைப்பு (.env கோப்பு):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **ஒரே நேர 병렬 செயலாக்க பரிசீலனைகள்:**
# - **வீத வரம்புகள்**: ஒரே நேர கோரிக்கைகளுக்கான Azure OpenAI வீத வரம்புகளை கண்காணிக்கவும்
# - **வள பயன்பாடு**: பல முகவர்களுடன் நினைவக மற்றும் CPU பயன்பாட்டை கருத்தில் கொள்ளவும்
# - **பிழை கையாளல்**: 병렬 செயல்பாடுக்கான வலுவான பிழை மீட்டல் நடைமுறை அமுல்படுத்தவும்
#
# ### 🏗️ **ஒரே நேர வேலை ஓட்டு கட்டமைப்பு**
#
# ```mermaid
# graph TD
#     A[பணிப்புழக்கம் துவக்கம்] --> B[ஒரே நேரத்தில் செயற்பாடு]
#     B --> C[முகவர் குழு 1]
#     B --> D[முகவர் குழு 2]
#     B --> E[முகவர் குழு 3]
#     C --> F[முடிவு சேகரிப்பு]
#     D --> F
#     E --> F
#     F --> G[இறுதி வெளியீடு]
#
#     H[மைக்ரோசாஃப்ட் ஃபவுண்ட்ரி] --> C
#     H --> D
#     H --> E
# ```
#
# **முக்கிய நன்மைகள்:**
# - **⚡ செயல்திறன்**: 병렬 இயக்கம் மூலம் குறிப்பிடத்தக்க வேகமாய்த் தீஉ
# - **📈 விரிவாக்கம்**: அதிகப்படியான வேலைப்பளுவை நேரம் அதிகரிப்பு இல்லாமல் கையாளவும்
# - **🔄 திறமையான பயன்பாடு**: கிடைக்கும் கணினி வளங்களை சிறந்த முறையில் பயன்படுத்தவும்
# - **🎯 திறனை**: அதே நேரத்தில் அதிகமான பணிகளை செயலாக்கவும்
#
# ## 🎨 **ஒரே நேர வேலை ஓட்டு வடிவமைப்பு முறைமைகள்**
#
# ### 🔍 **கற்றல் மற்றும் பகுப்பாய்வு குழாய்**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **தரவு செயலாக்க வேலை ஓட்டு**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **உள்ளடக்க உருவாக்க குழாய்**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **பல கட்ட பொழுது செயலாக்கம்**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **தொழிற்துறை செயல்திறன் நன்மைகள்**
#
# ### ⚡ **திறன் மேம்பாடு**
# - **병렬 இயக்கம்**: பல முகவர்கள் ஒரே நேரத்தில் வேலை செய்யும்
# - **வள பயன்பாடு**: கிடைக்கும் AI மாதிரி திறன் அதிகரித்திருப்பதற்கான முழு திறன்
# - **நேரக் குறைப்பு**: மொத்த செயலாக்க நேரத்தை மிகவும் குறைப்பது
# - **விரிவாக்கக்கூடிய கட்டமைப்பு**: தேவையான அளவு முகவர்களை எளிதாக கூட்டி அமைக்க முடியும்
#
# ### 🛡️ **நம்பகத்தன்மை மற்றும் சகிப்புத்தன்மை**
# - **பிழை சகிப்புத்தன்மை**: ஒரு முகவர் துபாதை மொத்த வேலை ஓட்டை நிறுத்தாது
# - **பிழை தனிமைப்படுத்தல்**: ஒரே 병렬 கிளையில் பிரச்சினைகள் பிற கிளைகளுக்கு பாதிப்பை ஏற்படுத்தாது
# - **மென்மையான சிதைவு**: குறைந்த முகவர் திறனுடன் கூட அமைப்பு இயங்கத் தொடர்கிறது
# - **மீட்டல் முறைகள்**: தோல்வியுற்ற செயல்களுக்கு தானாக மீண்டும் முயற்சி மற்றும் பிழை கையாளல்
#
# ### 📊 **கண்காணிப்பு மற்றும் கண்டறிதல்**
# - **ஒரே நேர 병렬 செயல்பாட்டை கண்காணித்தல்**: அனைத்து 병렬 செயல்பாடுகளின் முன்னேற்றத்தை கண்காணிக்கவும்
# - **செயல்திறன் அளவுகள்**: வேகமான மற்றும் திறமையான முன்னேற்றத்தைக் கணக்கிடவும்
# - **வள பயன்பாட்டு பகுப்பாய்வு**: 병렬 முகவர் ஒதுக்கீட்டை மேம்படுத்தவும்
# - **கட்டுப்பாட்டுப் புள்ளி கண்டறிதல்**: செயல்திறன் தடைமுகங்களை கண்டுபிடித்து சரி செய்யவும்
#
# உயர் செயல்திறன் ஒரே நேர 병렬 AI வேலை ஓட்டங்களை கட்டி முயற்சிப்போம்! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
