# %% [markdown]
# # ⚡ Microsoft Foundry உடன் ஒரே நேரத்தில் ஏஜென்ட் வேலைப்பாடுகள் (Python)
#
# ## 📋 மேம்பட்ட ஒத்த செயலாக்க பட்டறை
#
# இந்த நோட்ட்புக் Microsoft Agent Framework பயன்படுத்தி **ஒரே நேரத்தில் செயலாக்க வேலைப்பாட்டு வடிவமைப்புகளை** வெளிப்படுத்துகிறது. பல AI ஏஜென்ட்கள் ஒரே நேரத்தில் செயல்படும் உயர்திறன், ஒத்த செயலாக்க வேலைப்பாடுகளை எப்படி உருவாக்குவது என்பதை நீங்கள் கற்றுக் கொள்வீர்கள், இது மிக முக்கியமான தொழில்முறை செயல்முறைகளை திறம்பட முன்னெடுக்க உதவுகிறது.
#
# > **பயண குறிப்பு:** இந்த மாதிரி முன்பு GitHub Models ஐ குறிப்பிடப்பட்டது. GitHub Models 2026 ஜூலைக்குப் பின் ஓய்வுபெற உள்ளது, ஆகவே இப்போது இது `FoundryChatClient` மூலம் **Microsoft Foundry** ஐப் பயன்படுத்துகிறது, இது Azure OpenAI **Responses API** க்கு இலக்கு.
#
# ## 🎯 கற்றல் இலக்குகள்
#
# ### 🚀 **ஒத்த செயலாக்க அடிப்படைகள்**
# - **ஒத்த ஏஜென்ட் நிறைவேற்றல்**: மிக அதிக திறன்மிக்கதற்கான பல ஏஜென்ட்களை ஒரே நேரத்தில் இயக்கவும்
# - **வேலைப்பாட்டு ஒருங்கிணைப்பு**: தரவுகளின் ஒத்திசையை வைத்திருக்கும் போது ஒரே நேரத்தில் செயல்பாட்டை ஒருங்கிணைக்கவும்
# - **முன்னேற்ற மேம்பாடு**: ஒத்த செயலாக்கத்தால் கணிசமான வேகத்தை அடையவும்
# - **வள மேலாண்மை**: ஒரே நேரத்தில் செயல்படும் செயல்பாடுகளில் AI மாதிரி வளங்களை திறம்பட பயன்படுத்தவும்
#
# ### 🏗️ **மேம்பட்ட ஒத்த செயலாக்க வடிவமைப்புகள்**
# - **Fork-Join செயலாக்கம்**: பல ஏஜென்ட்களுக்கு வேலை பிரித்து முடிவுகளை ஒருங்கிணைக்கவும்
# - **நாடகம் ஒத்த செயலாக்கம்**: தொடர்ந்து செயல்பாடு கொண்டு நிலையான வெளிப்பாட்டுக்கு அடுக்கு நிலைகளின் ஒருங்கிணைப்பு
# - **பரபரப்பு சமதளிப்பு**: கிடைக்கும் ஏஜென்ட் வளங்களில் சமமாக வேலைப்பங்கீடு செய்தல்
# - **இணைப்புக் נקைகள்**: முக்கிய வேலைப்பாடுகளின் நிலையிலே ஒரே நேரத்தில் செயல்படும் ஏஜென்ட்களை ஒருங்கிணைக்கவும்
#
# ### 🏢 **பெருங் கம்பெனி ஒரே நேர செயல்பாடுகள்**
# - **அதிதாகப்பு ஆவண செயலாக்கம்**: பல ஆவணங்களை சமநிலையோடு செயலாக்குதல்
# - **உடனடி உள்ளடக்க பகுப்பாய்வு**: வரும் தரவுத்தொடர்களின் ஒரே நேர பகுப்பாய்வு
# - **குழு செயலாக்க மேம்பாடு**: பெரிய அளவிலான செயல்பாடுகளுக்கான அதிகப்படியாக வெளியீடு
# - **பல வடிவ பகுப்பாய்வு**: வேறுபட்ட உள்ளடக்க வகைகளை (எழுத்து, படங்கள், தரவு) ஒரே நேரம் செயலாக்குதல்
#
# ## ⚙️ தேவைகளும் அமைப்பும்
#
# ### 📦 **தேவைப்படும் சார்புகள்**
#
# ஒரே நேரத்தில் வேலைபாடுகளை ஆதரிக்கும் Agent Framework ஐ நிறுவவும்:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry அமைப்பு**
#
# Az CLI (`az login`) மூலம் உள்நுழையவும், அதனால் `AzureCliCredential` அங்கீகரிக்க முடியும், பின்னர் உங்கள் Microsoft Foundry திட்ட விவரங்களை அமைக்கவும்.
#
# **சூழல் அமைப்பு (.env கோப்பு):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **ஒரே நேர செயலாக்க கவனிப்புக்குறிகள்:**
# - **அளவுகோல் வரம்புகள்**: ஒரே நேர கோரிக்கைகளுக்கான Azure OpenAI அளவுகோல் வரம்புகளை கண்காணிக்கவும்
# - **வள பயன்பாடு**: பல ஏஜென்ட்களின் நினைவக மற்றும் CPU பயன்பாட்டை கணக்கில் எடுக்கவும்
# - **பிழை கையாளல்**: ஒத்த செயல்பாடுகளுக்கான வலுவான பிழை மீள்வு செயல்முறையை நடைமுறைப்படுத்தவும்
#
# ### 🏗️ **ஒத்த வேலைப்பாட்டு கட்டமைப்பு**
#
# ```mermaid
# graph TD
#     A[வேலைப்ப جریان தொடக்கம்] --> B[ஒரே நேரத்தில் செயல்]
#     B --> C[முகவர் குளம் 1]
#     B --> D[முகவர் குளம் 2]
#     B --> E[முகவர் குளம் 3]
#     C --> F[முடிவு சுகமயக்கல்]
#     D --> F
#     E --> F
#     F --> G[இறுதி வெளியீடு]
#
#     H[மைக்ரோசாஃப்ட் ஃபௌண்ட்ரி] --> C
#     H --> D
#     H --> E
# ```
#
# **முக்கிய நன்மைகள்:**
# - **⚡ திறன்**: ஒத்த நிறைவேற்றத்தால் கணிசமான வேக உயர்வு
# - **📈 விருத்தி**: அதிக வேலைப்பளுவையும் நேரத்தை சம்பந்தப்படுத்தாமல் கையாளவும்
# - **🔄 திறன்**: கிடைக்கும் கணினி வளங்களை சிறந்த முறையில் பயன்படுத்துதல்
# - **🎯 வெளிப்பாடு**: ஒரே நேரத்தில் மேலும் வேலை செய்ய முடியும்
#
# ## 🎨 **ஒத்த வேலைப்பாட்டு வடிவமைப்பு முறைகள்**
#
# ### 🔍 **ஆராய்ச்சி மற்றும் பகுப்பாய்வு நாடகம்**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **தரவு செயலாக்க வேலைப்பாடு**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **உள்ளடக்க உருவாக்க நாடகம்**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **பன்மடி செயலாக்கம்**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **பெருங் கம்பெனி திறன் நன்மைகள்**
#
# ### ⚡ **வெளிப்பாடு மேம்பாடு**
# - **ஒத்த நிறைவேற்றம்**: பல ஏஜென்ட் ஒரே நேரத்தில் வேலை செய்கிறார்கள்
# - **வள பயன்பாடு**: கிடைக்கும் AI மாதிரி திறனின் உச்சபட்ச திறன்
# - **நேரக் குறைப்பு**: மொத்த செயலாக்க நேரத்தில் கணிசமான குறைப்பு
# - **விருத்திசொதுக்கும் கட்டமைப்பு**: தேவையான அளவுக்கு மேலும் ஒத்த ஏஜென்டுகளை எளிதில் சேர்க்க முடியும்
#
# ### 🛡️ **நம்பகத்தன்மை மற்றும் வடிகட்டல் உறுதி**
# - **தோல்வி பொறுத்த தன்மை**: தனிப்பட்ட ஏஜென்ட் தோல்விகள் முழு வேலைப்பாட்டை நிறுத்தாது
# - **பிழை தீவ்ர தன்மை**: ஒரே நேர கிளைவிலுள்ள பிரச்சினைகள் மற்ற கிளைகளுக்கு பாதிப்பை ஏற்படுத்தாது
# - **மெல்லிய குறைப்பு**: குறைந்த ஏஜென்ட் திறனுடனும் அமைப்பு செயல்படத் தொடர்கிறது
# - **மீட்பு செயல்முறைகள்**: தவறிய செயல்களுக்கு தானாக மீண்டும் முயற்சி மற்றும் பிழை கையாளல்
#
# ### 📊 **கண்காணிப்பு மற்றும் பார்வையாள்தன்மை**
# - **ஒத்த நிறைவேற்றம் கண்காணிப்பு**: அனைத்து ஒத்த செயல்பாடுகளின் முன்னேற்றத்தை கண்காணிக்கவும்
# - **திறன் அளவுகோல்கள்**: வேக உயர்ச்சி மற்றும் திறன் வளர்ச்சியை அளவிடவும்
# - **வள பயன்பாடு பகுப்பாய்வு**: ஒத்த ஏஜென்ட் ஒதுக்கீட்டை மேம்படுத்தவும்
# - **கழுசுச் சிக்கல் கண்டுபிடிப்பு**: திறன் குறைபாடுகளை கண்டுபிடித்து சரிசெய்யவும்
#
# நம்முடன் சேர்ந்து உயர்திறன் ஒரே நேர AI வேலைப்பாடுகளை உருவாக்கலாம்! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
