# %% [markdown]
# # 🔄 Microsoft Foundry உடன் அடிப்படை முகவர் பணியமைப்புகள் (Python)
#
# ## 📋 பணியமைப்பு ஒருங்கிணைப்பு கற்றல் கையேடு
#
# இந்த நோட்புக் Microsoft முகவர் கட்டமைப்பின் சக்திவாய்ந்த **பணியமைப்பு உருவாக்கி** திறன்களை அறிமுகப்படுத்துகிறது. சிக்கலான வணிக செயல்முறைகளை கையாளும் மற்றும் பல AI செயல்பாடுகளை ஒன்றாக ஒருங்கிணைக்கும் நுட்பமான, பல-அடி முகவர் பணியமைப்புகளை உருவாக்குவது எப்படி என்பதை கற்றுக்கொள்ளுங்கள்.
#
# > **பெரிவரிசை குறிப்பு:** இந்த மாதிரி முந்தைய காலத்தில் GitHub மாதிரிகளை குறிப்பிடுகிறது. GitHub மாதிரிகள் குறைபாடு (2026 ஜூலைக்கு ஓய்வு), ஆகையால் இது இப்போது `FoundryChatClient` மூலமாக **Microsoft Foundry** ஐப் பயன்படுத்துகிறது, இது Azure OpenAI **Responses API** இலக்காகக் கொண்டுள்ளது.
#
# ## 🎯 கற்றல் நோக்கங்கள்
#
# ### 🏗️ **பணியமைப்பு தரவமைப்பு**
# - **பணியமைப்பு உருவாக்கி**: கடினமான பல-அடி செயல்முறைகளை வடிவமைத்து ஒருங்கிணைத்தல்
# - **நிகழ்வு வழிநடத்தப்பட்ட செயல்பாடு**: பணியமைப்பு நிகழ்வுகள் மற்றும் நிலை மாறுதல்களை கையாளுதல்
# - **காட்சிப்படுத்தும் பணியமைப்பு வடிவமைப்பு**: பணியமைப்பு கட்டமைப்புகளை உருவாக்கி காட்சிப்படுத்தல்
# - **Microsoft Foundry ஒருங்கிணைப்பு**: பணியமைப்பு சூழல்களில் AI மாதிரிகளை பயன்படுத்துதல்
#
# ### 🔄 **செயல்முறை ஒருங்கிணைப்பு**
# - **வரிசைப்படுத்தப்பட்ட செயல்பாடுகள்**: பல முகவர் பணிகளை தர்க்கபூர்வமான முறையில் இணைத்தல்
# - **நிபந்தனை உயிருக்குத் தீர்மானம்**: முடிவெடுக்கும் இடங்கள் மற்றும் கிளை பயணங்கள் செயல்படுத்தல்
# - **பிழை கையாளுதல்**: வலுவான பிழை மீட்பு மற்றும் பணியமைப்பு சோர்வுக்கு எதிர்ப்பு
# - **நிலை மேலாண்மை**: பணியமைப்பு செயல்பாட்டின் நிலையை கண்காணித்து நிர்வகித்தல்
#
# ### 📊 **என்டர்்பிரைஸ் பணியமைப்பு மாதிரிகள்**
# - **வணிக செயல்முறை தானியங்கி**: சிக்கலான நிறுவனர் பணியமைப்புகளை தானியக்கம்செய்தல்
# - **பல முகவர் ஒருங்கினைப்பு**: பல சிறப்பு முகவர்களை ஒருங்கிணைத்தல்
# - **பரவலான செயல்பாடு**: நிறுவன அளவிலான செயல்பாடுகளுக்கான பணியமைப்புகளை வடிவமைத்தல்
# - **கண்காணிப்பு மற்றும் பார்வையிடும் திறன்**: பணியமைப்பு செயல்திறன் மற்றும் முடிவுகளை கண்காணித்தல்
#
# ## ⚙️ முன் தேவைகள் & அமைப்பு
#
# ### 📦 **தேவையான சார்புகள்**
#
# பணியமைப்பு திறன்களுடன் முகவர் கட்டமைப்பை நிறுவுக:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry அமைப்பு**
#
# Azure CLI (`az login`) மூலம் உள்நுழைந்து `AzureCliCredential` அங்கீகாரம் பெறுவதற்குப் பிறகு, உங்கள் Microsoft Foundry திட்ட விவரங்களை அமைக்கவும்.
#
# **சூழல் அமைப்பு (.env கோப்பு):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# ### 🏢 **என்டர்்பிரைஸ் பயன்பாடுகள்**
#
# **வணிக செயல்முறை உதாரணங்கள்:**
# - **வாடிக்கையாளர் பதிவு**: பல-அடி சரிபார்ப்பு மற்றும் அமைப்பு பணியமைப்புகள்
# - **உள்ளடக்கு குழாய்**: தானியங்கி உள்ளடக்கம் உருவாக்கல், பரிசீலனை மற்றும் வெளியீடு
# - **தரவு செயலாக்கம்**: AI மூலம் சக்திவாய்ந்த மாற்றத்துடன் ETL பணியமைப்புகள்
# - **தர உறுதி**: தானியங்கிய சோதனை மற்றும் சரிபார்ப்பு செயல்முறைகள்
#
# **பணியமைப்பு நன்மைகள்:**
# - 🎯 **நம்பகத்தன்மை**: பிழை மீட்பு உடன் தீர்மானாதிகமாக செயல்பாடு
# - 📈 **பரவல்**: அதிக அளவிலான செயல்முறை தானியக்கத்தைக் கையாளுதல்
# - 🔍 **பார்வையிடுதல்**: முழுமையான கணக்குப் பதிவு மற்றும் கண்காணிப்பு
# - 🔧 **பராமரிப்பிற்கான எளிதாக்கல்**: காட்சிப்படுத்தும் வடிவமைப்பு மற்றும் தொகுதி கூறுகள்
#
# ## 🎨 பணியமைப்பு வடிவமைப்பு மாதிரிகள்
#
# ### அடிப்படை பணியமைப்பு கட்டமைப்பு
# ```mermaid
# graph TD
#     A[தொடக்கம்] --> B[முகவர் பணிகள் 1]
#     B --> C{முடிவு புள்ளி}
#     C -->|வெற்றி| D[முகவர் பணிகள் 2]
#     C -->|தோல்வி| E[பிழை கையாளுகிறவர்]
#     D --> F[முடிவு]
#     E --> F
# ```
#
# **முக்கிய கூறுகள்:**
# - **WorkflowBuilder**: முக்கிய ஒருங்கிணைப்பு இயந்திரம்
# - **WorkflowEvent**: நிகழ்வு கையாளுதல் மற்றும் தொடர்பு
# - **WorkflowViz**: காட்சிப்படுத்தும் பணியமைப்பின் பிரதிபலிப்பு மற்றும் பிழையறிதல்
#
# உங்கள் முதல் அறிவார்ந்த பணியமைப்பை கட்டுவோம்! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load Microsoft Foundry project settings from .env file
load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = provider.as_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = provider.as_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
