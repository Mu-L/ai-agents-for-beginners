# %% [markdown]
# # ⚡ Egyidejű Agent Munkafolyamatok a Microsoft Foundry-vel (Python)
#
# ## 📋 Haladó Párhuzamos Feldolgozás Bemutató
#
# Ez a jegyzetfüzet **egyidejű munkafolyamat mintákat** mutat be a Microsoft Agent Framework segítségével. Megtanulhatod, hogyan építs magas teljesítményű, párhuzamos feldolgozású munkafolyamatokat, ahol több MI agent egyszerre fut, jelentősen javítva az áteresztőképességet és lehetővé téve kifinomult, több szálon futó üzleti folyamatokat.
#
# > **Átállási megjegyzés:** Ez a minta korábban GitHub Models-t használt. A GitHub Models elavult (2026 júliusában megszűnik), ezért most a `FoundryChatClient`-en keresztül **Microsoft Foundry**-t használ, amely az Azure OpenAI **Responses API**-ra céloz.
#
# ## 🎯 Tanulási Célok
#
# ### 🚀 **Egyidejű Feldolgozás Alapjai**
# - **Párhuzamos Agent Végrehajtás**: Több agent egyidejű futtatása a maximális hatékonyság érdekében
# - **Munkafolyamat Orkesztráció**: Egyidejű műveletek koordinálása az adatok konzisztenciájának megőrzése mellett
# - **Teljesítmény Optimalizálás**: Jelentős gyorsulás elérése párhuzamos feldolgozással
# - **Erőforrás Kezelés**: AI modell erőforrások hatékony kihasználása egyidejű műveletek során
#
# ### 🏗️ **Haladó Egyidejűségi Minták**
# - **Fork-Join Feldolgozás**: Munka szétosztása több agent között és eredmények egyesítése
# - **Pipeline Párhuzamosság**: Egymást átfedő végrehajtási szakaszok a folyamatos áteresztőképességért
# - **Terheléselosztás**: Munka egyenletes szétosztása az elérhető agent erőforrások között
# - **Szinkronizációs Pontok**: Egyidejű ügynökök koordinálása kritikus munkafolyamat lépéseknél
#
# ### 🏢 **Vállalati Egyidejű Alkalmazások**
# - **Nagy volumenű dokumentumfeldolgozás**: Több dokumentum egyidejű feldolgozása
# - **Valós idejű tartalomelemzés**: Bejövő adatfolyamok egyidejű elemzése
# - **Köteges feldolgozás optimalizálás**: Nagyszabású műveletek áteresztőképességének maximalizálása
# - **Többmodális elemzés**: Különböző tartalomtípusok párhuzamos feldolgozása (szöveg, képek, adatok)
#
# ## ⚙️ Előfeltételek & Beállítás
#
# ### 📦 **Szükséges Függőségek**
#
# Telepítsd az Agent Framework-öt egyidejű munkafolyamat képességekkel:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Konfiguráció**
#
# Jelentkezz be az Azure CLI-vel (`az login`), hogy az `AzureCliCredential` hitelesíteni tudjon, majd állítsd be a Microsoft Foundry projekt részleteit.
#
# **Környezeti beállítás (.env fájl):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Egyidejű feldolgozási megfontolások:**
# - **Korlátozások ellenőrzése**: Figyeld az Azure OpenAI kérések korlátozásait egyidejű hívások esetén
# - **Erőforrás használat**: Vedd figyelembe a memória és CPU használatot több agent esetén
# - **Hibakezelés**: Erős hibakezelő megoldás párhuzamos műveletekhez
#
# ### 🏗️ **Egyidejű Munkafolyamat Architektúra**
#
# ```mermaid
# graph TD
#     A[Munkafolyamat Indítása] --> B[Párhuzamos Végrehajtás]
#     B --> C[Ügynöki Csoport 1]
#     B --> D[Ügynöki Csoport 2]
#     B --> E[Ügynöki Csoport 3]
#     C --> F[Eredmény Összegzés]
#     D --> F
#     E --> F
#     F --> G[Végső Kimenet]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Fő előnyök:**
# - **⚡ Teljesítmény**: Jelentős gyorsulás párhuzamos végrehajtással
# - **📈 Skálázhatóság**: Növekvő terhelés kezelése arányos időnövekedés nélkül
# - **🔄 Hatékonyság**: Jobb kihasználása a rendelkezésre álló számítási erőforrásoknak
# - **🎯 Áteresztőképesség**: Több munka feldolgozása ugyanannyi idő alatt
#
# ## 🎨 **Egyidejű Munkafolyamat Tervezési Minták**
#
# ### 🔍 **Kutatás & Elemzés Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Adatfeldolgozó Munkafolyamat**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Tartalomkészítő Pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Többfázisú Feldolgozás**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Vállalati Teljesítmény Előnyök**
#
# ### ⚡ **Áteresztőképesség Optimalizálás**
# - **Párhuzamos Végrehajtás**: Több agent dolgozik egyszerre
# - **Erőforrás Kihasználás**: Az elérhető MI modell kapacitás maximális kihasználása
# - **Időcsökkentés**: Jelentős csökkenés a teljes feldolgozási időben
# - **Skálázható Architektúra**: Szükség szerint további egyidejű agentek hozzáadása egyszerű
#
# ### 🛡️ **Megbízhatóság & Ellenállóképesség**
# - **Hibatűrés**: Egy agent hibája nem állítja le az egész munkafolyamatot
# - **Hiba Izoláció**: Egy egyidejű ág problémái nem befolyásolják a többit
# - **Gondos Lemorzsolódás**: A rendszer tovább működik még csökkent agent kapacitás mellett is
# - **Helyreállítási Mechanizmusok**: Automatikus újrapróbálkozás és hibakezelés sikertelen műveletek esetén
#
# ### 📊 **Monitoring & Megfigyelhetőség**
# - **Egyidejű Végrehajtás Követése**: Minden párhuzamos művelet előrehaladásának figyelése
# - **Teljesítménymutatók**: Gyorsulás és hatékonyság mérése
# - **Erőforrás Használat Analitika**: Egyidejű agent allokáció optimalizálása
# - **Szűk keresztmetszet azonosítás**: Teljesítménykorlátok felkutatása és megoldása
#
# Építsünk magas teljesítményű egyidejű MI munkafolyamatokat! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Jogi nyilatkozat**:
# Ez a dokumentum az AI fordítási szolgáltatás, a [Co-op Translator](https://github.com/Azure/co-op-translator) segítségével készült. Bár az pontosságra törekszünk, kérjük, vegye figyelembe, hogy az automatikus fordítások hibákat vagy pontatlanságokat tartalmazhatnak. Az eredeti dokumentum az anyanyelvén tekintendő hiteles forrásnak. Fontos információk esetén professzionális emberi fordítást javasolunk. Nem vállalunk felelősséget semmilyen félreértésért vagy téves értelmezésért, amely ebből a fordításból ered.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
