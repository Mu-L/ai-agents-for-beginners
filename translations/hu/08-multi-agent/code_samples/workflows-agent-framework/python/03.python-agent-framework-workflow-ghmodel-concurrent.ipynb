# %% [markdown]
# # ⚡ Párhuzamosügynök-munkafolyamatok a Microsoft Foundry-val (Python)
#
# ## 📋 Fejlett párhuzamos feldolgozási útmutató
#
# Ez a jegyzetfüzet bemutatja a **párhuzamos munkafolyamat mintákat** a Microsoft Agent Framework segítségével. Megtanulod, hogyan építs nagy teljesítményű, párhuzamos feldolgozó munkafolyamatokat, ahol több MI-ügynök egyszerre hajtódik végre, jelentősen javítva a feldolgozási kapacitást és lehetővé téve összetett, több szálú üzleti folyamatokat.
#
# > **Átállási megjegyzés:** Ez a minta korábban a GitHub Models-t használta. A GitHub Models elavult (2026 júliusában megszűnik), így most a **Microsoft Foundry**-t használja a `FoundryChatClient` segítségével, amely az Azure OpenAI **Responses API**-ra céloz.
#
# ## 🎯 Tanulási célok
#
# ### 🚀 **Párhuzamos feldolgozás alapjai**
# - **Ügynökök párhuzamos futtatása**: Több ügynök egyszerre futtatása a maximális hatékonyság érdekében
# - **Munkafolyamat-üzemeltetés**: Párhuzamos műveletek koordinálása az adatok konzisztenciájának megőrzése mellett
# - **Teljesítmény-optimalizálás**: Jelentős gyorsulás párhuzamos feldolgozás révén
# - **Erőforrás-kezelés**: Az MI modell erőforrásainak hatékony kihasználása párhuzamos műveletek között
#
# ### 🏗️ **Fejlett párhuzamossági minták**
# - **Fork-Join feldolgozás**: Munka megosztása több ügynök között és eredmények összevonása
# - **Csővezeték párhuzamosság**: Átfedő végrehajtási szakaszok folyamatos átbocsátásért
# - **Terheléskiegyenlítés**: Munkamegosztás egyenletesen az elérhető ügynök-erőforrások között
# - **Szinkronizációs pontok**: Párhuzamos ügynökök koordinálása kritikus munkafolyamat-szakaszokban
#
# ### 🏢 **Vállalati párhuzamos alkalmazások**
# - **Nagy volumenű dokumentumfeldolgozás**: Több dokumentum egyidejű feldolgozása
# - **Valós idejű tartalomelemzés**: Egyidejű bejövő adatfolyamok elemzése
# - **Kötegelt feldolgozás optimalizálása**: Nagy léptékű műveletek maximális átbocsátása
# - **Multi-módusú elemzés**: Különböző tartalomtípusok (szöveg, képek, adatok) párhuzamos feldolgozása
#
# ## ⚙️ Előfeltételek és beállítás
#
# ### 📦 **Szükséges függőségek**
#
# Telepítsd az Agent Frameworköt párhuzamos munkafolyamat-képességekkel:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry konfiguráció**
#
# Jelentkezz be az Azure CLI-vel (`az login`), hogy az `AzureCliCredential` hitelesíthessen, majd állítsd be Microsoft Foundry projektadataidat.
#
# **Környezeti beállítás (.env fájl):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Párhuzamos feldolgozási megfontolások:**
# - **Hívási limitációk**: Kövesd nyomon az Azure OpenAI párhuzamos kéréskorlátait
# - **Erőforrás-kihasználás**: Vedd figyelembe a memória- és CPU-használatot több párhuzamos ügynök esetén
# - **Hibakezelés**: Erős hibakezelési mechanizmusokat építs a párhuzamos műveletekhez
#
# ### 🏗️ **Párhuzamos munkafolyamat-architektúra**
#
# ```mermaid
# graph TD
#     A[Munkafolyamat kezdete] --> B[Párhuzamos végrehajtás]
#     B --> C[Ügynök csoport 1]
#     B --> D[Ügynök csoport 2]
#     B --> E[Ügynök csoport 3]
#     C --> F[Eredmények összesítése]
#     D --> F
#     E --> F
#     F --> G[Végső kimenet]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Fő előnyök:**
# - **⚡ Teljesítmény**: Jelentős gyorsulás párhuzamos végrehajtással
# - **📈 Skálázhatóság**: Növekvő munkaterhelés kezelése arányos időnövekedés nélkül
# - **🔄 Hatékonyság**: Az elérhető számítási erőforrások jobb kihasználása
# - **🎯 Átbocsátás**: Több feladat feldolgozása ugyanannyi idő alatt
#
# ## 🎨 **Párhuzamos munkafolyamat tervezési minták**
#
# ### 🔍 **Kutatási és elemzési csővezeték**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Adatfeldolgozó munkafolyamat**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Tartalomkészítő csővezeték**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Többszakaszos feldolgozás**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Vállalati teljesítményelőnyök**
#
# ### ⚡ **Átbocsátás optimalizálás**
# - **Párhuzamos végrehajtás**: Több ügynök egyszerre dolgozik
# - **Erőforrás-kihasználás**: Az elérhető MI modellkapacitás maximális hatékonysága
# - **Időcsökkentés**: Jelentős csökkenés az összes feldolgozási időben
# - **Skálázható architektúra**: Igény szerint könnyen bővíthető párhuzamos ügynökökkel
#
# ### 🛡️ **Megbízhatóság és ellenállóképesség**
# - **Hibatűrés**: Egyes ügynökök hibája nem állítja meg az egész munkafolyamatot
# - **Hibaizoláció**: Egy párhuzamos ágon fellépő problémák nem hatnak a többi ágra
# - **Elegáns degradáció**: A rendszer tovább működik csökkentett ügynökkapacitással is
# - **Helyreállítási mechanizmusok**: Automatikus újrapróbálkozás és hibakezelés sikertelen műveleteknél
#
# ### 📊 **Megfigyelés és észlelhetőség**
# - **Párhuzamos végrehajtás követése**: Az összes párhuzamos művelet nyomon követése
# - **Teljesítménymutatók**: Gyorsulás és hatékonyságnövekedés mérése
# - **Erőforrás-használat elemzése**: Párhuzamos ügynökök kiosztásának optimalizálása
# - **Szűk keresztmetszetek azonosítása**: Teljesítménykorlátozások feltárása és megoldása
#
# Építsünk nagy teljesítményű párhuzamos MI munkafolyamatokat! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Jogi nyilatkozat**:
# Ez a dokumentum az AI fordítási szolgáltatás, a [Co-op Translator](https://github.com/Azure/co-op-translator) segítségével készült. Bár az pontosságra törekszünk, kérjük, vegye figyelembe, hogy az automatikus fordítások hibákat vagy pontatlanságokat tartalmazhatnak. Az eredeti dokumentum az anyanyelvén tekintendő hiteles forrásnak. Fontos információk esetén professzionális emberi fordítást javasolunk. Nem vállalunk felelősséget semmilyen félreértésért vagy téves értelmezésért, amely ebből a fordításból ered.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
