# %% [markdown]
# # ⚡ เวิร์กโฟลว์เอเยนต์พร้อมกันกับ Microsoft Foundry (Python)
#
# ## 📋 บทเรียนประมวลผลแบบขนานขั้นสูง
#
# โน้ตบุ๊กนี้สาธิต **รูปแบบเวิร์กโฟลว์พร้อมกัน** โดยใช้ Microsoft Agent Framework คุณจะได้เรียนรู้วิธีสร้างเวิร์กโฟลว์การประมวลผลแบบขนานที่มีประสิทธิภาพสูง ซึ่งเอเยนต์ AI หลายตัวทำงานพร้อมกัน ช่วยเพิ่มประสิทธิภาพอย่างมากและสนับสนุนกระบวนการทางธุรกิจแบบมัลติเทรดที่ซับซ้อน
#
# > **หมายเหตุการย้ายข้อมูล:** ตัวอย่างนี้เคยอ้างอิง GitHub Models GitHub Models ถูกเลิกใช้แล้ว (จะหยุดบริการในกรกฎาคม 2026) ดังนั้นตอนนี้จึงใช้ **Microsoft Foundry** ผ่าน `FoundryChatClient` ซึ่งมุ่งเป้าไปที่ Azure OpenAI **Responses API**
#
# ## 🎯 เป้าหมายการเรียนรู้
#
# ### 🚀 **พื้นฐานการประมวลผลพร้อมกัน**
# - **การเรียกใช้เอเยนต์แบบขนาน**: รันเอเยนต์หลายตัวพร้อมกันเพื่อประสิทธิภาพสูงสุด
# - **การประสานงานเวิร์กโฟลว์**: ประสานงานการทำงานพร้อมกันพร้อมรักษาความสอดคล้องของข้อมูล
# - **การเพิ่มประสิทธิภาพการทำงาน**: เร่งความเร็วอย่างมีนัยสำคัญผ่านการประมวลผลแบบขนาน
# - **การจัดการทรัพยากร**: ใช้ทรัพยากรโมเดล AI อย่างมีประสิทธิภาพในงานพร้อมกัน
#
# ### 🏗️ **รูปแบบความพร้อมกันขั้นสูง**
# - **การประมวลผลแบบ Fork-Join**: แบ่งงานระหว่างเอเยนต์หลายตัวและรวมผลลัพธ์
# - **การประมวลผลแบบ Pipeline**: ขั้นตอนการดำเนินการทับซ้อนกันเพื่อความต่อเนื่อง
# - **การกระจายโหลด**: กระจายงานอย่างสมดุลในทรัพยากรเอเยนต์ที่มี
# - **จุดซิงโครไนซ์**: ประสานงานเอเยนต์พร้อมกันในขั้นตอนสำคัญของเวิร์กโฟลว์
#
# ### 🏢 **แอปพลิเคชันพร้อมกันสำหรับองค์กร**
# - **การประมวลผลเอกสารปริมาณมาก**: ประมวลผลเอกสารหลายชิ้นพร้อมกัน
# - **การวิเคราะห์เนื้อหาแบบเรียลไทม์**: วิเคราะห์ข้อมูลที่เข้ามาแบบพร้อมกัน
# - **การเพิ่มประสิทธิภาพการประมวลผลแบบแบตช์**: เพิ่มขีดความสามารถสำหรับงานขนาดใหญ่
# - **การวิเคราะห์มัลติโมดอล**: ประมวลผลแบบขนานของเนื้อหาหลากหลายประเภท (ข้อความ, รูปภาพ, ข้อมูล)
#
# ## ⚙️ สิ่งที่ต้องมี & การตั้งค่า
#
# ### 📦 **ไลบรารีที่จำเป็น**
#
# ติดตั้ง Agent Framework ที่รองรับเวิร์กโฟลว์แบบพร้อมกัน:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **การกำหนดค่า Microsoft Foundry**
#
# ลงชื่อเข้าใช้ด้วย Azure CLI (`az login`) เพื่อให้ `AzureCliCredential` ทำการยืนยันตัวตน จากนั้นตั้งค่ารายละเอียดโปรเจ็กต์ Microsoft Foundry ของคุณ
#
# **การตั้งค่าสภาพแวดล้อม (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **ข้อควรพิจารณาการประมวลผลพร้อมกัน:**
# - **ขีดจำกัดอัตรา**: ตรวจสอบขีดจำกัดอัตราของ Azure OpenAI สำหรับคำขอพร้อมกัน
# - **การใช้งานทรัพยากร**: พิจารณาการใช้หน่วยความจำและ CPU กับเอเยนต์พร้อมกันหลายตัว
# - **การจัดการข้อผิดพลาด**: นำระบบกู้คืนข้อผิดพลาดที่มีความทนทานสำหรับการดำเนินงานแบบขนาน
#
# ### 🏗️ **สถาปัตยกรรมเวิร์กโฟลว์พร้อมกัน**
#
# ```mermaid
# graph TD
#     A[เริ่มต้นเวิร์กโฟลว์] --> B[การดำเนินการพร้อมกัน]
#     B --> C[กลุ่มตัวแทน 1]
#     B --> D[กลุ่มตัวแทน 2]
#     B --> E[กลุ่มตัวแทน 3]
#     C --> F[การรวบรวมผลลัพธ์]
#     D --> F
#     E --> F
#     F --> G[ผลลัพธ์ขั้นสุดท้าย]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **ประโยชน์สำคัญ:**
# - **⚡ ประสิทธิภาพ**: เร่งความเร็วอย่างมีนัยสำคัญผ่านการประมวลผลพร้อมกัน
# - **📈 ความสามารถในการปรับขนาด**: รองรับภาระงานที่เพิ่มขึ้นโดยไม่เพิ่มเวลาสัดส่วน
# - **🔄 ประสิทธิผล**: ใช้ทรัพยากรคำนวณที่มีอยู่อย่างเต็มที่
# - **🎯 ขีดความสามารถการประมวลผล**: ประมวลผลงานได้มากขึ้นในเวลาที่เท่าเดิม
#
# ## 🎨 **รูปแบบการออกแบบเวิร์กโฟลว์พร้อมกัน**
#
# ### 🔍 **สายงานวิจัยและวิเคราะห์**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **เวิร์กโฟลว์ประมวลผลข้อมูล**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **สายงานสร้างสรรค์เนื้อหา**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **การประมวลผลหลายขั้นตอน**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ประโยชน์ด้านประสิทธิภาพสำหรับองค์กร**
#
# ### ⚡ **การเพิ่มประสิทธิภาพขีดความสามารถ**
# - **การทำงานพร้อมกันแบบขนาน**: เอเยนต์หลายตัวทำงานพร้อมกัน
# - **การใช้ทรัพยากร**: ใช้ความจุโมเดล AI ที่มีอย่างมีประสิทธิภาพสูงสุด
# - **การลดเวลา**: ลดเวลาการประมวลผลโดยรวมอย่างมาก
# - **สถาปัตยกรรมที่สามารถขยายได้**: เพิ่มเอเยนต์พร้อมกันได้ง่ายตามต้องการ
#
# ### 🛡️ **ความน่าเชื่อถือ & ความทนทาน**
# - **ความทนทานต่อความผิดพลาด**: ความล้มเหลวของเอเยนต์แต่ละตัวไม่หยุดเวิร์กโฟลว์ทั้งหมด
# - **การแยกข้อผิดพลาด**: ปัญหาในสาขาพร้อมกันหนึ่งสาขาจะไม่ส่งผลกระทบสาขาอื่น
# - **การลดทอนอย่างนุ่มนวล**: ระบบยังทำงานต่อได้แม้เอเยนต์มีความจุลดลง
# - **กลไกการกู้คืน**: การลองใหม่อัตโนมัติและการจัดการข้อผิดพลาดสำหรับงานที่ล้มเหลว
#
# ### 📊 **การตรวจสอบ & การสังเกตการณ์**
# - **การติดตามการทำงานพร้อมกัน**: ตรวจสอบความคืบหน้าของกระบวนการแบบขนานทั้งหมด
# - **เมตริกประสิทธิภาพ**: วัดการเร่งความเร็วและการเพิ่มประสิทธิภาพ
# - **การวิเคราะห์การใช้ทรัพยากร**: ปรับจ่ายเอเยนต์พร้อมกันอย่างเหมาะสม
# - **การระบุคอขวด**: ค้นพบและแก้ไขข้อจำกัดการทำงาน
#
# มาสร้างเวิร์กโฟลว์ AI พร้อมกันที่มีประสิทธิภาพสูงกันเถอะ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ปฏิเสธความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) ขณะที่เราพยายามให้ความถูกต้อง โปรดทราบว่าการแปลโดยอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาต้นทางควรถูกพิจารณาเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ แนะนำให้ใช้การแปลโดยมนุษย์มืออาชีพ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความที่ผิดพลาดที่เกิดขึ้นจากการใช้การแปลนี้
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
