# %% [markdown]
# # ⚡ กระบวนการทำงานของ Agent แบบพร้อมกันด้วย Microsoft Foundry (Python)
#
# ## 📋 บทเรียนการประมวลผลแบบขนานขั้นสูง
#
# สมุดบันทึกนี้สาธิต **รูปแบบการทำงานพร้อมกัน** โดยใช้ Microsoft Agent Framework คุณจะได้เรียนรู้วิธีสร้างกระบวนการทำงานที่มีประสิทธิภาพสูง แบบประมวลผลขนานที่หลายเอเย่นต์ AI ทำงานพร้อมกัน ซึ่งช่วยเพิ่มประสิทธิภาพอย่างมากและรองรับกระบวนการทางธุรกิจที่ซับซ้อนแบบมัลติ-เธรด
#
# > **หมายเหตุการย้ายข้อมูล:** ตัวอย่างนี้เคยอ้างอิงถึง GitHub Models ซึ่ง GitHub Models ถูกเลิกใช้งาน (สิ้นสุดในเดือนกรกฎาคม 2026) ดังนั้นจึงใช้ **Microsoft Foundry** ผ่าน `FoundryChatClient` ซึ่งใช้งาน Azure OpenAI **Responses API**
#
# ## 🎯 วัตถุประสงค์การเรียนรู้
#
# ### 🚀 **พื้นฐานการประมวลผลพร้อมกัน**
# - **การประมวลผลผ่านหลายเอเย่นต์**: รันหลายเอเย่นต์พร้อมกันเพื่อประสิทธิภาพสูงสุด
# - **การจัดการกระบวนการทำงาน**: ประสานงานการดำเนินการพร้อมกันพร้อมรักษาความสอดคล้องของข้อมูล
# - **การเพิ่มประสิทธิภาพการทำงาน**: เพิ่มความเร็วอย่างมีนัยสำคัญผ่านการประมวลผลขนาน
# - **การจัดการทรัพยากร**: ใช้ทรัพยากรโมเดล AI อย่างมีประสิทธิภาพในหลายการดำเนินงานพร้อมกัน
#
# ### 🏗️ **รูปแบบการทำงานพร้อมกันขั้นสูง**
# - **กระบวนการ Fork-Join**: แยกงานไปยังหลายเอเย่นต์และรวมผลลัพธ์
# - **Pipeline แบบขนาน**: ช่วงการประมวลผลทับซ้อนสำหรับการส่งข้อมูลต่อเนื่อง
# - **การกระจายงาน**: แจกจ่ายงานอย่างเท่าเทียมกันในส่วนทรัพยากรของเอเย่นต์
# - **จุดซิงโครไนซ์**: ประสานเอเย่นต์พร้อมกันในขั้นตอนสำคัญของกระบวนการทำงาน
#
# ### 🏢 **แอปพลิเคชันพร้อมกันสำหรับองค์กร**
# - **การประมวลผลเอกสารปริมาณมาก**: ประมวลผลเอกสารหลายชิ้นพร้อมกัน
# - **การวิเคราะห์เนื้อหาแบบเรียลไทม์**: วิเคราะห์ข้อมูลที่เข้ามาพร้อมกัน
# - **การเพิ่มประสิทธิภาพการประมวลผลเป็นชุด**: เพิ่มปริมาณงานสำหรับการดำเนินงานขนาดใหญ่
# - **การวิเคราะห์มัลติ-โหมด**: ประมวลผลเนื้อหาหลายประเภทแบบขนาน (ข้อความ, ภาพ, ข้อมูล)
#
# ## ⚙️ ข้อกำหนดเบื้องต้น & การติดตั้ง
#
# ### 📦 **ไลบรารีที่จำเป็น**
#
# ติดตั้ง Agent Framework ที่รองรับกระบวนการทำงานพร้อมกัน:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **การกำหนดค่า Microsoft Foundry**
#
# ลงชื่อเข้าใช้ด้วย Azure CLI (`az login`) เพื่อที่ `AzureCliCredential` จะผ่านการยืนยันตัวตน จากนั้นตั้งค่ารายละเอียดโปรเจกต์ Microsoft Foundry ของคุณ
#
# **การตั้งค่าสิ่งแวดล้อม (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **ข้อควรพิจารณาในการประมวลผลพร้อมกัน:**
# - **ข้อจำกัดอัตรา**: ตรวจสอบข้อจำกัดอัตราของ Azure OpenAI สำหรับคำขอพร้อมกัน
# - **การใช้ทรัพยากร**: พิจารณาการใช้งานหน่วยความจำและซีพียูเมื่อมีหลายเอเย่นต์ทำงานพร้อมกัน
# - **การจัดการข้อผิดพลาด**: ดำเนินการกู้คืนข้อผิดพลาดอย่างมั่นคงสำหรับการประมวลผลขนาน
#
# ### 🏗️ **สถาปัตยกรรมกระบวนการทำงานพร้อมกัน**
#
# ```mermaid
# graph TD
#     A[เริ่มต้นเวิร์กโฟลว์] --> B[การดำเนินการพร้อมกัน]
#     B --> C[กลุ่มตัวแทน 1]
#     B --> D[กลุ่มตัวแทน 2]
#     B --> E[กลุ่มตัวแทน 3]
#     C --> F[การรวบรวมผลลัพธ์]
#     D --> F
#     E --> F
#     F --> G[ผลลัพธ์สุดท้าย]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **ประโยชน์หลัก:**
# - **⚡ ประสิทธิภาพ**: เพิ่มความเร็วอย่างมีนัยสำคัญผ่านการประมวลผลแบบขนาน
# - **📈 ความสามารถในการปรับขยาย**: รองรับปริมาณงานที่เพิ่มขึ้นโดยไม่เพิ่มเวลาสัดส่วน
# - **🔄 ประสิทธิผล**: ใช้ทรัพยากรคอมพิวเตอร์ที่มีอยู่ได้ดีขึ้น
# - **🎯 ความสามารถในการส่งผ่าน**: ประมวลผลงานมากขึ้นในเวลาที่เท่ากัน
#
# ## 🎨 **รูปแบบการออกแบบกระบวนการทำงานพร้อมกัน**
#
# ### 🔍 **สายงานวิจัย & วิเคราะห์**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **กระบวนการประมวลผลข้อมูล**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **สายงานสร้างเนื้อหา**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **การประมวลผลหลายขั้นตอน**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ประโยชน์ประสิทธิภาพสำหรับองค์กร**
#
# ### ⚡ **การเพิ่มประสิทธิภาพการส่งผ่าน**
# - **การประมวลผลแบบขนาน**: เอเย่นต์หลายตัวทำงานพร้อมกัน
# - **การใช้ทรัพยากร**: ใช้ความสามารถของโมเดล AI ได้อย่างคุ้มค่าสูงสุด
# - **ลดเวลา**: ลดเวลาประมวลผลรวมอย่างมีนัยสำคัญ
# - **สถาปัตยกรรมปรับขยายได้**: เพิ่มเอเย่นต์พร้อมกันได้ตามต้องการง่ายๆ
#
# ### 🛡️ **ความน่าเชื่อถือ & ความยืดหยุ่น**
# - **ความทนทานต่อข้อผิดพลาด**: เอเย่นต์ล้มเหลวบางตัวไม่หยุดการทำงานทั้งหมด
# - **การแยกปัญหา**: ปัญหาในสายพร้อมกันหนึ่งสายไม่ส่งผลกระทบต่อตัวอื่น
# - **การลดระดับอย่างเหมาะสม**: ระบบยังคงทำงานได้แม้เอเย่นต์ลดลง
# - **กลไกการกู้คืน**: การลองใหม่อัตโนมัติและจัดการข้อผิดพลาดสำหรับการดำเนินงานล้มเหลว
#
# ### 📊 **การตรวจสอบ & การสังเกตการณ์**
# - **ติดตามการดำเนินงานพร้อมกัน**: ตรวจสอบความคืบหน้าของการดำเนินการแบบขนานทั้งหมด
# - **ตัวชี้วัดประสิทธิภาพ**: วัดการเพิ่มความเร็วและผลประโยชน์จากประสิทธิภาพ
# - **วิเคราะห์การใช้ทรัพยากร**: ปรับแต่งการจัดสรรเอเย่นต์พร้อมกัน
# - **การระบุคอขวด**: ค้นหาและแก้ไขข้อจำกัดประสิทธิภาพ
#
# มาร่วมสร้างกระบวนการทำงาน AI พร้อมกันที่มีประสิทธิภาพสูงกันเถอะ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ปฏิเสธความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) ขณะที่เราพยายามให้ความถูกต้อง โปรดทราบว่าการแปลโดยอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาต้นทางควรถูกพิจารณาเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ แนะนำให้ใช้การแปลโดยมนุษย์มืออาชีพ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความที่ผิดพลาดที่เกิดขึ้นจากการใช้การแปลนี้
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
