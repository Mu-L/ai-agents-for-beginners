# %% [markdown]
# # 🔍 ระบบ RAG สำหรับองค์กรด้วย Microsoft Foundry (.NET)
#
# ## 📋 วัตถุประสงค์การเรียนรู้
#
# โน้ตบุ๊กนี้สาธิตวิธีสร้างระบบ Retrieval-Augmented Generation (RAG) ระดับองค์กรโดยใช้ Microsoft Agent Framework ใน .NET กับ Microsoft Foundry คุณจะได้เรียนรู้วิธีสร้างเอเจนต์ที่พร้อมใช้งานจริง สามารถค้นหาในเอกสารและให้คำตอบที่แม่นยำเหมาะสมกับบริบท พร้อมการรักษาความปลอดภัยและการขยายขนาดสำหรับองค์กร
#
# **ความสามารถของ Enterprise RAG ที่คุณจะสร้าง:**
# - 📚 **ความฉลาดของเอกสาร**: การประมวลผลเอกสารขั้นสูงด้วยบริการ AI ของ Azure
# - 🔍 **การค้นหาเชิงความหมาย**: การค้นหาเวกเตอร์ประสิทธิภาพสูงพร้อมฟีเจอร์สำหรับองค์กร
# - 🛡️ **การผสานรวมความปลอดภัย**: การควบคุมสิทธิ์ตามบทบาทและรูปแบบการปกป้องข้อมูล
# - 🏢 **สถาปัตยกรรมที่ขยายขนาดได้**: ระบบ RAG พร้อมสำหรับการผลิตพร้อมการมอนิเตอร์
#
# ## 🎯 สถาปัตยกรรม Enterprise RAG
#
# ### องค์ประกอบหลักขององค์กร
# - **Microsoft Foundry**: แพลตฟอร์ม AI ระดับองค์กรที่มีการจัดการพร้อมความปลอดภัยและการปฏิบัติตามมาตรฐาน
# - **Persistent Agents**: เอเจนต์ที่มีสถานะพร้อมเก็บประวัติการสนทนาและการจัดการบริบท
# - **การจัดการที่เก็บเวกเตอร์**: การจัดทำดัชนีและการดึงเอกสารระดับองค์กร
# - **การผสานรวมตัวตน**: การรับรองความถูกต้องของ Azure AD และการควบคุมสิทธิ์ตามบทบาท
#
# ### ประโยชน์ของ .NET สำหรับองค์กร
# - **ความปลอดภัยของชนิดข้อมูล**: การตรวจสอบเวลาแปลงโค้ดสำหรับการปฏิบัติการ RAG และโครงสร้างข้อมูล
# - **ประสิทธิภาพแบบอะซิงโครนัส**: การประมวลผลและการค้นหาที่ไม่บล็อก
# - **การจัดการหน่วยความจำ**: การใช้ทรัพยากรอย่างมีประสิทธิภาพสำหรับชุดเอกสารขนาดใหญ่
# - **รูปแบบการผสานรวม**: การผสานรวมบริการ Azure แบบเนทีฟด้วยการฉีดพึ่งพา
#
# ## 🏗️ สถาปัตยกรรมทางเทคนิค
#
# ### ท่อข้อมูล Enterprise RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### องค์ประกอบหลักของ .NET
# - **Azure.AI.Agents.Persistent**: การจัดการเอเจนต์ระดับองค์กรพร้อมการเก็บสถานะ
# - **Azure.Identity**: การรับรองความถูกต้องที่ผสานรวมสำหรับการเข้าถึงบริการ Azure อย่างปลอดภัย
# - **Microsoft.Agents.AI.AzureAI**: การใช้งานเฟรมเวิร์กเอเจนต์ที่ปรับแต่งสำหรับ Azure
# - **System.Linq.Async**: การปฏิบัติการ LINQ แบบอะซิงโครนัสประสิทธิภาพสูง
#
# ## 🔧 ฟีเจอร์และประโยชน์สำหรับองค์กร
#
# ### ความปลอดภัยและการปฏิบัติตามมาตรฐาน
# - **การผสานรวม Azure AD**: การจัดการตัวตนและการรับรองความถูกต้องสำหรับองค์กร
# - **การควบคุมสิทธิ์ตามบทบาท**: สิทธิ์เข้าถึงและการดำเนินการเอกสารอย่างละเอียด
# - **การปกป้องข้อมูล**: การเข้ารหัสข้อมูลขณะพักและขณะส่งสำหรับเอกสารที่สำคัญ
# - **การบันทึกตรวจสอบ**: การติดตามกิจกรรมอย่างครบถ้วนเพื่อตอบสนองข้อกำหนดความปลอดภัย
#
# ### ประสิทธิภาพและการขยายขนาด
# - **การจัดกลุ่มการเชื่อมต่อ**: การจัดการการเชื่อมต่อบริการ Azure อย่างมีประสิทธิภาพ
# - **การประมวลผลแบบอะซิงโครนัส**: ปฏิบัติการที่ไม่บล็อกสำหรับสถานการณ์ที่มีการรับส่งข้อมูลสูง
# - **กลยุทธ์การแคช**: การแคชอัจฉริยะสำหรับเอกสารที่เข้าถึงบ่อย
# - **การปรับสมดุลโหลด**: การประมวลผลแบบกระจายสำหรับการปรับใช้ขนาดใหญ่
#
# ### การจัดการและมอนิเตอร์
# - **การตรวจสุขภาพระบบ**: การมอนิเตอร์ในตัวสำหรับองค์ประกอบระบบ RAG
# - **เมตริกประสิทธิภาพ**: การวิเคราะห์รายละเอียดเกี่ยวกับคุณภาพการค้นหาและเวลาตอบสนอง
# - **การจัดการข้อผิดพลาด**: การจัดการข้อยกเว้นอย่างครอบคลุมพร้อมนโยบายทดลองใหม่
# - **การจัดการการตั้งค่า**: การตั้งค่าสภาพแวดล้อมเฉพาะพร้อมการตรวจสอบความถูกต้อง
#
# ## ⚙️ ความพร้อมและการตั้งค่า
#
# **สภาพแวดล้อมการพัฒนา:**
# - .NET 9.0 SDK หรือสูงกว่า
# - Visual Studio 2022 หรือ VS Code พร้อมส่วนขยาย C#
# - การสมัครใช้งาน Azure ที่มีการเข้าถึง AI Foundry
#
# **แพ็กเกจ NuGet ที่จำเป็น:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **การตั้งค่าการรับรองความถูกต้องของ Azure:**
# ```bash
# # ติดตั้ง Azure CLI และเข้าสู่ระบบ
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **การตั้งค่าสภาพแวดล้อม (.env file):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 รูปแบบ Enterprise RAG
#
# ### รูปแบบการจัดการเอกสาร
# - **การอัปโหลดแบบกลุ่ม**: การประมวลผลชุดเอกสารขนาดใหญ่ที่มีประสิทธิภาพ
# - **การอัปเดตเพิ่มขึ้น**: การเพิ่มและแก้ไขเอกสารแบบเรียลไทม์
# - **การควบคุมเวอร์ชัน**: การจัดการเวอร์ชันเอกสารและการติดตามการเปลี่ยนแปลง
# - **การจัดการข้อมูลเมตา**: คุณลักษณะและระบบหมวดหมู่เอกสารที่หลากหลาย
#
# ### รูปแบบการค้นหาและดึงข้อมูล
# - **การค้นหาแบบไฮบริด**: การรวมการค้นหาเชิงความหมายและคำสำคัญเพื่อผลลัพธ์ที่ดีที่สุด
# - **การค้นหาแบบแบ่งตามมิติ**: การกรองและการจัดหมวดหมู่หลากหลายมิติ
# - **การปรับแต้มความเกี่ยวข้อง**: อัลกอริทึมการให้คะแนนเฉพาะทางสำหรับความต้องการโดเมน
# - **การจัดอันดับผลลัพธ์**: การจัดอันดับขั้นสูงพร้อมการผสานรวมตรรกะทางธุรกิจ
#
# ### รูปแบบความปลอดภัย
# - **ความปลอดภัยระดับเอกสาร**: การควบคุมสิทธิ์ละเอียดในแต่ละเอกสาร
# - **การจำแนกข้อมูล**: การติดป้ายความไวและการปกป้องโดยอัตโนมัติ
# - **บันทึกตรวจสอบ**: การบันทึกครบทุกปฏิบัติการ RAG
# - **การปกป้องความเป็นส่วนตัว**: การตรวจจับและการปกปิดข้อมูลส่วนบุคคล
#
# ## 🔒 ฟีเจอร์ความปลอดภัยสำหรับองค์กร
#
# ### การรับรองความถูกต้องและการอนุญาต
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### การปกป้องข้อมูล
# - **การเข้ารหัส**: การเข้ารหัสตั้งแต่ต้นทางถึงปลายทางสำหรับเอกสารและดัชนีค้นหา
# - **การควบคุมการเข้าถึง**: การผสานรวมกับ Azure AD สำหรับสิทธิ์ผู้ใช้และกลุ่ม
# - **ที่ตั้งข้อมูล**: การควบคุมที่ตั้งข้อมูลทางภูมิศาสตร์เพื่อปฏิบัติตามข้อกำหนด
# - **การสำรองและกู้คืน**: ความสามารถในการสำรองและกู้คืนอัตโนมัติในกรณีภัยพิบัติ
#
# ## 📈 การปรับแต่งประสิทธิภาพ
#
# ### รูปแบบการประมวลผลแบบอะซิงโครนัส
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### การจัดการหน่วยความจำ
# - **การประมวลผลแบบสตรีมมิ่ง**: จัดการเอกสารขนาดใหญ่โดยไม่เกิดปัญหาหน่วยความจำ
# - **กลุ่มทรัพยากร**: การใช้ทรัพยากรราคาแพงซ้ำอย่างมีประสิทธิภาพ
# - **การเก็บขยะ**: รูปแบบการจัดสรรหน่วยความจำที่ปรับแต่งแล้ว
# - **การจัดการการเชื่อมต่อ**: วงจรชีวิตการเชื่อมต่อบริการ Azure ที่เหมาะสม
#
# ### กลยุทธ์การแคช
# - **การแคชการค้นหา**: แคชการค้นหาที่ดำเนินการบ่อย
# - **การแคชเอกสาร**: การแคชในหน่วยความจำสำหรับเอกสารยอดนิยม
# - **การแคชดัชนี**: การแคชดัชนีเวกเตอร์ที่ปรับแต่ง
# - **การแคชผลลัพธ์**: การแคชอัจฉริยะของคำตอบที่สร้างขึ้น
#
# ## 📊 กรณีใช้งานในองค์กร
#
# ### การจัดการความรู้
# - **วิกิภายในองค์กร**: การค้นหาอัจฉริยะข้ามฐานความรู้ของบริษัท
# - **นโยบายและขั้นตอน**: การปฏิบัติตามและคำแนะนำการดำเนินงานอัตโนมัติ
# - **สื่อการฝึกอบรม**: การช่วยเหลือการเรียนรู้และพัฒนาอย่างชาญฉลาด
# - **ฐานข้อมูลวิจัย**: ระบบวิเคราะห์เอกสารวิชาการและงานวิจัย
#
# ### การสนับสนุนลูกค้า
# - **ฐานความรู้ฝ่ายสนับสนุน**: การตอบสนองบริการลูกค้าอัตโนมัติ
# - **เอกสารผลิตภัณฑ์**: การดึงข้อมูลผลิตภัณฑ์อัจฉริยะ
# - **คู่มือแก้ปัญหา**: การช่วยแก้ปัญหาที่มีบริบท
# - **ระบบคำถามที่พบบ่อย**: การสร้างคำถามที่พบบ่อยแบบไดนามิกจากชุดเอกสาร
#
# ### การปฏิบัติตามกฎระเบียบ
# - **การวิเคราะห์เอกสารทางกฎหมาย**: ความฉลาดสัญญาและเอกสารกฎหมาย
# - **การตรวจสอบการปฏิบัติตาม**: การตรวจสอบการปฏิบัติตามกฎระเบียบอัตโนมัติ
# - **การประเมินความเสี่ยง**: การวิเคราะห์และรายงานความเสี่ยงจากเอกสาร
# - **การสนับสนุนการตรวจสอบ**: การค้นพบเอกสารอัจฉริยะสำหรับการตรวจสอบ
#
# ## 🚀 การปรับใช้งานในสภาพแวดล้อมจริง
#
# ### การมอนิเตอร์และการสังเกตการณ์
# - **Application Insights**: การเทเลเมทรีและการมอนิเตอร์ประสิทธิภาพอย่างละเอียด
# - **เมตริกส์ที่กำหนดเอง**: การติดตามและแจ้งเตือนตัวชี้วัดทางธุรกิจ
# - **การติดตามแบบกระจาย**: การติดตามคำร้องขอแบบครบวงจรข้ามบริการ
# - **แดชบอร์ดสุขภาพระบบ**: การแสดงสถานะสุขภาพและประสิทธิภาพแบบเรียลไทม์
#
# ### การขยายขนาดและความน่าเชื่อถือ
# - **การปรับขนาดอัตโนมัติ**: การปรับขนาดโดยอัตโนมัติตามโหลดและเมตริกประสิทธิภาพ
# - **ความพร้อมใช้งานสูง**: การปรับใช้หลายภูมิภาคพร้อมความสามารถ failover
# - **การทดสอบโหลด**: การตรวจสอบประสิทธิภาพภายใต้เงื่อนไขโหลดขององค์กร
# - **การกู้คืนจากภัยพิบัติ**: ขั้นตอนการสำรองและกู้คืนอัตโนมัติ
#
# พร้อมสร้างระบบ RAG ระดับองค์กรที่สามารถจัดการเอกสารสำคัญในระดับใหญ่หรือยัง? มาออกแบบระบบความรู้ที่ชาญฉลาดสำหรับองค์กรกัน! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ปฏิเสธความรับผิดชอบ**:
# เอกสารนี้ได้รับการแปลโดยใช้บริการแปลภาษา AI [Co-op Translator](https://github.com/Azure/co-op-translator) ขณะที่เราพยายามให้ความถูกต้อง โปรดทราบว่าการแปลโดยอัตโนมัติอาจมีข้อผิดพลาดหรือความไม่ถูกต้อง เอกสารต้นฉบับในภาษาต้นทางควรถูกพิจารณาเป็นแหล่งข้อมูลที่เชื่อถือได้ สำหรับข้อมูลที่สำคัญ แนะนำให้ใช้การแปลโดยมนุษย์มืออาชีพ เราไม่รับผิดชอบต่อความเข้าใจผิดหรือการตีความที่ผิดพลาดที่เกิดขึ้นจากการใช้การแปลนี้
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
