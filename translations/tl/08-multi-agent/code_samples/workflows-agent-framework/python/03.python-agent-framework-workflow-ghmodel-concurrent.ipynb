# %% [markdown]
# # ⚡ Mga Sabay-sabay na Agent Workflows gamit ang Microsoft Foundry (Python)
#
# ## 📋 Tutorial sa Advanced Parallel Processing
#
# Ipinapakita ng notebook na ito ang **mga pattern ng sabay-sabay na workflow** gamit ang Microsoft Agent Framework. Matututuhan mo kung paano bumuo ng mga high-performance, parallel processing workflows kung saan maraming AI agents ang sabay-sabay na nagpapatakbo, na lubos na nagpapabuti sa throughput at nagpapagana ng sopistikadong multi-threaded na mga proseso ng negosyo.
#
# > **Paalala sa Migrasyon:** Ang sample na ito ay dating tumutukoy sa GitHub Models. Ang GitHub Models ay hindi na gagamitin (magre-retire sa Hulyo 2026), kaya ngayon ay gumagamit na ito ng **Microsoft Foundry** sa pamamagitan ng `FoundryChatClient`, na tumutok sa Azure OpenAI **Responses API**.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🚀 **Mga Pangunahing Kaalaman sa Sabay-sabay na Pagproseso**
# - **Parallel Agent Execution**: Paandarin ang maraming agents nang sabay-sabay para sa pinakamataas na kahusayan
# - **Orkestrasyon ng Workflow**: Isaayos ang sabay-sabay na mga operasyon habang pinananatili ang datos na konsistensi
# - **Pag-optimize ng Pagganap**: Makamit ang malaking bilis gamit ang parallel processing
# - **Pamamahala ng Mga Recurso**: Epektibong gamitin ang mga AI model na recurso sa mga sabay-sabay na operasyon
#
# ### 🏗️ **Mga Advanced na Pattern ng Sabay-sabay**
# - **Fork-Join Processing**: Hatiin ang trabaho sa maraming agents at pagsamahin ang mga resulta
# - **Pipeline Parallelism**: Magkapatong-patong na mga yugto ng pagpatakbo para sa tuloy-tuloy na throughput
# - **Load Balancing**: Pantay-pantay na ipamahagi ang trabaho sa mga magagamit na recurso ng agent
# - **Mga Punto ng Pagkakasabay**: Isaayos ang sabay-sabay na mga agents sa mga kritikal na yugto ng workflow
#
# ### 🏢 **Mga Sabay-sabay na Application sa Enterprise**
# - **Malakihang Pagproseso ng Dokumento**: Iproseso ang maraming dokumento nang sabay-sabay
# - **Real-Time Content Analysis**: Sabay-sabay na pagsusuri ng papasok na mga data stream
# - **Pag-optimize ng Batch Processing**: Maksimahin ang throughput para sa malakihang operasyon
# - **Multi-Modal Analysis**: Parallel na pagproseso ng iba't ibang uri ng nilalaman (teksto, mga larawan, data)
#
# ## ⚙️ Mga Kinakailangang Kagamitan & Setup
#
# ### 📦 **Mga Kinakailangang Dependency**
#
# I-install ang Agent Framework na may kakayahan para sa sabay-sabay na workflow:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Configuration**
#
# Mag-sign in gamit ang Azure CLI (`az login`) para makapag-authenticate ang `AzureCliCredential`, pagkatapos ay itakda ang detalye ng iyong proyekto sa Microsoft Foundry.
#
# **Pagsasaayos ng Kapaligiran (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Mga Pagsasaalang-alang sa Sabay-sabay na Pagproseso:**
# - **Rate Limits**: Bantayan ang mga rate limit ng Azure OpenAI para sa sabay-sabay na mga kahilingan
# - **Paggamit ng Recurso**: Isaalang-alang ang paggamit ng memorya at CPU sa maraming sabay-sabay na agents
# - **Paghawak ng Error**: Magpatupad ng matibay na recovery sa error para sa parallel na mga operasyon
#
# ### 🏗️ **Arkitektura ng Sabay-sabay na Workflow**
#
# ```mermaid
# graph TD
#     A[Simula ng Daloy ng Trabaho] --> B[Sabayang Pagsasakatuparan]
#     B --> C[Pool ng Ahente 1]
#     B --> D[Pool ng Ahente 2]
#     B --> E[Pool ng Ahente 3]
#     C --> F[Pagsasama-sama ng Resulta]
#     D --> F
#     E --> F
#     F --> G[Panghuling Output]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Pangunahing Mga Benepisyo:**
# - **⚡ Pagganap**: Makabuluhang pagkawala sa oras sa pamamagitan ng parallel na pagpapatakbo
# - **📈 Scalability**: Maghawak ng tumataas na workload nang hindi tumataas nang proporsyonal ang oras
# - **🔄 Kahusayan**: Mas mahusay na paggamit ng mga magagamit na computational na recurso
# - **🎯 Throughput**: Iproseso ang mas maraming trabaho sa parehong dami ng oras
#
# ## 🎨 **Mga Design Pattern ng Sabay-sabay na Workflow**
#
# ### 🔍 **Pipeline ng Pananaliksik at Pagsusuri**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Workflow ng Pagproseso ng Data**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Pipeline ng Paglikha ng Nilalaman**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Multi-Stage Processing**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Mga Benepisyo sa Pagganap para sa Enterprise**
#
# ### ⚡ **Pag-optimize ng Throughput**
# - **Parallel Execution**: Maraming agents na sabay-sabay na gumagana
# - **Paggamit ng Recurso**: Pinakamataas na kahusayan ng magagamit na kapasidad ng AI model
# - **Pagbawas ng Oras**: Makabuluhang pagbaba sa kabuuang oras ng pagproseso
# - **Scalable Architecture**: Madaling magdagdag ng mas maraming sabay-sabay na agents kapag kailangan
#
# ### 🛡️ **Katiyakan at Katatagan**
# - **Fault Tolerance**: Ang mga pagkabigo ng indibidwal na agent ay hindi humihinto sa buong workflow
# - **Error Isolation**: Ang mga problema sa isang sabay-sabay na sangay ay hindi nakakaapekto sa iba
# - **Graceful Degradation**: Nagpapatuloy ang sistema kahit may nabawas na kapasidad ng agent
# - **Mga Mekanismo ng Pagbawi**: Awtomatikong muling pagtatangka at paghawak ng error para sa mga nabigong operasyon
#
# ### 📊 **Pagmamanman at Obserbabilidad**
# - **Pagsubaybay sa Sabay-sabay na Pagpapatakbo**: Bantayan ang progreso ng lahat ng parallel na operasyon
# - **Mga Sukatan ng Pagganap**: Sukatin ang bilis at pagtaas ng kahusayan
# - **Analitika sa Paggamit ng Recurso**: I-optimize ang alokasyon ng sabay-sabay na mga agent
# - **Pagkilala sa Bottleneck**: Hanapin at ayusin ang mga limitasyon ng pagganap
#
# Gumawa tayo ng mataas na performance na sabay-sabay na AI workflows! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
