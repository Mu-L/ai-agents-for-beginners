# %% [markdown]
# # ⚡ Sabay-sabay na Mga Workflow ng Ahente gamit ang Microsoft Foundry (Python)
#
# ## 📋 Tutorial sa Advanced Parallel Processing
#
# Ipinapakita ng notebook na ito ang **mga pattern ng sabay-sabay na workflow** gamit ang Microsoft Agent Framework. Matututuhan mong bumuo ng mga high-performance, parallel processing na workflows kung saan maraming AI agents ang nagsasagawa nang sabay-sabay, na malaki ang pinapabuti sa throughput at nagpapahintulot ng mga sopistikadong multi-threaded na mga proseso ng negosyo.
#
# > **Tala sa Migration:** Dati ay tumutukoy ang sample na ito sa GitHub Models. Ang GitHub Models ay deprecated na (magre-retire sa Hulyo 2026), kaya ngayon ay gumagamit ito ng **Microsoft Foundry** sa pamamagitan ng `FoundryChatClient`, na tumutukoy sa Azure OpenAI **Responses API**.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🚀 **Mga Pangunahing Kaalaman sa Concurrent Processing**
# - **Parallel Agent Execution**: Patakbuhin ang maraming mga ahente nang sabay-sabay para sa pinakamataas na kahusayan
# - **Workflow Orchestration**: Isaayos ang mga sabay-sabay na operasyon habang pinapanatili ang pagkakapare-pareho ng data
# - **Performance Optimization**: Makamit ang malaking pagpapabilis gamit ang parallel processing
# - **Resource Management**: Epektibong gamitin ang mga AI model resources sa sabay-sabay na operasyon
#
# ### 🏗️ **Mga Advanced na Pattern ng Concurrency**
# - **Fork-Join Processing**: Hatiin ang gawain sa maraming ahente at pagsamahin ang mga resulta
# - **Pipeline Parallelism**: Pagsabay-sabay na mga yugto ng pagpapatupad para sa tuloy-tuloy na throughput
# - **Load Balancing**: Pantay na ipamahagi ang gawain sa magagamit na mga resource ng ahente
# - **Synchronization Points**: Isaayos ang sabay-sabay na mga ahente sa mga kritikal na yugto ng workflow
#
# ### 🏢 **Mga Enterprise Concurrent na Aplikasyon**
# - **High-Volume Document Processing**: Sabayang pagproseso ng maraming dokumento
# - **Real-Time Content Analysis**: Sabayang pagsusuri ng mga pasok na datastream
# - **Batch Processing Optimization**: Maksimahin ang throughput para sa malakihang operasyon
# - **Multi-Modal Analysis**: Parallel processing ng iba't ibang uri ng nilalaman (teksto, mga imahe, datos)
#
# ## ⚙️ Mga Kinakailangan & Setup
#
# ### 📦 **Kinakailangang Mga Dependency**
#
# I-install ang Agent Framework na may kakayahan para sa concurrent workflows:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Kumpigurasyon ng Microsoft Foundry**
#
# Mag-sign in gamit ang Azure CLI (`az login`) para makapag-authenticate ang `AzureCliCredential`, pagkatapos ay itakda ang mga detalye ng iyong Microsoft Foundry project.
#
# **Pag-setup ng Kapaligiran (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Mga Pagsasaalang-alang sa Concurrent Processing:**
# - **Rate Limits**: Subaybayan ang Azure OpenAI rate limits para sa mga sabay-sabay na request
# - **Resource Usage**: Isaalang-alang ang paggamit ng memorya at CPU sa maramihang sabay-sabay na ahente
# - **Error Handling**: Magpatupad ng matibay na error recovery para sa mga parallel na operasyon
#
# ### 🏗️ **Arkitektura ng Concurrent Workflow**
#
# ```mermaid
# graph TD
#     A[Simula ng Daloy ng Trabaho] --> B[Sabay-sabay na Pagpapatupad]
#     B --> C[Pool ng Ahente 1]
#     B --> D[Pool ng Ahente 2]
#     B --> E[Pool ng Ahente 3]
#     C --> F[Pagpupulong ng Resulta]
#     D --> F
#     E --> F
#     F --> G[Pangwakas na Output]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Pangunahing Mga Benepisyo:**
# - **⚡ Performance**: Malaking pagpapabilis dahil sa parallel execution
# - **📈 Scalability**: Kayang hawakan ang tumataas na workload nang hindi tumataas nang proporsyonal ang oras
# - **🔄 Efficiency**: Mas mahusay na paggamit ng magagamit na computational resources
# - **🎯 Throughput**: Mas maraming nagawang trabaho sa parehong oras
#
# ## 🎨 **Mga Disenyo ng Concurrent Workflow Pattern**
#
# ### 🔍 **Research & Analysis Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Data Processing Workflow**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Content Creation Pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Multi-Stage Processing**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Mga Benepisyo sa Performance ng Enterprise**
#
# ### ⚡ **Optimization ng Throughput**
# - **Parallel Execution**: Maraming ahente ang nagtatrabaho nang sabay-sabay
# - **Resource Utilization**: Pinakamataas na kahusayan ng magagamit na kapasidad ng AI model
# - **Time Reduction**: Malaking pagbawas sa kabuuang oras ng pagproseso
# - **Scalable Architecture**: Madaling magdagdag ng higit pang sabay-sabay na ahente kung kinakailangan
#
# ### 🛡️ **Katatagan at Kakayahan sa Pagbangon**
# - **Fault Tolerance**: Ang pagkabigo ng isang ahente ay hindi humihinto sa buong workflow
# - **Error Isolation**: Ang mga problema sa isang concurrent branch ay hindi nakaapekto sa iba
# - **Graceful Degradation**: Nagpapatuloy ang sistema kahit na may nabawasang kapasidad ng ahente
# - **Recovery Mechanisms**: Awtomatikong pag-ulit at paghawak ng error para sa mga nabigong operasyon
#
# ### 📊 **Monitoring at Observability**
# - **Concurrent Execution Tracking**: Subaybayan ang progreso ng lahat ng parallel na operasyon
# - **Performance Metrics**: Sukatin ang pagpapabilis at mga pagbuti sa kahusayan
# - **Resource Usage Analytics**: I-optimize ang allocation ng sabay-sabay na mga ahente
# - **Bottleneck Identification**: Hanapin at lutasin ang mga hadlang sa performance
#
# Gumawa tayo ng mga high-performance na concurrent AI workflows! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
