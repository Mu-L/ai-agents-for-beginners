# %% [markdown]
# # 🔄 Pangunahing Mga Workflow ng Ahente gamit ang Microsoft Foundry (Python)
#
# ## 📋 Tutorial sa Pag-oorganisa ng Workflow
#
# Ipinakikilala ng notebook na ito ang makapangyarihang mga kakayahan ng **Workflow Builder** ng Microsoft Agent Framework. Matutunan kung paano gumawa ng sopistikadong, maraming-hakbang na mga workflow ng ahente na kayang hawakan ang kumplikadong mga proseso ng negosyo at epektibong makipag-coordinate sa maraming operasyon ng AI.
#
# > **Tala sa Migrasyon:** Dati ay tinutukoy ng sample na ito ang GitHub Models. Ang GitHub Models ay hindi na gagamitin (magtatapos sa Hulyo 2026), kaya ito ay gumagamit na ngayon ng **Microsoft Foundry** sa pamamagitan ng `FoundryChatClient`, na tumutukoy sa Azure OpenAI **Responses API**.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🏗️ **Arkitektura ng Workflow**
# - **Workflow Builder**: Disenyo at pag-oorganisa ng komplikadong maraming-hakbang na mga proseso
# - **Pagpapatakbo Na Pinapatakbo ng Kaganapan**: Pamahalaan ang mga event sa workflow at mga pagbabago ng estado
# - **Visual na Disenyo ng Workflow**: Lumikha at i-visualize ang mga istruktura ng workflow
# - **Integrasyon ng Microsoft Foundry**: Gamitin ang mga AI model sa loob ng mga konteksto ng workflow
#
# ### 🔄 **Pag-oorganisa ng Proseso**
# - **Sunud-sunod na Operasyon**: Isunod-sunod ang maraming gawain ng ahente ayon sa lohikal na pagkakasunod
# - **Lohika ng Kondisyon**: Magpatupad ng mga desisyon at sanga-sangang workflow
# - **Paghawak ng Mali**: Matibay na pagkuha muli mula sa error at tibay ng workflow
# - **Pamamahala ng Estado**: Subaybayan at pamahalaan ang estado ng pagpapatupad ng workflow
#
# ### 📊 **Mga Pattern ng Enterprise Workflow**
# - **Automasyon ng Proseso ng Negosyo**: Awtomatiko ang mga kumplikadong workflow ng organisasyon
# - **Koordinasyon ng Maramihang Ahente**: I-coordinate ang maraming espesyal na ahente
# - **Nasusukat na Pagpapatupad**: Magdisenyo ng mga workflow para sa operasyon sa antas enterprise
# - **Pagmamanman at Observability**: Subaybayan ang pagganap at resulta ng workflow
#
# ## ⚙️ Mga Kinakailangan at Setup
#
# ### 📦 **Mga Kailangan na Depenensya**
#
# I-install ang Agent Framework na may kakayahan sa workflow:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Konfigurasyon ng Microsoft Foundry**
#
# Mag-sign in gamit ang Azure CLI (`az login`) para makapag-authenticate ang `AzureCliCredential`, pagkatapos ay itakda ang iyong mga detalye ng proyekto sa Microsoft Foundry.
#
# **Pag-setup ng Kapaligiran (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# ### 🏢 **Mga Gamit sa Enterprise**
#
# **Mga Halimbawa ng Proseso ng Negosyo:**
# - **Pagpapasok ng Customer**: Maraming hakbang ng beripikasyon at setup na workflows
# - **Content Pipeline**: Awtomatikong paglikha, pagsusuri, at paglalathala ng nilalaman
# - **Pagproseso ng Data**: ETL workflow na may AI-powered na transformasyon
# - **Quality Assurance**: Awtomatikong pagsusuri at mga proseso ng pagpapatunay
#
# **Mga Benepisyo ng Workflow:**
# - 🎯 **Katiyakan**: Deterministikong pagpapatupad na may pagkuha muli mula sa error
# - 📈 **Nasusukat**: Kayang hawakan ang mataas na volume ng automasyon ng proseso
# - 🔍 **Observability**: Kumpletong audit trail at pagmamanman
# - 🔧 **Madaling Mapanatili**: Visual na disenyo at mga modular na bahagi
#
# ## 🎨 Mga Pattern sa Disenyo ng Workflow
#
# ### Pangunahing Estruktura ng Workflow
# ```mermaid
# graph TD
#     A[Simula] --> B[Gawain ng Ahente 1]
#     B --> C{Punto ng Desisyon}
#     C -->|Tagumpay| D[Gawain ng Ahente 2]
#     C -->|Kabiguan| E[Tagahawak ng Error]
#     D --> F[Wakas]
#     E --> F
# ```
#
# **Pangunahing mga Komponente:**
# - **WorkflowBuilder**: Pangunahing makina ng pag-oorganisa
# - **WorkflowEvent**: Paghawak at komunikasyon ng event
# - **WorkflowViz**: Visual na representasyon ng workflow at debugging
#
# Gumawa tayo ng iyong unang matalinong workflow! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load Microsoft Foundry project settings from .env file
load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = provider.as_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = provider.as_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
