# %% [markdown]
# # 🔄 Pangunahing Daloy ng Gawa ng Ahente gamit ang Azure OpenAI (Responses API) (.NET)
#
# ## 📋 Tutorial sa Orkestrasyon ng Daloy ng Gawa
#
# Ipinapakita ng notebook na ito kung paano bumuo ng sopistikadong **daloy ng gawa ng ahente** gamit ang Microsoft Agent Framework para sa .NET at Azure OpenAI (Responses API). Matututuhan mong gumawa ng multi-step na mga proseso ng negosyo kung saan ang mga AI na ahente ay nagtutulungan upang maisakatuparan ang mga kumplikadong gawain sa pamamagitan ng istrukturadong mga pattern ng orkestrasyon.
#
# ## 🎯 Mga Layunin sa Pagkatuto
#
# ### 🏗️ **Mga Pangunahing Kaayusan ng Daloy ng Gawa**
# - **Tagabuo ng Daloy ng Gawa**: Magdisenyo at orkestrahin ang mga kumplikadong multi-step na proseso ng AI
# - **Koordinasyon ng Ahente**: I-coordinate ang maraming espesyalisadong ahente sa loob ng mga daloy ng gawa
# - **Azure OpenAI (Responses API)**: Gamitin ang Azure OpenAI Responses API sa mga daloy ng gawa
# - **Biswal na Disenyo ng Daloy ng Gawa**: Lumikha at biswal na ipakita ang mga estruktura ng daloy ng gawa para sa mas mahusay na pag-unawa
#
# ### 🔄 **Mga Pattern ng Orkestrasyon ng Proseso**
# - **Sunud-sunod na Pagpoproseso**: I-chain ang maraming gawain ng ahente ayon sa lohikal na pagkakasunod
# - **Pamamahala ng Estado**: Panatilihin ang konteksto at daloy ng datos sa bawat yugto ng daloy ng gawa
# - **Paghawak ng Mali**: Magpatupad ng matatag na pagbangon mula sa mga mali at tibay ng daloy ng gawa
# - **Pag-optimize ng Pagganap**: Magdisenyo ng mahusay na mga daloy ng gawa para sa mga operasyon sa antas ng enterprise
#
# ### 🏢 **Mga Aplikasyon ng Enterprise Workflow**
# - **Automasyon ng Proseso ng Negosyo**: I-automate ang mga komplikadong daloy ng gawain sa organisasyon
# - **Pipeline ng Produksyon ng Nilalaman**: Mga daloy ng gawa para sa editoryal na may mga yugto ng pagsusuri at pag-apruba
# - **Automasyon ng Serbisyong Pang-kustomer**: Multi-step na resolusyon ng mga katanungan ng kustomer
# - **Daloy ng Gawa sa Pagpoproseso ng Datos**: Mga ETL workflow na may AI-powered na transformasyon
#
# ## ⚙️ Mga Kinakailangan at Pagsisimula
#
# ### 📦 **Mga Kinakailangang NuGet Packages**
#
# Ang demonstrasyong daloy ng gawa na ito ay gumagamit ng ilang mahahalagang package ng .NET:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.13.1" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Konfigurasyon ng Azure OpenAI**
#
# **Pagsasaayos ng Kapaligiran (file .env):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-4.1-mini
# ```
#
# **Access sa Azure OpenAI:**
# 1. Gumawa ng Azure OpenAI resource sa Azure portal
# 2. I-deploy ang isang modelo (halimbawa, `gpt-4.1-mini`) at tandaan ang pangalan ng deployment
# 3. Mag-sign in gamit ang `az login` at i-configure ang mga environment variable gaya ng ipinakita sa itaas
#
# ### 🏗️ **Pangkalahatang-ideya ng Arkitektura ng Daloy ng Gawa**
#
# ```mermaid
# graph TD
#     A[Tagabuo ng Daloy ng Trabaho] --> B[Rehistro ng Ahente]
#     B --> C[Makina sa Pagpapatupad ng Daloy ng Trabaho]
#     C --> D[Agent 1: Tagalikha ng Nilalaman
#     C --> E[Agent 2: Tagasuri ng Nilalaman
#     D --> F[Mga Resulta ng Daloy ng Trabaho]
#     E --> F
#     G[Azure OpenAI (API ng mga Tugon)] --> D
#     G --> E
# ```
#
# **Pangunahing mga Sangkap:**
# - **WorkflowBuilder**: Pangunahing makina ng orkestrasyon para sa pagdisenyo ng mga daloy ng gawa
# - **AIAgent**: Mga indibidwal na espesyalisadong ahente na may partikular na kakayahan
# - **Azure OpenAI Client**: Integrasyon ng Azure OpenAI Responses API
# - **Execution Context**: Namamahala ng estado at daloy ng datos sa pagitan ng mga yugto ng daloy ng gawa
#
# ## 🎨 **Mga Pattern ng Disenyo ng Enterprise Workflow**
#
# ### 📝 **Daloy ng Gawa sa Produksyon ng Nilalaman**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **Pipeline sa Pagpoproseso ng Dokumento**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **Daloy ng Gawa sa Business Intelligence**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **Automasyon ng Serbisyong Pang-kustomer**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **Mga Benepisyo ng Enterprise**
#
# ### 🎯 **Pagkakatiwalaan at Kakayahang Mag-scale**
# - **Deterministikong Pagpapatupad**: Konsistenteng, nauulit na resulta ng daloy ng gawa
# - **Pagbangon mula sa Mali**: Maayos na paghawak ng mga pagkabigo sa anumang yugto ng daloy ng gawa
# - **Pagsubaybay sa Pagganap**: Subaybayan ang mga sukatan ng pagpapatupad at mga oportunidad sa pag-optimize
# - **Pamamahala ng Mga Yaman**: Mahusay na alokasyon at paggamit ng mga yaman ng AI model
#
# ### 🔒 **Seguridad at Pagsunod**
# - **Ligtas na Pag-authenticate**: Microsoft Entra ID authentication sa pamamagitan ng `az login` (AzureCliCredential)
# - **Audit Trails**: Kumpletong pag-log ng pagpapatupad ng daloy ng gawa at mga punto ng desisyon
# - **Kontrol ng Access**: Granular na mga permiso para sa pagpapatupad at pagsubaybay ng daloy ng gawa
# - **Privacy ng Datos**: Ligtas na paghawak ng sensitibong impormasyon sa buong daloy ng gawa
#
# ### 📊 **Obserbabilidad at Pamamahala**
# - **Biswal na Disenyo ng Daloy ng Gawa**: Malinaw na representasyon ng mga proseso at dependencies
# - **Pagsubaybay ng Pagpapatupad**: Real-time na pagsubaybay sa progreso at pagganap ng daloy ng gawa
# - **Pagsusuri ng Mali**: Detalyadong pagsusuri ng mali at kakayahan sa debugging
# - **Analytics sa Pagganap**: Mga sukatan para sa pag-optimize at pagpaplano ng kapasidad
#
# Simulan na natin ang iyong unang enterprise-ready AI workflow! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"
#r "nuget: OpenTelemetry.Api, 1.0.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.0.1</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"

# %%
using System;
using System.ComponentModel;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-4.1-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Visit the Louvre Museum. It's a must-see for art enthusiasts and history lovers.That recommendation is quite popular and likely to attract many tourists. To refine it for a more local and authentic experience, consider suggesting an alternative that focuses on smaller, lesser-known art venues or galleries. Look for places where local artists exhibit or community spaces that host cultural events. This approach allows travelers to connect with the local art scene more intimately, away from the typical tourist routes.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Pagtatanggi**:
# Ang dokumentong ito ay isinalin gamit ang serbisyo ng AI translation na [Co-op Translator](https://github.com/Azure/co-op-translator). Bagama't nagsusumikap kami para sa katumpakan, pakatandaan na ang awtomatikong pagsasalin ay maaaring maglaman ng mga pagkakamali o hindi pagkakatugma. Ang orihinal na dokumento sa orihinal nitong wika ang dapat ituring na pangunahing sanggunian. Para sa mahahalagang impormasyon, inirerekomenda ang propesyonal na pagsasalin ng tao. Hindi kami mananagot sa anumang maling pagkakaintindi o maling interpretasyon na nagmula sa paggamit ng pagsasaling ito.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
