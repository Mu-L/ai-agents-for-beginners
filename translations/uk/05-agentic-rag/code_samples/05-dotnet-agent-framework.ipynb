# %% [markdown]
# # 🔍 Корпоративний RAG з Microsoft Foundry (.NET)
#
# ## 📋 Цілі навчання
#
# Цей блокнот демонструє, як створювати корпоративні системи Retrieval-Augmented Generation (RAG) за допомогою Microsoft Agent Framework на .NET із Microsoft Foundry. Ви навчитеся створювати агенти для виробничого середовища, які можуть здійснювати пошук по документах і надавати точні, контекстно орієнтовані відповіді з корпоративною безпекою та масштабованістю.
#
# **Можливості корпоративного RAG, які ви побудуєте:**
# - 📚 **Інтелект документів**: Розширена обробка документів за допомогою сервісів Azure AI
# - 🔍 **Семантичний пошук**: Високопродуктивний векторний пошук із корпоративними функціями
# - 🛡️ **Інтеграція безпеки**: Управління доступом на основі ролей і шаблони захисту даних
# - 🏢 **Масштабована архітектура**: Системи RAG, готові для виробництва, із моніторингом
#
# ## 🎯 Архітектура корпоративного RAG
#
# ### Основні корпоративні компоненти
# - **Microsoft Foundry**: Керована корпоративна AI-платформа з безпекою та відповідністю
# - **Персистентні агенти**: Стейтові агенти з історією розмов і керуванням контекстом
# - **Управління векторним сховищем**: Індексація та пошук документів корпоративного рівня
# - **Інтеграція ідентичності**: Автентифікація Azure AD та контроль доступу на основі ролей
#
# ### Переваги .NET для підприємств
# - **Типобезпека**: Валідація на час компіляції для операцій RAG та структур даних
# - **Асинхронна продуктивність**: Безблокуюча обробка документів та операції пошуку
# - **Управління пам'яттю**: Ефективне використання ресурсів для великих колекцій документів
# - **Патерни інтеграції**: Рідна інтеграція сервісів Azure з впровадженням залежностей
#
# ## 🏗️ Технічна архітектура
#
# ### Канал корпоративного RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Основні компоненти .NET
# - **Azure.AI.Agents.Persistent**: Управління корпоративними агентами зі збереженням стану
# - **Azure.Identity**: Інтегрована автентифікація для безпечного доступу до сервісів Azure
# - **Microsoft.Agents.AI.AzureAI**: Реалізація агента з оптимізацією для Azure
# - **System.Linq.Async**: Високопродуктивні асинхронні LINQ операції
#
# ## 🔧 Корпоративні функції та переваги
#
# ### Безпека та відповідність
# - **Інтеграція Azure AD**: Управління ідентичністю підприємства та автентифікація
# - **Доступ на основі ролей**: Тонке управління пермісями для доступу та операцій з документами
# - **Захист даних**: Шифрування у спокої та при передачі для конфіденційних документів
# - **Аудит логування**: Комплексне відстеження діяльності для дотримання вимог
#
# ### Продуктивність та масштабованість
# - **Пулювання з'єднань**: Ефективне керування підключеннями до сервісів Azure
# - **Асинхронна обробка**: Безблокуючі операції для сценаріїв з високим навантаженням
# - **Стратегії кешування**: Інтелектуальне кешування часто використовуваних документів
# - **Балансування навантаження**: Розподілена обробка для великих розгортань
#
# ### Управління та моніторинг
# - **Перевірки стану**: Вбудований моніторинг компонентів системи RAG
# - **Метрики продуктивності**: Детальна аналітика якості пошуку та часу відгуку
# - **Обробка помилок**: Комплексне управління винятками з політиками повторних спроб
# - **Управління конфігурацією**: Налаштування для середовища з валідацією
#
# ## ⚙️ Необхідні умови та налаштування
#
# **Середовище розробки:**
# - .NET 9.0 SDK або новіше
# - Visual Studio 2022 або VS Code з розширенням C#
# - Підписка Azure з доступом до AI Foundry
#
# **Вимагаємі пакети NuGet:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Налаштування автентифікації Azure:**
# ```bash
# # Встановіть Azure CLI та виконайте автентифікацію
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Конфігурація середовища (.env файл):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Патерни корпоративного RAG
#
# ### Патерни управління документами
# - **Масове завантаження**: Ефективна обробка великих колекцій документів
# - **Інкрементальні оновлення**: Додавання та зміна документів у режимі реального часу
# - **Контроль версій**: Версіонування документів та відстеження змін
# - **Управління метаданими**: Розширені атрибути документів і таксономія
#
# ### Патерни пошуку та вилучення
# - **Гібридний пошук**: Поєднання семантичного та ключового пошуку для оптимальних результатів
# - **Фасетний пошук**: Багатовимірне фільтрування та категоризація
# - **Налаштування релевантності**: Користувацькі алгоритми оцінювання під доменні потреби
# - **Ранжування результатів**: Розширене ранжування з інтеграцією бізнес-логіки
#
# ### Патерни безпеки
# - **Безпека на рівні документів**: Тонке керування доступом для кожного документа
# - **Класифікація даних**: Автоматичне маркування чутливості та захист
# - **Аудитні журнали**: Комплексне логування всіх операцій RAG
# - **Захист конфіденційності**: Виявлення та редагування ПІБ (PII)
#
# ## 🔒 Корпоративні функції безпеки
#
# ### Автентифікація та авторизація
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Захист даних
# - **Шифрування**: Сквозне шифрування документів та індексів пошуку
# - **Контроль доступу**: Інтеграція з Azure AD для прав користувачів та груп
# - **Локалізація даних**: Керування географічним розташуванням даних для відповідності
# - **Резервне копіювання та відновлення**: Автоматичне резервування і відновлення після аварій
#
# ## 📈 Оптимізація продуктивності
#
# ### Патерни асинхронної обробки
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управління пам'яттю
# - **Потокова обробка**: Обробка великих документів без проблем з пам'яттю
# - **Пул ресурсів**: Ефективне повторне використання дорогих ресурсів
# - **Сміттєзбірник**: Оптимізовані патерни виділення пам'яті
# - **Управління з'єднаннями**: Коректний життєвий цикл підключень до сервісів Azure
#
# ### Стратегії кешування
# - **Кешування запитів**: Кешування часто виконуваних пошукових запитів
# - **Кешування документів**: Кешування в пам'яті для найактуальніших документів
# - **Кешування індексу**: Оптимізоване кешування векторного індексу
# - **Кешування результатів**: Інтелектуальне кешування генерованих відповідей
#
# ## 📊 Корпоративні сценарії використання
#
# ### Управління знаннями
# - **Корпоративна вікі**: Інтелектуальний пошук по базах знань компанії
# - **Політики та процедури**: Автоматизоване дотримання і керівництво процедурами
# - **Матеріали для навчання**: Інтелектуальна допомога у навчанні та розвитку
# - **Науково-дослідні бази даних**: Аналіз академічних і дослідницьких робіт
#
# ### Підтримка клієнтів
# - **База знань підтримки**: Автоматизовані відповіді служби підтримки
# - **Документація продукту**: Інтелектуальне вилучення інформації про продукт
# - **Посібники з усунення неполадок**: Контекстна допомога у вирішенні проблем
# - **Системи FAQ**: Динамічне створення FAQ з колекцій документів
#
# ### Відповідність регламентам
# - **Аналіз юридичних документів**: Інтелектуальний аналіз контрактів і юридичних документів
# - **Моніторинг відповідності**: Автоматизована перевірка відповідності регламентам
# - **Оцінка ризиків**: Аналіз та звітування ризиків на основі документів
# - **Підтримка аудитів**: Інтелектуальний пошук документів під час аудитів
#
# ## 🚀 Розгортання у виробництві
#
# ### Моніторинг та спостережуваність
# - **Application Insights**: Детальна телеметрія та моніторинг продуктивності
# - **Користувацькі метрики**: Відстеження KPI бізнесу та оповіщення
# - **Розподілене трасування**: Відстеження запитів скрізь сервіси
# - **Панелі стану**: Візуалізація стану та продуктивності системи в реальному часі
#
# ### Масштабованість та надійність
# - **Автоматичне масштабування**: Автоматичне збільшення ресурсів за навантаженням та метриками
# - **Висока доступність**: Розгортання у кількох регіонах з автоматичним перемиканням
# - **Тестування навантаження**: Перевірка продуктивності при корпоративних навантаженнях
# - **Відновлення після аварій**: Автоматизовані процедури резервного копіювання та відновлення
#
# Готові побудувати корпоративні системи RAG, які можуть обробляти конфіденційні документи у масштабі? Давайте проектувати інтелектуальні системи знань для підприємств! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено за допомогою сервісу штучного інтелекту для перекладу [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, будь ласка, майте на увазі, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ рідною мовою слід вважати авторитетним джерелом. Для критично важливої інформації рекомендується професійний людський переклад. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
