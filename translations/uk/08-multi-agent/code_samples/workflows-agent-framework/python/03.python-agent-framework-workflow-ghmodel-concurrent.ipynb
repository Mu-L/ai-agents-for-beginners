# %% [markdown]
# # ⚡ Паралельні робочі процеси агентів із Microsoft Foundry (Python)
#
# ## 📋 Поглиблений урок з паралельної обробки
#
# У цьому нотатнику демонструються **патерни паралельних робочих процесів** за допомогою Microsoft Agent Framework. Ви навчитеся створювати високопродуктивні робочі процеси з паралельною обробкою, де кілька AI-агентів виконуються одночасно, значно підвищуючи пропускну здатність і забезпечуючи складні багатопоточні бізнес-процеси.
#
# > **Примітка про міграцію:** Цей приклад раніше використовував моделі GitHub. Моделі GitHub застаріли (з припиненням підтримки у липні 2026 року), тому тепер використовується **Microsoft Foundry** через `FoundryChatClient`, який орієнтований на Azure OpenAI **Responses API**.
#
# ## 🎯 Навчальні цілі
#
# ### 🚀 **Основи паралельної обробки**
# - **Паралельне виконання агентів**: Запуск кількох агентів одночасно для максимальної ефективності
# - **Оркестрація робочих процесів**: Координація паралельних операцій з підтримкою цілісності даних
# - **Оптимізація продуктивності**: Досягнення суттєвого прискорення через паралельну обробку
# - **Управління ресурсами**: Ефективне використання ресурсів моделей AI у паралельних операціях
#
# ### 🏗️ **Складні патерни паралелізму**
# - **Обробка fork-join**: Розподіл роботи між кількома агентами і об'єднання результатів
# - **Паралелізм конвеєра**: Перекриття етапів виконання для постійної пропускної здатності
# - **Балансування навантаження**: Рівномірний розподіл роботи між доступними агентами
# - **Точки синхронізації**: Координація паралельних агентів на критичних етапах робочого процесу
#
# ### 🏢 **Паралельні корпоративні застосунки**
# - **Обробка великих обсягів документів**: Одночасна обробка кількох документів
# - **Аналіз даних у реальному часі**: Паралельний аналіз вхідних потоків даних
# - **Оптимізація пакетної обробки**: Максимізація пропускної здатності для великих масштабів
# - **Багатоканальний аналіз**: Паралельна обробка різних типів контенту (текст, зображення, дані)
#
# ## ⚙️ Вимоги та налаштування
#
# ### 📦 **Необхідні залежності**
#
# Встановіть Agent Framework з можливостями паралельних робочих процесів:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Конфігурація Microsoft Foundry**
#
# Увійдіть через Azure CLI (`az login`), щоб `AzureCliCredential` міг аутентифікуватися, потім встановіть дані вашого проєкту Microsoft Foundry.
#
# **Налаштування середовища (.env файл):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Особливості паралельної обробки:**
# - **Обмеження швидкості**: Моніторинг лімітів Azure OpenAI для паралельних запитів
# - **Використання ресурсів**: Урахування використання пам’яті та ЦП при кількох паралельних агентах
# - **Обробка помилок**: Впровадження надійного відновлення при паралельних операціях
#
# ### 🏗️ **Архітектура паралельних робочих процесів**
#
# ```mermaid
# graph TD
#     A[Початок робочого процесу] --> B[Паралельне виконання]
#     B --> C[Пул агентів 1]
#     B --> D[Пул агентів 2]
#     B --> E[Пул агентів 3]
#     C --> F[Агрегація результатів]
#     D --> F
#     E --> F
#     F --> G[Кінцевий результат]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Ключові переваги:**
# - **⚡ Продуктивність**: Значне прискорення завдяки паралельному виконанню
# - **📈 Масштабованість**: Обробка зростаючого навантаження без пропорційного збільшення часу
# - **🔄 Ефективність**: Краща експлуатація доступних обчислювальних ресурсів
# - **🎯 Пропускна здатність**: Виконання більшої кількості роботи за той самий час
#
# ## 🎨 **Патерни проєктування паралельних робочих процесів**
#
# ### 🔍 **Конвеєр досліджень та аналізу**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Робочий процес обробки даних**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Конвеєр створення контенту**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Багатостадійна обробка**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Переваги корпоративної продуктивності**
#
# ### ⚡ **Оптимізація пропускної здатності**
# - **Паралельне виконання**: Кілька агентів працюють одночасно
# - **Використання ресурсів**: Максимальна ефективність доступної потужності моделей AI
# - **Зменшення часу**: Значне скорочення загального часу обробки
# - **Масштабована архітектура**: Легке додавання більшої кількості паралельних агентів за потреби
#
# ### 🛡️ **Надійність і стійкість**
# - **Відмовостійкість**: Збої окремих агентів не зупиняють весь робочий процес
# - **Ізоляція помилок**: Проблеми в одному паралельному гілці не впливають на інші
# - **Граціозне погіршення**: Система продовжує роботу навіть із зменшеною кількістю агентів
# - **Механізми відновлення**: Автоматичне повторне виконання і обробка помилок для неуспішних операцій
#
# ### 📊 **Моніторинг та спостережливість**
# - **Відстеження паралельного виконання**: Контроль прогресу усіх паралельних операцій
# - **Метрики продуктивності**: Вимірювання прискорення та приросту ефективності
# - **Аналітика використання ресурсів**: Оптимізація розподілу паралельних агентів
# - **Виявлення вузьких місць**: Пошук і усунення обмежень в продуктивності
#
# Давайте створювати високопродуктивні паралельні AI-робочі процеси! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено за допомогою сервісу штучного інтелекту для перекладу [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, будь ласка, майте на увазі, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ рідною мовою слід вважати авторитетним джерелом. Для критично важливої інформації рекомендується професійний людський переклад. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
