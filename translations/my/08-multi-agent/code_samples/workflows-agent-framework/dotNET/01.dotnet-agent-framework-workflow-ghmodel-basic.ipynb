# %% [markdown]
# # 🔄 Azure OpenAI (Responses API) (.NET) ဖြင့် အခြေခံ Agent ဖြတ်လုပ်ငန်းစဉ်များ
#
# ## 📋 Workflow စီမံခန့်ခွဲခြင်း သင်ခန်းစာ
#
# ဒီ notebook သည် Microsoft Agent Framework for .NET နှင့် Azure OpenAI (Responses API) ကို အသုံးပြုပြီး ကြီးမားပြီး ဖန်တီးမှုပညာပြည့် စိတ်ဝင်စားဖို့လိုအပ်တဲ့ **agent workflows** များကို မည်သို့ တည်ဆောက်ရမည်ကို ပြသသည်။ သင်သည် AI agents များက စပ်ဆိုင်ရာ အဆင့်များ နှင့်စပ်လျဉ်းလျှောက် လုပ်ငန်းများကို ပူးပေါင်းပြီး ဖွဲ့စည်းစီမံမှု ဒီဇိုင်းများဖြင့် စွန့်ဆောင်နိုင်မှုရှိကြောင်း သင်ယူမည်။
#
# ## 🎯 သင်ယူရမည့် ရည်ရွယ်ချက်များ
#
# ### 🏗️ **Workflow ဖွဲ့စည်းမှု အခြေခံများ**
# - **Workflow Builder**: ကြီးမားပြီး ချည်းချပြီး မျိုးစုံ AI ပြုလုပ်စဉ်များကို ဒီဇိုင်းဆွဲခြင်းနှင့် စီမံခန့်ခွဲခြင်း
# - **Agent ညှိနှိုင်းမှု**: Workflow များ၌ စပ်ဆိုင်မှုရှိသော agent များကို ညှိနှိုင်းခြင်း
# - **Azure OpenAI (Responses API)**: Workflow များတွင် Azure OpenAI Responses API ကို အသုံးချခြင်း
# - **ကြည့်ရှုနိုင်သော Workflow ဒီဇိုင်း**: Workflow ဖွဲ့ စည်းအတည်ပြုနိုင်မှုအတွက် အပေါ်ယံအဆင့်များဖန်တီးခြင်းနှင့် မှတ်သားခြင်း
#
# ### 🔄 **လုပ်ငန်းစဉ် စီမံမှု စံနမူနာများ**
# - **ဆက်တိုက်လုပ်ဆောင်မှု**: ကောင်းမွန်စွာစီစဉ်ထားသော အဆင့်များဖြင့် agent လုပ်ငန်းများကို ဆက်တိုက်ချိတ်ဆက်ခြင်း
# - **အနေအထား စီမံခန့်ခွဲမှု**: Workflow အဆင့်များအတွင်း အကြောင်းအရာနှင့် ဒေတာပျံ့နှံမှုကို ထိန်းသိမ်းခြင်း
# - **အမှား ကိုင်တွယ်မှု**: မတော်တဆဖြစ်မှုများကို တည်ကြည်စွာ ဖြေရှင်းရေးနှင့် စနစ်တည်ငြိမ်မှု ထားရှိခြင်း
# - **ဆောင်ရွက်မှု အထူးပြုမှု**: စီးပွားရေးအဆင့်တွင် ထိရောက်သော workflow များ ဒီဇိုင်း ချခြင်း
#
# ### 🏢 **စီးပွားရေးလုပ်ငန်း Workflow အသုံးအနှုန်းများ**
# - **အလုပ်လုပ်ငန်း လုပ်ငန်းစဉ် အလိုအလျှော့သတ်မှတ်ခြင်း**: ကြီးမားသော အဖွဲ့အစည်း workflow များကို အလိုအလျှော့ ပြုလုပ်ခြင်း
# - **အကြောင်းအရာ ထုတ်လုပ်မှု လုပ်ငန်းစဉ်**: ပြန်လည်သုံးသပ်မှုနှင့် အတည်ပြုခြင်း အဆင့်ပါ editorial workflow များ
# - **ဖောက်သည် ဝန်ဆောင်မှု အလိုအလျော့သတ်မှတ်ခြင်း**: ဖောက်သည် မေးခွန်းများကို အဆင့်များစွာ ဖြေရှင်းခြင်း
# - **ဒေတာ ကိုင်တွယ်မှု Workflow များ**: AI ချိတ်ဆက်မှုပြုလုပ်ထားသော ETL workflow များ
#
# ## ⚙️ မတိုင်မီ လိုအပ်ချက်များနှင့် တပ်ဆင်ခြင်း
#
# ### 📦 **လိုအပ်သော NuGet Packages များ**
#
# ဒီ workflow ပြသမှုမှာ အခြေခံ .NET packages အချို့ကို အသုံးပြုသည်။
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.13.1" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI ပြင်ဆင်ခြင်း**
#
# **ပတ်ဝန်းကျင် ပြင်ဆင်ခြင်း (.env ဖိုင်):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-5-mini
# ```
#
# **Azure OpenAI ဝင်ရောက်မှု:**
# 1. Azure portal တွင် Azure OpenAI resource တည်ဆောက်ပါ
# 2. မော်ဒယ်တစ်ခု (ဥပမာ `gpt-5-mini`) တပ်ဆင်ပြီး deployment အမည် မှတ်သားသည်
# 3. `az login` ဖြင့် လက်မှတ်ထိုးဝင်၍ ပတ်ဝန်းကျင် အား 위와 같이 설정합니다
#
# ### 🏗️ **Workflow ဖွဲ့စည်းမှု အနှစ်ချုပ်**
#
# ```mermaid
# graph TD
#     A[လည်ပတ်မှု တည်ဆောက်သူ] --> B[এဂျင့် စာရင်း]
#     B --> C[လည်ပတ်မှု အကောင်အထည်ဖော်ရာ အင်ဂင်]
#     C --> D[Agent 1: အကြောင်းအရာ ဖန်တီးသူ]
#     C --> E[Agent 2: အကြောင်းအရာ ပြန်လည်စစ်မှန်သူ]
#     D --> F[လည်ပတ်မှု ရလဒ်များ]
#     E --> F
#     G[Azure OpenAI (တုံ့ပြန်ချက် API)] --> D
#     G --> E
# ```
#
# **အဓိက ဥယ်ာဥ်များ:**
# - **WorkflowBuilder**: Workflow များ ဒီဇိုင်းဆွဲခြင်းနှင့် ဆောင်ရွက်မှုပို့ဆောင်ရေးအင်ဂျင်
# - **AIAgent**: လုပ်ငန်းစွမ်းရည် သတ်မွတ်ထားသော ကိုယ်ပိုင် agent များ
# - **Azure OpenAI Client**: Azure OpenAI Responses API ပေါင်းစပ်မှု
# - **Execution Context**: Workflow အဆင့်များအတွင်း အနေအထား နှင့် ဒေတာလှိုင်းဖြတ်မှု အုပ်ချုပ်မှု
#
# ## 🎨 **စီးပွားရေး Workflow ဒီဇိုင်း စံနမူနာများ**
#
# ### 📝 **အကြောင်းအရာ ထုတ်လုပ်မှု Workflow**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **စာရွက်စာတမ်း ကိုင်တွယ်မှု လုပ်ငန်းစဉ်**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **စီးပွားရေး သတင်းအချက်အလက် Workflow**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **ဖောက်သည် ဝန်ဆောင်မှု အလိုအလျော့သတ်မှတ်ခြင်း**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **စီးပွားရေးပိုင်း အကျိုးကျေးဇူးများ**
#
# ### 🎯 **ယုံကြည်စိတ်ချမှု & မြင့်မားသော တိုးတက်မှု**
# - **တိကျသော ဆောင်ရွက်မှု**: တည်ငြိမ်ပြီး ထပ်မံလုပ်ဆောင်နိုင်သော workflow ရလဒ်များ
# - **အမှား ပြုပြင်ခြင်း**: Workflow အဆင့်မည့်သည့်အတွက် ဖြစ်ပျက်နိုင်သည့်အမှားများကို အေးချမ်းစွာ ဖြေရှင်းမှု
# - **ဆောင်ရွက်မှု ကြည့်ရှုမှု**: ကိန်းဂဏန်းများနှင့် တိုးတက်မှု အခွင့်အလမ်းများ စုံစမ်းထောက်လှမ်းခြင်း
# - **အရင်းအမြစ် စီမံခန့်ခွဲမှု**: AI မော်ဒယ် အရင်းအမြစ်ကို ထိရောက်စွာ ခွဲဝေ သုံးစွဲမှု
#
# ### 🔒 **လုံခြုံမှု နှင့် တည်းဖြတ်ထားမှု**
# - **လုံခြုံသော လက်မှတ်ထိုးခြင်း**: Microsoft Entra ID သုံးပြီး `az login` (AzureCliCredential) ဖြင့် အတည်ပြုခြင်း
# - **စစ်ဆေးမှု လမ်းကြောင်းများ**: Workflow ဆောင်ရွက်မှု သတင်းအချက်အလက်များ နှင့် ဆုံးဖြတ်ချက်များမှ ချုံ့ေရာင်းခြင်း
# - **ဝင်ရောက်ခွင့် ထိန်းချုပ်မှု**: Workflow ဆောင်ရွက်မှုနှင့် ကြည့်ရှုမှုအတွက် ခွင့်ပြုချက် အတိုင်းတစ်ကြိမ်မှန်စွာ ထိန်းချုပ်ခြင်း
# - **ဒေတာ ကိုယ်ပိုင်အချက်အလက် စနစ်**: Workflow များတွင် ပုဂ္ဂိုလ်ရေးအချက်အလက်များ ကို လုံခြုံစွာ ကိုင်တွယ်မှု
#
# ### 📊 **ကြည့်ရှုမှုနှင့် စီမံခန့်ခွဲမှု**
# - **ကြည့်ရှုနိုင်သော Workflow ဒီဇိုင်း**: လုပ်ငန်းစဉ်များနှင့် မကျေမနပ်သည့် အစိတ်အပိုင်းများ ပုံဖော်ပြသခြင်း
# - **ဆောင်ရွက်မှု ကြည့်ရှုမှု**: Workflow တိုးတက်မှုနှင့် ဆောင်ရွက်မှုကို အချိန်နှင့်တပြိုင်နက် စောင့်ကြည့်နိုင်ခြင်း
# - **အမှားအစီရင်ခံစာ**: အသေးစိတ် မှားယွင်းမှုစစ်တမ်းနှင့် ဖျက်ဆီးခြင်း ပုံရှာနိုင်စွမ်း
# - **ဆောင်ရွက်မှု တွက်ချက်မှု**: တိုးတက်ရေးနှင့် စွမ်းအားစီမံခန့်ခွဲမှုအတွက် အကွပ်အတည်းများ
#
# စီးပွားရေးအဆင့်အသင့် AI workflow ကို ပထမဆုံးတည်ဆောက်ကြစို့! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"
#r "nuget: OpenTelemetry.Api, 1.0.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.0.1</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"

# %%
using System;
using System.ComponentModel;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-5-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Visit the Louvre Museum. It's a must-see for art enthusiasts and history lovers.That recommendation is quite popular and likely to attract many tourists. To refine it for a more local and authentic experience, consider suggesting an alternative that focuses on smaller, lesser-known art venues or galleries. Look for places where local artists exhibit or community spaces that host cultural events. This approach allows travelers to connect with the local art scene more intimately, away from the typical tourist routes.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
