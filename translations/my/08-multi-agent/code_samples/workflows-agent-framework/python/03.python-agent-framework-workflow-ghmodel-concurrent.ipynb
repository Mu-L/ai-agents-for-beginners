# %% [markdown]
# # ⚡ Microsoft Foundry (Python) နှင့်အတူ တပြိုင်နက် Agent Workflow များ
#
# ## 📋 တိုးတက်ပြီး တပြိုင်နက် လုပ်ငန်းစဉ် သင်ခန်းစာ
#
# ဤ notebook တွင် Microsoft Agent Framework ကို အသုံးပြု၍ **တပြိုင်နက် Workflow များ** ကို ပြသထားသည်။ အများအပြား AI agent များ အချိန်တပြိုင်နက် တွက်ဆက်လုပ်ဆောင်ရာတွင် ထိရောက်မှုမြင့်ပြီး မြန်ဆန်စွာ လုပ်ငန်းစဉ်များကို များပြားစွာ တိုးတက်ကောင်းမွန်စေသည်။
#
# > **ရွေ့ပြောင်းရေး မှတ်ချက်:** ဤနမူနာသည် ယခင်က GitHub Models ကို ကိုးကားခဲ့သည်။ GitHub Models သည် ပိတ်သိမ်းသွားမည်ဖြစ်သောကြောင့် (၂ဝ၂၆ ဇူလိုင်တွင်), ယခုတွင် Microsoft Foundry ကို `FoundryChatClient` မှတဆင့် အသုံးပြုသည်။ ၎င်းသည် Azure OpenAI **Responses API** ကို ရည်ရွယ်သည်။
#
# ## 🎯 သင်ယူရမည့် ရည်မှန်းချက်များ
#
# ### 🚀 **တပြိုင်နက် လုပ်ငန်းစဉ် မူလအဆင့်**
# - **တပြိုင်နက် Agent ဆောင်ရွက်ခြင်း**: အရှိန်အဟုန်အပြည့်ဖြင့် အတူတကွ agent များကို စနစ်တကျ ဆောင်ရွက်ခြင်း
# - **Workflow ပေါင်းစည်းဆောင်ရွက်ခြင်း**: ဒေတာတည်ငြိမ်မှုရှိစေရန် တပြိုင်နက် လုပ်ငန်းစဉ်များကို ပေါင်းစည်းညှိနှိုင်းခြင်း
# - **စွမ်းဆောင်ရည် တိုးတက်စေရန်**: တပြိုင်နက် လုပ်ငန်းစဉ်မှတဆင့် အရှိန်မြှင့်ခြင်း
# - **အရင်းအမြစ် စီမံခန့်ခွဲမှု**: တပြိုင်နက်လုပ်ငန်းစဉ်များအတွင်း AI ပုံမှန်များကို အသုံးပြု ထိထိရောက်ရောက် စီမံခန့်ခွဲခြင်း
#
# ### 🏗️ **တိုးတက်သော တပြိုင်နက် စနစ်အပိုင်းများ**
# - **Fork-Join ဆောင်ရွက်ခြင်း**: အလုပ်ကို အများအပြား agent များသို့ ခွဲထုတ်ပြီး ရလဒ်များကို ပေါင်းစည်းခြင်း
# - **Pipeline ပြိုင်ဆိုင်မှု**: များစွာသော အဆင့်များကို အချိန်တပြေးညီ ဆောင်ရွက်ခြင်း
# - **စွမ်းဆောင်ရည် ချိန်ညှိခြင်း**: လက်ရှိ agentအရင်းအမြစ်များအပေါ် အလုပ်ခွဲဝေခြင်း
# - **ချိန်ညှိမှု စာရင်းများ**: မတူညီသော အဆင့်များတွင် တပြိုင်နက် agents များကို ညှိနှိုင်းခြင်း
#
# ### 🏢 **စီးပွားရေး တပြိုင်နက် စွမ်းဆောင်ရည်များ**
# - **မြင့်မားသောစာရွက်စာတမ်း ဆောင်ရွက်ခြင်း**: အပြိုင် အကြား စာရွက်စာတမ်းများအလိုက် လုပ်ငန်းဆောင်ရွက်ခြင်း
# - **အချိန်နှင့်တပြေးညီ အကြောင်းအရာ သုံးသပ်ခြင်း**: ရလာဒ်များကို တပြိုင်နက် ရေစီးကြား ဆန်းစစ်သုံးသပ်ခြင်း
# - **တစ်ခါတည်း လုပ်ငန်းစဉ်များ အမြှင့်ဆောင်ရွက်ခြင်း**: အကြီးစားလုပ်ငန်းများတွင် ထိရောက်မှု မြှင့်တင်ခြင်း
# - **အမျိုးမျိုး ပုံစံ သုံးသပ်မှု**: ကွဲပြားသော အကြောင်းအရာမျိုးစုံ (စာသား၊ ပုံရိပ်၊ ဒေတာ) များကို တပြိုင်နက် ဆောင်ရွက်ခြင်း
#
# ## ⚙️ အရင်လိုအပ်ချက်များ နှင့် ပြင်ဆင်ခြင်း
#
# ### 📦 **လိုအပ်သော အစိတ်အပိုင်းများ**
#
# တပြိုင်နက် workflow အတွက် Agent Framework ကို ထည့်သွင်းပါ။
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ပြင်ဆင်မှု**
#
# Azure CLI (`az login`) ဖြင့် အထောက်အထားယူပြီး `AzureCliCredential` ဖြင့် အတည်ပြုပါ။ ထို့နောက် Microsoft Foundry ပရောဂျက် အသေးစိတ်များ ထည့်သွင်းပါ။
#
# **ပတ်ဝန်းကျင် ပြင်ဆင်မှု (.env ဖိုင်):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **တပြိုင်နက် လုပ်ငန်းစဉ်တွင် စဉ်းစားရန်:**
# - **အရှိန် အကန့်အသတ်**: Azure OpenAI rate limit များကို စောင့်ကြည့်ပါ။
# - **အရင်းအမြစ် အသုံးပြုမှု**: တပြိုင်နက် agent များ၏ မျက်စိမှတဆင့် ပြန်လည်သုံးစွဲမှု
# - **အမှား ကိုင်တွယ်မှု**: တပြိုင်နက် လုပ်ငန်းစဉ်အတွက် ပြည့်စုံသော အမှား ပြန်လည်ထူထောင်မှု
#
# ### 🏗️ **တပြိုင်နက် Workflow အင်ဂျင်နီယာနည်းပညာ**
#
# ```mermaid
# graph TD
#     A[လုပ်ငန်းစဉ် အစ] --> B[ဆက်သွယ်ပြီး သတ်မှတ်လုပ်ဆောင်မှု]
#     B --> C[ကိုယ်စားလှယ်ကွင်း ၁]
#     B --> D[ကိုယ်စားလှယ်ကွင်း ၂]
#     B --> E[ကိုယ်စားလှယ်ကွင်း ၃]
#     C --> F[ရလဒ်စုစည်းခြင်း]
#     D --> F
#     E --> F
#     F --> G[နောက်ဆုံးထွက်ရှိမှု]
#
#     H[မိုက်ခရိုဆော့ဖ့် ဖောင်ဒရီ] --> C
#     H --> D
#     H --> E
# ```
#
# **အဓိက အကျိုးကျေးဇူးများ:**
# - **⚡ စွမ်းဆောင်ရည်မြင့်**: တပြိုင်နက် ဆောင်ရွက်မှုတို့မှ မြန်ဆန်မှု မြင့်တက်ခြင်း
# - **📈 တိုးချဲ့နိုင်မှု**: လုပ်ငန်းအလုံးစုံတိုးမြှင့်လာသော်လည်း အချိန် မတိုးခက်ခြင်း
# - **🔄 ထိတွေ့မှုမြင့်**: ရရှိနိုင်သော ကွန်ပျူတာ အရင်းအမြစ်များကို ထိထိရောက်ရောက် သုံးစွဲခြင်း
# - **🎯 အမြတ်အစွန်းများ**: အချိန်တူညီစွာ ပိုမိုအလုပ်များ ဆောင်ရွက်နိုင်ခြင်း
#
# ## 🎨 **တပြိုင်နက် Workflow ဒီဇိုင်းပုံစံများ**
#
# ### 🔍 **သုတေသန နှင့် သုံးသပ်မှု Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ဒေတာ ဆက်လက်လုပ်ငန်းစဉ်**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **အကြောင်းအရာ ဖန်တီးမှု Pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **အဆင့် များစွာ အလုပ်ဆောင်ခြင်း**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **စီးပွားရေး စွမ်းဆောင်ရည် အကျိုးကျေးဇူးများ**
#
# ### ⚡ **စွမ်းဆောင်ရည် တိုးမြှင့်ခြင်း**
# - **တပြိုင်နက် ဆောင်ရွက်မှု**: အများကြီးသော agents များ အချိန်တပြိုင်နက် ဆောင်ရွက်ခြင်း
# - **အရင်းအမြစ် အသုံးပြုမှု**: ရရှိနိုင်သမျှ AI capacity များကို အထူးပြု ထိရောက်စွာသုံးစွဲခြင်း
# - **အချိန် လျော့နည်းခြင်း**: စုစုပေါင်းလုပ်ငန်းစဉ်အချိန် ကို အထူးသဖြင့် လျော့နည်းစေခြင်း
# - **တိုးချဲ့နိုင်သည့် တည်ဆောက်မှု**: လိုအပ်သလို တပြိုင်နက် agents များ တိုးမြှင့်နိုင်ခြင်း
#
# ### 🛡️ **ယုံကြည်စိတ်ချရမှု နှင့် ပြန်လည်ခံနိုင်မှု**
# - **အမှားခံနိုင်မှု**: Agent တစ်ဦးချင်း ပျက်စီးမှုများသည် စနစ် စုစုပေါင်းကို မတားဆီးပါ။
# - **အမှား သီးခြားထားမှု**: တပြိုင်နက် branch တစ်ခုမှ ပြဿနာသည် အခြား branch များအား မထိခိုက်စေပါ။
# - **သွေးသန့်ပြန်လည်လျော့နည်းမှု**: Agent မြောက်မားမှု နည်းသော်လည်း စနစ် ဆက်လက်ပြေးဆွဲနိုင်ပါသည်။
# - **နောက်ထပ် ပြန်လည်လုပ်ဆောင်မှု**: မအောင်မြင်သော လုပ်ငန်းစဉ်များအတွက် အလိုအလျောက် retry နှင့် error ကိုင်တွယ်မှု
#
# ### 📊 **စောင့်ကြည့်မှုနှင့် တွေ့ရှိနိုင်မှု**
# - **တပြိုင်နက် ဆောင်ရွက်မှု ကြည့်ရှုခြင်း**: အားလုံးသော တပြိုင်နက် လုပ်ငန်းစဉ်များ အဆင့်အသွားများကို စောင့်ကြည့်
# - **စွမ်းဆောင်ရည် အချက်အလက် များ**: မြန်ဆန်မှုနှင့် ထိရောက်မှု တိုးတက်မှုတိုင်းတာခြင်း
# - **အရင်းအမြစ်အသုံးပြုမှု သုံးသပ်ခြင်း**: တပြိုင်နက် agent များ ဖန်တီးမှု မွမ်းမံခြင်း
# - **ပိတ်တားမှုများ ရှာဖွေရှင်းရမှု**: စွမ်းဆောင်ရည် ကန့်သတ်မှုများ တွေ့ရှိပြီး ဖြေရှင်းခြင်း
#
# အမြန်ဆုံး အတူတကွ AI Workflow များ တည်ဆောက်ကြရအောင်! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
