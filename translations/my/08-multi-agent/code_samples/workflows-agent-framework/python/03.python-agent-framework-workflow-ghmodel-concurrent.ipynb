# %% [markdown]
# # ⚡ Microsoft Foundry (Python) ဖြင့် အချိန်မီအေးဂျင့် လုပ်ငန်းစဉ်များ
#
# ## 📋 အဆင့်မြင့် 병렬ုလုပ်ငန်းစဉ် သင်ခန်းစာ
#
# ဤ notebook သည် Microsoft Agent Framework ကို အသုံးပြု၍ **အချိန်မီလုပ်ငန်းစဉ် များ** ကို ပြသပါသည်။ သင်သည် အမြန်နှုန်းမြင့်၊ 병렬(root)လုပ်ငန်းစဉ်များကို တည်ဆောက်နည်းကို လေ့လာမည်ဖြစ်ပြီး၊ ထိုလုပ်ငန်းစဉ်များတွင် အေးဂျင့်များစွာသည် တပြိုင်နက်တည်း လုပ်ဆောင်ပြီး throughput ကို ထိရောက်စွာမြှင့်တင်နိုင်ပြီး မဟာဗျူဟာ အပေါ်လုပ်ငန်းစဉ်များကို ခွဲထုတ်နိုင်ပါသည်။
#
# > **မိုင်ဂရိတ် နုတ်ချက်:** ဤနမုတ်က GitHub Models ကို ယခင်က ကိုးကားခဲ့သည်။ GitHub Models သည် အသုံးမပြုတော့တော့မည် (၂၀၂၆ ဇူလိုင်တွင် ထုတ်ချ) ဖြစ်၍ ယခုတွင် `FoundryChatClient` မှတဆင့် **Microsoft Foundry** ကို အသုံးပြုသည်၊ ၎င်းသည် Azure OpenAI **Responses API** ကို ပြုလုပ်ပါသည်။
#
# ## 🎯 သင်ယူရမည့် ရည်မှန်းချက်များ
#
# ### 🚀 **အချိန်မီ လုပ်ငန်းစဉ် အခြေခံမျိုးနွယ်များ**
# - **병렬 အေးဂျင့် ထိန်းချုပ်မှု**: အမြင့်ဆုံး ထိရောက်မှုအတွက် အေးဂျင့်အများကြီးကို တပြိုင်နက်တည်း စတင် စီမံခန့်ခွဲခြင်း
# - **လုပ်ငန်းစဉ် ချုပ်ကိုင်မှု**: အချိန်မီလုပ်ငန်းများကို ညှိနှိုင်းစဉ်းစားပြီး ဒေတာတစ်ခုထဲ ဖြစ်စဉ်ကို ထိန်းသိမ်းပါ
# - **ထိရောက်မှုပြုလုပ်ခြင်း**: 병렬 ဖြင့် အရှိန်မြှင့်တင်ခြင်း
# - **အရင်းအမြစ်စီမံခန့်ခွဲမှု**: အေးဂျင့်များအဖြစ် AI မော်ဒယ် များကို ထိရောက်စွာ အသုံးပြုခြင်း
#
# ### 🏗️ **အဆင့်မြင့် 병렬 မျိုးစိတ်**
# - **Fork-Join လုပ်ငန်းစဉ်**: အလုပ်ကို အေးဂျင့်စွမ်းရည်များဖြင့် ခွဲပြီး ရလဒ်များ ကို ပေါင်းစပ်စီမံခြင်း
# - **Pipeline 병렬မှု**: အဆင့်များသည် အချိန်ပြန်ဖြတ်၍ ဆက်တိုက်လုပ်ဆောင်ခြင်း
# - **အလုပ်ချိန်မျှဝေခြင်း**: အလုပ်များကို အေးဂျင့် မရနိုင်သူအပေါ် တန်းတူခွဲဝေခြင်း
# - **ညှိနှိုင်းမှု မှတ်စုများ**: အရေးကြီးသောအဆင့်များတွင် အေးဂျင့်များကို ညှိနှိုင်းခြင်း
#
# ### 🏢 **ကုမ္ပဏီ အချိန်မီလျှောက်လွှာများ**
# - **အတော်များများ စာရွက်စာတမ်း လုပ်ဆောင်ခြင်း**: စာရွက်စာတမ်းများ အတူတကွ လုပ်ငန်းဆောင်ရွက်ခြင်း
# - **တစ်ချက်ချင်း ဒေတာစီးဆင်းမှု သုံးသပ်ခြင်း**: ဝင်ရောက်လာသော ဒေတာများကို သုံးသပ်ခြင်း
# - **စုစုပေါင်းလုပ်ငန်းစဉ် ထိရောက်မှုမြှင့်တင်ခြင်း**: ကြီးမားသောနယ်ပယ်များတွင် throughput ကို အကြီးမားဆုံးမြှင့်တင်ခြင်း
# - **အမျိုးသားဖော်ပြမှု စစ်တမ်းများ**: လက်ရှိ မတူညီသောအကြောင်းအရာများကို 병렬 ဖြင့် ကြိုးပမ်းဆောင်ရွက်ခြင်း (စာသား၊ ပုံများ၊ ဒေတာ)
#
# ## ⚙️ မဖြစ်မနေ လိုအပ်ချက်များနှင့် သတ်မှတ်ချက်များ
#
# ### 📦 **လိုအပ်သော အမှီအခိုက်များ**
#
# concurrent workflow စွမ်းရည်များပါဝင်သော Agent Framework ကို ထည့်သွင်းပါ
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Configuration**
#
# Azure CLI (`az login`) ဖြင့် အကောင့်ဝင်ပြီး `AzureCliCredential` ဖြင့် အတည်ပြုချက်ယူပါ၊ ထို့နောက် Microsoft Foundry project အသေးစိတ်ဖော်ပြပါ။
#
# **ပတ်ဝန်းကျင် ပြင်ဆင်ခြင်း (.env ဖိုင်):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **အချိန်မီလုပ်ငန်းစဉ် တွင် စဉ်းစားရန်အချက်များ:**
# - **နိမ့်ချမှု အကန့်အသတ်များ**: Azure OpenAI request အတွက် နိမ့်ချမှု အကန့်အသတ်များကို စောင့်ကြည့်ပါ
# - **အရင်းအမြစ် အသုံးပြုမှု**: စွမ်းရည်များ ရှိသော အေးဂျင့်များစွာဖြင့် မေမရီနှင့် CPU ကို သုံးစွဲမှုကို စဉ်းစားပါ
# - **အမှားဆောင်ရွက်ခြင်း**: 병렬 လုပ်ငန်းများအတွက် ထင်ရှားသော အမှား ကာကွယ်မှုစနစ် တည်ဆောက်ပါ
#
# ### 🏗️ **အချိန်မီလုပ်ငန်းစဉ် ပုံစံ**
#
# ```mermaid
# graph TD
#     A[လုပ်ငန်းစဉ် စတင်ခြင်း] --> B[တပြိုင်နက် ဆောင်ရွက်ခြင်း]
#     B --> C[အေးဂျင့်ကွင်း ၁]
#     B --> D[အေးဂျင့်ကွင်း ၂]
#     B --> E[အေးဂျင့်ကွင်း ၃]
#     C --> F[ရလဒ် စုစည်းခြင်း]
#     D --> F
#     E --> F
#     F --> G[နောက်ဆုံးထွက်ရှိချက်]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **အဓိကအကျိုးအမြတ်များ:**
# - **⚡ ထိရောက်မှု**: 병렬 လုပ်ငန်းစဉ်မှ တစ်ဆင့် အရှိန်အဟုန် မြှင့်တင်ခြင်း
# - **📈 ပမာဏမြှင့်တင်မှု**: လုပ်ငန်းများ ကြီးထွားလာသော်လည်း အချိန်တိုးမခြင်း
# - **🔄 ထိရောက်မှု**: ရရှိနိုင်သော စက်ရုပ် အရင်းအမြစ်များကို ပိုမို အသုံးချခြင်း
# - **🎯 throughput**: တစ်ချိန်တည်းတွင် အလုပ်ပိုများဆောင်ရွက်ခြင်း
#
# ## 🎨 **အချိန်မီလုပ်ငန်းစဉ် ဒီဇိုင်းပုံစံများ**
#
# ### 🔍 **သုတေသနနှင့် သုံးသပ်ခြင်း pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ဒေတာလုပ်ငန်းစဉ်**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **အကြောင်းအရာ ဖန်တီးမှု pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **အဆင့်များဖြတ်သန်းပြီး လုပ်ဆောင်ခြင်း**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ကုမ္ပဏီစနစ် အမြတ်ထုတ်**
#
# ### ⚡ **throughput ကြီးမြတ်မှု**
# - **병렬 လုပ်ဆောင်ချက်များ**: အေးဂျင့်များစွာကို တပြိုင်နက် တည်း လုပ်ဆောင်ခြင်း
# - **အရင်းအမြစ်အသုံးပြုမှု**: ရရှိနိုင်သည့် AI မော်ဒယ် စွမ်းရည်များကို အများဆုံး အသုံးချခြင်း
# - **အချိန် လျော့ချမှု**: စုစုပေါင်း လုပ်ငန်းစဉ် အချိန် လျော့နည်းခြင်း
# - **ပြောင်းလို့ရသော ပုံဆောင်မှု**: လိုအပ်သလို concurrent အေးဂျင့်များကို တိုးချဲ့နိုင်ခြင်း
#
# ### 🛡️ **ယုံကြည်စိတ်ချမှုနှင့် ပြန်လည်ရယူနိုင်မှု**
# - **အမှားခံနိုင်ရည်**: တစ်ဦးချင်း အေးဂျင့် မအောင်မြင်မှုများသည် လုံးล 全လုပ်ငန်းစဉ် ကို မပိတ်ပင်ပါ
# - **အမှား ခွဲခြားစီမံခြင်း**: concurrent အကြောင်းအရာတစ်ခုမှာ ပြဿနာများသည် အခြားအကြောင်းအရာများကို မထိခိုက်စေပါ
# - **ဟန်ချက်ညီအောင်ချထားမှု**: အေးဂျင့်စွမ်းရည် လျော့ပါးသော်လည်း စနစ် ဆက်လက်တက်မြှင့်နိုင်ခြင်း
# - **ပြန်လည်ကောင်းမွန်စေနည်းများ**: အလုပ်မပြီးဆုံးသော အရာများအတွက် အလိုအလျောက် ထပ်မံကြိုးစားခြင်းနှင့် အမှား ကိုင်တွယ်ခြင်း
#
# ### 📊 **စောင့်ကြည့်မှုနှင့် ကြည့်ရှုနိုင်မှု**
# - **အချိန်မီ အလုပ်တိုးမြှင့်မှု စောင့်ကြည့်မှု**: 병렬 လုပ်ငန်းတိုင်း၏ တိုးတက်မှုကို ချိန်ဆမှုပေးခြင်း
# - **ထိရောက်မှု စံချိန်များ**: အရှိန်တိုးခြင်းနှင့် ထိရောက်မှုများကို တိုင်းတာခြင်း
# - **အရင်းအမြစ် အသုံးပြုမှု ဆန်းစစ်မှု**: concurrent အေးဂျင့် ခန့်သတ်မှုကို အကောင်းဆုံး ပြုလုပ်ရန်
# - **ဆင်းရဲနစ်နာဒေါင် Identification**: ထိရောက်မှု ကန့်သတ်ချက်များ ရှာဖွေရှင်းလင်းခြင်း
#
# လုပ်ပါစို့၊ အမြင့်ဆုံး concurrent AI workflow များကို တည်ဆောက်ကြပါစို့! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
