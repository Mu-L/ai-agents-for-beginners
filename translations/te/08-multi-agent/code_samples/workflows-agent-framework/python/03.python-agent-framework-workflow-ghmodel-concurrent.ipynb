# %% [markdown]
# # ⚡ Microsoft Foundry (Python) తో సమాంతర ఏజెంట్ వర్క్‌ఫ్లోలు
#
# ## 📋 అభివృద్ధి చేసిన సమాంతర ప్రాసెసింగ్ ట్యుటోరియల్
#
# ఈ నోట్‌బుక్ Microsoft Agent Framework ఉపయోగించి **సమాంతర వర్క్‌ఫ్లో నమూనాలు**ని చూపిస్తుంది. మీకు ఎట్లా బిల్ట్ చేయాలో నేర్చుకుంటారు, ఎక్కువ సామర్థ్యం గల, సమాంతర ప్రాసెసింగ్ వర్క్‌ఫ్లోలు, ఇక్కడ అనేక AI ఏజెంట్లు సమాంతరంగా అమలు చేస్తారు, చాలా గణనీయంగా throughput పెరుగుదల మరియు సమర్థవంతమైన బహు-థ్రెడ్ వ్యాపార ప్రక్రియలను సాధ్యపడుస్తుంది.
#
# > **మైగ్రేషన్ గమనిక:** ఈ నమూనా ముందుగా GitHub Models ను సూచించింది. GitHub Models డిప్రికేటెడ్ అయింది (జూలై 2026 లో రిటైర్ అవుతుంది), అందువల్ల ఇప్పుడు ఇది `FoundryChatClient` ద్వారా **Microsoft Foundry** ఉపయోగిస్తుంది, ఇది Azure OpenAI **Responses API** ని లక్ష్యం చేసుకుని ఉంటుంది.
#
# ## 🎯 నేర్చుకునే లక్ష్యాలు
#
# ### 🚀 **సమాంతర ప్రాసెసింగ్ بنیادی అంశాలు**
# - **సమాంతర ఏజెంట్ అమలులు**: గరిష్ట సామర్థ్యానికి అనేక ఏజెంట్లను సమాంతరంగా సంచాలించండి
# - **వర్క్‌ఫ్లో సమన్వయం**: డేటా సాంద్రతను నిర్వహిస్తూ సమాంతర ఆపరేషన్లను కూడగట్టండి
# - **సామర్థ్య మెరుగుదల**: సమాంతర ప్రాసెసింగ్ ద్వారా విశేష వేగవంతం
# - **వనరు నిర్వహణ**: సమాంతర ఆపరేషన్లకు AI మోడల్ వనరుల సమర్థవంతమైన వినియోగం
#
# ### 🏗️ **అభివృద్ధి చెందిన సమాంతర నమూనాలు**
# - **ఫోర్క్-జాయిన్ ప్రాసెసింగ్**: అనేక ఏజెంట్లలో పని విభజించి ఫలితాలు కలపడం
# - **పైప్‌లైన్ సమాంతరత**: నిరంతర throughput కోసం అమలులో దశల్ని అడ్డదీసే విధానం
# - **భారం సమతుల్యపరచడం**: లభ్యమయ్యే ఏజెంట్ వనరులపై పనిని సమానంగా పంపిణీ చేయడం
# - **సమన్వయ స్థానాలు**: కీలక వర్క్‌ఫ్లో దశలలో సమాంతర ఏజెంట్లను కోఆర్డినేట్ చేయడం
#
# ### 🏢 **ఎంటర్‌ప్రైజ్ సమాంతర అప్లికేషన్లు**
# - **హై-వాల్యూమ్ డాక్యుమెంట్ ప్రాసెసింగ్**: అనేక డాక్యుమెంట్లను ఒకేసారి ప్రాసెస్ చేయడం
# - **రియల్-టైం కంటెంట్ విశ్లేషణ**: వచ్చే డేటా స్ట్రీముల సమాంతర విశ్లేషణ
# - **బ్యాచ్ ప్రాసెసింగ్ మెరుగుదల**: భారీ operations కోసం throughput గరిష్ట పరచడం
# - **బహు-మోడల్ విశ్లేషణ**: భిన్న కంటెంట్ రకాల (టెక్స్ట్, చిత్రం, డేటా) సమాంతర ప్రాసెసింగ్
#
# ## ⚙️ ముందు అవశ్యకాలు & సెటప్
#
# ### 📦 **కావలసిన ఆధారాలు**
#
# సమాంతర వర్క్‌ఫ్లో సామర్ధ్యాలతో Agent Framework ను ఇన్స్‌టాల్ చేయండి:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry సెట్టింగ్స్**
#
# Azure CLI (`az login`) తో సైన్ ఇన్ అయి `AzureCliCredential` ప్రామాణీకరణ, తర్వాత Microsoft Foundry ప్రాజెక్టు వివరాలు సెట్ చేయండి.
#
# **పరిసర విజ్ఞానం సెటప్ (.env ఫైల్):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **సమాంతర ప్రాసెసింగ్ వాటి పరిగణనలు:**
# - **రేటు పరిమితులు**: సమాంతర అభ్యర్థనలకు Azure OpenAI రేటు పరిమితులను గమనించండి
# - **వనరు వినియోగం**: అనేక ఏజెంట్లతో మెమరీ, CPU వాడకం పరిగణించండి
# - **లోపాల నిర్వహణ**: సమాంతర ఆపరేషన్ల కోసం బలమైన లోప పునరుద్ధరణను అమలు చేయండి
#
# ### 🏗️ **సమాంతర వర్క్‌ఫ్లో నిర్మాణం**
#
# ```mermaid
# graph TD
#     A[వర్క్‌ఫ్లో ప్రారంభం] --> B[సమకాలీన అమలు]
#     B --> C[ఏజెంట్ పూల్ 1]
#     B --> D[ఏజెంట్ పూల్ 2]
#     B --> E[ఏజెంట్ పూల్ 3]
#     C --> F[ఫలితాల సమీకరణ]
#     D --> F
#     E --> F
#     F --> G[తుది ఔట్‌పుట్]
#
#     H[మైక్రోసాఫ్ట్ ఫౌండ్రీ] --> C
#     H --> D
#     H --> E
# ```
#
# **ప్రధాన లాభాలు:**
# - **⚡ సామర్థ్యం**: సమాంతర అమలుతో గణనీయ వేగవంతం
# - **📈 పెరుగుదల సామర్థ్యం**: పనిబంధన పెరిగినా సమయంలో అనుపాతంగా పెరుగుదల లేదు
# - **🔄 సమర్థవంతం**: అందుబాటులో ఉన్న కంప్యూటేషన్ వనరులు మెరుగ్గా వినియోగం
# - **🎯 throughput**: ఒకానే సమయ వ్యవధిలో ఎక్కువ పని చేయండి
#
# ## 🎨 **సమాంతర వర్క్‌ఫ్లో డిజైన్ నమూనాలు**
#
# ### 🔍 **గవేషణ & విశ్లేషణ పైప్‌లైన్**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **డేటా ప్రాసెసింగ్ వర్క్‌ఫ్లో**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **కంటెంట్ సృష్టి పైప్‌లైన్**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **బహు-దశ ప్రాసెసింగ్**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ఎంటర్‌ప్రైజ్ సామర్థ్య లాభాలు**
#
# ### ⚡ **throughput మెరుగుదల**
# - **సమాంతర అమలు**: అనేక ఏజెంట్లు ఒకేసారి పని చేస్తారు
# - **వనరు వినియోగం**: అందుబాటులో ఉన్న AI మోడల్ సామర్థ్యాన్ని గరిష్టంగా వినియోగించడమె
# - **సమయ తగ్గింపు**: మొత్తం ప్రాసెసింగ్ సమయంలో గణనీయమైన తగ్గుదల
# - **పెరుగుదల ఆర్కిటెక్చర్**: అవసరమైతే మరింత సమాంతర ఏజెంట్లను సులభంగా చేర్చుకోవచ్చు
#
# ### 🛡️ **నమ్మకత & సహనం**
# - **పొరపాటు సహనం**: వ్యక్తిగత ఏజెంట్ వైఫల్యాలు మొత్తం వర్క్‌ఫ్లోను ఆపవు
# - **లోపాల విడివిడింపు**: ఒక సమాంతర శాఖలో సమస్యలు ఇతరులను ప్రభావితం చేయవు
# - **శాంతియుత తగ్గుదల**: ఏజెంట్ సామర్థ్యం తగ్గినా వ్యవస్థ కొనసాగుతుంది
# - **పునరుద్ధరణ మెకానిజములు**: విఫలమైన ఆపరేషన్లకు ఆటోమేటిక్ రీట్రై మరియు లోప నిర్వహణ
#
# ### 📊 **నిరీక్షణ & దృష్టిగోచరత**
# - **సమాంతర అమలుల ట్రాకింగ్**: అన్ని సమాంతర ఆపరేషన్ల పురోగతి పై పర్యవేక్షణ
# - **సామర్థ్య ప్రమాణాలు**: వేగవంతం మరియు సమర్థత లాభాలను కొలవు
# - **వనరు వినియోగ విశ్లేషణ**: సమాంతర ఏజెంట్ కేటాయింపును సమర్థవంతం చేయండి
# - **బాటిల్‌నెక్ గుర్తింపు**: సామర్థ్య పరిమితులను కనుగొని పరిష్కరించండి
#
# అభివృద్ధి చెందిన సమాంతర AI వర్క్‌ఫ్లోలను నిర్మిద్దాం! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **అస్వీకరణ**:
# ఈ పత్రం AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించబడింది. మేము ఖచ్చితత్వానికి ప్రయత్నిస్తున్నప్పటికీ, ఆటోమేటెడ్ అనువాదాలు తప్పులు లేదా అసమగ్రతలను కలిగి ఉండవచ్చు. దాని స్వదేశ భాషలో ఉన్న అసలు పత్రాన్ని అధికారం కలిగిన మూలంగా పరిగణించాలి. కీలకమైన సమాచారం కోసం, ప్రొఫెషనల్ మానవ అనువాదాన్ని సిఫారసు చేస్తాము. ఈ అనువాదం ఉపయోగం వల్ల కలిగే ఏవైనా అపార్థాలు లేదా తప్పుదారులు కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
