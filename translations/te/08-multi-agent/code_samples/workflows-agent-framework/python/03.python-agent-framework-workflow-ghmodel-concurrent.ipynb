# %% [markdown]
# # ⚡ మైక్రోసాఫ్ట్ Foundry (Python)తో సమకాలీన ఏజెంట్ వర్క్‌ఫ్లోలు
#
# ## 📋 అధునాతన సమాంతర ప్రాసెసింగ్ ట్యూటోరియల్
#
# ఈ నోట్‌బుక్ Microsoft Agent Framework ఉపయోగించి **సమకాలీన వర్క్‌ఫ్లో నమూనాలు**ని చూపిస్తుంది. మీరు ఎలాంటి AI ఏజెంట్లు తోడుగా పనిచేసే సమాంతర ప్రాసెసింగ్ వర్క్‌ఫ్లోలు రూపొందించి, గరిష్ట పనితీరును సాధించడం ఎలా అనేది నేర్చుకుంటారు, దీని వల్ల పనితీరు మెరుగుపడుతుంది మరియు అత్యాధునిక బహుళ-తంత్ర విజయేశాల వ్యాపార ప్రక్రియలు సాధ్యమవుతాయి.
#
# > **మైగ్రేషన్ గమనిక:** ఈ ఉదాహరణ ముందు GitHub Models ను సూచించేది. GitHub Models 2026 జూలై నుండి వదిలివేతకు దారితీయబడినందున, ఇప్పుడు ఈ ఉదాహరణ **Microsoft Foundry** ను `FoundryChatClient` ద్వారా ఉపయోగిస్తుంది, ఇది Azure OpenAI **Responses API**ను లక్ష్యంగా చేసుకుంది.
#
# ## 🎯 నేర్చుకునే లక్ష్యాలు
#
# ### 🚀 **సమకాలీన ప్రాసెసింగ్ మూలాంశాలు**
# - **సమాంతర ఏజెంట్ అమలు**: గరిష్ట పనితీరుకు అనేక ఏజెంట్లను ఒకేసారి నడపండి
# - **వర్క్‌ఫ్లో సమన్వయం**: డేటా స్థిరత్వాన్ని పాటిస్తూ సమకాలీన కార్యకలాపాలను సమన్వయం చేయండి
# - **పనితీరు ఆప్టిమైజేషన్**: సమాంతర ప్రాసెసింగ్ ద్వారా అతి త్వరిత వేగం సాధించండి
# - **వనరుల నిర్వహణ**: సమకాలీన కార్యకలాపాల మధ్య AI మోడల్ వనరులను ప్రభావవంతంగా వినియోగించండి
#
# ### 🏗️ **అధునాతన సమకాలీన నమూనాలు**
# - **ఫోర్క్-జాయిన్ ప్రాసెసింగ్**: అనేక ఏజెంట్లకు పనిని విభజించి ఫలితాలను విలీనం చేయండి
# - **పైప్‌లైన్ సమాంతరత**: నిరంతర పనితీరుకు అమలు దశలను పరస్పరం జతచేయడం
# - **లోడ్ బ్యాలెన్సింగ్**: అందుబాటులో ఉన్న ఏజెంట్ వనరులపై సవర్తనగా పని పంపిణీ చేయండి
# - **సంకలనం పాయింట్లు**: కీలక వర్క్‌ఫ్లో దశల వద్ద సమకాలీన ఏజెంట్లను సమన్వయం చేయడం
#
# ### 🏢 **ఎంటర్ప్రైజ్ సమకాలీన అప్లికేషన్లు**
# - **అధిక-పరిమాణ డాక్యుమెంట్ ప్రాసెసింగ్**: అనేక డాక్యుమెంట్లను ఒకేసారి ప్రాసెస్ చేయండి
# - **నిజ-సమయం కంటెంట్ విశ్లేషణ**: వస్తువుల ప్రవాహాలను సమకాలీనంగా విశ్లేషించండి
# - **బ్యాచ్ ప్రాసెసింగ్ ఆప్టిమైజేషన్**: పెద్ద-స్థాయి కార్యకలాపాల కోసం అధిక పనితీరు సాధించండి
# - **బహుముఖ విశ్లేషణ**: వేరే వేరే కంటెంట్ రకాల (అక్షరాలు, చిత్రాలు, డేటా) సమాంతర ప్రాసెసింగ్
#
# ## ⚙️ ముందస్తు అవసరాలు & సెటప్
#
# ### 📦 **అవసరమైన ఆధారాలు**
#
# సమకాలీన వర్క్‌ఫ్లో సామర్థ్యాలతో Agent Frameworkనును ఇన్‌స్టాల్ చేయండి:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry కాన్ఫిగరేషన్**
#
# Azure CLI (`az login`) తో సైన్ ఇన్ అయి `AzureCliCredential` గుర్తింపు పొందిన తర్వాత మీ Microsoft Foundry ప్రాజెక్ట్ వివరాలను సెట్ చేయండి.
#
# **పర్యావరణ సెటప్ (.env ఫైల్):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **సమకాలీన ప్రాసెసింగ్ పరిగణనలు:**
# - **రేట్ పరిమితులు**: సమకాలీన అభ్యర్ధనలకు Azure OpenAI రేట్ పరిమితులను పర్యవేక్షించండి
# - **వనరుల వినియోగం**: అనేక ఏజెంట్స్ ఉన్నప్పుడు మెమరీ మరియు CPU వినియోగాన్ని పరిగణించండి
# - **లోపాల నిర్వహణ**: సమాంతర కార్యకలాపాల కోసం బలమైన లోప పునరుద్ధరణను అమలు చేయండి
#
# ### 🏗️ **సమకాలీన వర్క్‌ఫ్లో నిర్మాణ శిల్పం**
#
# ```mermaid
# graph TD
#     A[వర్క్‌ఫ్లో ప్రారంభం] --> B[సమకాలీన అమలు]
#     B --> C[ఏజెంట్ పూల్ 1]
#     B --> D[ఏజెంట్ పూల్ 2]
#     B --> E[ఏజెంట్ పూల్ 3]
#     C --> F[ఫలిత సంకలనం]
#     D --> F
#     E --> F
#     F --> G[తుది అవుట్‌పుట్]
#
#     H[మైక్రోసాఫ్ట్ ఫౌండ్రీ] --> C
#     H --> D
#     H --> E
# ```
#
# **ముఖ్య లాభాలు:**
# - **⚡ పనితీరు**: సమాంతర అమలు ద్వారా గణనీయమైన వేగవంతం
# - **📈 స్కేలబిలిటీ**: పని పరిమాణం పెరిగినప్పటికీ తగిన సమయం ఎక్కువకాదు
# - **🔄 సమర్ధత**: అందుబాటులో ఉన్న కంప్యూటేషనల్ వనరులను మెరుగ్గా వినియోగించడం
# - **🎯 గతి**: సమాన సమయానికి ఎక్కువ పని పూర్తిచేయండి
#
# ## 🎨 **సమకాలీన వర్క్‌ఫ్లో డిజైన్ నమూనాలు**
#
# ### 🔍 **పరిశోధన & విశ్లేషణ పైప్‌లైన్**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **డేటా ప్రాసెసింగ్ వర్క్‌ఫ్లో**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **కంటెంట్ సృష్టి పైప్‌లైన్**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **బహు-దశ ప్రాసెసింగ్**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **ఎంటర్ప్రైజ్ పనితీరు లాభాలు**
#
# ### ⚡ **గతి ఆప్టిమైజేషన్**
# - **సమాంతర అమలు**: అనేక ఏజెంట్లు ఒకేసారి పనిచేస్తున్నాయి
# - **వనరుల వినియోగం**: అందుబాటులో ఉన్న AI మోడల్ సామర్థ్యాన్ని గరిష్టంగా ఉపయోగించడం
# - **సమయ తగ్గింపు**: మొత్తం ప్రాసెసింగ్ సమయంలో గణనీయమైన తగ్గింపు
# - **పరిమాణం చేర్చే నిర్మాణం**: అవసరమైతే మరిన్ని సమకాలీన ఏజెంట్లను సులభంగా చేర్చండి
#
# ### 🛡️ **నమ్మకదారీతనము & సహనం**
# - **దోష సహనం**: ఒక ఏజెంట్ వైఫల్యం వల్ల మొత్తం వర్క్‌ఫ్లో ఆగదు
# - **లోపాల వేరుపాటు**: ఒక సమకాలీన శాఖలో సమస్యలు ఇతరులను ప్రభావితం చేయవు
# - **శాంతమైన తగ్గింపు**: ఏజెంట్ సామర్థ్యం తగ్గినా వ్యవస్థ పనిచేస్తూనే ఉంటుంది
# - **పునరుద్ధరణ యంత్రాంగాలు**: విఫలమైన కార్యాచరణలకు ఆటోమేటిక్ రీట్రై మరియు లోప నిర్వహణ
#
# ### 📊 **మానిటరింగ్ & దర్శనసాధ్యము**
# - **సమకాలీన అమలును ట్రాక్ చేయడం**: అన్ని సమాంతర కార్యకలాపాల పురోగతిని పర్యవేక్షించండి
# - **పనితీరు మెట్రిక్స్**: వేగవంతం మరియు సమర్ధత లాభాలు కొలవండి
# - **వనరు వినియోగ విశ్లేషణలు**: సమకాలీన ఏజెంట్ కేటాయింపును ఆప్టిమైజ్ చేయండి
# - **బాటిల్‌నెక్ గుర్తింపు**: పనితీరు పరిమితులను కనుగొని పరిష్కరించండి
#
# అధిక పనితీరు సమకాలీన AI వర్క్‌ఫ్లోలను నిర్మిద్దాం! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **అస్వీకరణ**:
# ఈ పత్రం AI అనువాద సేవ [Co-op Translator](https://github.com/Azure/co-op-translator) ఉపయోగించి అనువదించబడింది. మేము ఖచ్చితత్వానికి ప్రయత్నిస్తున్నప్పటికీ, ఆటోమేటెడ్ అనువాదాలు తప్పులు లేదా అసమగ్రతలను కలిగి ఉండవచ్చు. దాని స్వదేశ భాషలో ఉన్న అసలు పత్రాన్ని అధికారం కలిగిన మూలంగా పరిగణించాలి. కీలకమైన సమాచారం కోసం, ప్రొఫెషనల్ మానవ అనువాదాన్ని సిఫారసు చేస్తాము. ఈ అనువాదం ఉపయోగం వల్ల కలిగే ఏవైనా అపార్థాలు లేదా తప్పుదారులు కోసం మేము బాధ్యత వహించము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
