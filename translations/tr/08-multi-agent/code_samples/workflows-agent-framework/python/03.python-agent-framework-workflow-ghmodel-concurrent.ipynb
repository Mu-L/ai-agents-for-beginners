# %% [markdown]
# # ⚡ Microsoft Foundry ile Eşzamanlı Agent İş Akışları (Python)
#
# ## 📋 Gelişmiş Paralel İşleme Eğitimi
#
# Bu not defteri, Microsoft Agent Framework kullanarak **eşzamanlı iş akışı desenlerini** göstermektedir. Birden fazla AI ajanının aynı anda çalıştığı yüksek performanslı, paralel işleme iş akışları oluşturmayı öğrenecek, böylece iş hacmini önemli ölçüde artıracak ve karmaşık çoklu iş parçacıklı iş süreçlerini mümkün kılacaksınız.
#
# > **Geçiş notu:** Bu örnek daha önce GitHub Models'a referans vermekteydi. GitHub Models kullanımdan kaldırılacak (Temmuz 2026'da emekliye ayrılacak), bu yüzden artık `FoundryChatClient` aracılığıyla Azure OpenAI **Responses API** hedefleyen **Microsoft Foundry** kullanılmaktadır.
#
# ## 🎯 Öğrenme Hedefleri
#
# ### 🚀 **Eşzamanlı İşleme Temelleri**
# - **Paralel Agent Çalıştırma**: Maksimum verimlilik için birden fazla ajan aynı anda çalıştırın
# - **İş Akışı Orkestrasyonu**: Veri tutarlılığını korurken eşzamanlı işlemleri koordine edin
# - **Performans Optimizasyonu**: Paralel işlem yoluyla önemli hız artışı elde edin
# - **Kaynak Yönetimi**: Eşzamanlı işlemler sırasında AI model kaynaklarını verimli kullanın
#
# ### 🏗️ **Gelişmiş Eşzamanlılık Desenleri**
# - **Fork-Join İşleme**: Çalışmayı birden fazla ajana bölüp sonucu birleştirin
# - **Boru Hattı Paralellik**: Sürekli iş hacmi için üst üste binen yürütme aşamaları
# - **Yük Dengeleme**: Kullanılabilir ajan kaynakları arasında işi eşit dağıtın
# - **Senkronizasyon Noktaları**: Kritik iş akışı aşamalarında eşzamanlı ajanları koordine edin
#
# ### 🏢 **Kurumsal Eşzamanlı Uygulamalar**
# - **Yüksek Hacimli Belge İşleme**: Birden çok belgeyi aynı anda işleyin
# - **Gerçek Zamanlı İçerik Analizi**: Gelen veri akışlarını eşzamanlı analiz edin
# - **Toplu İşleme Optimizasyonu**: Büyük ölçekli işlemlerde iş hacmini maksimize edin
# - **Çok Modlu Analiz**: Farklı içerik türlerini (metin, resim, veri) paralel işleyin
#
# ## ⚙️ Ön Koşullar ve Kurulum
#
# ### 📦 **Gerekli Bağımlılıklar**
#
# Eşzamanlı iş akışı yetenekleri ile Agent Framework'ü kurun:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Konfigürasyonu**
#
# `AzureCliCredential` kimlik doğrulaması için Azure CLI ile oturum açın (`az login`), ardından Microsoft Foundry proje detaylarınızı ayarlayın.
#
# **Ortam Kurulumu (.env dosyası):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Eşzamanlı İşleme Dikkat Edilmesi Gerekenler:**
# - **Oran Sınırları**: Eşzamanlı istekler için Azure OpenAI oran sınırlarını izleyin
# - **Kaynak Kullanımı**: Birden fazla eşzamanlı ajanla bellek ve CPU kullanımını göz önünde bulundurun
# - **Hata Yönetimi**: Paralel işlemler için sağlam hata kurtarma uygulayın
#
# ### 🏗️ **Eşzamanlı İş Akışı Mimarisi**
#
# ```mermaid
# graph TD
#     A[İş Akışı Başlangıcı] --> B[Eşzamanlı Yürütme]
#     B --> C[Temsilci Havuzu 1]
#     B --> D[Temsilci Havuzu 2]
#     B --> E[Temsilci Havuzu 3]
#     C --> F[Sonuç Toplama]
#     D --> F
#     E --> F
#     F --> G[Nihai Çıktı]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Ana Avantajlar:**
# - **⚡ Performans**: Paralel yürütme ile önemli hız artışı
# - **📈 Ölçeklenebilirlik**: Artan iş yüklerini orantısal zaman artışı olmadan yönetin
# - **🔄 Verimlilik**: Kullanılabilir hesaplama kaynaklarının daha iyi kullanımı
# - **🎯 İş Hacmi**: Aynı zamanda daha fazla iş işleyin
#
# ## 🎨 **Eşzamanlı İş Akışı Tasarım Desenleri**
#
# ### 🔍 **Araştırma & Analiz Boru Hattı**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Veri İşleme İş Akışı**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **İçerik Oluşturma Boru Hattı**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Çok Aşamalı İşleme**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Kurumsal Performans Avantajları**
#
# ### ⚡ **İş Hacmi Optimizasyonu**
# - **Paralel Yürütme**: Birden fazla ajanın aynı anda çalışması
# - **Kaynak Kullanımı**: Mevcut AI model kapasitesinin maksimum verimliliği
# - **Zaman Azaltma**: Toplam işlem süresinde önemli azalma
# - **Ölçeklenebilir Mimari**: Gerektiğinde daha fazla eşzamanlı ajan ekleyin
#
# ### 🛡️ **Güvenilirlik & Dayanıklılık**
# - **Hata Toleransı**: Bireysel ajan hataları tüm iş akışını durdurmaz
# - **Hata İzolasyonu**: Bir eşzamanlı dalgadaki sorunlar diğerlerini etkilemez
# - **Kibar Bozulma**: Sistem ajan kapasitesi azalsa bile çalışmaya devam eder
# - **Kurtarma Mekanizmaları**: Başarısız işlemler için otomatik yeniden deneme ve hata yönetimi
#
# ### 📊 **İzleme & Gözlemlenebilirlik**
# - **Eşzamanlı Yürütme Takibi**: Tüm paralel işlemlerin ilerlemesini izleyin
# - **Performans Metrikleri**: Hızlanma ve verimlilik kazanımlarını ölçün
# - **Kaynak Kullanım Analizi**: Eşzamanlı ajan tahsisini optimize edin
# - **Dar Boğaz Tespiti**: Performans kısıtlamalarını bulun ve çözün
#
# Yüksek performanslı eşzamanlı AI iş akışları oluşturalım! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Feragatname**:
# Bu belge, AI çeviri hizmeti [Co-op Translator](https://github.com/Azure/co-op-translator) kullanılarak çevrilmiştir. Doğruluk için çaba sarf etsek de, otomatik çevirilerin hata veya yanlışlık içerebileceğini lütfen unutmayınız. Orijinal belge, kendi dilinde yetkili kaynak olarak kabul edilmelidir. Kritik bilgiler için profesyonel insan çevirisi önerilir. Bu çevirinin kullanımı sonucu ortaya çıkabilecek yanlış anlamalardan veya yanlış yorumlamalardan sorumlu değiliz.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
