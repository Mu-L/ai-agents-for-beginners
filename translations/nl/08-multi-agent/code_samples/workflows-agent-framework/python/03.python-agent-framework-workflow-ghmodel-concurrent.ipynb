# %% [markdown]
# # ⚡ Gelijktijdige Agent Workflows met Microsoft Foundry (Python)
#
# ## 📋 Geavanceerde Parallelle Verwerking Tutorial
#
# Deze notebook demonstreert **gelijktijdige workflowpatronen** met het Microsoft Agent Framework. Je leert hoe je hoogwaardige, parallelle verwerkingsworkflows bouwt waarbij meerdere AI-agenten tegelijkertijd uitvoeringen, wat de doorvoer dramatisch verbetert en geavanceerde multi-threaded bedrijfsprocessen mogelijk maakt.
#
# > **Migratie-opmerking:** Dit voorbeeld verwees eerder naar GitHub Models. GitHub Models wordt uitgefaseerd (stopzetting juli 2026), dus het maakt nu gebruik van **Microsoft Foundry** via de `FoundryChatClient`, die de Azure OpenAI **Responses API** aanroept.
#
# ## 🎯 Leerdoelen
#
# ### 🚀 **Grondbeginselen van Gelijktijdige Verwerking**
# - **Parallelle Agentuitvoering**: Voer meerdere agenten gelijktijdig uit voor maximale efficiëntie
# - **Workflow Orkestratie**: Coördineer gelijktijdige operaties terwijl dataconsistentie wordt gehandhaafd
# - **Prestatieoptimalisatie**: Bereik aanzienlijke versnelling dankzij parallelle verwerking
# - **Resourcebeheer**: Gebruik AI-modelbronnen efficiënt over gelijktijdige operaties
#
# ### 🏗️ **Geavanceerde Gelijktijdigheidspatronen**
# - **Fork-Join Verwerking**: Verdeel werk over meerdere agenten en voeg de resultaten samen
# - **Pijplijnparallelisme**: Overlappende uitvoeringsfasen voor continue doorvoer
# - **Load Balancing**: Verdeeld werk gelijkmatig over beschikbare agentbronnen
# - **Synchronisatiepunten**: Coördineer gelijktijdige agenten bij kritieke workflowfasen
#
# ### 🏢 **Gelijktijdige Enterprise-toepassingen**
# - **Documentverwerking met hoog volume**: Verwerk meerdere documenten tegelijkertijd
# - **Realtime inhoudsanalyse**: Gelijktijdige analyse van binnenkomende datastromen
# - **Batchverwerkingsoptimalisatie**: Maximaliseer doorvoer voor grootschalige operaties
# - **Multi-modale Analyse**: Parallelle verwerking van verschillende inhoudstypen (tekst, afbeeldingen, data)
#
# ## ⚙️ Vereisten & Setup
#
# ### 📦 **Vereiste afhankelijkheden**
#
# Installeer Agent Framework met gelijktijdige workflowmogelijkheden:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry Configuratie**
#
# Log in met de Azure CLI (`az login`) zodat `AzureCliCredential` kan authenticeren, stel vervolgens je Microsoft Foundry-projectgegevens in.
#
# **Omgevingsinstelling (.env-bestand):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Overwegingen voor gelijktijdige verwerking:**
# - **Snelheidslimieten**: Houd Azure OpenAI snelheidslimieten voor gelijktijdige aanvragen in de gaten
# - **Resourcegebruik**: Houd rekening met geheugen- en CPU-gebruik bij meerdere gelijktijdige agenten
# - **Foutafhandeling**: Implementeer robuuste foutherstelmechanismen voor parallelle operaties
#
# ### 🏗️ **Architectuur van gelijktijdige workflows**
#
# ```mermaid
# graph TD
#     A[Workflow Start] --> B[Gelijktijdige Uitvoering]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Resultaten Aggregatie]
#     D --> F
#     E --> F
#     F --> G[Einduitvoer]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Belangrijkste voordelen:**
# - **⚡ Prestatie**: Aanzienlijke versnelling dankzij parallelle uitvoering
# - **📈 Schaalbaarheid**: Verwerk hogere werkbelastingen zonder evenredige tijdtoename
# - **🔄 Efficiëntie**: Betere benutting van beschikbare rekencapaciteit
# - **🎯 Doorvoer**: Verwerk meer werk in dezelfde tijdspanne
#
# ## 🎨 **Ontwerppatronen voor gelijktijdige workflows**
#
# ### 🔍 **Onderzoek- en Analysepijplijn**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Dataverwerkingsworkflow**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Contentcreatiepijplijn**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Meervoudige verwerkingsfasen**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Enterprise prestatievoordelen**
#
# ### ⚡ **Doorstroomoptimalisatie**
# - **Parallelle uitvoering**: Meerdere agenten werken gelijktijdig
# - **Resourcebenutting**: Maximaal efficiënt gebruik van beschikbare AI-modelcapaciteit
# - **Tijdreductie**: Aanzienlijke vermindering van totale verwerkingstijd
# - **Schaalbare architectuur**: Voeg naar behoefte eenvoudig meer gelijktijdige agenten toe
#
# ### 🛡️ **Betrouwbaarheid & Veerkracht**
# - **Fouttolerantie**: Individuele agentstoringen stoppen de hele workflow niet
# - **Foutisolatie**: Problemen in één gelijktijdige tak beïnvloeden de andere niet
# - **Geleidelijke achteruitgang**: Systeem blijft functioneren, zelfs met verminderde agentcapaciteit
# - **Herstelmechanismen**: Automatisch opnieuw proberen en foutafhandeling voor mislukte operaties
#
# ### 📊 **Monitoring & Observeerbaarheid**
# - **Gelijktijdige Uitvoeringstracering**: Houd de voortgang van alle parallelle operaties in de gaten
# - **Prestatiestatistieken**: Meet versnelling en efficiëntiewinst
# - **Analyse van resourcegebruik**: Optimaliseer toewijzing van gelijktijdige agenten
# - **Bottleneck-identificatie**: Vind en los prestatiebeperkingen op
#
# Laten we krachtige gelijktijdige AI-workflows bouwen! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Disclaimer**:
# Dit document is vertaald met behulp van de AI vertaaldienst [Co-op Translator](https://github.com/Azure/co-op-translator). Hoewel we streven naar nauwkeurigheid, dient u er rekening mee te houden dat geautomatiseerde vertalingen fouten of onnauwkeurigheden kunnen bevatten. Het originele document in de oorspronkelijke taal moet worden beschouwd als de gezaghebbende bron. Voor kritieke informatie wordt professionele menselijke vertaling aanbevolen. Wij zijn niet aansprakelijk voor eventuele misverstanden of verkeerde interpretaties die voortvloeien uit het gebruik van deze vertaling.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
