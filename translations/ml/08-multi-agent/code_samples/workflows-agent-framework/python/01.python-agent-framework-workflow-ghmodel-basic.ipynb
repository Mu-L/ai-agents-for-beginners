# %% [markdown]
# # 🔄 മൈക്രോസോഫ്ട് ഫൗണ്ട്രിയുമായി അടിസ്ഥാന ഏജന്റ് വർക്ക്‌ഫ്ലോകൾ (Python)
#
# ## 📋 വർക്ക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ ട്യൂട്ടോറിയൽ
#
# മൈക്രോസോഫ്ട് ഏജന്റ് ഫ്രെയിംവർക്കിന്റെ ശക്തമായ **വർക്ക്‌ഫ്ലോ ബിൽഡർ** കഴിവുകളിലേക്ക് ഈ നോട്ട്‌ബുക്ക് പരിചയം നൽകുന്നു. സങ്കീർണ്ണമായ ബിസിനസ് പ്രക്രിയകൾ കൈകാര്യം ചെയ്ത് ഒന്നിലധികം AI ഓപ്പറേഷനുകൾ സ്മൂത്തു ആയി ഏകോപിപ്പിക്കുന്ന വികസിത, ബഹു-ഘട്ട ഏജന്റ് വർക്ക്‌ഫ്ലോകൾ സൃഷ്ടിക്കുന്നത് എങ്ങനെ എന്ന് മനസിലാക്കുക.
#
# > **ഇളവു കുറിപ്പ്:** ഈ സാമ്പിൾ മുൻപ് GitHub മോഡലുകൾ പരാമർശിച്ചിരുന്നു. GitHub മോഡലുകൾ ഉപേക്ഷിക്കപ്പെട്ടതാണ് (ജൂലൈ 2026-ന് വിരമിക്കും), അതിനാൽ ഇത് ഇപ്പോൾ `FoundryChatClient` വഴി **Microsoft Foundry** ഉപയോഗിക്കുന്നു, ഇത് Azure OpenAI **Responses API** ലക്ഷ്യമിടുന്നു.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🏗️ **വർക്ക്‌ഫ്ലോ ആർക്കിടെക്ചർ**
# - **Workflow Builder**: സൂക്ഷ്മമായ ബഹു-ഘട്ട പ്രക്രിയകൾ രൂപകൽപ്പന ചെയ്ത് ഓർക്കസ്ട്രേറ്റ് ചെയ്യുക
# - **ഇവന്റ്-ഡ്രിവൺ എക്സിക്യൂഷൻ**: വർക്ക്‌ഫ്ലോ ഇവന്റുകളും സ്റ്റേറ്റ് ട്രാൻസിഷനുകളും കൈകാര്യം ചെയ്യുക
# - **വിസ്വൽ വർക്ക്‌ഫ്ലോ ഡിസൈൻ**: വർക്ക്‌ഫ്ലോ ഘടനകൾ സൃഷ്ടിക്കുകയും ദൃശ്യമാക്കുകയും ചെയ്യുക
# - **Microsoft Foundry സംയോജനം**: വർക്ക്‌ഫ്ലോ കോൺടекстുകളിൽ AI മോഡലുകൾ ഉപയോഗിക്കുക
#
# ### 🔄 **പ്രോസസ്സ് ഓർക്കസ്ട്രേഷൻ**
# - **ക്രമിക പ്രവർത്തനങ്ങൾ**: ബഹുദിനസംഖ്യാ ഏജന്റ് പ്രവർത്തനങ്ങൾ താർക്കിക ക്രമത്തിൽ ബന്ധിപ്പിക്കുക
# - **നിബന്ധനാത്മക തർക്കം**: തീരുമാനബിന്ദുക്കളും ശാഖായുള്ള വർക്ക്‌ഫ്ലോകളും നടപ്പാക്കുക
# - **പിശക് കൈകാര്യം**: ശക്തമായ പിശക് പുനരുദ്ധാരണം, വർക്ക്‌ഫ്ലോ പ്രതിരോധശേഷി
# - **സ്റ്റേറ്റ് മാനേജ്‌മെന്റ്**: വർക്ക്‌ഫ്ലോ പ്രവർത്തന സ്റ്റേറ്റ് ട്രാക്ക് ചെയ്യുകയും നിയന്ത്രിക്കുകയും ചെയ്യുക
#
# ### 📊 **എന്റർപ്രൈസ് വർക്ക്‌ഫ്ലോ മാതൃകകൾ**
# - **ബിസിനസ് പ്രോസസ് ഓട്ടോമേഷൻ**: സങ്കീർണമുള്ള സംഘടനാത്മക വർക്ക്‌ഫ്ലോകൾ ഓട്ടോമേറ്റുചെയ്യുക
# - **ബഹു-ഏജന്റ് ഏകോപനം**: അനേകം പ്രത്യേക ഏജന്റുകളെ ഏകോപിപ്പിക്കുക
# - **സ്കേലബിൾ എക്സിക്യൂഷൻ**: എന്റർപ്രൈസ്-തരം പ്രവർത്തനങ്ങൾക്ക് വർക്ക്‌ഫ്ലോകൾ രൂപകൽപ്പന ചെയ്യുക
# - **മോണിറ്ററിംഗ് & ഒബ്‌സർവപ്പോബിലിറ്റി**: വർക്ക്‌ഫ്ലോ പ്രകടനവും ഫലവും ട്രാക്ക് ചെയ്യുക
#
# ## ⚙️ മുൻ‌ളവുകളും ക്രമീകരണങ്ങളും
#
# ### 📦 **ആവശ്യമായ ആശ്രിതങ്ങൾ**
#
# വർക്ക്‌ഫ്ലോ കഴിവുകളോടെയുള്ള ഏജന്റ് ഫ്രെയിംവർക്കിൻറെ ഇൻസ്റ്റാൾ ചെയ്യുക:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ഫിങ്ക്ഷനിംഗ്**
#
# `AzureCliCredential`-ന്റെ അംഗീകാരത്തിന് Azure CLI (`az login`) ഉപയോഗിച്ച് സൈൻ ഇൻ ചെയ്‌തു, തുടർന്ന് നിങ്ങളുടെ Microsoft Foundry പ്രോജക്റ്റ് വിശദാംശങ്ങൾ ക്രമീകരിക്കുക.
#
# **പരിസ്ഥിതി ക്രമീകരണം (.env ഫയൽ):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# ### 🏢 **എന്റർപ്രൈസ് ഉപയോഗകേസുകൾ**
#
# **ബിസിനസ് പ്രോസസ് ഉദാഹരണങ്ങൾ:**
# - **കസ്റ്റമർ ഓൺബോർഡിങ്**: ബഹു-ഘട്ട പരിശ്രമവും ക്രമീകരണവും ഉള്ള വർക്ക്‌ഫ്ലോകൾ
# - **കಂಟെന്റ് പൈപ്പ്‌ലൈന്‍**: ഓട്ടോമേറ്റുചെയ്ത ഉള്ളടക്കം നിർമ്മാണം, അവലോകനം, പ്രസിദ്ധീകരണം
# - **ഡേറ്റാ പ്രോസസ്സിംഗ്**: AI-ശക്തികരിച്ച മാറ്റങ്ങളോടെയുള്ള ETL വർക്ക്‌ഫ്ലോകൾ
# - **ക്വാളിറ്റി അഷുറൻസ്**: ഓട്ടോമേറ്റഡ് ടെസ്റ്റിംഗ് 및 സാധൂകരിക്കൽ പ്രക്രിയകൾ
#
# **വർക്ക്‌ഫ്ലോ ഗుణങ്ങൾ:**
# - 🎯 **വിശ്വാസ്യത**: പിശക് പുനരുദ്ധാരണത്തോടെ നിർണ്ണായക കർമനിർവഹണം
# - 📈 **സ്കേലബിൽറ്റി**: ഉയർന്ന വോളിയം പ്രോസസ്സ് ഓട്ടോമേഷൻ കൈകാര്യം ചെയ്യുക
# - 🔍 **ഒബ്‌സർവപ്പബിലിറ്റി**: പൂർണ്ണ ഓഡിറ്റ് ട്രെയ്‌ലുകളും മോണിറ്ററിംഗും
# - 🔧 **പരിപാലനക്ഷമത**: ദൃശ്യപരമായ രൂപകൽപ്പനയും ഘടകങ്ങളായ ഘടിപ്പുകൾ
#
# ## 🎨 വർക്ക്‌ഫ്ലോ ഡിസൈൻ മാതൃകകൾ
#
# ### അടിസ്ഥാന വർക്ക്‌ഫ്ലോ ഘടന
# ```mermaid
# graph TD
#     A[ആരംഭിക്കുക] --> B[ഏജന്റ് ടാസ്‌ക് 1]
#     B --> C{തീരുമാനം പോയിന്റ്}
#     C -->|വിജയം| D[ഏജന്റ് ടാസ്‌ക് 2]
#     C -->|പരാജയം| E[പിശക് കൈകാര്യം ചെയ്യുന്നവൻ]
#     D --> F[അവസാനിക്കുക]
#     E --> F
# ```
#
# **പ്രധാന ഘടകങ്ങൾ:**
# - **WorkflowBuilder**: മുഖ്യ ഓർക്കസ്ട്രേഷൻ എൻജിൻ
# - **WorkflowEvent**: ഇവന്റ് കൈകാര്യം ചെയ്യലും ആശയവിനിമയവും
# - **WorkflowViz**: ദൃശ്യ വർക്ക്‌ഫ്ലോ പ്രതിനിധാനം, ഡീബഗ് ചെയ്യൽ
#
# നിങ്ങളുടെ ആദ്യ ബുദ്ധിമുട്ടുള്ള വർക്ക്‌ഫ്ലോ നിർമിക്കാം! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
# Core components for building sophisticated agent workflows
from agent_framework import WorkflowBuilder, WorkflowEvent, WorkflowViz
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
# 📦 Import Environment and System Utilities
# Essential libraries for configuration and environment management

import os                      # 🔧 Environment variable access
from dotenv import load_dotenv # 📁 Secure configuration loading

# %%
# 🔧 Initialize Environment Configuration
# Load Microsoft Foundry project settings from .env file
load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. 
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
reviewer_agent = provider.as_agent(
    name=REVIEWER_NAME,
    instructions=REVIEWER_INSTRUCTIONS,
)

front_desk_agent = provider.as_agent(
    name=FRONTDESK_NAME,
    instructions=FRONTDESK_INSTRUCTIONS,
)

# %%
workflow = (
    WorkflowBuilder(start_executor=front_desk_agent)
    .add_edge(front_desk_agent, reviewer_agent)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
# Display the exported workflow SVG inline in the notebook

from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
# Workflow.run_stream is no longer part of the public API; the current Workflow
# returns a results object whose `get_outputs()` produces the AgentResponse from
# each output executor. The reviewer (last stage) is the only output here.
events = await workflow.run("I would like to go to Paris.")
outputs = events.get_outputs()
result = outputs[0].text if outputs else ""

# %%
result.replace("None", "")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
