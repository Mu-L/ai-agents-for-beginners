# %% [markdown]
# # ⚡ മൈക്രോസോഫ്റ്റ് ഫൗണ്ട്രി (പൈതൺ) ഉപയോഗിച്ച് സമകാലിക ഏജന്റ് വർക്‌ഫ്ലോകൾ
#
# ## 📋 ആധുനിക സമാന്തര പ്രോസസ്സ് ട്യൂട്ടോറിയൽ
#
# ഈ നോട്ട്‌ബുക്ക് മൈക്രോസോഫ്റ്റ് ഏജന്റ് ഫ്രെയിമ്വർക്കിൽ **സമകാലിക വർക്‌ഫ്ലോ മോഡലുകൾ** തെളിയിക്കുന്നു. നിങ്ങൾ എങ്ങനെ ഉയർന്ന പ്രവർത്തനക്ഷമതയും സമാന്തര പ്രോസസുകളും ഉള്ള വർക്‌ഫ്ലോകൾ നിർമ്മിക്കാമെന്ന് പഠിക്കും, ഇവിടെ നിരവധി AI ഏജന്റുകൾ ഒരുമിച്ച് പ്രവർത്തിച്ച് throughput ന്യായമായും മെച്ചപ്പെടുത്തുകയും സങ്കീർണ്ണമായ മൾട്ടി-ത്രെഡ് ചെയ്ത ബിസിനസ് പ്രക്രിയകൾ സാധ്യമാക്കുകയും ചെയ്യുന്നു.
#
# > **മൈഗ്രേഷൻ കുറിപ്പ്:** ഈ സാമ്പിൾ മുമ്പ് GitHub മോഡലുകളെ പരാമർശിച്ചിരുന്നു. GitHub മോഡലുകൾ മാറ്റിമറിച്ചിരിക്കുന്നു (ജൂലൈ 2026-ൽ വിരമിക്കുന്നു), അതിനാൽ ഇപ്പോൾ ഇത് **Microsoft Foundry** ഉപയോഗിച്ച് `FoundryChatClient` വഴി പ്രവർത്തിപ്പിക്കുന്നു, ഇത് Azure OpenAI **Responses API**-യെയാണ് ലക്ഷ്യമാക്കുന്നത്.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🚀 **സമകാലിക പ്രൊസ്സസ്സ് അടിസ്ഥാനങ്ങൾ**
# - **സമാന്തര ഏജന്റ് നിർവഹണം**: പരമാവധി കാര്യക്ഷമതയ്ക്കായി ഒരേ സമയം متعدد ഏജന്റുകൾ പ്രവർത്തിപ്പിക്കുക
# - **വർക്‌ഫ്ലോ ഏകീകരണം**: സമകാലിക പ്രവർത്തനങ്ങൾ ഏകീകരിച്ച് ഡാറ്റ സ്ഥിരത നിലനിർ‍ത്തുക
# - **പ്രകടന മെച്ചപ്പെടുത്തൽ**: സമാന്തര പ്രോസസ്സ് വഴി വേഗം വർധിപ്പിക്കുക
# - **സ്രോതസ്സ് നടത്തിപ്പ്**: സമകാലിക പ്രവർത്തനങ്ങളിൽ AI മോഡൽ സ്രോതസ്സ് കാര്യക്ഷമമായി ഉപയോഗിക്കുക
#
# ### 🏗️ **മുഖാമുഖConcurrency ഉദാഹരണങ്ങൾ**
# - **ഫോർക്ക്-ജോയിൻ പ്രൊസ്സസ്സ്**: പ്രവൃത്തി പല ഏജന്റുകൾക്ക് വിഭജിച്ച് ഫലങ്ങൾ സംയോജിപ്പിക്കുക
# - **പൈപ്പ്‌ലൈൻ സമാന്തരവൽക്കരണം**: തുടർച്ചയായി throughput നു വേണ്ടി നിർവഹണ ഘട്ടങ്ങൾ ഒട്ടിച്ചേർക്കുക
# - **ലോഡ് ബാലൻസിംഗ്**: ലഭ്യമായ ഏജന്റ് സ്രോതസ്സുകൾക്ക് സമമായി പ്രവൃത്തി വഹിക്കുക
# - **സാമയീകരണ പോയിന്റുകൾ**: നിർണായക വർക്‌ഫ്ലോ ഘട്ടങ്ങളിൽ സമകാലിക ഏജന്റുകള് ഏകോപിപ്പിക്കുക
#
# ### 🏢 **എന്റർപ്രൈസ് സമകാലിക ആപ്ലിക്കേഷനുകൾ**
# - **ഉയർന്ന വോളിയം ഡോക്യുമെന്റ് പ്രോസസിംഗ്**: ഒന്നിച്ച് നിരവധി ഡോക്യുമെന്റുകൾ പ്രോസസ് ചെയ്യുക
# - **റിയൽ-ടൈം ഉള്ളടക്ക വിശകലനം**: സമകാലികമായി വരുന്ന ഡാറ്റ സ്റ്റ്രീമുകളുടെ വിശകലനം
# - **ബാച്ച് പ്രോസസ്സ് മെച്ചപ്പെടുത്തൽ**: വലിയോദ്യമങ്ങൾക്ക് മേലായ throughput നിലനിർത്തുക
# - **ബഹുമുഖ വിശകലനം**: വിവിധ ഉള്ളടക്ക തരംകൾ (പാഠം, ചിത്രങ്ങൾ, ഡേറ്റ) സമാന്തരമായി പ്രോസസ് ചെയ്യുക
#
# ## ⚙️ മുൻ‌വൈ‌ദുകളും ക്രമീകരണവും
#
# ### 📦 **ആവശ്യമുള്ള ആശ്രിതത്വങ്ങൾ**
#
# സമകാലിക വർക്‌ഫ്ലോ കഴിവുകൾ ഉള്ള ഏജന്റ് ഫ്രെയിംവർക്ക് ഇൻസ്റ്റാൾ ചെയ്യുക:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry ക്രമീകരണം**
#
# Azure CLI-യിൽ `az login` ഉപയോഗിച്ച് സൈൻ ഇൻ ചെയ്ത് `AzureCliCredential` ഓθεν്ടീക്കേറ്റുചെയ്യണം, പിന്നെ Microsoft Foundry പ്രോജക്ട് വിശദാംശങ്ങൾ സജ്ജീകരിക്കുക.
#
# **പരിസ്ഥിതി ക്രമീകരണം (.env ഫയൽ):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **സമകാലിക പ്രൊസ്സസ്സ് പരിഗണനകൾ:**
# - **റേറ്റ് സീമകൾ**: സമകാലിക അഭ്യർത്ഥനകൾക്ക് Azure OpenAI റേറ്റ് സീമകൾ നിരീക്ഷിക്കുക
# - **സ്രോതസ്സുകളുടെ ഉപയോഗം**: വിവിധ സമകാലിക ഏജന്റുകൾ ഉള്ള മെമ്മറി, CPU ഉപയോഗം പരിഗണിക്കുക
# - **പിശക് കൈകാര്യം**: സമാന്തര പ്രവർത്തനങ്ങൾക്കായി മുറിവെടുപ്പ് പുനരുദ്ധാരണം നടപ്പാക്കുക
#
# ### 🏗️ **സമകാലിക വർക്‌ഫ്ലോ ഘടന**
#
# ```mermaid
# graph TD
#     A[പ്രവൃത്തി പ്രക്രിയ ആരംഭം] --> B[സസംവേദിത നിർവഹണം]
#     B --> C[ഏജന്റ് പൂളിൽ 1]
#     B --> D[ഏജന്റ് പൂളിൽ 2]
#     B --> E[ഏജന്റ് പൂളിൽ 3]
#     C --> F[ഫല സമാഹരണം]
#     D --> F
#     E --> F
#     F --> G[അന്തിമ വിജയം]
#
#     H[മൈക്രോസോഫ്റ്റ് ഫൗണ്ട്രി] --> C
#     H --> D
#     H --> E
# ```
#
# **പ്രധാന ഗുണങ്ങൾ:**
# - **⚡ പ്രകടനം**: സമാന്തര നിർവഹണത്തിലൂടെ വേഗതയിൽ വലിയ പുരോഗതി
# - **📈 നീട്ടുമാറ്റം**: വർദ്ധിച്ച ജോലി ഭാരം നേരത്തെക്കാൾ കുറവ് സമയത്ത് കൈകാര്യം ചെയ്യുക
# - **🔄 കാര്യക്ഷമത**: ലഭ്യമായ കംപ്യൂട്ടേഷൻ സ്രോതസ്സ് മെച്ചമായി ഉപയോഗിക്കൽ
# - **🎯 throughput**: ഒരേ സമയത്തെ കൂടുതൽ ജോലി പ്രോസസ്സ് ചെയ്യുക
#
# ## 🎨 **സമകാലിക വർക്‌ഫ്ലോ ഡിസൈൻ മാതൃകകൾ**
#
# ### 🔍 **ഗവേഷണവും വിശകലന പൈപ്പ്‌ലൈൻ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ഡേറ്റ പ്രോസസ്സ് വർക്‌ഫ്ലോ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ഉള്ളടക്കം സൃഷ്ടിക്കുന്ന പൈപ്പ്‌ലൈൻ**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ബഹുഭാഗ പ്രൊസ്സസ്സ്**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **എന്റർപ്രൈസ് പ്രകടനം ഗുണങ്ങൾ**
#
# ### ⚡ **തൊഴിൽ വേഗത മെച്ചപ്പെടുത്തൽ**
# - **സമാന്തര നിർവഹണം**: ഒരു സമയത്ത് നിരവധി ഏജന്റുകൾ പ്രവർത്തിക്കുന്നു
# - **സ്രോതസ് ഉപയോഗം**: ലഭ്യമായ AI മോഡൽ ശേഷിയുടെ പരമാവധി കാര്യക്ഷമത
# - **സമയം കുറയൽ**: ആകെ പ്രോസസ്സിംഗിൽ വലിയ കുറവ്
# - **മൂല്യവത്തായ ഘടന**: ആവശ്യത്തിനനുസരിച്ച് കൂടുതൽ സമകാലിക ഏജന്റുകൾ ചേർക്കാം
#
# ### 🛡️ **നിർവഹണക്ഷമതയും പ്രതിരോധ ശേഷിയും**
# - **ദോഷം സഹിഷ്ണുത**: ഒരു ഏജന്റിന്റെ പരാജയം മുഴുവൻ വർക്‌ഫ്ലോ നിർത്തുകയില്ല
# - **പിശക് വേർതിരിക്കൽ**: ഒരു സമകാലിക ശാഖയിലെ പ്രശ്നങ്ങൾ മറ്റുള്ളവയെ ബാധിക്കില്ല
# - **മനോഹരമായ ക്ഷീണം**: ഏജന്റ് ശേഷി കുറവ്വായാലും സിസ്റ്റം പ്രവർത്തനം തുടരും
# - **പുനരുജ്ജീവന മാർഗ്ഗങ്ങൾ**: പരാജയപ്പെട്ട പ്രവർത്തനങ്ങൾക്ക് സ്വയം പുനരൃജ്ജീവനം, പിശക് കൈകാര്യം
#
# ### 📊 **മോണിറ്ററിംഗ് & നിരീക്ഷണം**
# - **സമകാലിക നിർവഹണ ട്രാക്കിങ്**: എല്ലാ സമാന്തര പ്രവർത്തനങ്ങളുടെ പുരോഗതി നിരീക്ഷിക്കുക
# - **പ്രകടന മെട്രിക്‌സ്**: വേഗതയും കാര്യക്ഷമതയും അളക്കുക
# - **സ്രോതസ് ഉപയോഗ വിശകലനം**: സമകാലിക ഏജന്റ് നീട്ടലുകൾ മെച്ചപ്പെടുത്തുക
# - **ബോട്ടിൽനെക്ക് கண்டുപിടിക്കൽ**: പ്രകടന പ്രശ്‌നങ്ങൾ കണ്ടെത്തി പരിഹരിക്കുക
#
# നമുക്ക് ഉയർന്ന പ്രകടനമുള്ള സമകാലിക AI വർക്‌ഫ്ലോകൾ നിർമ്മിക്കാം! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
