# %% [markdown]
# # ⚡ Microsoft Foundry (Python) ഉപയോഗിച്ച് സമകാലിക ഏജന്റ് വർക്‌ഫ്ലോകൾ
#
# ## 📋 പരിപാലിത സമാന്തര പ്രോസസ്സിംഗ് ട്യൂട്ടോറിയൽ
#
# ഈ നോട്ട്ബുക്ക് Microsoft Agent Framework ഉപയോഗിച്ച് **സമകാലിക വർക്‌ഫ്ലോ പാറ്റേണുകൾ** പ്രദർശിപ്പിക്കുന്നു. ഒന്നിലധികം AI ഏജന്റുമാർ ഒരേസമയം പ്രവർത്തിക്കുന്ന ഉയർന്ന പ്രകടനവും സമാന്തര പ്രോസസ്സിംഗ് വർക്‌ഫ്ലോകൾ നിർമ്മിക്കുന്നത് നിങ്ങള്‍ക്ക് പഠിക്കും, ഇത് ത്രൂപുട്ട് പശ്ചാത്തലം നിതാന്തമായി മെച്ചപ്പെടുത്തുകയും വിശിഷ്ടമായ മൾട്ടി-ത്രെഡഡ് ബിസിനസ് പ്രക്രിയകൾ സജ്ജമാക്കുകയും ചെയ്യുന്നു.
#
# > **മൈഗ്രേഷൻ കുറിപ്പ്:** ഈ സാമ്പിൾ മുമ്പ് GitHub മാതൃകകൾ പരാമർശിച്ചിരുന്നു. GitHub മാതൃകകളെ ആഗസ്റ്റ് 2026-ൽ (ജൂലൈ 2026-ൽ) വിരമിക്കുകയാണ്, അതിനാൽ ഇപ്പോൾ ഇത് Azure OpenAI **Responses API** ലക്ഷ്യമിടുന്ന `FoundryChatClient` വഴി **Microsoft Foundry** ഉപയോഗിക്കുന്നു.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🚀 **സമകാലിക പ്രോസസ്സിംഗ് അടിസ്ഥാനങ്ങൾ**
# - **സമാന്തര ഏജന്റ് നടത്തിപ്പ്**: പരമാവധി ദക്ഷതയ്ക്കായി ഒരേ സമയം ഒന്നിലധികം ഏജന്റുമാർ പ്രവർത്തിക്കുക
# - **വർക്‌ഫ്ലോ കോർഡിനേഷൻ**: ഡാറ്റയുടെ സ്ഥിരത നിലനിർത്തുന്ന അതേസമയം സമകാലിക പ്രവർത്തനങ്ങൾ ഏകോപിപ്പിക്കുക
# - **പ്രകടന ഓപ്റ്റിമൈസേഷൻ**: സമാന്തര പ്രോസസ്സിങ്ങിലൂടെ പ്രധാനപ്പെട്ട വേഗത വർദ്ധിപ്പിക്കൽ
# - **റിസോഴ്‌സ് മാനേജ്മെന്റ്**: സമകാലിക പ്രവർത്തനങ്ങളിലൂടെയും AI മോഡൽ റിസോഴ്സുകളുടെ കാര്യക്ഷമമായ ഉപയോഗം
#
# ### 🏗️ **ഉന്നത സമകാലിക പാറ്റേണുകൾ**
# - **ഫോർക്ക്ജോയിൻ പ്രോസസിംഗ്**: ജോലിയ്‌ ഉപയോഗിച്ച് പല ഏജന്റുമാരിലായി വിഭജിച്ച് ഫലം സംയോജിപ്പിക്കൽ
# - **പൈപ്പ്‌ലൈൻ സമാന്തരത**: തുടർച്ചയായ ത്രൂപുട്ടിനായി ഓവർലാപ്പ് ചെയ്യുന്ന പ്രവർത്തനഘട്ടങ്ങൾ
# - **ലോഡ് ബാലൻസിംഗ്**: ലഭ്യമാക്കിയ ഏജന്റ് റിസോഴ്‌സുകളിലായി ജോലിയ് സമ ഭാവത്തോടെ വിതരണം ചെയ്യുക
# - **സമന്വയിപ്പിക്കൽ പോയിന്റുകൾ**: പ്രധാന വർക്‌ഫ്ലോ ഘട്ടങ്ങളിൽ സമകാലിക ഏജന്റുമാരെ ഏകോപിപ്പിക്കുക
#
# ### 🏢 **എന്റർപ്രൈസ് സമകാലിക അപ്ലിക്കേഷനുകൾ**
# - **ഉയർന്ന തോത് ഡോക്യുമന്റ് പ്രോസസിംഗ്**: ഒരേ സമയത്ത് ഒന്നിലധികം ഡോക്യുമെന്റുകൾ പ്രോസസ്സ് ചെയ്യുക
# - **റിയൽ-ടൈം ഉള്ളടക്കം വിശകലനം**: വരുന്ന ഡാറ്റാ സ്ട്രീമുകളിലെ സമകാലിക വിശകലനം
# - **ബാച്ച് പ്രോസസിംഗ് മെച്ചപ്പെടുത്തൽ**: വലുതായ പ്രവർത്തനങ്ങൾക്കായി പരമാവധി ത്രൂപുട്ട്
# - **മൾട്ടി-മോഡൽ വിശകലനം**: വ്യത്യസ്ത ഉള്ളടക്ക തരം (ടെസ്റ്റ്, ചിത്രങ്ങൾ, ഡാറ്റ) സമാന്തര പ്രോസസിംഗ്
#
# ## ⚙️ പ്രീറിക്വിസൈറ്റുകൾ & സജ്ജീകരണം
#
# ### 📦 **ആവശ്യമുള്ള ഡിപ്പെൻഡൻസികൾ**
#
# സമകാലിക വർക്‌ഫ്ലോ കഴിവുകൾ ഉള്ള Agent Framework ഇൻസ്റ്റാൾ ചെയ്യുക:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry കോൺഫിഗറേഷൻ**
#
# Azure CLI (`az login`) ഉപയോഗിച്ച് സൈൻ ഇൻ ചെയ്യുക, അതിനാൽ `AzureCliCredential` ഓതന്റിക്കേഷൻ നടത്താൻ കഴിയും, ശേഷം നിങ്ങളുടെ Microsoft Foundry പ്രോജക്ട് വിശദാംശങ്ങൾ സജ്ജമാക്കുക.
#
# **പരിസ്ഥിതി സജ്ജീകരിക്കൽ (.env ഫയൽ):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **സമകാലിക പ്രോസസ്സിംഗ് പരിഗണനകൾ:**
# - **റേറ്റ് ലിമിറ്റുകൾ**: സമകാലിക അഭ്യർത്ഥനകള്ക്കുള്ള Azure OpenAI റേറ്റ് ലിമിറ്റുകൾ ശ്രദ്ധിക്കുക
# - **റിസോഴ്‌സ് ഉപയോഗം**: പല സമകാലിക ഏജന്റുമാരുമായുള്ള മെമ്മറി, CPU ഉപയോഗം പരിഗണിക്കുക
# - **എറർ ഹാൻഡ്ലിംഗ്**: സമാന്തര പ്രവർത്തനങ്ങളിൽ ശക്തമായി പിശക് പുനരുദ്ധാരണം നടപ്പിലാക്കുക
#
# ### 🏗️ **സമകാലിക വർക്‌ഫ്ലോ ആർക്കിടെക്ചർ**
#
# ```mermaid
# graph TD
#     A[പ്രവൃത്തിപദ്ധതി തുടങ്ങി] --> B[സമകാലിക നിർവഹണം]
#     B --> C[ഏജന്റ് പൂൾ 1]
#     B --> D[ഏജന്റ് പൂൾ 2]
#     B --> E[ഏജന്റ് പൂൾ 3]
#     C --> F[ഫലം സംയോജനം]
#     D --> F
#     E --> F
#     F --> G[അന്തിമ ഔട്ട്പുട്ട്]
#
#     H[മൈക്രോസോഫ്റ്റ് ഫൗണ്ടറി] --> C
#     H --> D
#     H --> E
# ```
#
# **പ്രധാന നേട്ടങ്ങൾ:**
# - **⚡ പ്രകടനം**: സമാന്തര പ്രവർത്തനത്തിലൂടെ പ്രധാനപ്പെട്ട വേഗത വർദ്ധിപ്പിക്കൽ
# - **📈 സ്കേലബിലിറ്റി**: വർദ്ധിച്ച അളവ് ജോലികൾ അനുപാതികമായ സമയം കൂടാതെ കൈകാര്യം ചെയ്യുക
# - **🔄 കാര്യക്ഷമത**: ലഭ്യമായ കംപ്യൂട്ടേഷണൽ റിസോഴ്സുകളുടെ മെച്ചപ്പെട്ട ഉപയോഗം
# - **🎯 ത്രൂപുട്ട്**: ഒരേ സമയത്ത് കൂടുതൽ ജോലി പ്രോസസ്സ് ചെയ്യുക
#
# ## 🎨 **സമകാലിക വർക്‌ഫ്ലോ ഡിസൈൻ പാറ്റേണുകൾ**
#
# ### 🔍 **റിസർച് & അനാലിസിസ് പൈപ്പ്ലൈൻ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **ഡാറ്റ പ്രോസസിംഗ് വർക്‌ഫ്ലോ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **ഉള്ളടക്കം സൃഷ്ടി പൈപ്പ്ലൈൻ**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **മൾട്ടി-ഘട്ട പ്രോസസ്സിംഗ്**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **എന്റർപ്രൈസ് പ്രകടന നേട്ടങ്ങൾ**
#
# ### ⚡ **ത്രൂപുട്ട് ഓപ്റ്റിമൈസേഷൻ**
# - **സമാന്തര പ്രവർത്തനം**: ഒരേ സമയം നിരവധി ഏജന്റുമാർ പ്രവർത്തിക്കുന്നു
# - **റിസോഴ്‌സ് ഉപയോഗം**: ലഭ്യമായ AI മോഡൽ ശേഷിയുടെ പരമാവധി കാര്യക്ഷമത
# - **സമയം കുറവ്**: മൊത്തം പ്രോസസ്സിംഗ് സമയം വളരെ കുറയ്ക്കുക
# - **സ്കാലബിള്‍ ആർക്കിടെക്ചർ**: ആവശ്യത്തിന് കൂടുതൽ സമകാലിക ഏജന്റുമാർ എളുപ്പത്തിൽ ചേർക്കുക
#
# ### 🛡️ **നിലവാരവും പ്രതിരോധശേഷിയും**
# - **ഫോൾട്ട് ടോളറൻസ്**: വ്യക്തിഗത ഏജന്റ് പരാജയങ്ങൾ മുഴുവൻ വർക്‌ഫ്ലോ നിർത്തില്ല
# - **പിശക് വേർതിരിച്ചുവെക്കൽ**: ഒരോ സമകാലിക ശാഖയിൽപ്രശ്നങ്ങൾ മറ്റവയെ ബാധിക്കുന്നില്ല
# - **ദയാലു കുറവ്**: കുറവ് ഏജന്റ് ശേഷിയേത് ഉണ്ടായാലും സിസ്റ്റം പ്രവർത്തനം തുടരുന്നു
# - **പുനരുദ്ധാരണം ഉപാധികൾ**: പരാജയപ്പെട്ട പ്രവർത്തനങ്ങൾക്ക് സ്വയം വീണ്ടും ശ്രമിക്കുകയും പിശക് കൈകാര്യം ചെയ്യുകയും ചെയ്യുക
#
# ### 📊 **നീരീക്ഷണം & നിരീക്ഷണക്ഷമത**
# - **സമാന്തര പ്രവർത്തന ട്രാക്കിംഗ്**: എല്ലാ സമാന്തര പ്രവർത്തനങ്ങളുടെ പുരോഗതി നിരീക്ഷിക്കുക
# - **പ്രകടന മെട്രിക്സ്**: വേഗത വർദ്ധനവിനെയും കാര്യക്ഷമത നേട്ടങ്ങൾക്കും അളക്കുക
# - **റിസോഴ്‌സ് ഉപഭാവന വിശകലനം**: സമകാലിക ഏജന്റ് കൈവശീകരണം മെച്ചപ്പെടുത്തുക
# - **ബോട്ടിൽനെക് തിരിച്ചറിയൽ**: പ്രകടന നിയന്ത്രണങ്ങൾ കണ്ടെത്തി പരിഹരിക്കുക
#
# ഉയർന്ന പ്രകടനമുള്ള സമകാലിക AI വർക്‌ഫ്ലോകൾ നമുക്ക് നിർമ്മിക്കാം! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
