# %% [markdown]
# # 🔄 അടിയന്തര ഏജന്റ് വർക്ക്‌ഫ്ലോ -സകൾ Azure OpenAI (Responses API) (.NET) ഉപയോഗിച്ച്
#
# ## 📋 വർക്ക്‌ഫ്ലോ ഓർക്കസ്ട്രേഷൻ ട്യൂട്ടോറിയൽ
#
# ഈ നോട്ട്ബുക്കിൽ നിങ്ങൾ Microsoft Agent Framework .NET-നും Azure OpenAI (Responses API)-ഉം ഉപയോഗിച്ചുകൊണ്ട് സങ്കീർണ്ണമായ **ഏജന്റ് വർക്ക്‌ഫ്ലോ-കൾ** എങ്ങനെ സൃഷ്ടിക്കാമെന്ന് കാണിക്കുന്നു. ആധികാരികവും ഘടനാപരവുമായ ഓർക്കസ്ട്രേഷൻ പാറ്റേൺസ് വഴി AI ഏജന്റുകൾ സംയുക്തമായി പ്രവൃത്തി ചെയ്യുന്ന ബഹുവിധ ബിസിനസ് പ്രക്രിയകൾ സൃഷ്ടിക്കാൻ നിങ്ങൾക്ക് പഠിക്കാം.
#
# ## 🎯 പഠന ലക്ഷ്യങ്ങൾ
#
# ### 🏗️ **വർക്ക്‌ഫ്ലോ ആർക്കിടെക്ചർ അടിസ്ഥാന തത്വങ്ങൾ**
# - **വർക്ക്‌ഫ്ലോ બિલഡർ**: സങ്കീർണ്ണമായ ബഹു-പടിയിലെ AI പ്രക്രിയകൾ രൂപകൽപ്പന ചെയ്യാനും ഓർക്കസ്ട്രേറ്റ് ചെയ്യാനും
# - **ഏജന്റ് കോഓർഡിനേഷൻ**: സ്പെഷലൈസുകളും വിഭിന്നവുമായ നിരവധി ഏജന്റുകളെ വർക്ക്‌ഫ്ലോയിൽ ഏകോപിപ്പിക്കാൻ
# - **Azure OpenAI (Responses API)**: വർക്ക്‌ഫ്ലോയിൽ Azure OpenAI Responses API ഉപയോഗിക്കാൻ
# - **വിറ്റ്സ്വൽ വർക്ക്‌ഫ്ലോ ഡിസൈൻ**: വർക്ക്‌ഫ്ലോ ഘടനകൾ സൃഷ്ടിക്കുകയും ദൃശ്യവത്കരിക്കുകയും ചെയ്യാൻ
#
# ### 🔄 **പ്രക്രിയ ഓർക്കസ്ട്രേഷൻ പാറ്റേൺസ്**
# - **പരമ്പരാഗത പ്രോസസിംഗ്**: മാന്യമായ ക്രമത്തിൽ നിരവധി ഏജന്റ് ജോലി പൊളിച്ച് ചേർക്കാൻ
# - **സ്റ്റേറ്റ് മാനേജ്‌മെന്റ്**: വർക്ക്‌ഫ്ലോ ഘട്ടങ്ങളെ തുടർന്ന് പ്രസംഗവും ഡേറ്റാ പ്രവഹവും നിലനിർത്താൻ
# - **പിശക് കൈകാര്യം ചെയ്യൽ**: ശക്തമായ പിശക് പുനരുജ്ജീവനവും വർക്ക്‌ഫ്ലോ പ്രതിരോധവും നടപ്പാക്കാൻ
# - **പ്രവർത്തന കാര്യക്ഷമത മെച്ചപ്പെടുത്തൽ**: സംരംഭ-തല ഓപ്പറേഷനുകൾക്കായുള്ള പ്രവർത്തനക്ഷമമായ വർക്ക്‌ഫ്ലോ രൂപകൽപ്പന
#
# ### 🏢 **എന്റർപ്രൈസ് വർക്ക്‌ഫ്ലോ ആപ്ലിക്കേഷനുകൾ**
# - **ബിസിനസ് പ്രോസസ് ഓട്ടോമേഷൻ**: സങ്കീർണ്ണമായ സംഘടനാ വർക്ക്‌ഫ്ലോകൾ ഓട്ടോമേറ്റ് ചെയ്യാൻ
# - **കണ്ടന്റ് ഉൽപാദന പൈപ്പ്‌ലൈൻ**: അവലോകനവും അംഗീകാര ഘട്ടങ്ങളും ഉള്ള എഡിറ്റോറിയൽ വർക്ക്‌ഫ്ലോ
# - **കസ്റ്റമർ സർവീസ് ഓട്ടോമേഷൻ**: ബഹു-പടി ഉപഭോക്തൃ അന്വേഷണ പരിഹാരം
# - **ഡാറ്റ പ്രോസസിംഗ് വർക്ക്‌ഫ്ലോ**: AI സ്വാധീനിച്ച മാറ്റങ്ങളോടെ ETL വർക്ക്‌ഫ്ലോകൾ
#
# ## ⚙️ മുൻകരുതലുകളും സ്ഥാപിക്കൽ
#
# ### 📦 **ആവശ്യമായ NuGet പാക്കേജുകൾ**
#
# ഈ വർക്ക്‌ഫ്ലോ ഡെമോയ് പ്രധാന .NET പാക്കേജുകൾ ഉപയോഗിക്കുന്നു:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Azure OpenAI (Responses API) -->
# <PackageReference Include="Azure.AI.OpenAI" Version="2.1.0" />
# <PackageReference Include="Azure.Identity" Version="1.13.1" />
#
# <!-- Agent Framework (Local Development) -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - Azure OpenAI (Responses API) integration -->
#
# <!-- Configuration and Environment -->
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# ### 🔑 **Azure OpenAI കോൺഫിഗറേഷൻ**
#
# **പരിസരാവസ്ഥ ക്രമേന (.env ഫയൽ):**
# ```env
# AZURE_OPENAI_ENDPOINT=https://<your-resource>.openai.azure.com
# AZURE_OPENAI_DEPLOYMENT=gpt-4.1-mini
# ```
#
# **Azure OpenAI ആക്‌സസ്:**
# 1. Azure പോർട്ടലിൽ Azure OpenAI റിസോഴ്‌സ് സൃഷ്ടിക്കുക
# 2. ഒരു മോഡൽ (ഉദാ., `gpt-4.1-mini`) വിന്യസിക്കുക, വിന്യാസ നാമം ശ്രദ്ധിക്കുക
# 3. `az login` ഉപയോഗിച്ച് ലോഗിൻ ചെയ്ത് മുകളിൽ കാണിച്ചതുപോലെ പരിസരവ്യവസ്ഥ;margin-top:0;margin-bottom:0;margin-left:0;margin-right:0; പാരാമീറ്ററുകൾ ക്രമീകരിക്കുക
#
# ### 🏗️ **വർക്ക്‌ഫ്ലോ ആർക്കിടെക്ചർ അവലോകനം**
#
# ```mermaid
# graph TD
#     A[പ്രവൃത്തി പ്രക്രിയ നിർമ്മാതാവ്] --> B[ഏജന്റ് രജിസ്റ്റ്രി]
#     B --> C[പ്രവൃത്തി പ്രക്രിയ അതൃപ്തി എഞ്ചിൻ]
#     C --> D[Agent 1: ഉള്ളടക്കം രൂപകർത്താവ്]
#     C --> E[Agent 2: ഉള്ളടക്കം പരിശോധകൻ]
#     D --> F[പ്രവൃത്തി ഫലം]
#     E --> F
#     G[അസ്യൂർ OpenAI (പ്രതികരണങ്ങൾ API)] --> D
#     G --> E
# ```
#
# **പ്രധാന ഘടകങ്ങൾ:**
# - **WorkflowBuilder**: വർക്ക്‌ഫ്ലോകൾ രൂപകൽപ്പന ചെയ്യുന്നതിനും ഓർക്കസ്ട്രേറ്റ് ചെയ്യുന്നതിനും അടിസ്ഥാന എഞ്ചിൻ
# - **AIAgent**: പ്രത്യേക കഴിവുകൾ ഉള്ള വ്യക്തിഗത സ്പെഷലൈസ്‌ഡ് ഏജന്റുകൾ
# - **Azure OpenAI Client**: Azure OpenAI Responses API സംയോജനം
# - **Execution Context**: വർക്ക്‌ഫ്ലോ ഘട്ടങ്ങൾക്കിടയിൽ സ്റ്റേറ്റ്, ഡാറ്റ പ്രവഹം നിയന്ത്രിക്കുക
#
# ## 🎨 **എന്റർപ്രൈസ് വർക്ക്‌ഫ്ലോ ഡിസൈൻ പാറ്റേൺസ്**
#
# ### 📝 **കണ്ടന്റ് ഉൽപാദന വർക്ക്‌ഫ്ലോ**
# ```
# User Request → Content Generation → Quality Review → Final Output
# ```
#
# ### 🔍 **ഡോക്യുമെന്റ് പ്രോസസിംഗ് പൈപ്പ്‌ലൈൻ**
# ```
# Document Input → Analysis → Extraction → Validation → Structured Output
# ```
#
# ### 💼 **ബിസിനസ് ഇന്റലിജൻറ് വർക്ക്‌ഫ്ലോ**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ### 🤝 **കസ്റ്റമർ സർവീസ് ഓട്ടോമേഷൻ**
# ```
# Customer Inquiry → Classification → Processing → Response Generation → Follow-up
# ```
#
# ## 🏢 **എന്റർപ്രൈസ് നേട്ടങ്ങൾ**
#
# ### 🎯 **വിശ്വാസ്യതയും സ്കെയിലബിലിറ്റിയും**
# - **ഡിറ്റർമിനിസ്റ്റിക് എക്സിക്യൂഷൻ**: സ്ഥിരതയുള്ള, ആവർത്തിക്കാവുന്ന വർക്ക്‌ഫ്ലോ ഫലങ്ങൾ
# - **പിശക് പുനരുദ്ഘാടനം**: ഏതൊരു വർക്ക്‌ഫ്ലോ ഘട്ടത്തിലും പരാജയങ്ങൾ സൗമ്യമായി കൈകാര്യം ചെയ്യൽ
# - **പ്രവർത്തന നിരീക്ഷണം**: എക്സിക്യൂഷൻ മാനദണ്ഡങ്ങളും മെച്ചപ്പെടുത്തലുകൾ കണ്ടെത്താനുള്ള നിരീക്ഷണവും
# - **റിസോഴ്‌സ് മാനേജ്‌മെന്റ്**: AI മോഡൽ റിസോഴ്‌സുകൾ കാര്യക്ഷമമായി വിനിയോഗം
#
# ### 🔒 **സുരക്ഷയും അനുസരണയും**
# - **സുരക്ഷിത ആധികാരികത**: Microsoft Entra ID ആധികാരികത `az login` വഴി (AzureCliCredential)
# - **ഓഡിറ്റ് ട്രെയിലുകൾ**: വർക്ക്‌ഫ്ലോ എക്സിക്യൂഷനും തീരുമാന ബിന്ദുക്കളുടെ പൂർണ്ണ ലോഗിംഗ്
# - **ആക്‌സസ് നിയന്ത്രണം**: വർക്ക്‌ഫ്ലോ എക്സിക്യൂഷൻ, നിരീക്ഷണത്തിന് ഗ്രാനുലർ അനുമതികൾ
# - **ഡേറ്റാ പ്രൈവസി**: സങ്കടിപ്പിക്കുന്ന വിവരങ്ങളുടെ സുരക്ഷിത ഹാൻഡ്ലിംഗ് മുഴുവൻ വർക്ക്‌ഫ്ലോയിൽ
#
# ### 📊 **നിരീക്ഷണശക്തിയും മാനേജ്‌മെന്റും**
# - **വിജ്വൽ വർക്ക്‌ഫ്ലോ ഡിസൈൻ**: പ്രോസസ് പ്രവാഹവും ആശ്രിതത്വങ്ങളും വ്യക്തമായി പ്രതിനിധാനം ചെയ്യുക
# - **എക്സിക്യൂഷൻ നിരീക്ഷണം**: വർക്ക്‌ഫ്ലോ പുരോഗതിയും പ്രകടനവും യാഥാർത്ഥ്യകാല നിരീക്ഷണം
# - **പിശക് റിപ്പോർട്ടിംഗ്**: സമഗ്രമായ പിശക് വിശകലനവും ഡീബഗ് കഴിവുകളും
# - **പ്രവർത്തന വിശകലനം**: മെച്ചപ്പെടുത്തലിനും ശേഷി ആസൂത്രണത്തിനും മാനദണ്ഡങ്ങൾ
#
# നിങ്ങളുടെ ആദ്യത്തെ എന്റർപ്രൈസ്-സജ്ജമായ AI വർക്ക്‌ഫ്ലോ പണിയാം! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.OpenAI, 2.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
#r "nuget: OpenTelemetry.Api, 1.0.0"
#r "nuget: OpenTelemetry.Api, 1.0.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>OpenTelemetry.Api, 1.0.1</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.Workflows, 1.0.0-preview.251001.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.OpenAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
// #r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"

# %%
using System;
using System.ComponentModel;
using Azure.AI.OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
// Azure OpenAI with the Responses API (stable v1 endpoint). Sign in with `az login`.
var azureEndpoint = Environment.GetEnvironmentVariable("AZURE_OPENAI_ENDPOINT") ?? throw new InvalidOperationException("AZURE_OPENAI_ENDPOINT is not set.");
var deployment = Environment.GetEnvironmentVariable("AZURE_OPENAI_DEPLOYMENT") ?? "gpt-4.1-mini";

# %%
// The Azure OpenAI client is created directly from the endpoint and Azure CLI credential — no custom client options are required.

# %%
var azureClient = new AzureOpenAIClient(new Uri(azureEndpoint), new AzureCliCredential());

# %%
const string ReviewerAgentName = "Concierge";
const string ReviewerAgentInstructions = @"
    You are an are hotel concierge who has opinions about providing the most local and authentic experiences for travelers.
    The goal is to determine if the front desk travel agent has recommended the best non-touristy experience for a traveler.
    If so, state that it is approved.
    If not, provide insight on how to refine the recommendation without using a specific example. ";

# %%
const string FrontDeskAgentName = "FrontDesk";
const string FrontDeskAgentInstructions = @"""
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """;

# %%
AIAgent reviewerAgent = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:ReviewerAgentName,instructions:ReviewerAgentInstructions);
AIAgent frontDeskAgent  = azureClient.GetOpenAIResponseClient(deployment).CreateAIAgent(
    name:FrontDeskAgentName,instructions:FrontDeskAgentInstructions);

# %%
var workflow = new WorkflowBuilder(frontDeskAgent)
            .AddEdge(frontDeskAgent, reviewerAgent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("I would like to go to Paris.") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Visit the Louvre Museum. It's a must-see for art enthusiasts and history lovers.That recommendation is quite popular and likely to attract many tourists. To refine it for a more local and authentic experience, consider suggesting an alternative that focuses on smaller, lesser-known art venues or galleries. Look for places where local artists exhibit or community spaces that host cultural events. This approach allows travelers to connect with the local art scene more intimately, away from the typical tourist routes.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
