# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) ഉപയോഗിച്ചു എന്റർപ്രൈസ് RAG
#
# ## 📋 പഠന ലക്ഷ്യങ്ങൾ
#
# Microsoft Foundry ഉപയോഗിച്ച് .NET ല്‍ Microsoft Agent Framework ഉപയോഗിച്ച് എന്റർപ്രൈസ്-ഗ്രേഡ് Retrieval-Augmented Generation (RAG) സിസ്റ്റങ്ങൾ എങ്ങനെ ഉണ്ടാക്കാമെന്ന് ഈ നോട്ട്ബുക്ക് പ്രദർശിപ്പിക്കുന്നു. ദസ്താവേജുകൾ തിരയാനും, എന്റർപ്രൈസ് സുരക്ഷയും സ്കേലബിലിറ്റിയും ഉള്ള നിഗമനങ്ങൾ നല്‍കാനും കഴിയുന്ന ഉത്പാദനത്തിനുള്ള റെഡ്ഡി ഏജന്റുകൾ രൂപപ്പെടുത്താൻ പഠിക്കുമെന്ന് നിങ്ങൾക്കാം.
#
# **നിങ്ങൾ സൃഷ്ടിക്കാനുള്ള എന്റർപ്രൈസ് RAG കഴിവുകൾ:**
# - 📚 **ഡോക്യുമെന്റ് ഇന്റലിജൻസ്**: Azure AI സേവനങ്ങളോടുകൂടിയ മുൻ‌നിര ഡോക്യുമെന്റ് പ്രോസസ്സിംഗ്
# - 🔍 **സെമാന്റിക് സെർച്ച്**: എന്റർപ്രൈസ് ഫീച്ചറുകളുള്ള ഉയർന്ന പ്രകടനക്ഷമമായ വെക്ടർ സെർച്ച്
# - 🛡️ **സുരക്ഷ സംയോജനം**: റോൾ അടിസ്ഥാനമാക്കി പ്രാപ്യതയും ഡേറ്റാ സംരക്ഷണ മാതൃകകളും
# - 🏢 **സ്കേലബിള്‍ ആർക്കിടെക്ചർ**: നിരീക്ഷണം ഉള്ള ഉത്പാദനത്തിനുള്ള റെഡ്ഡി RAG സിസ്റ്റങ്ങൾ
#
# ## 🎯 എന്റർപ്രൈസ് RAG ആർക്കിടെക്ചർ
#
# ### കോർ എന്റർപ്രൈസ് ഘടകങ്ങൾ
# - **Microsoft Foundry**: സുരക്ഷയും അനുസരണയും ഉള്ള മാനേജ് ചെയ്‌ത എന്റർപ്രൈസ് AI പ്ലാറ്റ്‌ഫോം
# - **Persistent Agents**: സംഭാഷണചരിത്രവും സാങ്കേതികമാനേജ്മെന്റും ഉള്ള സ്റ്റേറ്റ്‌ഫുള്‍ ഏജന്റുകൾ
# - **Vector Store Management**: എന്റർപ്രൈസ്-ഗ്രേഡ് ഡോക്യുമെന്റ് ഇൻഡെക്സിങ് ഉം റീട്രീവലും
# - **Identity Integration**: Azure AD പ്രാമാണീകരണവും റോൾ അടിസ്ഥാനമാക്കിയുള്ള പ്രവേശന നിയന്ത്രണവും
#
# ### .NET എന്റർപ്രൈസ് ലാഭങ്ങൾ
# - **ടൈപ്പ് സേഫ്റ്റി**: RAG പ്രവർത്തനങ്ങൾക്കും ഡാറ്റാ ഘടനകള്ക്കും കോമ്പൈൽ സമയം പരിശോധന
# - **Async പ്രകടനം**: ബ്ലോക്കിംഗ് രഹിത ഡോക്യുമെന്റ് പ്രോസസ്സിംഗ് ഉം സെർച്ച് പ്രവർത്തനങ്ങൾ
# - **മെമ്മറി മാനേജ്മെന്റ്**: വലിയ ഡോക്യുമെന്റ് ശേഖരണങ്ങൾക്കായി കാര്യക്ഷമമായ വിഭവ ഉപയോഗം
# - **സമന്വയ മാതൃകകൾ**: ഡിപെൻഡൻസി ഇൻജെക്ഷനോടൊപ്പം സ്വദേശീയ Azure സേവന സംയോജനം
#
# ## 🏗️ സാങ്കേതിക ആർക്കിടെക്ചർ
#
# ### എന്റർപ്രൈസ് RAG പൈപ്പ്‌ലൈൻ
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### കോർ .NET ഘടകങ്ങൾ
# - **Azure.AI.Agents.Persistent**: സ്റ്റേറ്റ് പെർഷിസ്റന്റുമായി എന്റർപ്രൈസ് ഏജന്റ് മാനേജ്മെന്റ്
# - **Azure.Identity**: സുരക്ഷിത Azure സർവീസ് ആക്സസ്സിനുള്ള സമന്വയപ്പെട്ട പ്രാമാണീകരണം
# - **Microsoft.Agents.AI.AzureAI**: Azure ഓപ്റ്റിമൈസ്ഡ് ഏജന്റ് ഫ്രെയിംവർക്ക് നടപ്പാക്കൽ
# - **System.Linq.Async**: ഉയർന്ന പ്രകടനക്ഷമമായ അസിങ്ക് LINQ പ്രവർത്തനങ്ങൾ
#
# ## 🔧 എന്റർപ്രൈസ് ഫീച്ചറുകളും ഗുണങ്ങളും
#
# ### സുരക്ഷയും അനുസരണയും
# - **Azure AD സംയോജനം**: എന്റർപ്രൈസ് ഐഡന്റിറ്റി മാനേജ്മെന്റും പ്രാമാണീകരണവും
# - **റോൾ അടിസ്ഥാനമാക്കിയുള്ള പ്രവേശനം**: ഡോക്യുമെന്റ് ആക്സസിനും പ്രവർത്തനങ്ങൾക്കും സൂക്ഷ്മ അവകാശങ്ങൾ
# - **ഡാറ്റാ സംരക്ഷണം**: സ്നേഹസഹിത ഡോക്യുമെന്റുകൾക്കായി വിശ്രമവും ട്രാൻസിറ്റിലും എൻക്രിപ്ഷൻ
# - **ഓഡിറ്റ് ലോഗിങ്**: അനുസരണ ആവശ്യങ്ങൾക്ക് സമഗ്ര പ്രവർത്തന ട്രാക്കിംഗ്
#
# ### പ്രകടനവും സ്കേലബിലിറ്റിയും
# - **കണക്ഷൻ പൂലിംഗ്**: കാര്യക്ഷമ Azure സേവന കണക്ഷൻ മാനേജ്മെന്റ്
# - **അസിങ്ക് പ്രോസസ്സിംഗ്**: ഉയർന്ന ത്രൂപ്പുട്ട് സാഹചര്യങ്ങൾക്ക് ബ്ലോക്ക് രഹിത പ്രവർത്തനങ്ങൾ
# - **കാച്ചിംഗ് തന്ത്രങ്ങൾ**: പതിവായി ആക്സസ് ചെയ്യുന്ന ഡോക്യുമെന്റുകൾക്കായി ബുദ്ധിമുട്ടുള്ള കാച്ചിങ്
# - **ലോഡ് ബാലൻസിംഗ്**: വലിയ തോതിലെ വിന്യസനങ്ങൾക്ക് വിതരണം ചെയ്ത പ്രോസസ്സിംഗ്
#
# ### മാനേജ്മെന്റും നിരീക്ഷണവും
# - **ഹെൽത്ത് ചെക്കുകൾ**: RAG സിസ്റ്റം ഘടകങ്ങൾക്ക് നിർമ്മിത നിരീക്ഷണം
# - **പ്രകടന മീട്രിക്‌സ്**: സെർച്ച് നിലവാരം, പ്രതികരണം സമയം എന്നിവയുടെ വിശദമായ വിശകലനം
# - **പിശക് കൈകാര്യം**: പുനരാരംഭ നയങ്ങളോടെയുള്ള സമഗ്ര അപവാദ മാനേജ്മെന്റ്
# - **സംഘടന മാനേജ്മെന്റ്**: പരിസ്ഥിതി-ഗുണപരമായ സെറ്റിംഗുകളോട് പരിശോധന
#
# ## ⚙️ മുൻ‌അവശyakതകളും ക്രമീകരണങ്ങളും
#
# **ഡവലപ്‌മെന്റ് പരിസ്ഥിതി:**
# - .NET 9.0 SDK അല്ലെങ്കിൽ അതിൽ മുകളിൽ
# - Visual Studio 2022 അല്ലെങ്കിൽ C# എക്സ്റ്റൻഷൻ ഉള്ള VS Code
# - AI Foundry ആക്സസ് ഉള്ള Azure സബ്സ്ക്രിപ്ഷൻ
#
# **ആവശ്യമായ NuGet പാക്കേജുകൾ:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure പ്രാമാണീകരണ ക്രമീകരണം:**
# ```bash
# # Azure CLI ഇൻസ്റ്റാൾ ചെയ്യുക અને പ്രാമാണീകരിക്കുക
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **പരിസ്ഥിതി കോൺഫിഗറേഷൻ (.env ഫയൽ):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 എന്റർപ്രൈസ് RAG മാതൃകകൾ
#
# ### ഡോക്യുമെന്റ് മാനേജ്മെന്റ് മാതൃകകൾ
# - **ബൾക്ക് അപ്‍ലോഡ്**: വലിയ ഡോക്യുമെന്റ് ശേഖരങ്ങളുടെ കാര്യക്ഷമമായ പ്രോസസ്സിംഗ്
# - **ഇൻക്രീമെന്റൽ അപ്‌ഡേറ്റുകൾ**: റിയൽ ടൈം ഡോക്യുമെന്റ് ചേർക്കലും തിരുത്തലും
# - **വർഷൻ കൺട്രോൾ**: ഡോക്യുമെന്റിന്റെ പതിപ്പും മാറ്റമടക്കൽ ട്രാക്കിംഗ്
# - **മറ്റഡേറ്റ മാനേജ്മെന്റ്**: സമൃദ്ധമായ ഡോക്യുമെന്റ് ഗുണങ്ങളും വർഗ്ഗീകരണവും
#
# ### സെർച്ച് & റീട്രീവൽ മാതൃകകൾ
# - **ഹൈബ്രിഡ് സെർച്ച്**: മികച്ച ഫലത്തിനായി സെമാന്റിക് പിന്നും കീവർഡ് സെർചും ചേർക്കൽ
# - **ഫാസറ്റഡ് സെർച്ച്**: ബഹുരൂപ ഫിൽട്ടറിംഗ് ഉം വർഗ്ഗീകരണവും
# - **രിലവൻസ് ട്യൂണിംഗ്**: ഡൊമെയ്ൻ പ്രത്യേക ആവശ്യങ്ങൾക്കുള്ള കസ്റ്റം സ്കോറിംഗ് ആൾഗോരിതങ്ങൾ
# - **ഫലം റാങ്കിംഗ്**: ബിസിനസ് ലജിക് സംയോജനമുള്ള മുൻനിര റാങ്കിംഗ്
#
# ### സുരക്ഷ മാതൃകകൾ
# - **ഡോക്യുമെന്റ്-ലെവൽ സുരക്ഷ**: ഓരോ ഡോക്യുമെന്റിനും സൂക്ഷ്മ പ്രവേശന നിയന്ത്രണം
# - **ഡാറ്റാ ക്ലാസിഫിക്കേഷൻ**: സ്വയം സ്നേഹസഹിത ലേബലിംഗും സംരക്ഷണവും
# - **ഓഡിറ്റ് ട്രെയിൽസ്**: എല്ലാ RAG പ്രവർത്തനങ്ങളുടെ സമഗ്ര ലോഗ്ഗിംഗ്
# - **സ്വകാര്യത സംരക്ഷണം**: PII കണ്ടെത്തലും റെഡാക്ഷനും
#
# ## 🔒 എന്റർപ്രൈസ് സുരക്ഷാ ഫീച്ചറുകൾ
#
# ### പ്രാമാണീകരണവും അധികാരനിർണ്ണയവും
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### ഡാറ്റ സംരക്ഷണം
# - **എൻക്രിപ്ഷൻ**: ഡോക്യുമെന്റുകൾക്കും സെർച്ച് ഇൻഡീസുകൾക്കുമായി എൺഡ്-ടു-എൺഡ് എൻക്രിപ്ഷൻ
# - **പ്രവേശന നിയന്ത്രണങ്ങൾ**: ഉപയോക്താവിനും ഗ്രൂപ്പിനും അനുവാദങ്ങൾക്ക് Azure AD സംയോജനം
# - **ഡാറ്റാ റസിഡൻസി**: അനുസരണത്തിനായി ഭൂമിശാസ്ത്ര ഡാറ്റ സ്ഥലം നിയന്ത്രണങ്ങൾ
# - **ബാക്കപ്പ് & പുനരുദ്ധാരം**: സ്വയം പ്രവർത്തിക്കുന്ന ബാക്കപ്പും ദുരന്തം പുനരുദ്ധാരവും
#
# ## 📈 പ്രകടനം മെച്ചപ്പെടുത്തൽ
#
# ### അസിങ്ക് പ്രോസസ്സിംഗ് മാതൃകകൾ
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### മെമ്മറി മാനേജ്മെന്റ്
# - **സ്റ്റ്രീമിങ് പ്രോസസ്സിംഗ്**: മെമ്മറി പ്രശ്നങ്ങളില്ലാതെ വലിയ ഡോക്യുമെന്റുകൾ കൈകാര്യം ചെയ്യുക
# - **റിസോഴ്‌സ് പൂലിംഗ്**: ചെലവേറിയ വിഭവങ്ങളുടെ കാര്യക്ഷമ പുനരുപയോഗം
# - **ഗാർബേജ് കളക്ഷൻ**: മെമ്മറി നിയമിത അവകാശവത്കരണം മാതൃകകൾ
# - **കണക്ഷൻ മാനേജ്മെന്റ്**: അതീവത Azure സർവീസ് കണക്ഷൻ ലൈഫ്സൈകിൾ
#
# ### കാച്ചിംഗ് തന്ത്രങ്ങൾ
# - **ക്വേരി കാച്ചിംഗ്**: പതിവായി നിർവഹിക്കുന്ന സെർച്ചുകൾ കാച്ചുചെയ്യുക
# - **ഡോക്യുമെന്റ് കാച്ചിംഗ്**: ഹോട്ട് ഡോക്യുമെന്റുകൾക്കായി ഇൻ-മെമ്മറി കാച്ചിംഗ്
# - **ഇൻഡക്സ് കാച്ചിംഗ്**: മെച്ചപ്പെടുത്തിയ വെക്ടർ ഇൻഡക്സ് കാച്ചിംഗ്
# - **ഫലം കാച്ചിംഗ്**: സൃഷ്ടിക്കപ്പെട്ട പ്രതികരണങ്ങളുടെ ബുദ്ധിവുത്തുള്ള കാച്ചിംഗ്
#
# ## 📊 എന്റർപ്രൈസ് ഉപയോഗ കേസുകൾ
#
# ### അറിവ് മാനേജ്മെന്റ്
# - **കോർപ്പറേറ്റ് വിക്കി**: കമ്പനിയുടെ അറിവ് ബേസുകളിലൂടെ ബുദ്ധിമുട്ടുള്ള സെർച്ച്
# - **പോലിസിയും പ്രവർത്തനരീതികളും**: സ്വയം പ്രവർത്തിക്കുന്ന അനുസരണവും പ്രക്രിയ മാർഗ്ഗനിർദേശവും
# - **ട്രെയിനിംഗ് മെറ്റീരിയലുകൾ**: ബുദ്ധിമുട്ടുള്ള പഠനവും വികസന സഹായവും
# - **ഗവേഷണ ഡാറ്റാബേസുകൾ**: അക്കാദമികവും ഗവേഷണ പേപ്പർ വിശകലന സിസ്റ്റങ്ങളും
#
# ### ഉപഭോക്തൃ പിന്തുണ
# - **സഹായ അറിവ് ബേസ്**: സ്വയം പ്രവർത്തിക്കുന്ന ഉപഭോക്തൃ സേവന പ്രതികരണങ്ങൾ
# - **ഉൽപ്പന്ന ഡോക്യുമെന്റേഷൻ**: ബുദ്ധിമുട്ടുള്ള ഉൽപ്പന്ന വിവരങ്ങൾ റീട്രീവൽ
# - **പ്രശ്‌നം പരിഹാര മാർഗ്ഗനിർദ്ദേശങ്ങൾ**: സാങ്കേതിക പ്രശ്‌ന പരിഹാര സഹായം
# - **FAQ സിസ്റ്റങ്ങൾ**: ഡോക്യുമെന്റ് ശേഖരങ്ങളിൽ നിന്ന് ഡൈനാമിക് FAQ സൃഷ്ടി
#
# ### നിയമാനുസരണ മലയാളം
# - **കാനൂനി ഡോക്യുമെന്റ് വിശകലനം**: കരാറുകൾക്കും നിയമാനുസരണ ഡോക്യുമെന്റുകൾക്കും ഇന്റലിജൻസ്
# - **അനുസരണ മോണിറ്ററിംഗ്**: സ്വയം പ്രവർത്തിക്കുന്ന നിയമാനുസരണ പരിശോധന
# - **റിസ്‌ക് അസസ്മെന്റ്**: ഡോക്യുമെന്റ് അടിസ്ഥാനമാക്കിയുള്ള റിസ്‌ക് വിശകലനവും റിപ്പോർട്ടിംഗും
# - **ഓഡിറ്റ് പിന്തുണ**: ഓഡിറ്റുകൾക്കായുള്ള ബുദ്ധിമുട്ടുള്ള ഡോ큐മെന്റ് കണ്ടുപിടുത്തം
#
# ## 🚀 ഉത്പാദന വിന്യാസം
#
# ### നിരീക്ഷണവും ദൃശ്യവൽക്കരണവും
# - **ആപ്ലിക്കേഷൻ ഇൻസൈറ്റ്സ്**: വിശദമായ ടെലിമെട്രിയും പ്രകടന നിരീക്ഷണവും
# - **കസ്റ്റം മീട്രിക്‌സ്**: ബിസിനസ്-നിഷ്‌ട KPI ട്രാക്കിംഗും അലേർട്ടിംഗും
# - **വിതരണം ട്രേസിംഗ്**: സർവീസുകൾക്ക് ഇടയിലുള്ള പൂർണ്ണമായ അഭ്യർത്ഥന ട്രാക്കിംഗ്
# - **ഹെൽത്ത് ഡാഷ്ബോർഡുകൾ**: റിയൽ ടൈം സിസ്റ്റം ആരോഗ്യവും പ്രകടനവും ദൃശ്യവൽക്കരണം
#
# ### സ്കേലബിലിറ്റിയും വിശ്വസനീയതയും
# - **ഓട്ടോ-സ്കെയിലിംഗ്**: ലോഡ് ഉം പ്രകടന മീത്രിക്സും അടിസ്ഥാനമാക്കി സ്വയം സ്കെയിലിംഗ്
# - **ഹൈ അറ്റൈലിബിലിറ്റി**: ഫെയിലോവർ വൈദ്യതികളോടെ മൾട്ടി-റിയോൺ വിന്യാസം
# - **ലോഡ് ടെസ്റ്റിംഗ്**: എന്റർപ്രൈസ് ലോഡ് വ്യവസ്ഥകളിലുള്ള പ്രകടന പരിശോധന
# - **ഡിസാസ്റ്റർ റികവറി**: സ്വയം പ്രവർത്തിക്കുന്ന ബാക്കപ്പ് ഉം പുനരുദ്ധാര പ്രക്രിയകൾ
#
# സംവേദനശേഷിയുള്ള ഡോക്യുമെന്റുകൾ വലിയ തോതിൽ കൈകാര്യം ചെയ്യുന്ന എന്റർപ്രൈസ് ഗ്രേഡ് RAG സിസ്റ്റങ്ങൾ നിർമ്മിക്കാൻ തയ്യാറേ? എന്റർപ്രൈസിനുള്ള ബുദ്ധിയുള്ള അറിവ് സിസ്റ്റങ്ങൾ ആർക്കിടെക്ചർ ചെയ്യാം! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
