# %% [markdown]
# # 🔍 نظام استرجاع معزز على مستوى المؤسسات مع Microsoft Foundry (.NET)
#
# ## 📋 أهداف التعلم
#
# يوضح هذا الدفتر كيفية بناء أنظمة استرجاع معزز على مستوى المؤسسات باستخدام إطار عمل Microsoft Agent في .NET مع Microsoft Foundry. ستتعلم كيفية إنشاء وكلاء جاهزين للإنتاج يمكنهم البحث عبر المستندات وتقديم ردود دقيقة وواعية للسياق مع أمان المؤسسات وقابليتها للتوسع.
#
# **قدرات نظام RAG على مستوى المؤسسات التي ستبنيها:**
# - 📚 **ذكاء الوثائق**: معالجة متقدمة للوثائق باستخدام خدمات Azure AI
# - 🔍 **البحث الدلالي**: بحث متجه عالي الأداء مع ميزات للمؤسسات
# - 🛡️ **تكامل الأمان**: التحكم في الوصول بناءً على الدور ونماذج حماية البيانات
# - 🏢 **هيكلية قابلة للتوسع**: أنظمة RAG جاهزة للإنتاج مع المراقبة
#
# ## 🎯 هيكلية نظام RAG على مستوى المؤسسات
#
# ### المكونات الأساسية للمؤسسات
# - **Microsoft Foundry**: منصة ذكاء اصطناعي مدارة للمؤسسات مع الأمان والامتثال
# - **الوكلاء الدائمون**: وكلاء بحالة يتذكرون تاريخ المحادثة وإدارة السياق
# - **إدارة مخزن المتجهات**: فهرسة مستندات على مستوى المؤسسات واسترجاعها
# - **تكامل الهوية**: مصادقة Azure AD والتحكم في الوصول بناءً على الدور
#
# ### فوائد .NET للمؤسسات
# - **أمان النوع**: التحقق وقت الترجمة لعمليات RAG وهياكل البيانات
# - **أداء غير متزامن**: معالجة مستندات وبحث غير محظور
# - **إدارة الذاكرة**: استخدام موارد فعال لمجموعات مستندات كبيرة
# - **أنماط التكامل**: تكامل خدمات Azure الأصلي مع حقن التبعيات
#
# ## 🏗️ الهيكلية التقنية
#
# ### خط أنابيب RAG على مستوى المؤسسات
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### المكونات الأساسية لـ .NET
# - **Azure.AI.Agents.Persistent**: إدارة الوكلاء المؤسسية مع حفظ الحالة
# - **Azure.Identity**: مصادقة مدمجة للوصول الآمن إلى خدمات Azure
# - **Microsoft.Agents.AI.AzureAI**: تنفيذ إطار عمل الوكلاء المحسن لـ Azure
# - **System.Linq.Async**: عمليات LINQ غير متزامنة عالية الأداء
#
# ## 🔧 ميزات وفوائد المؤسسة
#
# ### الأمان والامتثال
# - **تكامل Azure AD**: إدارة الهوية المؤسسية والمصادقة
# - **الوصول بناءً على الدور**: أذونات دقيقة للوصول إلى المستندات والعمليات
# - **حماية البيانات**: التشفير أثناء التخزين والنقل للمستندات الحساسة
# - **تسجيل التدقيق**: تتبع النشاط الشامل لمتطلبات الامتثال
#
# ### الأداء وقابلية التوسع
# - **تجمع الاتصالات**: إدارة فعالة لاتصالات خدمات Azure
# - **المعالجة غير المتزامنة**: عمليات غير محظورة لسيناريوهات ذات حجم كبير
# - **استراتيجيات التخزين المؤقت**: تخزين ذكي للمستندات التي يتم الوصول إليها بشكل متكرر
# - **توازن التحميل**: معالجة موزعة لنشر واسع النطاق
#
# ### الإدارة والمراقبة
# - **فحوصات الصحة**: مراقبة مدمجة لمكونات نظام RAG
# - **مقاييس الأداء**: تحليلات مفصلة لجودة البحث وأوقات الاستجابة
# - **معالجة الأخطاء**: إدارة شاملة للاستثناءات مع سياسات إعادة المحاولة
# - **إدارة التكوين**: إعدادات خاصة بالبيئة مع التحقق
#
# ## ⚙️ المتطلبات الأساسية والإعداد
#
# **بيئة التطوير:**
# - .NET SDK 9.0 أو أعلى
# - Visual Studio 2022 أو VS Code مع امتداد C#
# - اشتراك Azure مع وصول إلى AI Foundry
#
# **حزم NuGet المطلوبة:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **إعداد المصادقة لـ Azure:**
# ```bash
# # تثبيت Azure CLI وتسجيل الدخول
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **تكوين البيئة (ملف .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 أنماط RAG على مستوى المؤسسات
#
# ### أنماط إدارة الوثائق
# - **تحميل مجمع**: معالجة فعالة لمجموعات المستندات الكبيرة
# - **التحديثات التزايدية**: إضافة وتعديل المستندات في الوقت الحقيقي
# - **التحكم في الإصدارات**: إصدار الوثائق وتتبع التغييرات
# - **إدارة البيانات الوصفية**: سمات غنية وتصنيف المستندات
#
# ### أنماط البحث والاسترجاع
# - **البحث الهجين**: دمج البحث الدلالي وبحث الكلمات المفتاحية للحصول على أفضل النتائج
# - **البحث ذات الأوجه**: التصفية والتصنيف متعدد الأبعاد
# - **ضبط الصلة**: خوارزميات تقييم مخصصة لاحتياجات المجال
# - **ترتيب النتائج**: ترتيب متقدم مع تكامل منطق الأعمال
#
# ### أنماط الأمان
# - **أمان على مستوى الوثيقة**: تحكم دقيق في الوصول لكل وثيقة
# - **تصنيف البيانات**: تصنيف تلقائي للحساسية وحماية
# - **سجلات التدقيق**: تسجيل كامل لجميع عمليات RAG
# - **حماية الخصوصية**: كشف بيانات التعريف الشخصية وقدرات الحجب
#
# ## 🔒 ميزات أمان المؤسسات
#
# ### المصادقة والتفويض
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### حماية البيانات
# - **التشفير**: تشفير نهاية إلى نهاية للوثائق وفهارس البحث
# - **ضوابط الوصول**: التكامل مع Azure AD لأذونات المستخدمين والمجموعات
# - **موقع البيانات**: التحكم الجغرافي لموقع البيانات للامتثال
# - **النسخ الاحتياطي والاسترداد**: نسخ احتياطي آلي وقدرات استرداد الكوارث
#
# ## 📈 تحسين الأداء
#
# ### أنماط المعالجة غير المتزامنة
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### إدارة الذاكرة
# - **المعالجة المتدفقة**: التعامل مع مستندات كبيرة بدون مشاكل في الذاكرة
# - **تجميع الموارد**: إعادة استخدام فعالة للموارد المكلفة
# - **جمع القمامة**: أنماط تخصيص الذاكرة المحسنة
# - **إدارة الاتصال**: دورة حياة اتصال خدمة Azure المناسبة
#
# ### استراتيجيات التخزين المؤقت
# - **تخزين مؤقت للاستعلامات**: تخزين البحثات المتكررة
# - **تخزين مستندات مؤقت**: التخزين المؤقت داخل الذاكرة للمستندات الساخنة
# - **تخزين فهرس المؤشرات**: تحسين التخزين المؤقت لفهرس المتجه
# - **تخزين مؤقت للنتائج**: تخزين ذكي للردود المُولدة
#
# ## 📊 حالات استخدام المؤسسات
#
# ### إدارة المعرفة
# - **ويكي الشركة**: بحث ذكي عبر قواعد معرفة الشركة
# - **السياسات والإجراءات**: الامتثال الآلي وإرشادات الإجراءات
# - **مواد التدريب**: المساعدة الذكية للتعلم والتطوير
# - **قواعد بيانات البحث**: أنظمة تحليل الورق الأكاديمي والبحثي
#
# ### دعم العملاء
# - **قاعدة المعرفة للدعم**: الردود الآلية لخدمة العملاء
# - **توثيق المنتج**: استرجاع معلومات المنتج الذكي
# - **أدلة استكشاف الأخطاء**: مساعدة حل المشكلات حسب السياق
# - **أنظمة الأسئلة الشائعة**: إنشاء الأسئلة الشائعة الديناميكي من مجموعات الوثائق
#
# ### الامتثال التنظيمي
# - **تحليل الوثائق القانونية**: ذكاء العقود والوثائق القانونية
# - **مراقبة الامتثال**: التحقق الآلي من الالتزام التنظيمي
# - **تقييم المخاطر**: تحليل المخاطر والتقارير المبنية على الوثائق
# - **دعم التدقيق**: اكتشاف الوثائق الذكي للتدقيقات
#
# ## 🚀 نشر الإنتاج
#
# ### المراقبة والرصد
# - **Application Insights**: التتبع التفصيلي للأداء والقياسات
# - **مقاييس مخصصة**: تتبع وتنبيه مؤشرات أداء الأعمال المحددة
# - **التتبع الموزع**: تتبع الطلبات من البداية للنهاية عبر الخدمات
# - **لوحات صحة النظام**: تصور صحة وأداء النظام في الوقت الحقيقي
#
# ### القابلية للتوسع والموثوقية
# - **التحجيم التلقائي**: التحجيم التلقائي بناءً على الحمل وقياسات الأداء
# - **التوفر العالي**: النشر في مناطق متعددة مع قدرات تجاوز الفشل
# - **اختبار الحمل**: التحقق من الأداء تحت ظروف حمل المؤسسات
# - **التعافي من الكوارث**: إجراءات النسخ الاحتياطي والاسترداد الآلية
#
# هل أنت مستعد لبناء أنظمة RAG على مستوى المؤسسات يمكنها التعامل مع المستندات الحساسة على نطاق واسع؟ دعنا نصمم أنظمة معرفة ذكية للمؤسسة! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **تنويه**:
# تمت ترجمة هذا المستند باستخدام خدمة الترجمة بالذكاء الاصطناعي [Co-op Translator](https://github.com/Azure/co-op-translator). بينما نسعى للدقة، يرجى العلم أن الترجمات الآلية قد تحتوي على أخطاء أو عدم دقة. يجب اعتبار المستند الأصلي بلغته الأصلية المصدر الرسمي والمعتمد. للمعلومات الهامة، يُنصح بالاستعانة بترجمة بشرية محترفة. نحن غير مسؤولين عن أي سوء فهم أو تفسير ناتج عن استخدام هذه الترجمة.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
