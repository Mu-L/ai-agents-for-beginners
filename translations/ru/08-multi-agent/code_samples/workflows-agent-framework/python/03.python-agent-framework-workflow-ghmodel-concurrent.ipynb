# %% [markdown]
# # ⚡ Параллельные рабочие процессы агентов с Microsoft Foundry (Python)
#
# ## 📋 Руководство по продвинутой параллельной обработке
#
# В этой записной книжке демонстрируются **паттерны параллельных рабочих процессов** с использованием Microsoft Agent Framework. Вы научитесь создавать высокопроизводительные рабочие процессы параллельной обработки, в которых несколько ИИ-агентов выполняются одновременно, значительно повышая пропускную способность и позволяя реализовать сложные многопоточные бизнес-процессы.
#
# > **Примечание по миграции:** Этот пример ранее ссылался на GitHub Models. GitHub Models устарел (выводится из эксплуатации в июле 2026 года), поэтому теперь используется **Microsoft Foundry** через `FoundryChatClient`, который работает с Azure OpenAI **Responses API**.
#
# ## 🎯 Цели обучения
#
# ### 🚀 **Основы параллельной обработки**
# - **Параллельное выполнение агентов**: запускайте нескольких агентов одновременно для максимальной эффективности
# - **Оркестровка рабочих процессов**: координируйте параллельные операции при сохранении целостности данных
# - **Оптимизация производительности**: достигаете значительного ускорения за счёт параллельной обработки
# - **Управление ресурсами**: эффективно используйте ресурсы моделей ИИ в параллельных операциях
#
# ### 🏗️ **Продвинутые паттерны параллелизма**
# - **Обработка с fork-join**: разделяйте работу между несколькими агентами и объединяйте результаты
# - **Параллелизм конвейера**: перекрывающиеся стадии выполнения для непрерывной пропускной способности
# - **Балансировка нагрузки**: равномерно распределяйте работу между доступными агентами
# - **Точки синхронизации**: координируйте параллельных агентов на критических этапах рабочего процесса
#
# ### 🏢 **Параллельные корпоративные приложения**
# - **Обработка большого объёма документов**: одновременно обрабатывайте множество документов
# - **Анализ контента в реальном времени**: параллельный анализ входящих потоков данных
# - **Оптимизация пакетной обработки**: максимальная пропускная способность для масштабных операций
# - **Мультимодальный анализ**: параллельная обработка разных типов контента (текст, изображения, данные)
#
# ## ⚙️ Требования и настройка
#
# ### 📦 **Необходимые зависимости**
#
# Установите Agent Framework с поддержкой параллельных рабочих процессов:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Настройка Microsoft Foundry**
#
# Выполните вход через Azure CLI (`az login`), чтобы `AzureCliCredential` мог пройти аутентификацию, затем укажите детали вашего проекта Microsoft Foundry.
#
# **Настройка окружения (файл .env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Особенности параллельной обработки:**
# - **Ограничения по скорости**: контролируйте лимиты Azure OpenAI для параллельных запросов
# - **Использование ресурсов**: учитывайте использование памяти и ЦП при множестве параллельных агентов
# - **Обработка ошибок**: реализуйте надёжное восстановление после ошибок для параллельных операций
#
# ### 🏗️ **Архитектура параллельного рабочего процесса**
#
# ```mermaid
# graph TD
#     A[Начало рабочего процесса] --> B[Параллельное выполнение]
#     B --> C[Пул агентов 1]
#     B --> D[Пул агентов 2]
#     B --> E[Пул агентов 3]
#     C --> F[Агрегация результатов]
#     D --> F
#     E --> F
#     F --> G[Итоговый вывод]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Ключевые преимущества:**
# - **⚡ Производительность**: значительное ускорение за счёт параллельного выполнения
# - **📈 Масштабируемость**: обрабатывайте возросшую нагрузку без пропорционального увеличения времени
# - **🔄 Эффективность**: лучшее использование доступных вычислительных ресурсов
# - **🎯 Пропускная способность**: выполните больше работы за то же время
#
# ## 🎨 **Паттерны проектирования параллельных рабочих процессов**
#
# ### 🔍 **Конвейер исследований и анализа**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Рабочий процесс обработки данных**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Конвейер создания контента**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Многоступенчатая обработка**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Корпоративные преимущества производительности**
#
# ### ⚡ **Оптимизация пропускной способности**
# - **Параллельное выполнение**: несколько агентов работают одновременно
# - **Использование ресурсов**: максимальная эффективность использования возможностей модели ИИ
# - **Сокращение времени**: значительное уменьшение общего времени обработки
# - **Масштабируемая архитектура**: легко добавить больше параллельных агентов по мере необходимости
#
# ### 🛡️ **Надёжность и устойчивость**
# - **Отказоустойчивость**: сбои отдельного агента не останавливают весь рабочий процесс
# - **Изоляция ошибок**: проблемы в одной параллельной ветке не влияют на другие
# - **Плавное деградирование**: система продолжает работать даже при сниженной ёмкости агентов
# - **Механизмы восстановления**: автоматический повтор и обработка ошибок неудачных операций
#
# ### 📊 **Мониторинг и наблюдаемость**
# - **Отслеживание параллельного выполнения**: контроль прогресса всех параллельных операций
# - **Метрики производительности**: измеряйте ускорение и прирост эффективности
# - **Аналитика использования ресурсов**: оптимизируйте распределение параллельных агентов
# - **Идентификация узких мест**: находите и устраняйте ограничения производительности
#
# Давайте создавать высокопроизводительные параллельные рабочие процессы ИИ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от ответственности**:
# Этот документ был переведен с использованием сервиса машинного перевода [Co-op Translator](https://github.com/Azure/co-op-translator). Несмотря на наши усилия по обеспечению точности, имейте в виду, что автоматический перевод может содержать ошибки или неточности. Оригинальный документ на его исходном языке следует считать авторитетным источником. Для получения критически важной информации рекомендуется обратиться к профессиональному человеческому переводу. Мы не несем ответственности за любые недоразумения или неправильные толкования, возникшие в результате использования этого перевода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
