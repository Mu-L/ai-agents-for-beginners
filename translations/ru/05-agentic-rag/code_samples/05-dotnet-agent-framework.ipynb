# %% [markdown]
# # 🔍 Корпоративный RAG с Microsoft Foundry (.NET)
#
# ## 📋 Цели обучения
#
# В этой тетрадке демонстрируется, как создавать корпоративные системы Retrieval-Augmented Generation (RAG) с использованием Microsoft Agent Framework в .NET и Microsoft Foundry. Вы научитесь создавать готовых к производству агентов, которые могут искать по документам и предоставлять точные, контекстно-осведомленные ответы с корпоративной безопасностью и масштабируемостью.
#
# **Возможности корпоративного RAG, которые вы создадите:**
# - 📚 **Интеллектуальная обработка документов**: Продвинутая обработка документов с помощью Azure AI сервисов
# - 🔍 **Семантический поиск**: Высокопроизводительный векторный поиск с корпоративными функциями
# - 🛡️ **Интеграция безопасности**: Ролевая модель доступа и шаблоны защиты данных
# - 🏢 **Масштабируемая архитектура**: Производственные RAG-системы с мониторингом
#
# ## 🎯 Архитектура корпоративного RAG
#
# ### Основные корпоративные компоненты
# - **Microsoft Foundry**: Управляемая корпоративная AI платформа с безопасностью и соответствием требованиям
# - **Постоянные агенты**: Состояние агентов с историей разговоров и управлением контекстом
# - **Управление векторным хранилищем**: Корпоративная индексация и извлечение документов
# - **Интеграция идентификации**: Аутентификация Azure AD и контроль доступа на основе ролей
#
# ### Преимущества .NET для корпоративных решений
# - **Типобезопасность**: Проверка во время компиляции для операций RAG и структур данных
# - **Асинхронная производительность**: Неблокирующая обработка документов и операции поиска
# - **Управление памятью**: Эффективное использование ресурсов для больших коллекций документов
# - **Шаблоны интеграции**: Родная интеграция Azure-сервисов с внедрением зависимостей
#
# ## 🏗️ Техническая архитектура
#
# ### Корпоративный RAG конвейер
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Основные .NET-компоненты
# - **Azure.AI.Agents.Persistent**: Управление корпоративными агентами с сохранением состояния
# - **Azure.Identity**: Интегрированная аутентификация для безопасного доступа к Azure сервисам
# - **Microsoft.Agents.AI.AzureAI**: Оптимизированная для Azure реализация фреймворка агентов
# - **System.Linq.Async**: Высокопроизводительные асинхронные операции LINQ
#
# ## 🔧 Корпоративные функции и преимущества
#
# ### Безопасность и соответствие требованиям
# - **Интеграция Azure AD**: Корпоративное управление идентичностями и аутентификация
# - **Управление доступом по ролям**: Тонкая настройка прав доступа к документам и операциям
# - **Защита данных**: Шифрование в состоянии покоя и при передаче для конфиденциальных документов
# - **Аудит журналирования**: Всеобъемлющее отслеживание действий для соответствия требованиям
#
# ### Производительность и масштабируемость
# - **Пул соединений**: Эффективное управление соединениями с Azure сервисами
# - **Асинхронная обработка**: Неблокирующие операции для сценариев с высокой пропускной способностью
# - **Стратегии кэширования**: Интеллектуальное кэширование часто запрашиваемых документов
# - **Балансировка нагрузки**: Распределённая обработка для масштабных развёртываний
#
# ### Управление и мониторинг
# - **Проверки состояния**: Встроенный мониторинг компонентов RAG-системы
# - **Метрики производительности**: Детальная аналитика качества поиска и времени отклика
# - **Обработка ошибок**: Всестороннее управление исключениями с политиками повторения
# - **Управление конфигурацией**: Настройки под конкретные окружения с валидацией
#
# ## ⚙️ Требования и настройка
#
# **Среда разработки:**
# - SDK .NET 9.0 или выше
# - Visual Studio 2022 или VS Code с расширением C#
# - Подписка Azure с доступом к AI Foundry
#
# **Необходимые NuGet пакеты:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Настройка аутентификации Azure:**
# ```bash
# # Установите Azure CLI и выполните аутентификацию
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Конфигурация окружения (файл .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Корпоративные шаблоны RAG
#
# ### Шаблоны управления документами
# - **Массовая загрузка**: Эффективная обработка больших коллекций документов
# - **Инкрементальные обновления**: Редактирование и добавление документов в реальном времени
# - **Контроль версий**: Версионирование документов и отслеживание изменений
# - **Управление метаданными**: Богатые атрибуты документов и таксономия
#
# ### Шаблоны поиска и извлечения
# - **Гибридный поиск**: Сочетание семантического и ключевого поиска для оптимальных результатов
# - **Фасетный поиск**: Многоизмерная фильтрация и категоризация
# - **Настройка релевантности**: Пользовательские алгоритмы оценки под задачи конкретной области
# - **Ранжирование результатов**: Продвинутая сортировка с интеграцией бизнес-логики
#
# ### Шаблоны безопасности
# - **Безопасность на уровне документа**: Тонкая настройка доступа для каждого документа
# - **Классификация данных**: Автоматическое определение чувствительности и защита
# - **Аудит**: Всеобъемлющее журналирование всех операций RAG
# - **Защита конфиденциальности**: Обнаружение и скрытие персональных данных (PII)
#
# ## 🔒 Корпоративные функции безопасности
#
# ### Аутентификация и авторизация
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Защита данных
# - **Шифрование**: Сквозное шифрование документов и поисковых индексов
# - **Контроль доступа**: Интеграция с Azure AD для управления правами пользователей и групп
# - **Резиденция данных**: Географический контроль расположения данных для соответствия требованиям
# - **Резервное копирование и восстановление**: Автоматические процедуры бэкапа и аварийного восстановления
#
# ## 📈 Оптимизация производительности
#
# ### Асинхронные шаблоны обработки
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управление памятью
# - **Потоковая обработка**: Работа с большими документами без проблем с памятью
# - **Пул ресурсов**: Эффективное повторное использование дорогих ресурсов
# - **Сборка мусора**: Оптимизированные схемы выделения памяти
# - **Управление соединениями**: Корректный жизненный цикл соединений с Azure сервисами
#
# ### Стратегии кэширования
# - **Кэширование запросов**: Кэширование часто выполняемых поисков
# - **Кэширование документов**: Кэширование «горячих» документов в памяти
# - **Кэширование индексов**: Оптимизированное кэширование векторных индексов
# - **Кэширование результатов**: Интеллектуальное кэширование сгенерированных ответов
#
# ## 📊 Корпоративные сценарии использования
#
# ### Управление знаниями
# - **Корпоративная вики**: Интеллектуальный поиск по базам знаний компании
# - **Политики и процедуры**: Автоматическое соблюдение и руководство по процедурам
# - **Учебные материалы**: Интеллектуальная помощь в обучении и развитии
# - **Исследовательские базы данных**: Анализ академических и исследовательских статей
#
# ### Клиентская поддержка
# - **База знаний поддержки**: Автоматические ответы службам поддержки клиентов
# - **Документация продуктов**: Интеллектуальный поиск информации о продуктах
# - **Руководства по устранению неполадок**: Контекстная помощь в решении проблем
# - **FAQ-системы**: Динамическая генерация FAQ из коллекций документов
#
# ### Регуляторное соответствие
# - **Анализ юридических документов**: Интеллектуальная обработка контрактов и юридических бумаг
# - **Мониторинг соответствия**: Автоматическая проверка соблюдения нормативных требований
# - **Оценка рисков**: Анализ рисков и отчетность на основе документов
# - **Поддержка аудита**: Интеллектуальный поиск документов для аудитов
#
# ## 🚀 Развёртывание в продакшн
#
# ### Мониторинг и наблюдаемость
# - **Application Insights**: Подробная телеметрия и мониторинг производительности
# - **Пользовательские метрики**: Отслеживание KPI и оповещения по бизнес-показателям
# - **Распределённое трассирование**: Сквозное отслеживание запросов между сервисами
# - **Дашборды состояния**: Визуализация состояния системы и производительности в реальном времени
#
# ### Масштабируемость и надёжность
# - **Автоматическое масштабирование**: Автоматическое изменение мощности в зависимости от нагрузки и метрик
# - **Высокая доступность**: Развёртывание в нескольких регионах с возможностью переключения при сбоях
# - **Тестирование нагрузки**: Валидация производительности под корпоративными условиями нагрузки
# - **Аварийное восстановление**: Автоматизированные процедуры резервного копирования и восстановления
#
# Готовы создавать корпоративные RAG-системы, способные обрабатывать конфиденциальные документы в масштабах? Давайте проектировать интеллектуальные системы управления знаниями для корпораций! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от ответственности**:
# Этот документ был переведен с использованием сервиса машинного перевода [Co-op Translator](https://github.com/Azure/co-op-translator). Несмотря на наши усилия по обеспечению точности, имейте в виду, что автоматический перевод может содержать ошибки или неточности. Оригинальный документ на его исходном языке следует считать авторитетным источником. Для получения критически важной информации рекомендуется обратиться к профессиональному человеческому переводу. Мы не несем ответственности за любые недоразумения или неправильные толкования, возникшие в результате использования этого перевода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
