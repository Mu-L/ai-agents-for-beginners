# %% [markdown]
# # ⚡ Các Luồng Công Việc Tác Nhân Đồng Thời với Microsoft Foundry (Python)
#
# ## 📋 Hướng Dẫn Xử Lý Song Song Nâng Cao
#
# Sổ tay này trình bày các **mô hình luồng công việc đồng thời** sử dụng Microsoft Agent Framework. Bạn sẽ học cách xây dựng các luồng công việc xử lý song song hiệu suất cao nơi nhiều tác nhân AI thực thi đồng thời, cải thiện đáng kể hiệu suất và cho phép các quy trình kinh doanh đa luồng tinh vi.
#
# > **Ghi chú di cư:** Mẫu này trước đây tham chiếu GitHub Models. GitHub Models hiện đã ngừng sử dụng (rút lui vào tháng 7 năm 2026), vì vậy nó hiện sử dụng **Microsoft Foundry** thông qua `FoundryChatClient`, nhắm đến API **Responses** của Azure OpenAI.
#
# ## 🎯 Mục Tiêu Học Tập
#
# ### 🚀 **Kiến Thức Cơ Bản về Xử Lý Đồng Thời**
# - **Thực Thi Tác Nhân Song Song**: Chạy nhiều tác nhân đồng thời để đạt hiệu quả tối đa
# - **Điều Phối Luồng Công Việc**: Phối hợp các hoạt động đồng thời trong khi duy trì tính nhất quán dữ liệu
# - **Tối Ưu Hiệu Suất**: Đạt được tăng tốc đáng kể thông qua xử lý song song
# - **Quản Lý Tài Nguyên**: Sử dụng hiệu quả các tài nguyên mô hình AI trong các hoạt động đồng thời
#
# ### 🏗️ **Mô Hình Đồng Thời Nâng Cao**
# - **Xử Lý Fork-Join**: Chia công việc cho nhiều tác nhân và hợp nhất kết quả
# - **Song Song Đường Ống**: Các giai đoạn thực thi chồng lấp cho dòng chảy liên tục
# - **Cân Bằng Tải**: Phân phối công việc đều trên các tài nguyên tác nhân có sẵn
# - **Điểm Đồng Bộ**: Phối hợp các tác nhân đồng thời tại các giai đoạn quan trọng của luồng công việc
#
# ### 🏢 **Ứng Dụng Đồng Thời Doanh Nghiệp**
# - **Xử Lý Tài Liệu Số Lượng Lớn**: Xử lý nhiều tài liệu cùng lúc
# - **Phân Tích Nội Dung Thời Gian Thực**: Phân tích đồng thời các luồng dữ liệu đầu vào
# - **Tối Ưu Xử Lý Lô**: Tối đa hóa thông lượng cho các hoạt động quy mô lớn
# - **Phân Tích Đa Phương Thức**: Xử lý song song các loại nội dung khác nhau (văn bản, hình ảnh, dữ liệu)
#
# ## ⚙️ Yêu Cầu & Cài Đặt
#
# ### 📦 **Phụ Thuộc Yêu Cầu**
#
# Cài đặt Agent Framework với khả năng luồng công việc đồng thời:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Cấu Hình Microsoft Foundry**
#
# Đăng nhập với Azure CLI (`az login`) để `AzureCliCredential` có thể xác thực, sau đó thiết lập chi tiết dự án Microsoft Foundry của bạn.
#
# **Thiết lập Môi trường (.env file):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Lưu ý về Xử Lý Đồng Thời:**
# - **Giới Hạn Tốc Độ**: Theo dõi giới hạn tốc độ Azure OpenAI đối với các yêu cầu đồng thời
# - **Sử Dụng Tài Nguyên**: Xem xét bộ nhớ và CPU khi có nhiều tác nhân đồng thời
# - **Xử Lý Lỗi**: Triển khai phục hồi lỗi vững chắc cho các hoạt động song song
#
# ### 🏗️ **Kiến Trúc Luồng Công Việc Đồng Thời**
#
# ```mermaid
# graph TD
#     A[Bắt đầu luồng công việc] --> B[Thực thi đồng thời]
#     B --> C[Nhóm tác nhân 1]
#     B --> D[Nhóm tác nhân 2]
#     B --> E[Nhóm tác nhân 3]
#     C --> F[Tổng hợp kết quả]
#     D --> F
#     E --> F
#     F --> G[Kết quả cuối cùng]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Lợi Ích Chính:**
# - **⚡ Hiệu Suất**: Tăng tốc đáng kể thông qua thực thi song song
# - **📈 Khả Năng Mở Rộng**: Xử lý khối lượng công việc tăng mà không tăng thời gian tương ứng
# - **🔄 Hiệu Quả**: Tận dụng tốt hơn các tài nguyên tính toán có sẵn
# - **🎯 Thông Lượng**: Xử lý nhiều công việc hơn trong cùng khoảng thời gian
#
# ## 🎨 **Mô Hình Thiết Kế Luồng Công Việc Đồng Thời**
#
# ### 🔍 **Đường Ống Nghiên Cứu & Phân Tích**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Luồng Công Việc Xử Lý Dữ Liệu**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Đường Ống Tạo Nội Dung**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Xử Lý Nhiều Giai Đoạn**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Lợi Ích Hiệu Suất Doanh Nghiệp**
#
# ### ⚡ **Tối Ưu Thông Lượng**
# - **Thực Thi Song Song**: Nhiều tác nhân làm việc đồng thời
# - **Sử Dụng Tài Nguyên**: Hiệu quả tối đa công suất mô hình AI hiện có
# - **Giảm Thời Gian**: Giảm đáng kể tổng thời gian xử lý
# - **Kiến Trúc Có Khả Năng Mở Rộng**: Dễ dàng thêm nhiều tác nhân đồng thời khi cần
#
# ### 🛡️ **Độ Tin Cậy & Khả Năng Chịu Lỗi**
# - **Chịu Lỗi**: Lỗi tác nhân riêng lẻ không làm gián đoạn toàn bộ luồng công việc
# - **Phân Lập Lỗi**: Sự cố trong một nhánh đồng thời không ảnh hưởng đến các nhánh khác
# - **Giảm Chất Lượng Một Cách Nhẹ Nhàng**: Hệ thống tiếp tục hoạt động ngay cả khi giảm công suất tác nhân
# - **Cơ Chế Phục Hồi**: Tự động thử lại và xử lý lỗi cho các hoạt động thất bại
#
# ### 📊 **Giám Sát & Quan Sát**
# - **Theo Dõi Thực Thi Đồng Thời**: Giám sát tiến độ của tất cả các hoạt động song song
# - **Chỉ Số Hiệu Suất**: Đo lường tốc độ và lợi ích về hiệu quả
# - **Phân Tích Sử Dụng Tài Nguyên**: Tối ưu phân bổ tác nhân song song
# - **Nhận Diện Nút Thắt**: Tìm và giải quyết các giới hạn hiệu năng
#
# Hãy cùng xây dựng các luồng công việc AI đồng thời hiệu suất cao! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Tuyên bố miễn trừ trách nhiệm**:
# Tài liệu này đã được dịch bằng dịch vụ dịch thuật AI [Co-op Translator](https://github.com/Azure/co-op-translator). Mặc dù chúng tôi cố gắng đảm bảo độ chính xác, xin lưu ý rằng bản dịch tự động có thể chứa lỗi hoặc sai sót. Tài liệu gốc bằng ngôn ngữ gốc nên được coi là nguồn tin chính thức. Đối với thông tin quan trọng, nên sử dụng dịch vụ dịch thuật chuyên nghiệp bởi con người. Chúng tôi không chịu trách nhiệm về bất kỳ hiểu lầm hoặc giải thích sai nào phát sinh từ việc sử dụng bản dịch này.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
