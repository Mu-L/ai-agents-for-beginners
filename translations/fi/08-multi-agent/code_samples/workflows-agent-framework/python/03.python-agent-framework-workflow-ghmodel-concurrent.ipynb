# %% [markdown]
# # ⚡ Samanaikaiset agenttityönkulut Microsoft Foundryn kanssa (Python)
#
# ## 📋 Edistynyt rinnakkaisprosessointiohjeistus
#
# Tämä muistikirja demonstroi **samanaikaisia työnkulkujen malleja** Microsoft Agent Frameworkin avulla. Opit rakentamaan suorituskykyisiä, rinnakkaisia työnkulkuja, joissa useat tekoälyagentit suorittavat samanaikaisesti, mikä parantaa läpimenokykyä dramaattisesti ja mahdollistaa monimutkaiset monisäikeiset liiketoimintaprosessit.
#
# > **Migraatiomuistio:** Tämä esimerkki viittasi aiemmin GitHub-malleihin. GitHub-mallit ovat vanhentumassa (poistuvat heinäkuussa 2026), joten nyt käytetään **Microsoft Foundrya** `FoundryChatClient`-asiakkaan kautta, joka käyttää Azure OpenAI:n **Responses API:a**.
#
# ## 🎯 Oppimistavoitteet
#
# ### 🚀 **Samanaikaisen prosessoinnin perusteet**
# - **Rinnakkainen agenttien suoritus**: Suorita useita agentteja samanaikaisesti maksimaalisen tehokkuuden saavuttamiseksi
# - **Työnkulun orkestrointi**: Koordinoi samanaikaisia toimintoja säilyttäen datan yhdenmukaisuuden
# - **Suorituskyvyn optimointi**: Saavuta merkittävä nopeutus rinnakkaisprosessoinnin avulla
# - **Resurssienhallinta**: Hyödynnä tehokkaasti tekoälymallien resursseja samanaikaisissa toiminnoissa
#
# ### 🏗️ **Edistyneet samanaikaisuuden mallit**
# - **Fork-Join-prosessointi**: Jaa työ useille agenteille ja yhdistä tulokset
# - **Putkirunkorinnakkaisuus**: Päällekkäiset suoritustasot jatkuvan läpimenokyvyn saavuttamiseksi
# - **Kuormantasapainotus**: Jaa työ tasaisesti käytettävissä olevien agenttiresurssien kesken
# - **Synkronointipisteet**: Koordinoi samanaikaisia agenteja kriittisissä työnkulun vaiheissa
#
# ### 🏢 **Yritysten samanaikaiset sovellukset**
# - **Suuren määrän dokumenttien käsittely**: Käsittele useita dokumentteja samanaikaisesti
# - **Reaaliaikainen sisällön analysointi**: Samanaikainen analyysi saapuvista tietovirroista
# - **Eräprosessoinnin optimointi**: Maksimoi läpimeno suurissa toiminnoissa
# - **Monimodaalinen analyysi**: Rinnakkainen prosessointi eri sisältötyypeille (teksti, kuvat, data)
#
# ## ⚙️ Esivaatimukset ja asennus
#
# ### 📦 **Vaaditut riippuvuudet**
#
# Asenna Agent Framework rinnakkaisten työnkulkujen tueksi:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundryn konfigurointi**
#
# Kirjaudu sisään Azure CLI:llä (`az login`), jotta `AzureCliCredential` voi autentikoida, ja aseta Microsoft Foundry -projektisi tiedot.
#
# **Ympäristön asetukset (.env-tiedosto):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Samanaikaisen prosessoinnin huomioita:**
# - **Nopeusrajoitukset**: Seuraa Azure OpenAI:n nopeusrajoituksia samanaikaisille pyynnöille
# - **Resurssien käyttö**: Huomioi muistin ja suorittimen käyttö useiden samanaikaisten agenttien kohdalla
# - **Virheenkäsittely**: Toteuta vankka virheenkorjaus rinnakkaisissa toiminnoissa
#
# ### 🏗️ **Samanaikaisen työnkulun arkkitehtuuri**
#
# ```mermaid
# graph TD
#     A[Työnkulun aloitus] --> B[Samanaikainen suoritus]
#     B --> C[Agenttipooli 1]
#     B --> D[Agenttipooli 2]
#     B --> E[Agenttipooli 3]
#     C --> F[Tulosten yhteenvedon tekeminen]
#     D --> F
#     E --> F
#     F --> G[Loppulähtö]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Keskeiset hyödyt:**
# - **⚡ Suorituskyky**: Merkittävä nopeutus rinnakkaissuorituksen ansiosta
# - **📈 Skaalautuvuus**: Käsittele lisääntyneitä työkuormia ilman ajankäytön kasvua
# - **🔄 Tehokkuus**: Parempi hyöty käytettävissä olevista laskentaresursseista
# - **🎯 Läpiaines**: Käsittele enemmän työtä samalla aikamäärällä
#
# ## 🎨 **Samanaikaisen työnkulun suunnittelumallit**
#
# ### 🔍 **Tutkimus- ja analyysiputki**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Datan prosessointityönkulku**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisällöntuotantoputki**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Monivaiheinen prosessointi**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Yritysten suorituskykyedut**
#
# ### ⚡ **Läpimenon optimointi**
# - **Rinnakkainen suoritus**: Useat agentit työskentelevät samanaikaisesti
# - **Resurssien hyödyntäminen**: Maksimaalinen tehokkuus käytettävissä olevasta tekoälymallin kapasiteetista
# - **Ajan lyhennys**: Merkittävä kokonaiskäsittelyajan lyheneminen
# - **Skaalautuva arkkitehtuuri**: Lisää helposti lisää samanaikaisia agentteja tarpeen mukaan
#
# ### 🛡️ **Luotettavuus ja resilienssi**
# - **Vikasietoisuus**: Yksittäiset agentin virheet eivät pysäytä koko työnkulkua
# - **Virheiden eristäminen**: Ongelmilla yhdessä samanaikaisessa haarassa ei ole vaikutusta muihin
# - **Arvokas heikkeneminen**: Järjestelmä jatkaa toimintaansa myös vähentyneellä agenttiteholla
# - **Palautumismekanismit**: Automaattinen uudelleenyritys ja virheenkäsittely epäonnistuneille toiminnoille
#
# ### 📊 **Seuranta ja havaittavuus**
# - **Samanaikaisen suorittamisen seuranta**: Seuraa kaikkien rinnakkaistoimintojen etenemistä
# - **Suorituskykymittarit**: Mittaa nopeutus- ja tehokkuushyödyt
# - **Resurssienkäytön analytiikka**: Optimoi samanaikaisten agenttien allokointi
# - **Pullonkaulojen tunnistus**: Löydä ja ratkaise suorituskykyongelmat
#
# Rakennetaan korkeasuorituskykyisiä samanaikaisia tekoälytyönkulkuja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastuuvapauslauseke**:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, otathan huomioon, että automaattiset käännökset saattavat sisältää virheitä tai epätarkkuuksia. Alkuperäinen asiakirja sen alkuperäiskielellä on virallinen lähde. Tärkeissä asioissa suositellaan ammattimaista ihmiskäännöstä. Emme ole vastuussa tämän käännöksen käytöstä aiheutuvista väärinymmärryksistä tai tulkinnoista.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
