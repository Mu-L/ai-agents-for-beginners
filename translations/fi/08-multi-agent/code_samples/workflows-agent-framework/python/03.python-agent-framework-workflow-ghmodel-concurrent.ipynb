# %% [markdown]
# # ⚡ Samanaikaiset agenttityönkulut Microsoft Foundryn kanssa (Python)
#
# ## 📋 Edistynyt rinnakkaiskäsittelyopas
#
# Tämä muistikirja näyttää **samanaikaisten työnkulkujen mallit** käyttäen Microsoft Agent Frameworkia. Opit rakentamaan suorituskykyisiä, rinnakkaisia työnkulkuja, joissa useat tekoälyagentit suorittavat samanaikaisesti, mikä parantaa huomattavasti läpimenoa ja mahdollistaa monimutkaiset monisäikeiset liiketoimintaprosessit.
#
# > **Siirtymismuistio:** Tämä esimerkki viittasi aiemmin GitHub-malleihin. GitHub-mallit on poistettu käytöstä (eläkkeelle siirtyminen heinäkuussa 2026), joten se käyttää nyt **Microsoft Foundrya** `FoundryChatClient`in kautta, joka kohdistuu Azure OpenAI:n **Responses APIin**.
#
# ## 🎯 Oppimistavoitteet
#
# ### 🚀 **Samanaikaisen käsittelyn perusteet**
# - **Rinnakkainen agenttien suoritus**: Suorita useita agenteja samanaikaisesti maksimaalisen tehokkuuden saavuttamiseksi
# - **Työnkulun orkestrointi**: Koordinoi samanaikaiset toiminnot säilyttäen tietojen yhdenmukaisuuden
# - **Suorituskyvyn optimointi**: Saavuta merkittävä nopeutus rinnakkaiskäsittelyn avulla
# - **Resurssien hallinta**: Käytä tekoälymallien resursseja tehokkaasti samanaikaisissa toiminnoissa
#
# ### 🏗️ **Edistyneet samanaikaisuuden mallit**
# - **Fork-Join-käsittely**: Jaa työ useille agenteille ja yhdistä tulokset
# - **Putkirivistysrinnakkaisuus**: Päällekkäiset suoritusvaiheet jatkuvaan läpimenoaikaan
# - **Kuormantasapainotus**: Jaa työ tasaisesti käytettävissä olevien agenttien kesken
# - **Synkronointipisteet**: Koordinoi samanaikaisia agenteja kriittisissä työnkulun vaiheissa
#
# ### 🏢 **Yritystason samanaikaiset sovellukset**
# - **Suuri dokumenttikäsittely**: Käsittele useita asiakirjoja samanaikaisesti
# - **Reaaliaikainen sisällön analyysi**: Saapuvien datavirtojen samanaikainen analyysi
# - **Eräkäsittelyn optimointi**: Maksimoi läpimeno suurissa mittakaavoissa
# - **Monimodaalinen analyysi**: Eri sisältötyyppien (teksti, kuvat, data) rinnakkainen käsittely
#
# ## ⚙️ Esivaatimukset & asetukset
#
# ### 📦 **Vaaditut riippuvuudet**
#
# Asenna Agent Framework rinnakkaisten työnkulkujen mahdollistamiseksi:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundryn määritykset**
#
# Kirjaudu Azure CLI:llä (`az login`), jotta `AzureCliCredential` voi todentaa, ja aseta sitten Microsoft Foundry -projektin tiedot.
#
# **Ympäristön asetustiedosto (.env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **Samanaikaisen käsittelyn huomioitavaa:**
# - **Nopeusrajat**: Seuraa Azure OpenAI:n nopeusrajoituksia samanaikaisille pyyntöille
# - **Resurssien käyttö**: Huomioi muisti- ja suorittimen käyttö useiden samanaikaisten agenttien kanssa
# - **Virheenkäsittely**: Toteuta vankka virheiden palautumisen mekanismi rinnakkaistoiminnoille
#
# ### 🏗️ **Samanaikaisten työnkulkujen arkkitehtuuri**
#
# ```mermaid
# graph TD
#     A[Työnkulun aloitus] --> B[Samanaikainen suoritus]
#     B --> C[Agenttiallas 1]
#     B --> D[Agenttiallas 2]
#     B --> E[Agenttiallas 3]
#     C --> F[Tulosten yhdistäminen]
#     D --> F
#     E --> F
#     F --> G[Lopullinen tulos]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Keskeiset edut:**
# - **⚡ Suorituskyky**: Merkittävä nopeutus rinnakkaissuorituksen avulla
# - **📈 Skaalautuvuus**: Käsittele lisääntyviä työkuormia ilman suhteellista ajan kasvua
# - **🔄 Tehokkuus**: Parempi käytön hyödyntäminen saatavilla olevista laskentaresursseista
# - **🎯 Läpäisykyky**: Käsittele enemmän työtä samassa ajassa
#
# ## 🎨 **Samanaikaisten työnkulkujen suunnittelumallit**
#
# ### 🔍 **Tutkimus- ja analyysiputki**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Datan prosessointityönkulku**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Sisällöntuotantoputki**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Monivaiheinen käsittely**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Yrityksen suorituskykyhyödyt**
#
# ### ⚡ **Läpimenoajan optimointi**
# - **Rinnakkainen suoritus**: Useat agentit työskentelevät samanaikaisesti
# - **Resurssien hyödyntäminen**: Maksimaalinen tehokkuus käytettävissä olevasta tekoälymallikapasiteetista
# - **Ajan lyhennys**: Merkittävä kokonaistyöaika lyhenee
# - **Skaalautuva arkkitehtuuri**: Lisää helposti useampia samanaikaisia agentteja tarpeen mukaan
#
# ### 🛡️ **Luotettavuus & Resilienssi**
# - **Vikasietoisuus**: Yksittäiset agenttien viat eivät pysäytä koko työnkulkua
# - **Virheiden eristäminen**: Ongelmilla yhdessä samanaikaisessa haarassa ei ole vaikutusta muihin
# - **Sujuva degradaatio**: Järjestelmä jatkaa toimintaansa, vaikka agenttikapasiteetti on rajoittunut
# - **Palautumismekanismit**: Automaattinen uudelleenyritys ja virheiden käsittely epäonnistuneille toiminnoille
#
# ### 📊 **Seuranta & havaittavuus**
# - **Samanaikaisen suorituksen seuranta**: Valvo kaikkien rinnakkaistoimintojen etenemistä
# - **Suorituskykymittarit**: Mittaa nopeutus ja tehokkuuden parantaminen
# - **Resurssien käyttöanalytiikka**: Optimoi samanaikaisten agenttien allokointi
# - **Pullonkaulojen tunnistus**: Löydä ja ratkaise suorituskyvyn rajoitteet
#
# Rakennetaan korkeasuorituskykyisiä samanaikaisia tekoälytyönkulkuja! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vastuuvapauslauseke**:
# Tämä asiakirja on käännetty käyttämällä tekoälypohjaista käännöspalvelua [Co-op Translator](https://github.com/Azure/co-op-translator). Vaikka pyrimme tarkkuuteen, otathan huomioon, että automaattiset käännökset saattavat sisältää virheitä tai epätarkkuuksia. Alkuperäinen asiakirja sen alkuperäiskielellä on virallinen lähde. Tärkeissä asioissa suositellaan ammattimaista ihmiskäännöstä. Emme ole vastuussa tämän käännöksen käytöstä aiheutuvista väärinymmärryksistä tai tulkinnoista.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
