# %% [markdown]
# # 🔍 RAG ארגונית עם Microsoft Foundry (.NET)
#
# ## 📋 יעדי למידה
#
# פנקס זה מציג כיצד לבנות מערכות Retrieval-Augmented Generation (RAG) ברמת ארגון באמצעות מסגרת הסוכנים של Microsoft ב-.NET עם Microsoft Foundry. תלמד ליצור סוכנים מוכנים לייצור שיכולים לחפש בתוך מסמכים ולספק תגובות מדויקות, מודעות להקשר, עם אבטחה וסקלאביליות ארגוניות.
#
# **יכולות RAG ארגוניות שתבנה:**
# - 📚 **אינטליגנציה במסמכים**: עיבוד מתקדם של מסמכים עם שירותי Azure AI
# - 🔍 **חיפוש סמנטי**: חיפוש וקטורי ביצועי גבוה עם תכונות ארגוניות
# - 🛡️ **אינטגרציית אבטחה**: גישה מבוססת תפקיד ודפוסי הגנת נתונים
# - 🏢 **ארכיטקטורה סקלאבילית**: מערכות RAG מוכנות ייצור עם ניטור
#
# ## 🎯 ארכיטקטורת RAG ארגונית
#
# ### רכיבים מרכזיים בארגון
# - **Microsoft Foundry**: פלטפורמת AI מנוהלת לארגונים עם אבטחה וציות
# - **סוכנים מתמידים**: סוכנים בעלי מצב עם היסטוריית שיחה וניהול הקשר
# - **ניהול מאגר וקטורים**: אינדוקס ושליפה של מסמכים ברמת ארגון
# - **אינטגרציית זהות**: אימות Azure AD ושליטה בגישה מבוססת תפקיד
#
# ### יתרונות .NET בארגון
# - **בטיחות טיפוס**: אימות בזמן הקומפילציה לפעולות RAG ומבני נתונים
# - **ביצועים אסינכרוניים**: עיבוד מסמכים וחיפושים שאינם חוסמים
# - **ניהול זיכרון**: ניצול יעיל של משאבים לאוספי מסמכים גדולים
# - **דפוסי אינטגרציה**: אינטגרציה טבעית של שירות Azure עם הזרקת תלות
#
# ## 🏗️ ארכיטקטורה טכנית
#
# ### צינור RAG ארגוני
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### רכיבי ליבה ב-.NET
# - **Azure.AI.Agents.Persistent**: ניהול סוכנים ארגוני עם שימור מצב
# - **Azure.Identity**: אימות משולב לגישה מאובטחת לשירותי Azure
# - **Microsoft.Agents.AI.AzureAI**: יישום מסגרת סוכנים מותאמת ל-Azure
# - **System.Linq.Async**: פעולות LINQ אסינכרוניות וביצועיות גבוהות
#
# ## 🔧 תכונות ויתרונות ארגוניים
#
# ### אבטחה וציות
# - **אינטגרציית Azure AD**: ניהול זהויות ארגוני ואימות
# - **גישה מבוססת תפקיד**: הרשאות מדויקות לגישה למסמכים ולפעולות
# - **הגנת מידע**: הצפנה במנוחה ובהעברה למסמכים רגישים
# - **רישום ביקורת**: מעקב פעילות מקיף לדרישות ציות
#
# ### ביצועים וסקלאביליות
# - **בריכות חיבורים**: ניהול יעיל של חיבורים לשירותי Azure
# - **עיבוד אסינכרוני**: פעולות ללא חסימה לתרחישי עיבוד בעומס גבוה
# - **אסטרטגיות מטמון**: מטמון אינטליגנטי למסמכים הנגישים לעיתים קרובות
# - **איזון עומסים**: עיבוד מבוזר לפריסות בקנה מידה גדול
#
# ### ניהול וניטור
# - **בדיקות בריאות**: ניטור מובנה לרכיבי מערכת RAG
# - **מדדי ביצועים**: ניתוח מפורט על איכות החיפוש וזמני תגובה
# - **ניהול שגיאות**: ניהול חריגות כולל עם מדיניות ניסיונות חוזרים
# - **ניהול קונפיגורציה**: הגדרות סביבתיות עם אימות
#
# ## ⚙️ דרישות מוקדמות והגדרות
#
# **סביבת פיתוח:**
# - .NET 9.0 SDK או גרסה גבוהה יותר
# - Visual Studio 2022 או VS Code עם תוסף C#
# - מנוי Azure עם גישה ל-AI Foundry
#
# **חבילות NuGet דרושות:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **הגדרת אימות Azure:**
# ```bash
# # התקן את Azure CLI ואמת את זהותך
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **קונפיגורציית סביבה (קובץ .env):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 דפוסי RAG ארגוניים
#
# ### דפוסי ניהול מסמכים
# - **העלאה מרוכזת**: עיבוד יעיל של אוספי מסמכים גדולים
# - **עדכונים הדרגתיים**: הוספה ושינוי מסמכים בזמן אמת
# - **בקרת גרסאות**: ניהול גרסאות ומעקב שינויים במסמכים
# - **ניהול מטה-דאטה**: תכונות עשירות וקטלוג מסמכים
#
# ### דפוסי חיפוש ושליפה
# - **חיפוש היברידי**: שילוב חיפוש סמנטי וחיפוש מילות מפתח לתוצאות מיטביות
# - **חיפוש ממויין**: סינון ורב-מימדי וקטלוג
# - **כוונון רלוונטיות**: אלגוריתמי ניקוד מותאמים לצרכים תחומיים
# - **דירוג תוצאות**: דירוג מתקדם עם אינטגרציה של לוגיקת עסקית
#
# ### דפוסי אבטחה
# - **אבטחת רמת מסמך**: בקרת גישה מדויקת לכל מסמך
# - **סיווג נתונים**: תיוג אוטומטי של רגישות והגנה
# - **מסלולי ביקורת**: רישום מקיף של כל פעולות ה-RAG
# - **הגנת פרטיות**: זיהוי והסוואת מידע אישי מזהה (PII)
#
# ## 🔒 תכונות אבטחה ארגוניות
#
# ### אימות והרשאה
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### הגנת נתונים
# - **הצפנה**: הצפנה מקצה לקצה למסמכים ומדדי חיפוש
# - **בקרות גישה**: אינטגרציה עם Azure AD להרשאות משתמשים וקבוצות
# - **מיקום נתונים**: בקרות מיקום גיאוגרפי לציות
# - **גיבוי ושחזור**: יכולות גיבוי ושחזור אוטומטיות במקרה של אסון
#
# ## 📈 אופטימיזציית ביצועים
#
# ### דפוסי עיבוד אסינכרוני
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### ניהול זיכרון
# - **עיבוד בשידור**: טיפול במסמכים גדולים ללא בעיות זיכרון
# - **בריכות משאבים**: שימוש יעיל מחדש במשאבים יקרים
# - **איסוף פסולת**: דפוסי הקצאת זיכרון מותאמים
# - **ניהול חיבורים**: מחזור חיים נכון של חיבור לשירותי Azure
#
# ### אסטרטגיות מטמון
# - **מטמון שאילתות**: מטמון חיפושים הנעשים לעיתים קרובות
# - **מטמון מסמכים**: מטמון בזיכרון למסמכים חמים
# - **מטמון אינדקסים**: מטמון מאונדקס וקטורי מותאם
# - **מטמון תוצאות**: מטמון אינטליגנטי לתגובות שהופקו
#
# ## 📊 מקרי שימוש ארגוניים
#
# ### ניהול ידע
# - **ויקי תאגידי**: חיפוש אינטליגנטי בבסיסי ידע של החברה
# - **מדיניות ונהלים**: ציות אוטומטי והדרכה פרוצדורלית
# - **חומרי הדרכה**: סיוע אינטליגנטי ללמידה והתפתחות
# - **מאגרי מחקר**: מערכות לניתוח מאמרים אקדמיים ומחקריים
#
# ### תמיכת לקוחות
# - **מאגר ידע תמיכה**: תגובות שירות לקוחות אוטומטיות
# - **תיעוד מוצרים**: שליפת מידע על מוצרים אינטליגנטית
# - **מדריכי פתרון בעיות**: סיוע להפקת פתרונות בהקשר
# - **מערכות שאלות נפוצות**: יצירת שאלות נפוצות דינמית מאוספי מסמכים
#
# ### ציות רגולטורי
# - **ניתוח מסמכי משפט**: אינטליגנציה למסמכי חוזים ומשפט
# - **ניטור ציות**: בדיקת ציות רגולטורית אוטומטית
# - **הערכת סיכונים**: ניתוח ודיווח סיכונים מבוססי מסמכים
# - **תמיכה בביקורת**: גילוי אינטליגנטי של מסמכים לבדיקה
#
# ## 🚀 פריסת ייצור
#
# ### ניטור ותצפית
# - **Application Insights**: טלימטריה מפורטת וניטור ביצועים
# - **מדדים מותאמים אישית**: מעקב והתרעות עבור KPI עסקיים
# - **מעקב מבוזר**: מעקב בקשות מקצה לקצה בין שירותים
# - **לוחות בריאות**: ויזואליזציה בזמן אמת של בריאות המערכת וביצועים
#
# ### סקלאביליות ואמינות
# - **הרחבה אוטומטית**: הרחבה אוטומטית מבוססת על עומס ומדדי ביצועים
# - **זמינות גבוהה**: פריסה רב-אזורית עם יכולות כשל והתאוששות
# - **בדיקת עומס**: אימות ביצועים תחת תנאי עומס ארגוניים
# - **שחזור מאסון**: נהלי גיבוי ושחזור אוטומטיים
#
# מוכן לבנות מערכות RAG ברמת ארגון שיכולות להתמודד עם מסמכים רגישים בקנה מידה? בואו נבנה מערכות ידע אינטליגנטיות לארגון! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **כתב ויתור**:
# מסמך זה תורגם באמצעות שירות תרגום אוטומטי [Co-op Translator](https://github.com/Azure/co-op-translator). למרות שאנו שואפים לדיוק, יש לקחת בחשבון שתרגומים אוטומטיים עלולים להכיל שגיאות או אי-דיוקים. יש להחשיב את המסמך המקורי בשפתו הטבעית כמקור הסמכות. למידע קריטי מומלץ להשתמש בתרגום מקצועי על ידי מתרגם אדם. אנו לא אחראים לכל אי-הבנה או פירוש שגוי הנובע מהשימוש בתרגום זה.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
