# %% [markdown]
# # ⚡ זרימות עבודה מקביליות עם Microsoft Foundry (Python)
#
# ## 📋 מדריך מתקדם לעיבוד מקבילי
#
# דף זה מדגים **דפוסי זרימות עבודה מקביליות** באמצעות מסגרת הסוכנים של מיקרוסופט. תלמד איך לבנות זרימות עבודה יעילות עם עיבוד מקבילי שבהן מספר סוכני AI פועלים במקביל, ומשפרות במידה משמעותית את קצב התפוקה ומאפשרות תהליכי עסקים רב-תהליכיים מתוחכמים.
#
# > **הערת מעבר:** דוגמה זו התבססה בעבר על GitHub Models. GitHub Models יוצא משימוש (יפסיק להיות זמין ביולי 2026), ולכן כעת משתמשים ב-**Microsoft Foundry** דרך `FoundryChatClient`, שמפנה ל-API של Azure OpenAI **Responses**.
#
# ## 🎯 מטרות הלמידה
#
# ### 🚀 **יסודות עיבוד מקבילי**
# - **ריצת סוכנים במקביל**: הפעל מספר סוכנים במקביל למקסימום יעילות
# - **תזמור זרימות עבודה**: תיאום פעולות במקביל תוך שמירת עקביות נתונים
# - **אופטימיזציה של ביצועים**: השגת מהירות משמעותית דרך עיבוד מקבילי
# - **ניהול משאבים**: שימוש יעיל במשאבי מודל AI בפעולות מקביליות
#
# ### 🏗️ **דפוסי מקביליות מתקדמים**
# - **עיבוד Fork-Join**: פיצול עבודה בין מספר סוכנים ואיחוד תוצאות
# - **מקביליות בצינור עבודה**: שלבי ביצוע חופפים לשיפור הרציפות
# - **איזון עומסים**: הפצת העבודה באופן שווה בין משאבי הסוכנים הזמינים
# - **נקודות סנכרון**: תיאום סוכנים במקביל בשלבים קריטיים של הזרימה
#
# ### 🏢 **יישומים מקבילים בארגונים**
# - **עיבוד מסמכים בכמויות גבוהות**: טיפול במסמכים רבים במקביל
# - **ניתוח תוכן בזמן אמת**: ניתוח מקבילי של זרמי נתונים נכנסים
# - **אופטימיזציה לעיבוד באצווה**: מקסום תפוקה בפעולות בסדר גודל גדול
# - **ניתוח רב-מודלי**: עיבוד מקבילי של סוגי תוכן שונים (טקסט, תמונות, נתונים)
#
# ## ⚙️ דרישות וכינון
#
# ### 📦 **תלויות דרושות**
#
# התקן את מסגרת הסוכנים עם תמיכה בזרימות עבודה מקביליות:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **כינון Microsoft Foundry**
#
# התחבר עם Azure CLI (`az login`) כדי ש-`AzureCliCredential` יאמת אותך, ואז הגדר את פרטי הפרויקט שלך ב-Microsoft Foundry.
#
# **כינון סביבה (.env):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **שיקולים בעיבוד מקבילי:**
# - **מגבלות קצב:** מעקב אחר מגבלות קצב של Azure OpenAI עבור בקשות מקבילות
# - **שימוש במשאבים:** לקחת בחשבון שימוש בזיכרון ומעבד עם סוכנים מרובים במקביל
# - **טיפול בשגיאות:** יישום התאוששות מטעויות יציבה עבור פעולות מקבילות
#
# ### 🏗️ **ארכיטקטורת זרימות עבודה מקבילות**
#
# ```mermaid
# graph TD
#     A[התחלת זרימת עבודה] --> B[ביצוע מקבילי]
#     B --> C[מאגר סוכנים 1]
#     B --> D[מאגר סוכנים 2]
#     B --> E[מאגר סוכנים 3]
#     C --> F[איסוף תוצאות]
#     D --> F
#     E --> F
#     F --> G[הפלט הסופי]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **יתרונות מרכזיים:**
# - **⚡ ביצועים:** מהירות משמעותית דרך ביצוע מקבילי
# - **📈 מדרגיות:** טפל בעומסים גדלים ללא עלייה פרופורציונלית בזמן
# - **🔄 יעילות:** שימוש טוב יותר במשאבי המחשב הזמינים
# - **🎯 תפוקה:** עיבוד יותר עבודה באותו פרק זמן
#
# ## 🎨 **דפוסי עיצוב זרימות עבודה מקבילות**
#
# ### 🔍 **צינור מחקר וניתוח**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **זרימת עיבוד נתונים**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **צינור יצירת תוכן**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **עיבוד רב-שלבי**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **יתרונות ביצועים לארגון**
#
# ### ⚡ **אופטימיזציה של תפוקה**
# - **ביצוע במקביל:** מספר סוכנים העובדים במקביל
# - **ניצול משאבים:** יעילות מקסימלית של קיבולת מודל ה-AI הזמינה
# - **הפחתת זמן:** הורדה משמעותית בזמן עיבוד כולל
# - **ארכיטקטורה מדרגת:** הוספת סוכנים מקבילים בקלות לפי הצורך
#
# ### 🛡️ **אמינות ועמידות**
# - **טולרנטיות לתקלות:** כשלים בסוכן בודד לא מפסיקים את כל זרימת העבודה
# - **בידוד שגיאות:** בעיות בענף מקביל אחד לא משפיעות על האחרים
# - **דהגרדציה מתונה:** המערכת ממשיכה לפעול גם במצב של קיבולת סוכן מופחתת
# - **מנגנוני התאוששות:** ניסיון אוטומטי וטיפול בשגיאות עבור פעולות שנכשלו
#
# ### 📊 **ניטור ותצפית**
# - **מעקב אחר ביצוע מקבילי:** ניטור ההתקדמות של כל הפעולות במקביל
# - **מדדי ביצועים:** מדידת ההאצה ויתרונות היעילות
# - **אנליטיקה של שימוש משאבים:** אופטימיזציה של הקצאת סוכנים מקבילים
# - **זיהוי נקודות צוואר בקבוק:** מציאת והסרת חסמים בביצועים
#
# בואו ונבנה זרימות עבודה AI מקבילות עם ביצועים גבוהים! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **כתב ויתור**:
# מסמך זה תורגם באמצעות שירות תרגום אוטומטי [Co-op Translator](https://github.com/Azure/co-op-translator). למרות שאנו שואפים לדיוק, יש לקחת בחשבון שתרגומים אוטומטיים עלולים להכיל שגיאות או אי-דיוקים. יש להחשיב את המסמך המקורי בשפתו הטבעית כמקור הסמכות. למידע קריטי מומלץ להשתמש בתרגום מקצועי על ידי מתרגם אדם. אנו לא אחראים לכל אי-הבנה או פירוש שגוי הנובע מהשימוש בתרגום זה.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
