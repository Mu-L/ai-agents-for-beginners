# %% [markdown]
# # 🔍 Microsoft Foundry (.NET) सँग एंटरप्राइज RAG
#
# ## 📋 सिकाइ उद्देश्यहरू
#
# यस नोटबुकले कसरी Microsoft Foundry सँग .NET मा Microsoft Agent Framework प्रयोग गरेर एंटरप्राइज-ग्रेड Retrieval-Augmented Generation (RAG) प्रणालीहरू निर्माण गर्ने देखाउँछ। तपाईंले उत्पादन-तयार एजेन्टहरू सिर्जना गर्न सिक्नु हुनेछ जसले कागजातहरूमा खोजी गर्न सक्छ र एंटरप्राइज सुरक्षा र विस्तारशीलताका साथ सन्दर्भ-ज्ञानयुक्त र सही प्रतिक्रिया प्रदान गर्न सक्छ।
#
# **तपाईंले निर्माण गर्ने एंटरप्राइज RAG क्षमता:**
# - 📚 **कागजात बुद्धिमत्ता**: Azure AI सेवाहरूका साथ उन्नत कागजात प्रशोधन
# - 🔍 **सामान्य खोज**: एंटरप्राइज सुविधाहरू भएको उच्च-प्रदर्शन भेक्टर खोज
# - 🛡️ **सुरक्षा एकीकरण**: रोल-आधारित पहुँच र डाटा संरक्षण ढाँचा
# - 🏢 **विस्तारशील वास्तुकला**: निगरानीसहित उत्पादन-तयार RAG प्रणालीहरू
#
# ## 🎯 एंटरप्राइज RAG वास्तुकला
#
# ### मुख्य एंटरप्राइज कम्पोनेन्टहरू
# - **Microsoft Foundry**: सुरक्षा र अनुपालन सहित व्यवस्थापित एंटरप्राइज AI प्लेटफर्म
# - **स्थायी एजेन्टहरू**: कन्वर्सेसन इतिहास र सन्दर्भ व्यवस्थापन सहित Stateful एजेन्टहरू
# - **भेक्टर स्टोर व्यवस्थापन**: एंटरप्राइज-ग्रेड कागजात अनुक्रमणिका र पुनःप्राप्ति
# - **पहिचान एकीकरण**: Azure AD प्रमाणीकरण र रोल-आधारित पहुँच नियन्त्रण
#
# ### .NET एंटरप्राइज फाइदाहरू
# - **प्रकार सुरक्षा**: RAG अपरेसनहरू र डाटा संरचनाहरूको कम्पाइल-समय प्रमाणीकरण
# - **असिंक्रोनस प्रदर्शन**: गैर-अवरुद्ध कागजात प्रशोधन र खोज अपरेसनहरू
# - **स्मृति व्यवस्थापन**: ठूलो कागजात संग्रहहरूको लागि कुशल स्रोत उपयोग
# - **एकीकरण ढाँचाहरू**: निर्भरता इंजेक्शनसहित नेटिभ Azure सेवा एकीकरण
#
# ## 🏗️ प्राविधिक वास्तुकला
#
# ### एंटरप्राइज RAG पाइपलाइन
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### मुख्य .NET कम्पोनेन्टहरू
# - **Azure.AI.Agents.Persistent**: स्थिति स्थायीकरणसहित एंटरप्राइज एजेन्ट व्यवस्थापन
# - **Azure.Identity**: सुरक्षित Azure सेवा पहुँचको लागि एकीकृत प्रमाणीकरण
# - **Microsoft.Agents.AI.AzureAI**: Azure-अनुकूलित एजेन्ट फ्रेमवर्क कार्यान्वयन
# - **System.Linq.Async**: उच्च-प्रदर्शन असिंक्रोनस LINQ अपरेसनहरू
#
# ## 🔧 एंटरप्राइज सुविधा र फाइदाहरू
#
# ### सुरक्षा र अनुपालन
# - **Azure AD एकीकरण**: एंटरप्राइज पहिचान व्यवस्थापन र प्रमाणीकरण
# - **रोल-आधारित पहुँच**: कागजात पहुँच र अपरेसनहरूको लागि सूक्ष्म अनुमतिहरू
# - **डेटा संरक्षण**: संवेदनशील कागजातहरूको लागि आराममा र ट्राफिकमा इन्क्रिप्सन
# - **लेखा परीक्षण लगिङ**: अनुपालन आवश्यकताहरूका लागि व्यापक क्रियाकलाप ट्र्याकिङ
#
# ### प्रदर्शन र विस्तारशीलता
# - **कनेक्शन पूलिङ**: कुशल Azure सेवा कनेक्शन व्यवस्थापन
# - **असिंक्रोनस प्रशोधन**: उच्च-थ्रुपुट अवस्थाहरूका लागि गैर-अवरुद्ध अपरेसनहरू
# - **कैशिङ रणनीतिहरू**: प्रायः पहुँच गरिने कागजातहरूको लागि बौद्धिक कैशिङ
# - **लोड ब्यालेन्सिङ**: ठूलो-स्तरिय परिनियोजनहरूको लागि वितरणित प्रशोधन
#
# ### व्यवस्थापन र अनुगमन
# - **स्वास्थ्य जाँचहरू**: RAG प्रणाली कम्पोनेन्टहरूको लागि निर्मित अनुगमन
# - **प्रदर्शन मेट्रिक्स**: खोज गुणस्तर र प्रतिक्रिया समयका विस्तृत विश्लेषण
# - **त्रुटि व्यवस्थापन**: पुन: प्रयास नीतिहरू सहित व्यापक अपवाद व्यवस्थापन
# - **कन्फिगरेसन व्यवस्थापन**: वातावरण-विशिष्ट सेटिङहरू प्रमाणीकरणसहित
#
# ## ⚙️ पूर्वापेक्षाहरू र सेटअप
#
# **विकास वातावरण:**
# - .NET 9.0 SDK वा माथि
# - Visual Studio 2022 वा C# एक्सटेन्सनसहित VS Code
# - AI Foundry पहुँचसहित Azure सदस्यता
#
# **आवश्यक NuGet प्याकेजहरू:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Azure प्रमाणीकरण सेटअप:**
# ```bash
# # Azure CLI स्थापना गर्नुहोस् र प्रमाणित गर्नुहोस्
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **पर्यावरण कन्फिगरेसन (.env फाइल):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 एंटरप्राइज RAG ढाँचाहरू
#
# ### कागजात व्यवस्थापन ढाँचाहरू
# - **थोक अपलोड**: ठूलो कागजात संग्रहहरूको कुशल प्रशोधन
# - **क्रमिक अपडेटहरू**: वास्तविक-समय कागजात थप र परिमार्जन
# - **संस्करण नियन्त्रण**: कागजात संस्करण र परिवर्तन ट्र्याकिङ
# - **मेटाडाटा व्यवस्थापन**: धनी कागजात विशेषताहरू र वर्गीकरण
#
# ### खोज र पुनःप्राप्ति ढाँचाहरू
# - **हाइब्रिड खोज**: उत्तम परिणामहरूको लागि सिमान्टिक र कीवर्ड खोज संयोजन
# - **फेसेटेड खोज**: बहु-आयामी फिल्टरिङ र वर्गीकरण
# - **प्रासंगिकता ट्यूनिङ**: डोमेन-विशिष्ट आवश्यकताहरूका लागि अनुकूलित स्कोरिङ एल्गोरिदमहरू
# - **परिणाम र्याङ्किङ**: व्यापार तर्क एकीकरणसहित उन्नत र्याङ्किङ
#
# ### सुरक्षा ढाँचाहरू
# - **कागजात-स्तर सुरक्षा**: प्रत्येक कागजातको लागि सूक्ष्म पहुँच नियन्त्रण
# - **डेटा वर्गीकरण**: स्वतः संवेदनशीलता लेबलिङ र संरक्षण
# - **लेखा परीक्षण मार्गहरू**: सबै RAG अपरेसनहरूको व्यापक लगिङ
# - **गोपनीयता संरक्षण**: PII पहिचान र छुपाउने क्षमताहरू
#
# ## 🔒 एंटरप्राइज सुरक्षा सुविधाहरू
#
# ### प्रमाणीकरण र प्राधिकरण
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### डेटा संरक्षण
# - **इन्क्रिप्सन**: कागजात र खोज सूचकांकहरूको लागि अन्त-देखि-अन्त इन्क्रिप्सन
# - **पहुँच नियन्त्रणहरू**: प्रयोगकर्ता र समूह अनुमतिका लागि Azure AD सँग एकीकरण
# - **डेटा बसोबास**: अनुपालनका लागि भौगोलिक डाटा स्थान नियन्त्रणहरू
# - **ब्याकअप र पुनःप्राप्ति**: स्वचालित ब्याकअप र विपद् पुनःप्राप्ति क्षमता
#
# ## 📈 प्रदर्शन अनुकूलन
#
# ### असिंक्रोनस प्रशोधन ढाँचाहरू
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### स्मृति व्यवस्थापन
# - **स्ट्रिमिङ प्रशोधन**: स्मृति समस्याविना ठूलो कागजातहरू सम्हाल्ने
# - **स्रोत पूलिङ**: महँगो स्रोतहरूको कुशल पुन: प्रयोग
# - **ग्यारेबेज कलेक्सन**: अनुकूलित स्मृति विनियोजन ढाँचाहरू
# - **कनेक्शन व्यवस्थापन**: उचित Azure सेवा कनेक्शन जीवनचक्र
#
# ### कैशिङ रणनीतिहरू
# - **प्रश्न कैशिङ**: बारम्बार चलाइने खोजहरूको क्यासिङ
# - **कागजात कैशिङ**: तातो कागजातहरूको लागि इन-मेमोरी क्यासिङ
# - **इन्डेक्स कैशिङ**: अनुकूलित भेक्टर इन्डेक्स क्यासिङ
# - **परिणाम क्यासिङ**: उत्पन्न प्रतिक्रियाहरूको बौद्धिक क्यासिङ
#
# ## 📊 एंटरप्राइज उपयोग केसहरू
#
# ### ज्ञान व्यवस्थापन
# - **कर्पोरेट विकि**: कम्पनी ज्ञान आधारहरूमा बौद्धिक खोज
# - **नीति र प्रक्रिया**: स्वचालित अनुपालन र प्रक्रिया मार्गदर्शन
# - **प्रशिक्षण सामग्री**: बौद्धिक सिकाइ र विकास सहायता
# - **अनुसन्धान डाटाबेसहरू**: शैक्षिक र अनुसन्धान कागजात विश्लेषण प्रणालीहरू
#
# ### ग्राहक समर्थन
# - **समर्थन ज्ञान आधार**: स्वचालित ग्राहक सेवा प्रतिक्रियाहरू
# - **उत्पादन कागजात**: बौद्धिक उत्पादन जानकारी पुनःप्राप्ति
# - **समस्या समाधान गाइडहरू**: सन्दर्भगत समस्या समाधान सहायता
# - **सोधिने प्रश्न प्रणालीहरू**: कागजात संग्रहहरूबाट गतिशील FAQ उत्पादन
#
# ### नियामक अनुपालन
# - **कानुनी कागजात विश्लेषण**: सम्झौता र कानुनी कागजात बुद्धिमत्ता
# - **अनुपालन अनुगमन**: स्वचालित नियामक अनुपालन जाँच
# - **जोखिम मूल्याङ्कन**: कागजात-आधारित जोखिम विश्लेषण र रिपोर्टिङ
# - **लेखा समर्थन**: लेखाहरूका लागि बौद्धिक कागजात खोज
#
# ## 🚀 उत्पादन परिनियोजन
#
# ### अनुगमन र अवलोकनयोग्यता
# - **एप्लिकेशन इनसाइट्स**: विस्तृत टेलिमेट्री र प्रदर्शन अनुगमन
# - **अनुकूलित मेट्रिक्स**: व्यापार-विशिष्ट KPI ट्र्याकिङ र सचेतना
# - **वितरित ट्रेसिङ**: सेवाहरूमा अन्तदेखि-अन्त अनुरोध ट्र्याकिङ
# - **स्वास्थ्य ड्यासबोर्डहरू**: वास्तविक-समय प्रणाली स्वास्थ्य र प्रदर्शन दृश्यचित्रण
#
# ### विस्तारशीलता र विश्वसनीयता
# - **स्वतः-स्केलिङ**: लोड र प्रदर्शन मेट्रिक्समा आधारित स्वचालित स्केलिङ
# - **उच्च उपलब्धता**: असफलताबाट बच्ने क्षमतासहित बहु-क्षेत्र परिनियोजन
# - **लोड परीक्षण**: एंटरप्राइज लोड अवस्थाहरूको अन्तर्गत प्रदर्शन प्रमाणीकरण
# - **विपद् पुनःप्राप्ति**: स्वचालित ब्याकअप र पुनःप्राप्ति प्रक्रिया
#
# संवेदनशील कागजातहरू ठूलो मात्रामा सम्हाल्न सक्ने एंटरप्राइज-ग्रेड RAG प्रणालीहरू निर्माण गर्न तयार? आउनुहोस् एंटरप्राइजका लागि बौद्धिक ज्ञान प्रणालीहरू वास्तुकला गरौं! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# यो दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) प्रयोग गरेर अनुवाद गरिएको हो। हामी सही हुन प्रयास गर्छौं, तर कृपया जानकार हुनुस् कि स्वचालित अनुवादमा त्रुटिहरू वा अशुद्धताहरू हुन सक्छन्। मूल दस्तावेज़ यसको मूल भाषामा आधिकारिक स्रोत मानिनुपर्छ। महत्वपूर्ण जानकारीका लागि व्यावसायिक मानव अनुवाद सिफारिस गरिन्छ। यस अनुवादको प्रयोगबाट उत्पन्न कुनै पनि गलत बुझाइ वा त्रुटिको लागि हामी जिम्मेवार छैनौं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
