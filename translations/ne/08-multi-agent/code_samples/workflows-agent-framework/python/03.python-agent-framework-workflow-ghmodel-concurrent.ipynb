# %% [markdown]
# # ⚡ माइक्रोसफ्ट फाउन्ड्रीसँग समवर्ती एजेन्ट कार्यप्रवाहहरू (Python)
#
# ## 📋 उन्नत समानान्तर प्रक्रियाकरण ट्यूटोरियल
#
# यो नोटबुकले माइक्रोसफ्ट एजेन्ट फ्रेमवर्क प्रयोग गरी **समवर्ती कार्यप्रवाह ढाँचाहरू** प्रदर्शन गर्दछ। तपाईंले कसरी उच्च प्रदर्शन, समानान्तर प्रक्रियाकरणको साथ कार्यप्रवाह निर्माण गर्ने सिक्नुहुनेछ जहाँ धेरै AI एजेन्टहरू एकै समयमा कार्यान्वयन हुन्छन्, जसले थ्रूपुटलाई नाटकीय रूपमा सुधार गर्दछ र जटिल मल्टि-थ्रेडेड व्यापार प्रक्रियाहरू सक्षम पार्दछ।
#
# > **स्थानान्तरण नोट:** यस नमूनाले पहिले GitHub मोडेलहरू उल्लेख गरेको थियो। GitHub मोडेलहरू अप्रचलित छन् (जुलाई २०२६ मा अवसान हुँदैछ), त्यसैले अहिले यसले `FoundryChatClient` मार्फत **Microsoft Foundry** प्रयोग गर्दछ, जुन Azure OpenAI **Responses API** लाई लक्षित गर्दछ।
#
# ## 🎯 सिकाइ उद्देश्यहरू
#
# ### 🚀 **समवर्ती प्रक्रियाकरण आधारहरू**
# - **समानान्तर एजेन्ट कार्यान्वयन**: अधिकतम दक्षताका लागि धेरै एजेन्टहरू एकै साथ चलाउनुहोस्
# - **कार्यप्रवाह व्यवस्थापन**: डेटा स्थिरता कायम राख्दै समवर्ती अपरेसनहरू समन्वय गर्नुहोस्
# - **प्रदर्शन अनुकूलन**: समानान्तर प्रक्रियाकरणमार्फत महत्वपूर्ण गति वृद्धि हासिल गर्नुहोस्
# - **स्रोत व्यवस्थापन**: समवर्ती अपरेसनहरूमा AI मोडेल स्रोतहरूको प्रभावकारी उपयोग गर्नुहोस्
#
# ### 🏗️ **उन्नत समवर्ती ढाँचाहरू**
# - **फोर्क-ज्वाइन प्रक्रियाकरण**: धेरै एजेन्टहरूमा काम विभाजन गर्नुहोस् र परिणामहरू मर्ज गर्नुहोस्
# - **पाइपलाइन समानान्तरता**: निरन्तर थ्रूपुटका लागि कार्यान्वयन चरणहरू ओभरल्यान्ड गर्नुहोस्
# - **लोड सन्तुलन**: उपलब्ध एजेन्ट स्रोतहरूमा समान रूपमा काम वितरण गर्नुहोस्
# - **समन्वय बिन्दुहरू**: महत्त्वपूर्ण कार्यप्रवाह चरणहरूमा समवर्ती एजेन्टहरू समन्वय गर्नुहोस्
#
# ### 🏢 **उद्यम समवर्ती अनुप्रयोगहरू**
# - **उच्च-परिमाण कागजात प्रक्रियाकरण**: धेरै कागजातहरू एकै साथ प्रक्रिया गर्नुहोस्
# - **रियल-टाइम सामग्री विश्लेषण**: आउँदै गरेको डाटा स्ट्रिमहरूको समवर्ती विश्लेषण
# - **ब्याच प्रक्रियाकरण अनुकूलन**: ठूलो-स्केल अपरेसनहरूको लागि थ्रूपुट अधिकतम गर्नुहोस्
# - **मल्टि-मोडल विश्लेषण**: फरक सामग्री प्रकारहरूको समानान्तर प्रक्रियाकरण (पाठ, छवि, डाटा)
#
# ## ⚙️ पूर्वसर्तहरू र सेटअप
#
# ### 📦 **आवश्यक निर्भरता**
#
# समानान्तर कार्यप्रवाह क्षमतासहित एजेन्ट फ्रेमवर्क स्थापना गर्नुहोस्:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Microsoft Foundry कन्फिगरेसन**
#
# Azure CLI (`az login`) मार्फत साइन इन गर्नुहोस् ताकि `AzureCliCredential` प्रमाणीकरण गर्न सकोस्, त्यसपछि तपाईंको Microsoft Foundry परियोजना विवरणहरू सेट गर्नुहोस्।
#
# **परिवेश सेटअप (.env फाइल):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4.1-mini
# ```
#
# **समवर्ती प्रक्रियाकरण विचारहरू:**
# - **दर सीमा**: समवर्ती अनुरोधहरूको लागि Azure OpenAI दर सीमा अनुगमन गर्नुहोस्
# - **स्रोत प्रयोग**: धेरै समवर्ती एजेन्टहरूसँग मेमोरी र CPU प्रयोग विचार गर्नुहोस्
# - **त्रुटि ह्यान्डलिङ**: समानान्तर अपरेसनहरूको लागि मजबुत त्रुटि पुन: प्राप्ति कार्यान्वयन गर्नुहोस्
#
# ### 🏗️ **समवर्ती कार्यप्रवाह वास्तुकला**
#
# ```mermaid
# graph TD
#     A[कार्यप्रवाह सुरु] --> B[समानान्तर कार्यान्वयन]
#     B --> C[एजेन्ट पूल १]
#     B --> D[एजेन्ट पूल २]
#     B --> E[एजेन्ट पूल ३]
#     C --> F[परिणाम सङ्कलन]
#     D --> F
#     E --> F
#     F --> G[अन्तिम नतिजा]
#
#     H[माइक्रोसफ्ट फाउन्ड्री] --> C
#     H --> D
#     H --> E
# ```
#
# **प्रमुख फाइदाहरू:**
# - **⚡ प्रदर्शन**: समानान्तर कार्यान्वयनको माध्यमबाट महत्वपूर्ण गति वृद्धि
# - **📈 विस्तारयोग्यता**: समयको अनुपातमा बिना बृद्धि, बढ्दो कार्यभार समात्नुहोस्
# - **🔄 दक्षता**: उपलब्ध कम्प्यूटिङ स्रोतहरूको राम्रो उपयोग
# - **🎯 थ्रूपुट**: उस्तै समयमा बढी काम प्रक्रिया गर्नुहोस्
#
# ## 🎨 **समवर्ती कार्यप्रवाह डिजाइन ढाँचाहरू**
#
# ### 🔍 **अनुसन्धान र विश्लेषण पाइपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डाटा प्रक्रियाकरण कार्यप्रवाह**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री सिर्जना पाइपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **बहु-चरण प्रक्रियाकरण**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **उद्यम प्रदर्शन लाभहरू**
#
# ### ⚡ **थ्रूपुट अनुकूलन**
# - **समानान्तर कार्यान्वयन**: धेरै एजेन्टहरू एकै साथ काम गर्दै
# - **स्रोत उपयोग**: उपलब्ध AI मोडेल क्षमताको अधिकतम दक्षता
# - **समय कटौती**: कुल प्रक्रियाकरण समयमा महत्वपूर्ण कमी
# - **विस्तारयोग्य वास्तुकला**: आवश्यक अनुसार थप समवर्ती एजेन्टहरू सजिलै थप्नुहोस्
#
# ### 🛡️ **विश्वसनीयता र स्थायित्व**
# - **फॉल्ट टोलरेन्स**: एकल एजेन्ट असफलताले पूरै कार्यप्रवाह रोक्दैन
# - **त्रुटि पृथक्करण**: एक समवर्ती शाखामा समस्या अन्यलाई असर गर्दैन
# - **सहज अपक्षय**: प्रणाली घटेको एजेन्ट क्षमतासँग पनि सञ्चालनमा रहन्छ
# - **पुन: प्राप्ति संयन्त्रहरू**: असफल अपरेसनहरूको लागि स्वचालित पुन: प्रयास र त्रुटि ह्यान्डलिङ
#
# ### 📊 **अनुगमन र अवलोकन**
# - **समवर्ती कार्यान्वयन ट्र्याकिङ**: सबै समानान्तर अपरेसनहरूको प्रगति निगरानी गर्नुहोस्
# - **प्रदर्शन मेट्रिक्स**: गति वृद्धि र दक्षता लाभहरू मापन गर्नुहोस्
# - **स्रोत प्रयोग विश्लेषण**: समवर्ती एजेन्ट आवंटन अनुकूलन गर्नुहोस्
# - **बोटलनेक पहिचान**: प्रदर्शन सीमाहरू फेला पार्नुहोस् र समाधान गर्नुहोस्
#
# आउनुहोस् उच्च प्रदर्शन समवर्ती AI कार्यप्रवाहहरू बनाउँ! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# यो दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) प्रयोग गरेर अनुवाद गरिएको हो। हामी सही हुन प्रयास गर्छौं, तर कृपया जानकार हुनुस् कि स्वचालित अनुवादमा त्रुटिहरू वा अशुद्धताहरू हुन सक्छन्। मूल दस्तावेज़ यसको मूल भाषामा आधिकारिक स्रोत मानिनुपर्छ। महत्वपूर्ण जानकारीका लागि व्यावसायिक मानव अनुवाद सिफारिस गरिन्छ। यस अनुवादको प्रयोगबाट उत्पन्न कुनै पनि गलत बुझाइ वा त्रुटिको लागि हामी जिम्मेवार छैनौं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
