# %% [markdown]
# # ⚡ माइक्रोसफ्ट फाउन्ड्रीसँग समानान्तर एजेन्ट कार्यप्रवाहहरू (Python)
#
# ## 📋 उन्नत समानान्तर प्रसोधन ट्युटोरियल
#
# यस नोटबुकले माइक्रोसफ्ट एजेन्ट फ्रेमवर्क प्रयोग गरेर **समानान्तर कार्यप्रवाह ढाँचाहरू** देखाउँदछ। तपाईं कसरी उच्च कार्यसम्पादन, समानान्तर प्रशोधन कार्यप्रवाहहरू निर्माण गर्ने सिक्नुहुनेछ जहाँ धेरै AI एजेन्टहरू एकै समयमा कार्यान्वयन हुन्छन्, जसले थ्रूपुटलाई नाटकीय रूपमा सुधार गर्दछ र जटिल बहु-थ्रेडेड व्यवसाय प्रक्रियाहरू सक्षम पार्दछ।
#
# > **स्थानान्तरण नोट:** यो नमूना पहिले GitHub मोडेलहरूलाई उल्लेख गर्थ्यो। GitHub मोडेलहरू अवसान हुँदैछन् (जुलाई 2026 मा सेवानिवृत्त हुँदै), त्यसैले अहिले यसले `FoundryChatClient` मार्फत **माइक्रोसफ्ट फाउन्ड्री** प्रयोग गर्दछ, जुन Azure OpenAI **Responses API** लाई लक्षित गर्दछ।
#
# ## 🎯 सिकाई उद्देश्यहरू
#
# ### 🚀 **समानान्तर प्रसोधनका आधारहरू**
# - **समानान्तर एजेन्ट कार्यान्वयन**: अधिकतम दक्षताका लागि धेरै एजेन्टहरू एकै समयमा चलाउनुहोस्
# - **कार्यप्रवाह समन्वय**: समानान्तर अपरेसनहरू समन्वय गर्नुहोस् र डाटा स्थिरता कायम राख्नुहोस्
# - **कार्यसम्पादन अनुकूलन**: समानान्तर प्रसोधन मार्फत महत्वपूर्ण गति वृद्धि प्राप्त गर्नुहोस्
# - **स्रोत व्यवस्थापन**: समानान्तर अपरेसनहरूमा AI मोडेल स्रोतहरू कुशलतापूर्वक प्रयोग गर्नुहोस्
#
# ### 🏗️ **उन्नत समानान्तरता ढाँचाहरू**
# - **फोर्क-जोइन प्रसोधन**: कार्यलाई विभिन्न एजेन्टहरूमा विभाजन गरी परिणामहरू मर्ज गर्नुहोस्
# - **पाइपलाइन समानान्तरता**: निरन्तर थ्रूपुटका लागि कार्यान्वयन चरणहरू ओछ्यान गर्नुहोस्
# - **लोड ब्यालेन्सिङ**: उपलब्ध एजेन्ट स्रोतहरूमा कार्य समान रूपमा वितरण गर्नुहोस्
# - **समक्रमण बिन्दुहरू**: महत्वपूर्ण कार्यप्रवाह चरणहरूमा समानान्तर एजेन्ट समन्वय गर्नुहोस्
#
# ### 🏢 **उद्यम समानान्तर अनुप्रयोगहरू**
# - **उच्च-परिमाण कागजात प्रसोधन**: धेरै कागजातहरू एउटै समयमा प्रक्रिया गर्नुहोस्
# - **रियल-टाइम सामग्री विश्लेषण**: आउने डाटाका स्ट्रिमहरूको समानान्तर विश्लेषण
# - **ब्याच प्रसोधन अनुकूलन**: ठूलो-स्तरका अपरेसनहरूको थ्रूपुट अधिकतम गर्नुहोस्
# - **बहु-मोडल विश्लेषण**: विभिन्न सामग्री प्रकार (टेक्स्ट, चित्रहरू, डेटा) को समानान्तर प्रसोधन
#
# ## ⚙️ पूर्वापेक्षाहरू र सेटअप
#
# ### 📦 **आवश्यक निर्भरताहरू**
#
# समानान्तर कार्यप्रवाह क्षमताहरू सहित एजेन्ट फ्रेमवर्क इन्स्टल गर्नुहोस्:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **माइक्रोसफ्ट फाउन्ड्री कन्फिगरेसन**
#
# Azure CLI (`az login`) मार्फत साइन इन गर्नुहोस् ताकि `AzureCliCredential` प्रमाणित गर्न सकोस्, त्यसपछि आफ्नो माइक्रोसफ्ट फाउन्ड्री परियोजना विवरणहरू सेट गर्नुहोस्।
#
# **परिवेश सेटअप (.env फाइल):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **समानान्तर प्रसोधन विचारहरू:**
# - **रेट सीमाहरू**: समानान्तर अनुरोधहरूको लागि Azure OpenAI रेट सीमाहरू अनुगमन गर्नुहोस्
# - **स्रोत प्रयोग**: धेरै समानान्तर एजेन्टहरूसँग मेमोरी र CPU प्रयोग विचार गर्नुहोस्
# - **त्रुटि व्यवस्थापन**: समानान्तर अपरेसनहरूको लागि दिगो त्रुटि पुन: प्राप्ति कार्यान्वयन गर्नुहोस्
#
# ### 🏗️ **समानान्तर कार्यप्रवाह वास्तुकला**
#
# ```mermaid
# graph TD
#     A[कार्यप्रवाह प्रारम्भ] --> B[समानान्तर कार्यान्वयन]
#     B --> C[एजेन्ट पूल १]
#     B --> D[एजेन्ट पूल २]
#     B --> E[एजेन्ट पूल ३]
#     C --> F[परिणाम संक्षेपण]
#     D --> F
#     E --> F
#     F --> G[अन्तिम उत्पादन]
#
#     H[माइक्रोसफ्ट फाउन्ड्री] --> C
#     H --> D
#     H --> E
# ```
#
# **मुख्य लाभहरू:**
# - **⚡ कार्यसम्पादन**: समानान्तर कार्यान्वयन मार्फत महत्वपूर्ण गति वृद्धि
# - **📈 स्केलेबिलिटी**: अनुपातमा समय वृद्धि बिना बढ्दो कार्यभार सम्हाल्नुहोस्
# - **🔄 दक्षता**: उपलब्ध कम्प्युटेशनल स्रोतहरूको राम्रो उपयोग
# - **🎯 थ्रूपुट**: उस्तै समयमा बढी कार्य प्रक्रिया गर्नुहोस्
#
# ## 🎨 **समानान्तर कार्यप्रवाह डिजाइन ढाँचाहरू**
#
# ### 🔍 **अनुसन्धान र विश्लेषण पाइपलाइन**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **डेटा प्रशोधन कार्यप्रवाह**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **सामग्री सिर्जना पाइपलाइन**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **बहु-चरण प्रसोधन**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **उद्यम कार्यसम्पादन लाभहरू**
#
# ### ⚡ **थ्रूपुट अनुकूलन**
# - **समानान्तर कार्यान्वयन**: धेरै एजेन्टहरू एकै साथ काम गर्दै
# - **स्रोत उपयोग**: उपलब्ध AI मोडेल क्षमता अधिकतम दक्षता
# - **समय कमी**: कुल प्रसोधन समयमा महत्वपूर्ण कमी
# - **स्केलेबल वास्तुकला**: आवश्यक परेमा सजिलै थप समानान्तर एजेन्टहरू थप्नुहोस्
#
# ### 🛡️ **विश्वसनीयता र दृढता**
# - **फोल्ट टोलरेन्स**: व्यक्तिगत एजेन्ट असफलताहरूले सम्पूर्ण कार्यप्रवाह रोकेनन्
# - **त्रुटि पृथक्करण**: एउटै समानान्तर शाखामा समस्या आउँदा अन्यहरू प्रभावित हुँदैनन्
# - **सौम्य कटौती**: कम एजेन्ट क्षमतासँग पनि प्रणाली सञ्चालन जारी राख्छ
# - **पुन: प्राप्ति यन्त्रहरू**: असफल अपरेसनहरूको लागि स्वचालित पुन: प्रयास र त्रुटि व्यवस्थापन
#
# ### 📊 **अनुगमन र प्रदर्शन अवलोकन**
# - **समानान्तर कार्यान्वयन ट्र्याकिंग**: सबै समानान्तर अपरेसनहरूको प्रगति अनुगमन गर्नुहोस्
# - **कार्यसम्पादन मेट्रिक्स**: गति र दक्षता वृद्धि मापन गर्नुहोस्
# - **स्रोत प्रयोग विश्लेषण**: समानान्तर एजेन्ट वितरण अनुकूलन गर्नुहोस्
# - **बोटलनेक पहिचान**: कार्यसम्पादन सीमाहरू पत्ता लगाएर समाधान गर्नुहोस्
#
# आउँनुहोस् उच्च कार्यसम्पादन समानान्तर AI कार्यप्रवाहहरू निर्माण गरौं! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# यो दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) प्रयोग गरेर अनुवाद गरिएको हो। हामी सही हुन प्रयास गर्छौं, तर कृपया जानकार हुनुस् कि स्वचालित अनुवादमा त्रुटिहरू वा अशुद्धताहरू हुन सक्छन्। मूल दस्तावेज़ यसको मूल भाषामा आधिकारिक स्रोत मानिनुपर्छ। महत्वपूर्ण जानकारीका लागि व्यावसायिक मानव अनुवाद सिफारिस गरिन्छ। यस अनुवादको प्रयोगबाट उत्पन्न कुनै पनि गलत बुझाइ वा त्रुटिको लागि हामी जिम्मेवार छैनौं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
