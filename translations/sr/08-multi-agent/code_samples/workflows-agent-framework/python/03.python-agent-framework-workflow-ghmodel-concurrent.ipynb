# %% [markdown]
# # ⚡ Конкурентни агенцијски токови рада са Microsoft Foundry (Python)
#
# ## 📋 Напредни водич за паралелну обраду
#
# Овај бележник демонстрира **шаблоне конкурентних токова рада** користећи Microsoft Agent Framework. Научићете како да изградите перформансно извршавање токова рада у паралелној обради где више AI агената ради истовремено, драматично побољшавајући пропусност и омогућавајући сложене мултитхреадед пословне процесе.
#
# > **Напомена о миграцији:** Овај пример је раније користио GitHub Models. GitHub Models је застарео (престанак употребе у јулу 2026), па сада користи **Microsoft Foundry** преко `FoundryChatClient`, који циља на Azure OpenAI **Responses API**.
#
# ## 🎯 Циљеви учења
#
# ### 🚀 **Основе конкурентне обраде**
# - **Паралелно извршавање агената**: покрени више агената истовремено ради максималне ефикасности
# - **Оркестрација токова рада**: координиши конкурентне операције при одржавању конзистентности података
# - **Оптимизација перформанси**: оствари значајно убрзање кроз паралелну обраду
# - **Управљање ресурсима**: ефикасно користи ресурсе AI модела током конкурентних операција
#
# ### 🏗️ **Напредни образци конкурентности**
# - **Форк-џоин обрада**: подели рад између више агената и споји резултате
# - **Паралелизам у линији обраде**: преклапање фаза извршавања за континуирани проток
# - **Уравнотежење оптерећења**: равномерно дистрибуирај рад између расположивих ресурса агената
# - **Синхронизационе тачке**: координиши конкурентне агенте у кључним фазама тока рада
#
# ### 🏢 **Предузетничке конкурентне апликације**
# - **Обрада великог обима докумената**: обрађуј више докумената истовремено
# - **Анализа садржаја у реалном времену**: конкурентна анализа долазних токова података
# - **Оптимизација пакетне обраде**: максимизуј пропусност за операције великог обима
# - **Мултимодална анализа**: паралелна обрада различитих типова садржаја (текст, слике, подаци)
#
# ## ⚙️ Захтеви и подешавање
#
# ### 📦 **Потребне зависности**
#
# Инсталирај Agent Framework са могућностима конкурентног тока рада:
#
# ```bash
# pip install agent-framework -U
# ```
#
# ### 🔑 **Конфигурација Microsoft Foundry**
#
# Пријави се помоћу Azure CLI (`az login`) како би `AzureCliCredential` аутентификовала, затим подеси детаље о вашем Microsoft Foundry пројекту.
#
# **Подешавање окружења (.env фајл):**
# ```env
# AZURE_AI_PROJECT_ENDPOINT=https://<your-project>.services.ai.azure.com
# AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-5-mini
# ```
#
# **Разматрања за конкурентну обраду:**
# - **Ограничења брзине**: прати Azure OpenAI ограничења броја захтева за конкурентне операције
# - **Коришћење ресурса**: разматрај употребу меморије и ЦПУ током рада више агената истовремено
# - **Обрада грешака**: имплементирај робусно опоравак од грешака за паралелне операције
#
# ### 🏗️ **Архитектура конкурентног тока рада**
#
# ```mermaid
# graph TD
#     A[Почетак тока посла] --> B[Паралелно извршење]
#     B --> C[Базен агената 1]
#     B --> D[Базен агената 2]
#     B --> E[Базен агената 3]
#     C --> F[Агрегирање резултата]
#     D --> F
#     E --> F
#     F --> G[Коначни резултат]
#
#     H[Microsoft Foundry] --> C
#     H --> D
#     H --> E
# ```
#
# **Кључне предности:**
# - **⚡ Перформансе**: значајно убрзање кроз паралелно извршавање
# - **📈 Скалирање**: руковање повећаним оптерећењем без пропорционалног повећања времена
# - **🔄 Ефикасност**: боља искоришћеност расположивих рачунарских ресурса
# - **🎯 Пропусност**: обради више рада у истом временском периоду
#
# ## 🎨 **Обрасци дизајна конкурентног тока рада**
#
# ### 🔍 **Поток истраживања и анализе**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Поток обраде података**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Поток креирања садржаја**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Обрада у више фаза**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Предности перформанси у предузећу**
#
# ### ⚡ **Оптимизација пропусности**
# - **Паралелно извршавање**: више агената ради истовремено
# - **Употреба ресурса**: максимална ефикасност расположивог капацитета AI модела
# - **Смањење времена**: значајно скраћење укупног времена обраде
# - **Скалирајућа архитектура**: лако додавање више конкурентих агената по потреби
#
# ### 🛡️ **Поузданост и отпорност**
# - **Отпорност на грешке**: појединачни неуспеси агената не заустављају цео ток рада
# - **Изолација грешака**: проблеми у једној конкуретној грани не утичу на друге
# - **Лагани пад перформанси**: систем наставља рад чак и са смањеним капацитетом агената
# - **Механизми опоравка**: аутоматска поновна покуша и обрада грешака за неуспеле операције
#
# ### 📊 **Надгледање и посматрање**
# - **Праћење конкурентног извршавања**: прати напредак свих паралелних операција
# - **Метрике перформанси**: мери убрзање и добитке у ефикасности
# - **Аналитика коришћења ресурса**: оптимизује распоређивање конкуретних агената
# - **Идентификација грла**: открива и решава ограничења у перформансама
#
# Хајде да изградимо перформансне конкурентне AI токове рада! 🚀

# %%
# Already covered by repo-level requirements.txt; left for reference.
# !pip install agent-framework -U

# %%
import os
from typing import Any

from agent_framework import (
    Executor,
    Message,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowViz,
    handler,
)
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential
from dotenv import load_dotenv

load_dotenv()

# %%
# Configure the Microsoft Foundry client with keyless authentication.
# FoundryChatClient targets the Azure OpenAI Responses API.
provider = FoundryChatClient(
    project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"],
    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
    credential=AzureCliCredential(),
)

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent = provider.as_agent(
    name=ResearcherAgentName,
    instructions=ResearcherAgentInstructions,
)

plan_agent = provider.as_agent(
    name=PlanAgentName,
    instructions=PlanAgentInstructions,
)

# %%
# A passthrough executor that broadcasts the user input to every agent in parallel.
class InputDispatcher(Executor):
    """Forward the user input unchanged to all participating agents."""

    @handler
    async def forward(self, text: str, ctx: WorkflowContext[str]) -> None:
        await ctx.send_message(text)


dispatcher = InputDispatcher(id="dispatcher")
agents = [research_agent, plan_agent]

workflow = (
    WorkflowBuilder(
        start_executor=dispatcher,
        output_executors=agents,
    )
    .add_fan_out_edges(dispatcher, agents)
    .build()
)

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
# SVG export needs the optional graphviz extra plus the graphviz system binary;
# fall back gracefully if it is not available.
try:
    svg_file = viz.export(format="svg")
    print(f"SVG file saved to: {svg_file}")
except ImportError as e:
    svg_file = None
    print(f"SVG export skipped (install graphviz to enable): {e}")

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
    print("===== Final Aggregated Responses =====")
    # outputs is a list of AgentResponse objects, one per output executor
    # (research_agent then plan_agent), in the order given to output_executors.
    for i, response in enumerate(outputs, start=1):
        print(f"{'-' * 60}\n\n{i:02d}:\n{response.text}")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Изјава о одрицању одговорности**:
# Овај документ је преведен коришћењем услуге за аутоматски превод [Co-op Translator](https://github.com/Azure/co-op-translator). Иако тежимо тачности, имајте у виду да аутоматски преводи могу садржати грешке или нетачности. Оригинални документ на његовом изворном језику треба сматрати ауторитативним извором. За критичне информације препоручује се професионални људски превод. Нисмо одговорни за било каква неспоразума или погрешна тумачења која произилазе из коришћења овог превода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
