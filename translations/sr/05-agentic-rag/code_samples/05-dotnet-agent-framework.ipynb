# %% [markdown]
# # 🔍 Привредни RAG са Microsoft Foundry (.NET)
#
# ## 📋 Циљеви учења
#
# Овај нотебоок показује како изградити системе за генерацију уз прикупљање информација (RAG) за предузећа користећи Microsoft Agent Framework у .NET-у са Microsoft Foundry-ом. Научићете како да креирате агенте спремне за производњу који могу претраживати документе и пружати прецизне, контекстуално свесне одговоре уз безбедност и скалабилност за предузећа.
#
# **Капацитети Привредног RAG-а које ћете изградити:**
# - 📚 **Интелигенција докумената**: Напредна обрада докумената са Azure AI сервисима
# - 🔍 **Семантичка претрага**: Векторска претрага високе перформансе са функцијама за предузећа
# - 🛡️ **Интеграција безбедности**: Приступ заснован на улогама и обрасци заштите података
# - 🏢 **Скалабилна архитектура**: RAG системи спремни за производњу са праћењем
#
# ## 🎯 Архитектура Привредног RAG-а
#
# ### Основне компоненте за предузећа
# - **Microsoft Foundry**: Управљана платформа за предузећа за AI са безбедношћу и усклађеношћу
# - **Перистентни агенти**: Државни агенти са историјом разговора и управљањем контекстом
# - **Управљање векторским складиштем**: Индексирање и проналажење докумената за предузећа
# - **Интеграција идентитета**: Azure AD аутентификација и контролa приступа по улогама
#
# ### Предности .NET за предузећа
# - **Сигурност типова**: Валидација у време компилације за RAG операције и структуре података
# - **Асинхрони перформансе**: Обрада и претрага докумената без блокирања
# - **Управљање меморијом**: Ефикасно коришћење ресурса за велике колекције докумената
# - **Обрасци интеграције**: Натива интеграција Azure сервиса са dependency injection-ом
#
# ## 🏗️ Техничка архитектура
#
# ### Производни ланац за предузећа RAG
# ```csharp
# Document Upload → Security Validation → Vector Processing → Index Creation
#                       ↓                    ↓                  ↓
# User Query → Authentication → Semantic Search → Context Ranking → AI Response
# ```
#
# ### Основне .NET компоненте
# - **Azure.AI.Agents.Persistent**: Управљање агентима са перзистенцијом стања за предузећа
# - **Azure.Identity**: Интегрисана аутентификација за безбедан приступ Azure сервисима
# - **Microsoft.Agents.AI.AzureAI**: Имплементација оквира агената оптимизована за Azure
# - **System.Linq.Async**: Високоперформансне асинхроне LINQ операције
#
# ## 🔧 Карактеристике и предности за предузећа
#
# ### Безбедност и усклађеност
# - **Интеграција Azure AD-а**: Управљање идентитетом и аутентификација за предузећа
# - **Приступ заснован на улогама**: Детаљне дозволе за приступ документима и операције
# - **Заштита података**: Енкрипција у миру и током преноса за осетљиве документе
# - **Реџистар активности**: Свеобухватно праћење активности за захтеве усклађености
#
# ### Перформансе и скалабилност
# - **Пулање веза**: Ефикасно управљање везама ка Azure сервисима
# - **Асинхрона обрада**: Операције без блокирања за сценарије високе пропусности
# - **Стратегије кеширања**: Интелигентно кеширање за често приступане документе
# - **Балансирање оптерећења**: Распоређена обрада за велике имплементације
#
# ### Управљање и праћење
# - **Провере здравља**: Уграђено праћење компоненти RAG система
# - **Метрике перформанси**: Детаљна аналитика квалитета претраге и времена одговора
# - **Обрада грешака**: Свеобухватно управљање изузецима са политикама поновног покушаја
# - **Управљање конфигурацијом**: Подешавања специфична за окружење са валидацијом
#
# ## ⚙️ Захтеви и подешавање
#
# **Развојно окружење:**
# - .NET 9.0 SDK или новији
# - Visual Studio 2022 или VS Code са C# екстензијом
# - Azure претплата са приступом AI Foundry-у
#
# **Обавезни NuGet пакети:**
# ```xml
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
# <PackageReference Include="Azure.AI.Agents.Persistent" Version="1.2.0-beta.5" />
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
# <PackageReference Include="DotNetEnv" Version="3.1.1" />
# ```
#
# **Подешавање аутентификације на Azure-у:**
# ```bash
# # Инсталирајте Azure CLI и аутентификујте се
# az login
# az account set --subscription "your-subscription-id"
# ```
#
# **Конфигурација окружења (.env фајл):**
# ```env
# # Microsoft Foundry configuration (automatically handled via Azure CLI)
# # Ensure you're authenticated to the correct Azure subscription
# ```
#
# ## 📊 Обрасци за предузећа RAG
#
# ### Обрасци управљања документима
# - **Масовно отпремање**: Ефикасна обрада великих колекција докумената
# - **Инкременталне измене**: Додавање и модификација докумената у реалном времену
# - **Контрола верзија**: Верзионисање и праћење промена докумената
# - **Управљање метаподацима**: Богати атрибути докумената и таксономија
#
# ### Обрасци претраге и проналажења
# - **Хибридна претрага**: Комбинација семантичке и претраге по кључним речима за оптималне резултате
# - **Фацетирана претрага**: Вишедимензонално филтрирање и категоризација
# - **Подешавање релевантности**: Прилагођени алгоритми бодовања за потребе домена
# - **Рангирање резултата**: Напредно рангирање са интеграцијом пословне логике
#
# ### Обрасци безбедности
# - **Безбедност на нивоу докумената**: Детаљна контрола приступа по документу
# - **Класификација података**: Аутоматско означавање осетљивости и заштита
# - **Логови акција**: Свеобухватно бележење свих RAG операција
# - **Заштита приватности**: Детекција и црвенац PII (лични подаци)
#
# ## 🔒 Безбедносне карактеристике за предузећа
#
# ### Аутентификација и ауторизација
# ```csharp
# // Azure AD integrated authentication
# var credential = new AzureCliCredential();
# var agentsClient = new PersistentAgentsClient(endpoint, credential);
#
# // Role-based access validation
# if (!await ValidateUserPermissions(user, documentId))
# {
#     throw new UnauthorizedAccessException("Insufficient permissions");
# }
# ```
#
# ### Заштита података
# - **Енкрипција**: Крајњо-крајња енкрипција за документе и индексе претраге
# - **Контролa приступа**: Интеграција са Azure AD за дозволе корисника и група
# - **Локација података**: Контрола географске локације података ради усклађености
# - **Резервне копије и опоравак**: Аутоматизоване могућности резервисања и опоравка од нестанка
#
# ## 📈 Оптимизација перформанси
#
# ### Обрасци асинхроне обраде
# ```csharp
# // Efficient async document processing
# await foreach (var document in documentStream.AsAsyncEnumerable())
# {
#     await ProcessDocumentAsync(document, cancellationToken);
# }
# ```
#
# ### Управљање меморијом
# - **Стриминг обрада**: Обрадите велике документе без проблема са меморијом
# - **Пулање ресурса**: Ефикасна поновна употреба скупоцених ресурса
# - **Гарбаџ колекција**: Оптимизовани обрасци распореда меморије
# - **Управљање везама**: Правилни циклус животног века веза ка Azure сервисима
#
# ### Стратегије кеширања
# - **Кеширање упита**: Кеширање често извршаваних претрага
# - **Кеширање докумената**: Кеширање у меморији за „вруће“ документе
# - **Кеширање индекса**: Оптимизовано кеширање векторских индекса
# - **Кеширање резултата**: Интелигентно кеширање генерисаних одговора
#
# ## 📊 Примери употребе у предузећима
#
# ### Управљање знањем
# - **Корпоративни Wiki**: Интелигентна претрага кроз базе знања компаније
# - **Политике и процедуре**: Аутоматизована упутства за усклађеност и процедуре
# - **Материјали за обуку**: Интелигентна подршка за учење и развој
# - **Истраживачке базе података**: Системи за анализу академских и истраживачких радова
#
# ### Корисничка подршка
# - **База знања за подршку**: Аутоматски одговори корисничке службе
# - **Продуктна документација**: Интелигентно проналажење информација о производу
# - **Водичи за решавање проблема**: Контекстуална помоћ у решавању проблема
# - **FAQ системи**: Динамичка генерација FAQ из колекција докумената
#
# ### Усклађеност са прописима
# - **Анализа правних докумената**: Интелигенција уговора и правних докумената
# - **Мониторинг усклађености**: Аутоматско проверавање регулаторне усклађености
# - **Процена ризика**: Анализа ризика заснована на документима и извештаји
# - **Подршка ревизији**: Интелигентно откривање докумената за ревизије
#
# ## 🚀 Примена у производњи
#
# ### Праћење и посматрање
# - **Application Insights**: Детаљна телеметрија и праћење перформанси
# - **Прилагођене метрике**: Праћење и алармирање KPI-ја специфичних за посао
# - **Дистрибуирано трасирање**: Прати захтеве од краја до краја кроз сервисе
# - **Дашборди здравља**: Визуелизација здравља и перформанси система у реалном времену
#
# ### Скалабилност и поузданост
# - **Ауто-скалирање**: Аутоматско скалирање базирано на оптерећењу и метрикама перформанси
# - **Висока расположивост**: Имплементација у више регија са могућностима прекида
# - **Тестирање оптерећења**: Валидација перформанси под оптерећењем предузећа
# - **Опоравак од катастрофа**: Аутоматизовани поступци резервног копирања и опоравка
#
# Спремни да изградите RAG системе за предузећа који могу руковати осетљивим документима у великом обиму? Хајде да архитектуришемо интелигентне системе знања за предузећа! 🏢📖✨

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Agents.AI.AzureAI, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Agents.AI, 1.0.0-preview.251001.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.agents.ai, 1.0.0-preview.251001.2</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-5-mini";

# %%
string pdfPath = "./document.md";

# %%
using System.IO;

async Task<Stream> OpenImageStreamAsync(string path)
{
	return await Task.Run(() => File.OpenRead(path));
}

var pdfStream = await OpenImageStreamAsync(pdfPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
PersistentAgentFileInfo fileInfo = await persistentAgentsClient.Files.UploadFileAsync(pdfStream, PersistentAgentFilePurpose.Agents, "demo.md");

# %%
PersistentAgentsVectorStore fileStore =
            await persistentAgentsClient.VectorStores.CreateVectorStoreAsync(
                [fileInfo.Id],
                metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
PersistentAgent agentModel = await persistentAgentsClient.Administration.CreateAgentAsync(
            azure_foundry_model_id,
            name: "DotNetRAGAgent",
            tools: [new FileSearchToolDefinition()],
            instructions: """
                You are an AI assistant designed to answer user questions using only the information retrieved from the provided document(s).

                - If a user's question cannot be answered using the retrieved context, **you must clearly respond**: 
                "I'm sorry, but the uploaded document does not contain the necessary information to answer that question."
                - Do not answer from general knowledge or reasoning. Do not make assumptions or generate hypothetical explanations.
                - Do not provide definitions, tutorials, or commentary that is not explicitly grounded in the content of the uploaded file(s).
                - If a user asks a question like "What is a Neural Network?", and this is not discussed in the uploaded document, respond as instructed above.
                - For questions that do have relevant content in the document (e.g., Contoso's travel insurance coverage), respond accurately, and cite the document explicitly.

                You must behave as if you have no external knowledge beyond what is retrieved from the uploaded document.
                """,
            toolResources: new()
            {
                FileSearch = new()
                {
                    VectorStoreIds = { fileStore.Id },
                }
            },
            metadata: new Dictionary<string, string>() { { "agentkey", bool.TrueString } });

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentModel.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Can you explain Contoso's travel insurance coverage?", thread));
# Out:
# Contoso's travel insurance coverage includes protection for medical emergencies, trip cancellations, and lost baggage. This ensures that travelers are supported in case of health-related issues during their trip, unforeseen cancellations, and the loss of their belongings while traveling【4:0†demo.md】.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Изјава о одрицању одговорности**:
# Овај документ је преведен коришћењем услуге за аутоматски превод [Co-op Translator](https://github.com/Azure/co-op-translator). Иако тежимо тачности, имајте у виду да аутоматски преводи могу садржати грешке или нетачности. Оригинални документ на његовом изворном језику треба сматрати ауторитативним извором. За критичне информације препоручује се професионални људски превод. Нисмо одговорни за било каква неспоразума или погрешна тумачења која произилазе из коришћења овог превода.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
